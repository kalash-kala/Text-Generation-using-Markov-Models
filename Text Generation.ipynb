# %%
from collections import defaultdict

import numpy as np
import pandas as pd
import string

# %%
initial_state = defaultdict(int)
first_order = {}
second_order = {}

# %% [markdown]
# ### Reading Dataset

# %%
poems = defaultdict(list)

# %%
with open('robert_frost.txt') as f:
    poems['text'] = f.readlines()

poems['labels'] = ['Robert Frost']*len(poems['text'])

# %% [markdown]
# ### Creating Dataframe and preprcessing the text data

# %%
poems = pd.DataFrame.from_dict(poems)

# %%
# Removing newline character and lowering the case
poems['text'] = poems['text'].apply(lambda x : x.rstrip().lower())

# Removing the Punctuation 
poems['text'] = poems['text'].apply(lambda x : x.translate(str.maketrans('','',string.punctuation)))

# Removing empty text
poems = poems.drop(poems.loc[poems['text']==''].index)

poems
# Out:
#                                                 text        labels
# 0                two roads diverged in a yellow wood  Robert Frost
# 1                  and sorry i could not travel both  Robert Frost
# 2                   and be one traveler long i stood  Robert Frost
# 3              and looked down one as far as i could  Robert Frost
# 4                to where it bent in the undergrowth  Robert Frost
# ...                                              ...           ...
# 1575  to say which buds are leaf and which are bloom  Robert Frost
# 1577            a featherhammer gives a double knock  Robert Frost
# 1578             this eden day is done at two oclock  Robert Frost
# 1579      an hour of winter day might seem too short  Robert Frost
# 1580  to make it worth lifes while to wake and sport  Robert Frost
#
# [1436 rows x 2 columns]

# %% [markdown]
# ### Filling initial state probability distribution dictionary

# %%
total_text = len(poems['text'])
total_text
# Out:
# 1436

# %%
for text in poems['text']:
    initial_state[text.split()[0]]+=1

# %%
initial_state
# Out:
# defaultdict(int,
#             {'two': 8,
#              'and': 129,
#              'to': 50,
#              'then': 12,
#              'because': 1,
#              'though': 7,
#              'had': 4,
#              'in': 29,
#              'oh': 4,
#              'yet': 3,
#              'i': 118,
#              'somewhere': 1,
#              'whose': 2,
#              'his': 7,
#              'he': 34,
#              'my': 7,
#              'between': 3,
#              'the': 82,
#              'of': 29,
#              'but': 51,
#              'some': 5,
#              'from': 10,
#              'is': 5,
#              'natures': 1,
#              'her': 2,
#              'so': 13,
#              'nothing': 2,
#              'when': 9,
#              'came': 1,
#              'one': 11,
#              'proclaimed': 1,
#              'smoothlaid': 1,
#              'half': 3,
#              'up': 7,
#              'a': 30,
#              'disturbed': 2,
#              'comes': 1,
#              'by': 11,
#              'if': 12,
#              'were': 3,
#              'ten': 1,
#              'as': 14,
#              'it': 23,
#              'lifted': 1,
#              'she': 17,
#              'transfixed': 1,
#              'across': 1,
#              'was': 9,
#              'once': 2,
#              'that': 29,
#              'looked': 1,
#              'stood': 1,
#              'you': 40,
#              'me': 1,
#              'sometimes': 4,
#              'brown': 2,
#              'cross': 1,
#              'describing': 1,
#              'got': 1,
#              'walls': 1,
#              'like': 8,
#              'upon': 2,
#              'with': 18,
#              'faster': 1,
#              'sitting': 1,
#              'according': 1,
#              'hes': 11,
#              'or': 11,
#              'incredulous': 1,
#              'well—i—be—': 1,
#              'on': 11,
#              'should': 2,
#              'yankees': 1,
#              'dont': 7,
#              'until': 2,
#              'after': 1,
#              'not': 13,
#              'at': 6,
#              'no': 13,
#              'ive': 4,
#              'while': 1,
#              'bout': 1,
#              'now': 4,
#              'im': 5,
#              'theyve': 1,
#              'flattered': 1,
#              'they': 19,
#              'always': 1,
#              'ill': 10,
#              'theyll': 1,
#              'for': 7,
#              'couldnt': 2,
#              'voted': 1,
#              'which': 3,
#              'their': 2,
#              'wentworth': 1,
#              'only': 5,
#              'rights': 1,
#              'has': 2,
#              'itd': 1,
#              'said': 1,
#              'hed': 5,
#              'all': 8,
#              'gnaws': 1,
#              'last': 1,
#              'over': 5,
#              'well': 5,
#              'off': 2,
#              'old': 2,
#              'thered': 1,
#              'someday': 1,
#              'today': 1,
#              'huh': 1,
#              'lets': 3,
#              'youve': 1,
#              'can': 1,
#              'be': 3,
#              'we': 15,
#              'ascending': 1,
#              'sos': 2,
#              'hadnt': 1,
#              'look': 1,
#              'what': 14,
#              'however': 2,
#              'come': 4,
#              'its': 21,
#              'perhaps': 2,
#              'excuse': 1,
#              'who': 6,
#              'life': 1,
#              'our': 2,
#              'through': 2,
#              'except': 2,
#              'books': 2,
#              'where': 8,
#              'enough': 1,
#              'unfortunately': 1,
#              'boys': 1,
#              'shatter': 1,
#              'how': 6,
#              'till': 2,
#              'tried': 1,
#              'having': 1,
#              'here': 4,
#              'take': 3,
#              'why': 3,
#              'goodlooking': 1,
#              'both': 1,
#              'legitimately': 1,
#              'there': 6,
#              'crosslegged': 1,
#              'alias': 1,
#              'about': 1,
#              'theres': 1,
#              'give': 1,
#              'thrown': 1,
#              'unless': 1,
#              'than': 2,
#              'behind': 2,
#              'mother': 7,
#              'summoning': 1,
#              'whos': 1,
#              'son': 9,
#              'done': 1,
#              'rather': 1,
#              'tell': 2,
#              'yes': 8,
#              'against': 1,
#              'halting': 1,
#              'never': 1,
#              'another': 2,
#              'right': 1,
#              'father': 1,
#              'especially': 1,
#              'might': 1,
#              'toffile': 5,
#              'struck': 1,
#              'began': 1,
#              'waiting': 1,
#              'flashed': 1,
#              'smoke': 1,
#              'hand': 1,
#              'stillgoing': 1,
#              'before': 2,
#              'almost': 1,
#              'quick': 1,
#              'let': 2,
#              'brushing': 1,
#              'thats': 5,
#              '2o3': 1,
#              'wed': 1,
#              'could': 1,
#              'among': 3,
#              'ancestral': 1,
#              'someone': 1,
#              'thence': 1,
#              'made': 1,
#              'are': 1,
#              'strolled': 1,
#              'anyone': 2,
#              'this': 6,
#              'provision': 1,
#              'drawn': 2,
#              'stark': 1,
#              'would': 2,
#              'several': 1,
#              'under': 2,
#              'just': 1,
#              'does': 2,
#              'bowed': 1,
#              'beyond': 2,
#              'four': 1,
#              'dyou': 1,
#              'studying': 1,
#              'first': 2,
#              'bless': 2,
#              'shes': 3,
#              'heres': 1,
#              'making': 1,
#              'see': 1,
#              'strung': 1,
#              'something': 2,
#              'speaking': 1,
#              'strangely': 1,
#              'call': 2,
#              'nor': 4,
#              'nine': 1,
#              'anything': 1,
#              'folks': 1,
#              'mebbe': 1,
#              'more': 1,
#              'will': 2,
#              'nowhere': 1,
#              'builder': 1,
#              'whatever': 1,
#              'inscription': 1,
#              'winds': 1,
#              'moisture': 1,
#              'heaven': 1,
#              'back': 2,
#              'may': 1,
#              'great': 1,
#              'long': 1,
#              'besides': 1,
#              'still': 2,
#              'charge': 1,
#              'make': 2,
#              'someones': 1,
#              'into': 1,
#              'weep': 1,
#              'your': 1,
#              'cold': 1,
#              'too': 2,
#              'drink': 1,
#              'wherever': 1,
#              'birch': 1,
#              'time': 1,
#              'small': 1,
#              'out': 1,
#              'awake': 1,
#              'wishing': 1,
#              'saturn': 1,
#              'speculation': 1,
#              'theirs': 1,
#              'uttered': 1,
#              'trembled': 1,
#              'appear': 1,
#              'around': 1,
#              'since': 1,
#              'lord': 1,
#              'havent': 2,
#              'whats': 4,
#              'estelles': 2,
#              'weve': 1,
#              'left': 1,
#              'hell': 1,
#              'skyhigh': 1,
#              'arent': 1,
#              'john': 6,
#              'better': 1,
#              'reason': 1,
#              'such': 1,
#              'twas': 1,
#              'johns': 2,
#              'estelle': 1,
#              'farmers': 1,
#              'full': 1,
#              'moving': 1,
#              'nothings': 1,
#              'twenty': 1,
#              'receipted': 1,
#              'wampum': 1,
#              'cant': 1,
#              'being': 1,
#              'oho': 1,
#              'bad': 1,
#              'nonsense': 1,
#              'whod': 1,
#              'say': 1,
#              'youll': 1,
#              'coming': 1,
#              'isnt': 1,
#              'do': 1,
#              'content': 1,
#              'an': 1})

# %%
for keys in initial_state.keys():
    initial_state[keys]/=total_text

initial_state
# Out:
# defaultdict(int,
#             {'two': 0.005571030640668524,
#              'and': 0.08983286908077995,
#              'to': 0.034818941504178275,
#              'then': 0.008356545961002786,
#              'because': 0.0006963788300835655,
#              'though': 0.004874651810584958,
#              'had': 0.002785515320334262,
#              'in': 0.0201949860724234,
#              'oh': 0.002785515320334262,
#              'yet': 0.0020891364902506965,
#              'i': 0.08217270194986072,
#              'somewhere': 0.0006963788300835655,
#              'whose': 0.001392757660167131,
#              'his': 0.004874651810584958,
#              'he': 0.023676880222841225,
#              'my': 0.004874651810584958,
#              'between': 0.0020891364902506965,
#              'the': 0.057103064066852366,
#              'of': 0.0201949860724234,
#              'but': 0.035515320334261836,
#              'some': 0.003481894150417827,
#              'from': 0.006963788300835654,
#              'is': 0.003481894150417827,
#              'natures': 0.0006963788300835655,
#              'her': 0.001392757660167131,
#              'so': 0.009052924791086351,
#              'nothing': 0.001392757660167131,
#              'when': 0.006267409470752089,
#              'came': 0.0006963788300835655,
#              'one': 0.00766016713091922,
#              'proclaimed': 0.0006963788300835655,
#              'smoothlaid': 0.0006963788300835655,
#              'half': 0.0020891364902506965,
#              'up': 0.004874651810584958,
#              'a': 0.020891364902506964,
#              'disturbed': 0.001392757660167131,
#              'comes': 0.0006963788300835655,
#              'by': 0.00766016713091922,
#              'if': 0.008356545961002786,
#              'were': 0.0020891364902506965,
#              'ten': 0.0006963788300835655,
#              'as': 0.009749303621169917,
#              'it': 0.016016713091922007,
#              'lifted': 0.0006963788300835655,
#              'she': 0.011838440111420613,
#              'transfixed': 0.0006963788300835655,
#              'across': 0.0006963788300835655,
#              'was': 0.006267409470752089,
#              'once': 0.001392757660167131,
#              'that': 0.0201949860724234,
#              'looked': 0.0006963788300835655,
#              'stood': 0.0006963788300835655,
#              'you': 0.027855153203342618,
#              'me': 0.0006963788300835655,
#              'sometimes': 0.002785515320334262,
#              'brown': 0.001392757660167131,
#              'cross': 0.0006963788300835655,
#              'describing': 0.0006963788300835655,
#              'got': 0.0006963788300835655,
#              'walls': 0.0006963788300835655,
#              'like': 0.005571030640668524,
#              'upon': 0.001392757660167131,
#              'with': 0.012534818941504178,
#              'faster': 0.0006963788300835655,
#              'sitting': 0.0006963788300835655,
#              'according': 0.0006963788300835655,
#              'hes': 0.00766016713091922,
#              'or': 0.00766016713091922,
#              'incredulous': 0.0006963788300835655,
#              'well—i—be—': 0.0006963788300835655,
#              'on': 0.00766016713091922,
#              'should': 0.001392757660167131,
#              'yankees': 0.0006963788300835655,
#              'dont': 0.004874651810584958,
#              'until': 0.001392757660167131,
#              'after': 0.0006963788300835655,
#              'not': 0.009052924791086351,
#              'at': 0.004178272980501393,
#              'no': 0.009052924791086351,
#              'ive': 0.002785515320334262,
#              'while': 0.0006963788300835655,
#              'bout': 0.0006963788300835655,
#              'now': 0.002785515320334262,
#              'im': 0.003481894150417827,
#              'theyve': 0.0006963788300835655,
#              'flattered': 0.0006963788300835655,
#              'they': 0.013231197771587743,
#              'always': 0.0006963788300835655,
#              'ill': 0.006963788300835654,
#              'theyll': 0.0006963788300835655,
#              'for': 0.004874651810584958,
#              'couldnt': 0.001392757660167131,
#              'voted': 0.0006963788300835655,
#              'which': 0.0020891364902506965,
#              'their': 0.001392757660167131,
#              'wentworth': 0.0006963788300835655,
#              'only': 0.003481894150417827,
#              'rights': 0.0006963788300835655,
#              'has': 0.001392757660167131,
#              'itd': 0.0006963788300835655,
#              'said': 0.0006963788300835655,
#              'hed': 0.003481894150417827,
#              'all': 0.005571030640668524,
#              'gnaws': 0.0006963788300835655,
#              'last': 0.0006963788300835655,
#              'over': 0.003481894150417827,
#              'well': 0.003481894150417827,
#              'off': 0.001392757660167131,
#              'old': 0.001392757660167131,
#              'thered': 0.0006963788300835655,
#              'someday': 0.0006963788300835655,
#              'today': 0.0006963788300835655,
#              'huh': 0.0006963788300835655,
#              'lets': 0.0020891364902506965,
#              'youve': 0.0006963788300835655,
#              'can': 0.0006963788300835655,
#              'be': 0.0020891364902506965,
#              'we': 0.010445682451253482,
#              'ascending': 0.0006963788300835655,
#              'sos': 0.001392757660167131,
#              'hadnt': 0.0006963788300835655,
#              'look': 0.0006963788300835655,
#              'what': 0.009749303621169917,
#              'however': 0.001392757660167131,
#              'come': 0.002785515320334262,
#              'its': 0.014623955431754874,
#              'perhaps': 0.001392757660167131,
#              'excuse': 0.0006963788300835655,
#              'who': 0.004178272980501393,
#              'life': 0.0006963788300835655,
#              'our': 0.001392757660167131,
#              'through': 0.001392757660167131,
#              'except': 0.001392757660167131,
#              'books': 0.001392757660167131,
#              'where': 0.005571030640668524,
#              'enough': 0.0006963788300835655,
#              'unfortunately': 0.0006963788300835655,
#              'boys': 0.0006963788300835655,
#              'shatter': 0.0006963788300835655,
#              'how': 0.004178272980501393,
#              'till': 0.001392757660167131,
#              'tried': 0.0006963788300835655,
#              'having': 0.0006963788300835655,
#              'here': 0.002785515320334262,
#              'take': 0.0020891364902506965,
#              'why': 0.0020891364902506965,
#              'goodlooking': 0.0006963788300835655,
#              'both': 0.0006963788300835655,
#              'legitimately': 0.0006963788300835655,
#              'there': 0.004178272980501393,
#              'crosslegged': 0.0006963788300835655,
#              'alias': 0.0006963788300835655,
#              'about': 0.0006963788300835655,
#              'theres': 0.0006963788300835655,
#              'give': 0.0006963788300835655,
#              'thrown': 0.0006963788300835655,
#              'unless': 0.0006963788300835655,
#              'than': 0.001392757660167131,
#              'behind': 0.001392757660167131,
#              'mother': 0.004874651810584958,
#              'summoning': 0.0006963788300835655,
#              'whos': 0.0006963788300835655,
#              'son': 0.006267409470752089,
#              'done': 0.0006963788300835655,
#              'rather': 0.0006963788300835655,
#              'tell': 0.001392757660167131,
#              'yes': 0.005571030640668524,
#              'against': 0.0006963788300835655,
#              'halting': 0.0006963788300835655,
#              'never': 0.0006963788300835655,
#              'another': 0.001392757660167131,
#              'right': 0.0006963788300835655,
#              'father': 0.0006963788300835655,
#              'especially': 0.0006963788300835655,
#              'might': 0.0006963788300835655,
#              'toffile': 0.003481894150417827,
#              'struck': 0.0006963788300835655,
#              'began': 0.0006963788300835655,
#              'waiting': 0.0006963788300835655,
#              'flashed': 0.0006963788300835655,
#              'smoke': 0.0006963788300835655,
#              'hand': 0.0006963788300835655,
#              'stillgoing': 0.0006963788300835655,
#              'before': 0.001392757660167131,
#              'almost': 0.0006963788300835655,
#              'quick': 0.0006963788300835655,
#              'let': 0.001392757660167131,
#              'brushing': 0.0006963788300835655,
#              'thats': 0.003481894150417827,
#              '2o3': 0.0006963788300835655,
#              'wed': 0.0006963788300835655,
#              'could': 0.0006963788300835655,
#              'among': 0.0020891364902506965,
#              'ancestral': 0.0006963788300835655,
#              'someone': 0.0006963788300835655,
#              'thence': 0.0006963788300835655,
#              'made': 0.0006963788300835655,
#              'are': 0.0006963788300835655,
#              'strolled': 0.0006963788300835655,
#              'anyone': 0.001392757660167131,
#              'this': 0.004178272980501393,
#              'provision': 0.0006963788300835655,
#              'drawn': 0.001392757660167131,
#              'stark': 0.0006963788300835655,
#              'would': 0.001392757660167131,
#              'several': 0.0006963788300835655,
#              'under': 0.001392757660167131,
#              'just': 0.0006963788300835655,
#              'does': 0.001392757660167131,
#              'bowed': 0.0006963788300835655,
#              'beyond': 0.001392757660167131,
#              'four': 0.0006963788300835655,
#              'dyou': 0.0006963788300835655,
#              'studying': 0.0006963788300835655,
#              'first': 0.001392757660167131,
#              'bless': 0.001392757660167131,
#              'shes': 0.0020891364902506965,
#              'heres': 0.0006963788300835655,
#              'making': 0.0006963788300835655,
#              'see': 0.0006963788300835655,
#              'strung': 0.0006963788300835655,
#              'something': 0.001392757660167131,
#              'speaking': 0.0006963788300835655,
#              'strangely': 0.0006963788300835655,
#              'call': 0.001392757660167131,
#              'nor': 0.002785515320334262,
#              'nine': 0.0006963788300835655,
#              'anything': 0.0006963788300835655,
#              'folks': 0.0006963788300835655,
#              'mebbe': 0.0006963788300835655,
#              'more': 0.0006963788300835655,
#              'will': 0.001392757660167131,
#              'nowhere': 0.0006963788300835655,
#              'builder': 0.0006963788300835655,
#              'whatever': 0.0006963788300835655,
#              'inscription': 0.0006963788300835655,
#              'winds': 0.0006963788300835655,
#              'moisture': 0.0006963788300835655,
#              'heaven': 0.0006963788300835655,
#              'back': 0.001392757660167131,
#              'may': 0.0006963788300835655,
#              'great': 0.0006963788300835655,
#              'long': 0.0006963788300835655,
#              'besides': 0.0006963788300835655,
#              'still': 0.001392757660167131,
#              'charge': 0.0006963788300835655,
#              'make': 0.001392757660167131,
#              'someones': 0.0006963788300835655,
#              'into': 0.0006963788300835655,
#              'weep': 0.0006963788300835655,
#              'your': 0.0006963788300835655,
#              'cold': 0.0006963788300835655,
#              'too': 0.001392757660167131,
#              'drink': 0.0006963788300835655,
#              'wherever': 0.0006963788300835655,
#              'birch': 0.0006963788300835655,
#              'time': 0.0006963788300835655,
#              'small': 0.0006963788300835655,
#              'out': 0.0006963788300835655,
#              'awake': 0.0006963788300835655,
#              'wishing': 0.0006963788300835655,
#              'saturn': 0.0006963788300835655,
#              'speculation': 0.0006963788300835655,
#              'theirs': 0.0006963788300835655,
#              'uttered': 0.0006963788300835655,
#              'trembled': 0.0006963788300835655,
#              'appear': 0.0006963788300835655,
#              'around': 0.0006963788300835655,
#              'since': 0.0006963788300835655,
#              'lord': 0.0006963788300835655,
#              'havent': 0.001392757660167131,
#              'whats': 0.002785515320334262,
#              'estelles': 0.001392757660167131,
#              'weve': 0.0006963788300835655,
#              'left': 0.0006963788300835655,
#              'hell': 0.0006963788300835655,
#              'skyhigh': 0.0006963788300835655,
#              'arent': 0.0006963788300835655,
#              'john': 0.004178272980501393,
#              'better': 0.0006963788300835655,
#              'reason': 0.0006963788300835655,
#              'such': 0.0006963788300835655,
#              'twas': 0.0006963788300835655,
#              'johns': 0.001392757660167131,
#              'estelle': 0.0006963788300835655,
#              'farmers': 0.0006963788300835655,
#              'full': 0.0006963788300835655,
#              'moving': 0.0006963788300835655,
#              'nothings': 0.0006963788300835655,
#              'twenty': 0.0006963788300835655,
#              'receipted': 0.0006963788300835655,
#              'wampum': 0.0006963788300835655,
#              'cant': 0.0006963788300835655,
#              'being': 0.0006963788300835655,
#              'oho': 0.0006963788300835655,
#              'bad': 0.0006963788300835655,
#              'nonsense': 0.0006963788300835655,
#              'whod': 0.0006963788300835655,
#              'say': 0.0006963788300835655,
#              'youll': 0.0006963788300835655,
#              'coming': 0.0006963788300835655,
#              'isnt': 0.0006963788300835655,
#              'do': 0.0006963788300835655,
#              'content': 0.0006963788300835655,
#              'an': 0.0006963788300835655})

# %% [markdown]
# ### Cumulative Probability Distribution of initial state

# %%
initial_state_key_list = list(initial_state)

for idx, key in enumerate(initial_state_key_list):
    
    if(idx==0):
        continue
    
    initial_state[key]+=initial_state[initial_state_key_list[idx-1]]

initial_state
# Out:
# defaultdict(int,
#             {'two': 0.005571030640668524,
#              'and': 0.09540389972144847,
#              'to': 0.13022284122562675,
#              'then': 0.13857938718662954,
#              'because': 0.1392757660167131,
#              'though': 0.14415041782729807,
#              'had': 0.14693593314763234,
#              'in': 0.16713091922005574,
#              'oh': 0.16991643454039002,
#              'yet': 0.1720055710306407,
#              'i': 0.25417827298050144,
#              'somewhere': 0.254874651810585,
#              'whose': 0.2562674094707521,
#              'his': 0.26114206128133705,
#              'he': 0.28481894150417825,
#              'my': 0.2896935933147632,
#              'between': 0.2917827298050139,
#              'the': 0.34888579387186625,
#              'of': 0.36908077994428967,
#              'but': 0.40459610027855153,
#              'some': 0.40807799442896936,
#              'from': 0.415041782729805,
#              'is': 0.41852367688022285,
#              'natures': 0.4192200557103064,
#              'her': 0.4206128133704735,
#              'so': 0.42966573816155984,
#              'nothing': 0.43105849582172695,
#              'when': 0.43732590529247906,
#              'came': 0.4380222841225626,
#              'one': 0.4456824512534818,
#              'proclaimed': 0.4463788300835654,
#              'smoothlaid': 0.44707520891364894,
#              'half': 0.44916434540389966,
#              'up': 0.4540389972144846,
#              'a': 0.4749303621169916,
#              'disturbed': 0.4763231197771587,
#              'comes': 0.47701949860724224,
#              'by': 0.48467966573816146,
#              'if': 0.49303621169916423,
#              'were': 0.49512534818941495,
#              'ten': 0.4958217270194985,
#              'as': 0.5055710306406684,
#              'it': 0.5215877437325904,
#              'lifted': 0.522284122562674,
#              'she': 0.5341225626740946,
#              'transfixed': 0.5348189415041782,
#              'across': 0.5355153203342617,
#              'was': 0.5417827298050139,
#              'once': 0.543175487465181,
#              'that': 0.5633704735376044,
#              'looked': 0.5640668523676879,
#              'stood': 0.5647632311977715,
#              'you': 0.5926183844011141,
#              'me': 0.5933147632311977,
#              'sometimes': 0.5961002785515319,
#              'brown': 0.597493036211699,
#              'cross': 0.5981894150417826,
#              'describing': 0.5988857938718661,
#              'got': 0.5995821727019497,
#              'walls': 0.6002785515320332,
#              'like': 0.6058495821727018,
#              'upon': 0.6072423398328689,
#              'with': 0.6197771587743731,
#              'faster': 0.6204735376044567,
#              'sitting': 0.6211699164345402,
#              'according': 0.6218662952646238,
#              'hes': 0.629526462395543,
#              'or': 0.6371866295264622,
#              'incredulous': 0.6378830083565458,
#              'well—i—be—': 0.6385793871866293,
#              'on': 0.6462395543175485,
#              'should': 0.6476323119777156,
#              'yankees': 0.6483286908077992,
#              'dont': 0.6532033426183842,
#              'until': 0.6545961002785513,
#              'after': 0.6552924791086349,
#              'not': 0.6643454038997212,
#              'at': 0.6685236768802226,
#              'no': 0.677576601671309,
#              'ive': 0.6803621169916432,
#              'while': 0.6810584958217267,
#              'bout': 0.6817548746518103,
#              'now': 0.6845403899721445,
#              'im': 0.6880222841225623,
#              'theyve': 0.6887186629526458,
#              'flattered': 0.6894150417827294,
#              'they': 0.7026462395543172,
#              'always': 0.7033426183844007,
#              'ill': 0.7103064066852364,
#              'theyll': 0.7110027855153199,
#              'for': 0.7158774373259049,
#              'couldnt': 0.717270194986072,
#              'voted': 0.7179665738161556,
#              'which': 0.7200557103064062,
#              'their': 0.7214484679665734,
#              'wentworth': 0.7221448467966569,
#              'only': 0.7256267409470747,
#              'rights': 0.7263231197771582,
#              'has': 0.7277158774373254,
#              'itd': 0.7284122562674089,
#              'said': 0.7291086350974925,
#              'hed': 0.7325905292479102,
#              'all': 0.7381615598885788,
#              'gnaws': 0.7388579387186623,
#              'last': 0.7395543175487459,
#              'over': 0.7430362116991637,
#              'well': 0.7465181058495814,
#              'off': 0.7479108635097486,
#              'old': 0.7493036211699157,
#              'thered': 0.7499999999999992,
#              'someday': 0.7506963788300828,
#              'today': 0.7513927576601663,
#              'huh': 0.7520891364902499,
#              'lets': 0.7541782729805006,
#              'youve': 0.7548746518105841,
#              'can': 0.7555710306406677,
#              'be': 0.7576601671309183,
#              'we': 0.7681058495821718,
#              'ascending': 0.7688022284122553,
#              'sos': 0.7701949860724224,
#              'hadnt': 0.770891364902506,
#              'look': 0.7715877437325895,
#              'what': 0.7813370473537594,
#              'however': 0.7827298050139265,
#              'come': 0.7855153203342607,
#              'its': 0.8001392757660156,
#              'perhaps': 0.8015320334261827,
#              'excuse': 0.8022284122562663,
#              'who': 0.8064066852367677,
#              'life': 0.8071030640668513,
#              'our': 0.8084958217270184,
#              'through': 0.8098885793871855,
#              'except': 0.8112813370473526,
#              'books': 0.8126740947075197,
#              'where': 0.8182451253481883,
#              'enough': 0.8189415041782718,
#              'unfortunately': 0.8196378830083554,
#              'boys': 0.8203342618384389,
#              'shatter': 0.8210306406685225,
#              'how': 0.8252089136490239,
#              'till': 0.826601671309191,
#              'tried': 0.8272980501392746,
#              'having': 0.8279944289693582,
#              'here': 0.8307799442896924,
#              'take': 0.832869080779943,
#              'why': 0.8349582172701937,
#              'goodlooking': 0.8356545961002773,
#              'both': 0.8363509749303608,
#              'legitimately': 0.8370473537604444,
#              'there': 0.8412256267409458,
#              'crosslegged': 0.8419220055710294,
#              'alias': 0.8426183844011129,
#              'about': 0.8433147632311965,
#              'theres': 0.84401114206128,
#              'give': 0.8447075208913636,
#              'thrown': 0.8454038997214471,
#              'unless': 0.8461002785515307,
#              'than': 0.8474930362116978,
#              'behind': 0.8488857938718649,
#              'mother': 0.8537604456824499,
#              'summoning': 0.8544568245125335,
#              'whos': 0.855153203342617,
#              'son': 0.8614206128133691,
#              'done': 0.8621169916434527,
#              'rather': 0.8628133704735362,
#              'tell': 0.8642061281337033,
#              'yes': 0.8697771587743719,
#              'against': 0.8704735376044554,
#              'halting': 0.871169916434539,
#              'never': 0.8718662952646226,
#              'another': 0.8732590529247897,
#              'right': 0.8739554317548732,
#              'father': 0.8746518105849568,
#              'especially': 0.8753481894150403,
#              'might': 0.8760445682451239,
#              'toffile': 0.8795264623955417,
#              'struck': 0.8802228412256252,
#              'began': 0.8809192200557088,
#              'waiting': 0.8816155988857923,
#              'flashed': 0.8823119777158759,
#              'smoke': 0.8830083565459594,
#              'hand': 0.883704735376043,
#              'stillgoing': 0.8844011142061265,
#              'before': 0.8857938718662937,
#              'almost': 0.8864902506963772,
#              'quick': 0.8871866295264608,
#              'let': 0.8885793871866279,
#              'brushing': 0.8892757660167114,
#              'thats': 0.8927576601671292,
#              '2o3': 0.8934540389972128,
#              'wed': 0.8941504178272963,
#              'could': 0.8948467966573799,
#              'among': 0.8969359331476305,
#              'ancestral': 0.8976323119777141,
#              'someone': 0.8983286908077976,
#              'thence': 0.8990250696378812,
#              'made': 0.8997214484679648,
#              'are': 0.9004178272980483,
#              'strolled': 0.9011142061281319,
#              'anyone': 0.902506963788299,
#              'this': 0.9066852367688004,
#              'provision': 0.907381615598884,
#              'drawn': 0.9087743732590511,
#              'stark': 0.9094707520891346,
#              'would': 0.9108635097493017,
#              'several': 0.9115598885793853,
#              'under': 0.9129526462395524,
#              'just': 0.913649025069636,
#              'does': 0.9150417827298031,
#              'bowed': 0.9157381615598866,
#              'beyond': 0.9171309192200537,
#              'four': 0.9178272980501373,
#              'dyou': 0.9185236768802209,
#              'studying': 0.9192200557103044,
#              'first': 0.9206128133704715,
#              'bless': 0.9220055710306386,
#              'shes': 0.9240947075208893,
#              'heres': 0.9247910863509728,
#              'making': 0.9254874651810564,
#              'see': 0.92618384401114,
#              'strung': 0.9268802228412235,
#              'something': 0.9282729805013906,
#              'speaking': 0.9289693593314742,
#              'strangely': 0.9296657381615577,
#              'call': 0.9310584958217248,
#              'nor': 0.9338440111420591,
#              'nine': 0.9345403899721426,
#              'anything': 0.9352367688022262,
#              'folks': 0.9359331476323097,
#              'mebbe': 0.9366295264623933,
#              'more': 0.9373259052924768,
#              'will': 0.938718662952644,
#              'nowhere': 0.9394150417827275,
#              'builder': 0.940111420612811,
#              'whatever': 0.9408077994428946,
#              'inscription': 0.9415041782729782,
#              'winds': 0.9422005571030617,
#              'moisture': 0.9428969359331453,
#              'heaven': 0.9435933147632288,
#              'back': 0.9449860724233959,
#              'may': 0.9456824512534795,
#              'great': 0.946378830083563,
#              'long': 0.9470752089136466,
#              'besides': 0.9477715877437302,
#              'still': 0.9491643454038973,
#              'charge': 0.9498607242339808,
#              'make': 0.9512534818941479,
#              'someones': 0.9519498607242315,
#              'into': 0.952646239554315,
#              'weep': 0.9533426183843986,
#              'your': 0.9540389972144822,
#              'cold': 0.9547353760445657,
#              'too': 0.9561281337047328,
#              'drink': 0.9568245125348164,
#              'wherever': 0.9575208913648999,
#              'birch': 0.9582172701949835,
#              'time': 0.958913649025067,
#              'small': 0.9596100278551506,
#              'out': 0.9603064066852341,
#              'awake': 0.9610027855153177,
#              'wishing': 0.9616991643454013,
#              'saturn': 0.9623955431754848,
#              'speculation': 0.9630919220055684,
#              'theirs': 0.9637883008356519,
#              'uttered': 0.9644846796657355,
#              'trembled': 0.965181058495819,
#              'appear': 0.9658774373259026,
#              'around': 0.9665738161559861,
#              'since': 0.9672701949860697,
#              'lord': 0.9679665738161533,
#              'havent': 0.9693593314763204,
#              'whats': 0.9721448467966546,
#              'estelles': 0.9735376044568217,
#              'weve': 0.9742339832869052,
#              'left': 0.9749303621169888,
#              'hell': 0.9756267409470724,
#              'skyhigh': 0.9763231197771559,
#              'arent': 0.9770194986072395,
#              'john': 0.9811977715877409,
#              'better': 0.9818941504178245,
#              'reason': 0.982590529247908,
#              'such': 0.9832869080779916,
#              'twas': 0.9839832869080751,
#              'johns': 0.9853760445682422,
#              'estelle': 0.9860724233983258,
#              'farmers': 0.9867688022284093,
#              'full': 0.9874651810584929,
#              'moving': 0.9881615598885765,
#              'nothings': 0.98885793871866,
#              'twenty': 0.9895543175487436,
#              'receipted': 0.9902506963788271,
#              'wampum': 0.9909470752089107,
#              'cant': 0.9916434540389942,
#              'being': 0.9923398328690778,
#              'oho': 0.9930362116991613,
#              'bad': 0.9937325905292449,
#              'nonsense': 0.9944289693593285,
#              'whod': 0.995125348189412,
#              'say': 0.9958217270194956,
#              'youll': 0.9965181058495791,
#              'coming': 0.9972144846796627,
#              'isnt': 0.9979108635097462,
#              'do': 0.9986072423398298,
#              'content': 0.9993036211699133,
#              'an': 0.9999999999999969})

# %% [markdown]
# ### Filling first order markov distribution

# %%
for text in poems['text']:
    l = text.split()
    
    if len(l)<2:
        continue
    
    if l[0] not in first_order.keys():
        first_order[l[0]] = defaultdict(int)
    first_order[l[0]][l[1]]+=1

first_order
# Out:
# {'two': defaultdict(int,
#              {'roads': 2,
#               'miles': 1,
#               'oldbelievers': 1,
#               'winds': 1,
#               'weeks': 1,
#               'of': 1,
#               'at': 1}),
#  'and': defaultdict(int,
#              {'sorry': 2,
#               'be': 1,
#               'looked': 1,
#               'having': 1,
#               'both': 2,
#               'that': 2,
#               'miles': 2,
#               'would': 1,
#               'dropped': 1,
#               'further': 1,
#               'when': 1,
#               'tell': 3,
#               'the': 4,
#               'caught': 1,
#               'put': 2,
#               'threw': 1,
#               'birds': 1,
#               'suddenly': 1,
#               'scurf': 1,
#               'since': 2,
#               'whats': 1,
#               'many': 1,
#               'blew': 1,
#               'stamped': 1,
#               'sometimes': 1,
#               'some': 1,
#               'then': 3,
#               'came': 1,
#               'this': 2,
#               'politician': 1,
#               'thatd': 1,
#               'rode': 1,
#               'if': 2,
#               'from': 1,
#               'i': 4,
#               'he': 1,
#               'full': 1,
#               'experts': 1,
#               'built': 1,
#               'thats': 1,
#               'spoke': 2,
#               'anyway': 1,
#               'had': 1,
#               'how': 1,
#               'taken': 1,
#               'lie': 1,
#               'left': 1,
#               'stroked': 1,
#               'a': 2,
#               'me': 1,
#               'between': 1,
#               'wont': 1,
#               'hes': 1,
#               'his': 1,
#               'nothing': 1,
#               'better': 1,
#               'kick': 1,
#               'carried': 1,
#               'thought': 1,
#               'swollen': 2,
#               'hold': 1,
#               'all': 2,
#               'fell': 1,
#               'set': 1,
#               'sit': 2,
#               'bring': 1,
#               'push': 1,
#               'those': 2,
#               'sproutlands': 1,
#               'perhaps': 2,
#               'see': 1,
#               'dangle': 1,
#               'disappeared': 1,
#               'below': 1,
#               'what': 1,
#               'come': 1,
#               'begin': 1,
#               'build': 1,
#               'in': 2,
#               'theres': 1,
#               'stifling': 1,
#               'got': 1,
#               'lift': 1,
#               'give': 1,
#               'fight': 1,
#               'such': 1,
#               'moon': 1,
#               'jupiter': 1,
#               'save': 1,
#               'nation': 1,
#               'though': 1,
#               'now': 1,
#               'wheres': 1,
#               'shell': 1,
#               'no': 1,
#               'end': 1,
#               'after': 1,
#               'we': 1,
#               'like': 1,
#               'youre': 1,
#               'turn': 1,
#               'not': 1,
#               'last': 1}),
#  'to': defaultdict(int,
#              {'where': 1,
#               'watch': 2,
#               'stop': 1,
#               'ask': 1,
#               'say': 2,
#               'carry': 1,
#               'think': 1,
#               'make': 6,
#               'everything': 1,
#               'spare': 1,
#               'see': 5,
#               'turn': 1,
#               'undo': 1,
#               'let': 1,
#               'go': 1,
#               'shut': 1,
#               'bring': 1,
#               'entertain': 1,
#               'find': 1,
#               'send': 1,
#               'such': 1,
#               'wonder': 1,
#               'no': 1,
#               'tell': 1,
#               'stand': 1,
#               'reconnoitre': 1,
#               'set': 1,
#               'blow': 1,
#               'ridgely': 1,
#               'the': 2,
#               'curl': 1,
#               'call': 1,
#               'which': 1,
#               'be': 1,
#               'drag': 1,
#               'come': 1,
#               'live': 1,
#               'break': 1}),
#  'then': defaultdict(int,
#              {'took': 1,
#               'leaf': 1,
#               'shook': 1,
#               'that': 1,
#               'he': 1,
#               'ran': 1,
#               'we': 1,
#               'i': 1,
#               'make': 1,
#               'for': 1,
#               'cane': 1,
#               'its': 1}),
#  'because': defaultdict(int, {'it': 1}),
#  'though': defaultdict(int,
#              {'as': 1,
#               'slight': 1,
#               'what': 2,
#               'not': 1,
#               'strange': 1,
#               'set': 1}),
#  'had': defaultdict(int, {'worn': 1, 'spilled': 1, 'been': 1, 'checked': 1}),
#  'in': defaultdict(int,
#              {'leaves': 1,
#               'front': 3,
#               'the': 1,
#               'every': 2,
#               'winter': 1,
#               'warren': 1,
#               'wentworth': 1,
#               'dalton': 1,
#               'eightyfive': 1,
#               'dust': 1,
#               'virgin': 1,
#               'time': 1,
#               'one': 2,
#               'snow': 1,
#               'its': 1,
#               'summer': 1,
#               'going': 1,
#               'an': 1,
#               'a': 1,
#               'rain': 2,
#               'that': 2,
#               'separate': 1,
#               'ways': 1}),
#  'oh': defaultdict(int, {'i': 1, 'if': 2, 'thats': 1}),
#  'yet': defaultdict(int, {'knowing': 1, 'oh': 1, 'does': 1}),
#  'i': defaultdict(int,
#              {'doubted': 1,
#               'shall': 2,
#               'took': 1,
#               'hold': 1,
#               'think': 2,
#               'have': 9,
#               'end': 1,
#               'cant': 5,
#               'fancied': 1,
#               'looked': 1,
#               'was': 6,
#               'paused': 1,
#               'saw': 2,
#               'wonder': 5,
#               'could': 3,
#               'guess': 4,
#               'know': 4,
#               'made': 2,
#               'hope': 1,
#               'might': 1,
#               'thought': 3,
#               'am': 1,
#               'wont': 2,
#               'want': 3,
#               'vow': 1,
#               'didnt': 2,
#               'never': 3,
#               'stay': 1,
#               'can': 3,
#               'staid': 1,
#               'went': 2,
#               'had': 6,
#               'struck': 1,
#               'sat': 1,
#               'listened': 1,
#               'pushed': 1,
#               'wanted': 2,
#               'heard': 1,
#               'promised': 1,
#               'mean': 3,
#               'dont': 4,
#               'verified': 1,
#               'judged': 1,
#               'only': 2,
#               'idled': 1,
#               'may': 1,
#               'let': 3,
#               'should': 1,
#               'like': 1,
#               'turned': 1,
#               'often': 1,
#               'name': 1,
#               'stole': 1,
#               'walked': 1,
#               'help': 1,
#               'tell': 1,
#               'hate': 1,
#               'blame': 1,
#               'take': 1,
#               'suppose': 1}),
#  'somewhere': defaultdict(int, {'ages': 1}),
#  'whose': defaultdict(int, {'woods': 1, 'shoes': 1}),
#  'his': defaultdict(int,
#              {'house': 1,
#               'lantern': 1,
#               'wild': 1,
#               'journey': 1,
#               'neck': 1,
#               'names': 1,
#               'small': 1}),
#  'he': defaultdict(int,
#              {'will': 1,
#               'gives': 1,
#               'saw': 1,
#               'gained': 1,
#               'never': 3,
#               'reeled': 1,
#               'fell': 1,
#               'looked': 1,
#               'couldnt': 1,
#               'bowed': 1,
#               'steered': 1,
#               'want': 1,
#               'stood': 1,
#               'said': 3,
#               'dont': 1,
#               'guessed': 1,
#               'read': 1,
#               'broke': 1,
#               'always': 1,
#               'thinks': 2,
#               'must': 1,
#               'wont': 1,
#               'cant': 1,
#               'gets': 1,
#               'and': 1,
#               'hoed': 1,
#               'knows': 1,
#               'manages': 1,
#               'can': 1}),
#  'my': defaultdict(int,
#              {'little': 1,
#               'french': 1,
#               'first': 1,
#               'mother': 1,
#               'window': 1,
#               'fingers': 1,
#               'but': 1}),
#  'between': defaultdict(int, {'the': 2, 'me': 1}),
#  'the': defaultdict(int,
#              {'darkest': 1,
#               'only': 1,
#               'woods': 1,
#               'headless': 1,
#               'whir': 1,
#               'hillside': 1,
#               'swarm': 1,
#               'moon': 1,
#               'spell': 1,
#               'thought': 1,
#               'figures': 1,
#               'arthur': 2,
#               'tote': 1,
#               'poor': 1,
#               'crib': 1,
#               'smarty': 1,
#               'mica': 1,
#               'early': 1,
#               'mountain': 1,
#               'old': 1,
#               'two': 1,
#               'outside': 1,
#               'poetess': 2,
#               'posies': 1,
#               'attic': 2,
#               'small': 1,
#               'seal': 1,
#               'night': 1,
#               'board': 1,
#               'way': 2,
#               'bulkhead': 1,
#               'cellar': 1,
#               'door': 1,
#               'faintest': 1,
#               'fingerpieces': 1,
#               'kitchen': 1,
#               'uncommonly': 1,
#               'steps': 1,
#               'least': 1,
#               'rural': 1,
#               'west': 1,
#               'breath': 1,
#               'origin': 1,
#               'past': 1,
#               'young': 1,
#               'second': 1,
#               'town': 1,
#               'situation': 1,
#               'sound': 1,
#               'indians': 1,
#               'nose': 1,
#               'meaning': 1,
#               'voices': 2,
#               'life': 1,
#               'hours': 1,
#               'road': 1,
#               'ledges': 1,
#               'chisel': 1,
#               'height': 1,
#               'playthings': 1,
#               'sun': 1,
#               'frogs': 1,
#               'minute': 1,
#               'same': 1,
#               'snow': 1,
#               'tower': 1,
#               'sigmas': 1,
#               'cosmic': 1,
#               'utmost': 1,
#               'surest': 1,
#               'strains': 1,
#               'rights': 1,
#               'smell': 1,
#               'little': 1,
#               'upper': 1,
#               'crystal': 1,
#               'man': 1}),
#  'of': defaultdict(int,
#              {'easy': 1,
#               'the': 6,
#               'wire': 1,
#               'getting': 1,
#               'arthur': 1,
#               'having': 1,
#               'door': 1,
#               'his': 1,
#               'what': 1,
#               'here': 1,
#               'stranger': 1,
#               'an': 2,
#               'castles': 1,
#               'youthful': 1,
#               'detail': 1,
#               'being': 1,
#               'country': 1,
#               'dust': 1,
#               'earthly': 1,
#               'constellations': 1,
#               'yawning': 1,
#               'once': 1,
#               'both': 1}),
#  'but': defaultdict(int,
#              {'i': 8,
#               'if': 3,
#               'only': 2,
#               'not': 3,
#               'a': 1,
#               'though': 2,
#               'saved': 1,
#               'now': 1,
#               'most': 1,
#               'everybody': 1,
#               'smith': 1,
#               'you': 2,
#               'welcomed': 1,
#               'all': 1,
#               'it': 1,
#               'we': 1,
#               'wont': 1,
#               'left': 1,
#               'tonight': 1,
#               'rain': 1,
#               'the': 1,
#               'wait': 1,
#               'why': 2,
#               'theres': 1,
#               'dont': 1,
#               'please': 1,
#               'me': 1,
#               'where': 1,
#               'get': 1,
#               'feared': 1,
#               'being': 1,
#               'when': 2,
#               'estelle': 1,
#               'its': 1,
#               'whats': 1}),
#  'some': defaultdict(int,
#              {'say': 2, 'cried': 1, 'zealous': 1, 'shattered': 1}),
#  'from': defaultdict(int,
#              {'what': 1,
#               'the': 4,
#               'that': 1,
#               'my': 1,
#               'north': 1,
#               'stumps': 1,
#               'sleeping': 1}),
#  'is': defaultdict(int,
#              {'also': 1, 'sadder': 1, 'back': 1, 'supposed': 1, 'this': 1}),
#  'natures': defaultdict(int, {'first': 1}),
#  'her': defaultdict(int, {'hardest': 1, 'early': 1}),
#  'so': defaultdict(int,
#              {'eden': 1,
#               'dawn': 1,
#               'halfway': 1,
#               'now': 1,
#               'they': 1,
#               'as': 2,
#               'suddenly': 1,
#               'that': 2,
#               'lying': 1,
#               'cant': 1,
#               'near': 1}),
#  'nothing': defaultdict(int, {'gold': 1, 'would': 1}),
#  'when': defaultdict(int,
#              {'far': 1, 'i': 4, 'the': 1, 'there': 1, 'shoeing': 1, 'all': 1}),
#  'came': defaultdict(int, {'over': 1}),
#  'one': defaultdict(int,
#              {'luminary': 1,
#               'lizard': 1,
#               'of': 1,
#               'and': 1,
#               'ought': 1,
#               'mustnt': 1,
#               'down': 2,
#               'thing': 1,
#               'level': 2}),
#  'proclaimed': defaultdict(int, {'the': 1}),
#  'smoothlaid': defaultdict(int, {'like': 1}),
#  'half': defaultdict(int, {'closes': 1, 'looking': 1, 'of': 1}),
#  'up': defaultdict(int,
#              {'from': 1, 'at': 1, 'where': 1, 'attic': 2, 'one': 1, 'to': 1}),
#  'a': defaultdict(int,
#              {'tree': 2,
#               'voice': 1,
#               'swamp': 1,
#               'barkless': 1,
#               'hole': 1,
#               'leak': 1,
#               'cliff': 1,
#               'likeness': 1,
#               'whole': 1,
#               'small': 1,
#               'moment': 1,
#               'bird': 1,
#               'single': 1,
#               'brush': 1,
#               'piercing': 1,
#               'governor': 1,
#               'rockstrewn': 1,
#               'bead': 1,
#               'little': 1,
#               'shelfs': 1,
#               'chimney': 1,
#               'few': 1,
#               'brook': 1,
#               'broken': 1,
#               'note': 1,
#               'friend': 1,
#               'bill': 1,
#               'winter': 1,
#               'featherhammer': 1}),
#  'disturbed': defaultdict(int, {'i': 1, 'the': 1}),
#  'comes': defaultdict(int, {'softly': 1}),
#  'by': defaultdict(int,
#              {'picking': 1,
#               'doubling': 1,
#               'all': 1,
#               'its': 1,
#               'road': 1,
#               'having': 1,
#               'being': 1,
#               'flying': 1,
#               'a': 1,
#               'now': 1,
#               'tying': 1}),
#  'if': defaultdict(int,
#              {'all': 1,
#               'i': 3,
#               'some': 1,
#               'anyone': 1,
#               'you': 1,
#               'seen': 1,
#               'the': 2,
#               'he': 1,
#               'hes': 1}),
#  'were': defaultdict(int, {'not': 3}),
#  'ten': defaultdict(int, {'million': 1}),
#  'as': defaultdict(int,
#              {'often': 2,
#               'if': 2,
#               'standing': 1,
#               'long': 1,
#               'we': 1,
#               'gilt': 1,
#               'one': 1,
#               'pale': 1,
#               'for': 1,
#               'winds': 1,
#               'married': 1,
#               'near': 1}),
#  'it': defaultdict(int,
#              {'looks': 2,
#               'takes': 1,
#               'must': 2,
#               'want': 1,
#               'doesnt': 1,
#               'wasnt': 1,
#               'was': 2,
#               'took': 1,
#               'ought': 2,
#               'rests': 1,
#               'has': 2,
#               'in': 1,
#               'will': 1,
#               'seems': 1,
#               'makes': 1,
#               'lifts': 2}),
#  'lifted': defaultdict(int, {'the': 1}),
#  'she': defaultdict(int,
#              {'has': 1,
#               'thinks': 2,
#               'might': 1,
#               'never': 1,
#               'was': 1,
#               'could': 1,
#               'hadnt': 1,
#               'swept': 1,
#               'made': 1,
#               'should': 1,
#               'does': 1,
#               'seems': 1,
#               'wants': 1,
#               'wont': 2,
#               'raised': 1}),
#  'transfixed': defaultdict(int, {'on': 1}),
#  'across': defaultdict(int, {'each': 1}),
#  'was': defaultdict(int,
#              {'wrought': 1,
#               'arthur': 1,
#               'singing': 1,
#               'only': 1,
#               'a': 1,
#               'something': 1,
#               'hot': 1,
#               'counting': 1,
#               'it': 1}),
#  'once': defaultdict(int, {'on': 1, 'more': 1}),
#  'that': defaultdict(int,
#              {'had': 2,
#               'everyone': 1,
#               'cased': 1,
#               'is': 1,
#               'even': 1,
#               'as': 1,
#               'they': 1,
#               'was': 1,
#               'happens': 1,
#               'overflowing': 1,
#               'doesnt': 1,
#               'need': 1,
#               'theres': 1,
#               'made': 1,
#               'now': 1,
#               'turned': 1,
#               'the': 1,
#               'a': 1,
#               'you': 1,
#               'there': 2,
#               'are': 1,
#               'no': 1,
#               'braced': 1,
#               'sends': 1,
#               'struck': 1,
#               'much': 1,
#               'isnt': 1}),
#  'looked': defaultdict(int, {'up': 1}),
#  'stood': defaultdict(int, {'over': 1}),
#  'you': defaultdict(int,
#              {'here': 1,
#               'can': 3,
#               'said': 2,
#               'wont': 1,
#               'mean': 3,
#               'dont': 3,
#               'must': 4,
#               'and': 1,
#               'know': 2,
#               'riddle': 1,
#               'take': 1,
#               'look': 1,
#               'never': 2,
#               'poor': 1,
#               'will': 2,
#               'want': 1,
#               'see': 2,
#               'seem': 1,
#               'think': 1,
#               'let': 1,
#               'couldnt': 1,
#               'cant': 1,
#               'say': 1,
#               'spoke': 1,
#               'ought': 1,
#               'neednt': 1}),
#  'me': defaultdict(int, {'im': 1}),
#  'sometimes': defaultdict(int, {'i': 1, 'he': 2, 'as': 1}),
#  'brown': defaultdict(int, {'lived': 1, 'makes': 1}),
#  'cross': defaultdict(int, {'lots': 1}),
#  'describing': defaultdict(int, {'rings': 1}),
#  'got': defaultdict(int, {'him': 1}),
#  'walls': defaultdict(int, {'were': 1}),
#  'like': defaultdict(int,
#              {'wings': 1,
#               'no': 1,
#               'a': 2,
#               'wild': 1,
#               'profanation': 1,
#               'graveyard': 1,
#               'some': 1}),
#  'upon': defaultdict(int, {'his': 1, 'a': 1}),
#  'with': defaultdict(int,
#              {'no': 1,
#               'all': 2,
#               'stone': 1,
#               'furs': 1,
#               'the': 4,
#               'our': 1,
#               'sounds': 1,
#               'clouds': 1,
#               'a': 1,
#               'his': 1,
#               'flowers': 1,
#               'half': 1,
#               'whose': 1,
#               'me': 1}),
#  'faster': defaultdict(int, {'or': 1}),
#  'sitting': defaultdict(int, {'or': 1}),
#  'according': defaultdict(int, {'as': 1}),
#  'hes': defaultdict(int,
#              {'celebrating': 1,
#               'so': 1,
#               'after': 1,
#               'groping': 1,
#               'nothing': 1,
#               'just': 1,
#               'got': 1,
#               'fiftyfive': 1,
#               'given': 1,
#               'fond': 1,
#               'been': 1}),
#  'or': defaultdict(int,
#              {'been': 1,
#               'even': 1,
#               'stained': 1,
#               'like': 1,
#               'else': 1,
#               'a': 1,
#               'i': 1,
#               'it': 1,
#               'creaking': 1,
#               'some': 1,
#               'old': 1}),
#  'incredulous': defaultdict(int, {'of': 1}),
#  'well—i—be—': defaultdict(int, {'that': 1}),
#  'on': defaultdict(int,
#              {'motorcars': 1,
#               'moosilauke': 1,
#               'slippery': 1,
#               'marshall': 1,
#               'an': 1,
#               'fathers': 1,
#               'last': 1,
#               'planets': 1,
#               'his': 1,
#               'something': 1,
#               'some': 1}),
#  'should': defaultdict(int, {'say': 1, 'take': 1}),
#  'yankees': defaultdict(int, {'are': 1}),
#  'dont': defaultdict(int,
#              {'think': 1,
#               'donkeys': 1,
#               'ask': 1,
#               'make': 1,
#               'be': 1,
#               'the': 1,
#               'build': 1}),
#  'until': defaultdict(int, {'the': 1, 'id': 1}),
#  'after': defaultdict(int, {'the': 1}),
#  'not': defaultdict(int,
#              {'much': 2,
#               'that': 1,
#               'so': 1,
#               'like': 1,
#               'from': 1,
#               'fireweed': 1,
#               'bluebells': 1,
#               'lupine': 1,
#               'in': 2,
#               'to': 1,
#               'answering': 1}),
#  'at': defaultdict(int, {'that': 1, 'having': 2, 'least': 2, 'ten': 1}),
#  'no': defaultdict(int,
#              {'more': 2,
#               'doubt': 1,
#               'bird': 1,
#               'fête': 1,
#               'its': 1,
#               'one': 3,
#               'i': 1,
#               'matter': 1,
#               'he': 1}),
#  'ive': defaultdict(int, {'kept': 1, 'never': 1, 'been': 1, 'got': 1}),
#  'while': defaultdict(int, {'i': 1}),
#  'bout': defaultdict(int, {'out': 1}),
#  'now': defaultdict(int, {'that': 1, 'give': 1, 'lefts': 1, 'slowly': 1}),
#  'im': defaultdict(int,
#              {'going': 1, 'stark': 1, 'waiting': 1, 'getting': 1, 'sure': 1}),
#  'theyve': defaultdict(int, {'got': 1}),
#  'flattered': defaultdict(int, {'i': 1}),
#  'they': defaultdict(int,
#              {'dont': 1,
#               'set': 1,
#               'made': 1,
#               'found': 1,
#               'bad': 1,
#               'simply': 1,
#               'were': 3,
#               'have': 1,
#               'eddy': 1,
#               'think': 1,
#               'might': 1,
#               'spoke': 3,
#               'left': 2,
#               'filled': 1}),
#  'always': defaultdict(int, {'the': 1}),
#  'ill': defaultdict(int,
#              {'double': 1,
#               'tell': 3,
#               'find': 1,
#               'show': 2,
#               'hardly': 1,
#               'say': 1,
#               'talk': 1}),
#  'theyll': defaultdict(int, {'find': 1}),
#  'for': defaultdict(int,
#              {'hog': 1,
#               'gods': 1,
#               'a': 2,
#               'god': 1,
#               'helping': 1,
#               'fifty': 1}),
#  'couldnt': defaultdict(int, {'have': 1, 'one': 1}),
#  'voted': defaultdict(int, {'the': 1}),
#  'which': defaultdict(int, {'wasnt': 1, 'means': 1, 'is': 1}),
#  'their': defaultdict(int, {'arthur': 1, 'solemn': 1}),
#  'wentworth': defaultdict(int, {'and': 1}),
#  'only': defaultdict(int,
#              {'i': 1, 'bewitched': 1, 'to': 1, 'one': 1, 'too': 1}),
#  'rights': defaultdict(int, {'right': 1}),
#  'has': defaultdict(int, {'always': 1, 'been': 1}),
#  'itd': defaultdict(int, {'make': 1}),
#  'said': defaultdict(int, {'that': 1}),
#  'hed': defaultdict(int, {'bet': 1, 'like': 1, 'say': 2, 'need': 1}),
#  'all': defaultdict(int,
#              {'four': 1,
#               'is': 2,
#               'the': 1,
#               'claiming': 1,
#               'fresh': 1,
#               'that': 1,
#               'we': 1}),
#  'gnaws': defaultdict(int, {'in': 1}),
#  'last': defaultdict(int, {'night': 1}),
#  'over': defaultdict(int, {'the': 2, 'so': 1, 'descended': 1, 'back': 1}),
#  'well': defaultdict(int, {'i': 1, 'take': 1, 'if': 1, 'then': 2}),
#  'off': defaultdict(int, {'from': 1, 'here': 1}),
#  'old': defaultdict(int, {'davis': 1, 'as': 1}),
#  'thered': defaultdict(int, {'been': 1}),
#  'someday': defaultdict(int, {'i': 1}),
#  'huh': defaultdict(int, {'that': 1}),
#  'lets': defaultdict(int, {'talk': 1, 'go': 1, 'trap': 1}),
#  'youve': defaultdict(int, {'lost': 1}),
#  'can': defaultdict(int, {'do': 1}),
#  'be': defaultdict(int, {'dragged': 1, 'ready': 1, 'good': 1}),
#  'we': defaultdict(int,
#              {'made': 1,
#               'came': 2,
#               'may': 1,
#               'struck': 1,
#               'trod': 1,
#               'were': 1,
#               'have': 4,
#               'know': 1,
#               'can': 1,
#               'wouldnt': 1,
#               'fence': 1}),
#  'ascending': defaultdict(int, {'to': 1}),
#  'sos': defaultdict(int, {'everything': 1, 'to': 1}),
#  'hadnt': defaultdict(int, {'you': 1}),
#  'look': defaultdict(int, {'here': 1}),
#  'what': defaultdict(int,
#              {'signify': 1,
#               'it': 2,
#               'bones': 1,
#               'do': 3,
#               'i': 2,
#               'is': 1,
#               'he': 1,
#               'childishness': 1,
#               'are': 1,
#               'well': 1}),
#  'however': defaultdict(int, {'natural': 1, 'far': 1}),
#  'come': defaultdict(int, {'straight': 1, 'down': 1, 'here': 1, 'out': 1}),
#  'its': defaultdict(int,
#              {'hell': 1,
#               'not': 2,
#               'sometimes': 1,
#               'the': 1,
#               'to': 1,
#               'harmless': 1,
#               'coming': 1,
#               'with': 1,
#               'looking': 1,
#               'raining': 1,
#               'as': 3,
#               'going': 1,
#               'hands': 1,
#               'whirling': 1,
#               'you': 1,
#               'gone': 1,
#               'too': 1,
#               'different': 1}),
#  'perhaps': defaultdict(int, {'to': 1, 'you': 1}),
#  'excuse': defaultdict(int, {'me': 1}),
#  'who': defaultdict(int,
#              {'used': 1,
#               'failed': 1,
#               'only': 1,
#               'may': 1,
#               'are': 1,
#               'wants': 1}),
#  'life': defaultdict(int, {'long': 1}),
#  'our': defaultdict(int, {'business': 1, 'hens': 1}),
#  'through': defaultdict(int, {'a': 1, 'everything': 1}),
#  'except': defaultdict(int, {'it': 1, 'always': 1}),
#  'books': defaultdict(int, {'i': 1, 'were': 1}),
#  'where': defaultdict(int,
#              {'driven': 1,
#               'did': 1,
#               'shall': 1,
#               'the': 1,
#               'were': 1,
#               'is': 1,
#               'conies': 1,
#               'he': 1}),
#  'enough': defaultdict(int, {'to': 1}),
#  'unfortunately': defaultdict(int, {'all': 1}),
#  'boys': defaultdict(int, {'and': 1}),
#  'shatter': defaultdict(int, {'it': 1}),
#  'how': defaultdict(int,
#              {'had': 1, 'could': 1, 'shall': 2, 'do': 1, 'are': 1}),
#  'till': defaultdict(int, {'it': 1, 'well': 1}),
#  'tried': defaultdict(int, {'to': 1}),
#  'having': defaultdict(int, {'tried': 1}),
#  'here': defaultdict(int, {'were': 1, 'are': 1, 'he': 1, 'loveless': 1}),
#  'take': defaultdict(int, {'one': 1, 'all': 1, 'it': 1}),
#  'why': defaultdict(int, {'not': 2, 'do': 1}),
#  'goodlooking': defaultdict(int, {'books': 1}),
#  'both': defaultdict(int, {'either': 1}),
#  'legitimately': defaultdict(int, {'my': 1}),
#  'there': defaultdict(int, {'wasnt': 1, 'aint': 1, 'is': 2, 'was': 2}),
#  'alias': defaultdict(int, {'john': 1}),
#  'about': defaultdict(int, {'where': 1}),
#  'theres': defaultdict(int, {'not': 1}),
#  'give': defaultdict(int, {'a': 1}),
#  'thrown': defaultdict(int, {'away': 1}),
#  'unless': defaultdict(int, {'it': 1}),
#  'than': defaultdict(int, {'lifes': 1, 'folks': 1}),
#  'behind': defaultdict(int, {'the': 2}),
#  'mother': defaultdict(int,
#              {'folks': 1,
#               'and': 1,
#               'bones': 1,
#               'well': 1,
#               'the': 1,
#               'we': 1,
#               'yes': 1}),
#  'summoning': defaultdict(int, {'spirits': 1}),
#  'whos': defaultdict(int, {'got': 1}),
#  'son': defaultdict(int,
#              {'mother': 1,
#               'you': 2,
#               'but': 1,
#               'it': 1,
#               'we': 2,
#               'knows': 1,
#               'looks': 1}),
#  'rather': defaultdict(int, {'than': 1}),
#  'tell': defaultdict(int, {'you': 1, 'me': 1}),
#  'yes': defaultdict(int,
#              {'theres': 1,
#               'stark': 1,
#               'what': 1,
#               'its': 1,
#               'you': 1,
#               'whats': 1,
#               'but': 1,
#               'i': 1}),
#  'against': defaultdict(int, {'the': 1}),
#  'halting': defaultdict(int, {'perplexed': 1}),
#  'another': defaultdict(int, {'from': 2}),
#  'right': defaultdict(int, {'past': 1}),
#  'father': defaultdict(int, {'had': 1}),
#  'especially': defaultdict(int, {'in': 1}),
#  'might': defaultdict(int, {'just': 1}),
#  'toffile': defaultdict(int,
#              {'had': 1, 'for': 1, 'agreed': 1, 'get': 1, 'if': 1}),
#  'struck': defaultdict(int, {'the': 1}),
#  'began': defaultdict(int, {'the': 1}),
#  'waiting': defaultdict(int, {'for': 1}),
#  'flashed': defaultdict(int, {'out': 1}),
#  'smoke': defaultdict(int, {'rolled': 1}),
#  'hand': defaultdict(int, {'me': 1}),
#  'stillgoing': defaultdict(int, {'every': 1}),
#  'before': defaultdict(int, {'i': 1, 'its': 1}),
#  'almost': defaultdict(int, {'the': 1}),
#  'quick': defaultdict(int, {'i': 1}),
#  'let': defaultdict(int, {'them': 1, 'people': 1}),
#  'brushing': defaultdict(int, {'their': 1}),
#  'thats': defaultdict(int, {'what': 1, 'a': 2, 'no': 1, 'his': 1}),
#  '2o3': defaultdict(int, {'let': 1}),
#  'wed': defaultdict(int, {'kept': 1}),
#  'could': defaultdict(int, {'tell': 1}),
#  'among': defaultdict(int, {'the': 2, 'unearthed': 1}),
#  'ancestral': defaultdict(int, {'memories': 1}),
#  'someone': defaultdict(int, {'had': 1}),
#  'thence': defaultdict(int, {'they': 1}),
#  'made': defaultdict(int, {'shift': 1}),
#  'are': defaultdict(int, {'there': 1}),
#  'strolled': defaultdict(int, {'thither': 1}),
#  'anyone': defaultdict(int, {'else': 1, 'upon': 1}),
#  'this': defaultdict(int, {'was': 2, 'he': 1, 'is': 2, 'eden': 1}),
#  'provision': defaultdict(int, {'there': 1}),
#  'drawn': defaultdict(int, {'on': 1, 'into': 1}),
#  'stark': defaultdict(int, {'he': 1}),
#  'would': defaultdict(int, {'have': 1, 'name': 1}),
#  'several': defaultdict(int, {'times': 1}),
#  'under': defaultdict(int, {'the': 1, 'a': 1}),
#  'just': defaultdict(int, {'so': 1}),
#  'does': defaultdict(int, {'the': 1, 'it': 1}),
#  'bowed': defaultdict(int, {'outward': 1}),
#  'beyond': defaultdict(int, {'where': 1, 'which': 1}),
#  'four': defaultdict(int, {'cards': 1}),
#  'dyou': defaultdict(int, {'know': 1}),
#  'studying': defaultdict(int, {'genealogy': 1}),
#  'first': defaultdict(int, {'let': 1, 'theres': 1}),
#  'bless': defaultdict(int, {'you': 2}),
#  'shes': defaultdict(int, {'after': 1, 'in': 1, 'let': 1}),
#  'heres': defaultdict(int, {'hoping': 1}),
#  'making': defaultdict(int, {'allowance': 1}),
#  'see': defaultdict(int, {'that': 1}),
#  'strung': defaultdict(int, {'on': 1}),
#  'something': defaultdict(int, {'i': 1, 'went': 1}),
#  'speaking': defaultdict(int, {'or': 1}),
#  'strangely': defaultdict(int, {'its': 1}),
#  'call': defaultdict(int, {'her': 2}),
#  'nor': defaultdict(int, {'grannys': 1, 'never': 1, 'need': 1, 'want': 1}),
#  'nine': defaultdict(int, {'times': 1}),
#  'anything': defaultdict(int, {'she': 1}),
#  'folks': defaultdict(int, {'in': 1}),
#  'mebbe': defaultdict(int, {'im': 1}),
#  'more': defaultdict(int, {'of': 1}),
#  'will': defaultdict(int, {'you': 1, 'leave': 1}),
#  'nowhere': defaultdict(int, {'but': 1}),
#  'builder': defaultdict(int, {'in': 1}),
#  'whatever': defaultdict(int, {'they': 1}),
#  'inscription': defaultdict(int, {'for': 1}),
#  'winds': defaultdict(int, {'blow': 1}),
#  'moisture': defaultdict(int, {'and': 1}),
#  'heaven': defaultdict(int, {'gives': 1}),
#  'back': defaultdict(int, {'out': 1, 'in': 1}),
#  'may': defaultdict(int, {'seem': 1}),
#  'great': defaultdict(int, {'monolithic': 1}),
#  'long': defaultdict(int, {'since': 1}),
#  'besides': defaultdict(int, {'the': 1}),
#  'still': defaultdict(int, {'said': 1, 'more': 1}),
#  'charge': defaultdict(int, {'that': 1}),
#  'make': defaultdict(int, {'yourself': 1, 'so': 1}),
#  'someones': defaultdict(int, {'road': 1}),
#  'into': defaultdict(int, {'each': 1}),
#  'weep': defaultdict(int, {'for': 1}),
#  'your': defaultdict(int, {'destination': 1}),
#  'cold': defaultdict(int, {'as': 1}),
#  'too': defaultdict(int, {'lofty': 1, 'late': 1}),
#  'drink': defaultdict(int, {'and': 1}),
#  'wherever': defaultdict(int, {'the': 1}),
#  'birch': defaultdict(int, {'boughs': 1}),
#  'time': defaultdict(int, {'someone': 1}),
#  'small': defaultdict(int, {'good': 1}),
#  'out': defaultdict(int, {'in': 1}),
#  'awake': defaultdict(int, {'that': 1}),
#  'wishing': defaultdict(int, {'that': 1}),
#  'saturn': defaultdict(int, {'and': 1}),
#  'theirs': defaultdict(int, {'interlock': 1}),
#  'uttered': defaultdict(int, {'alone': 1}),
#  'trembled': defaultdict(int, {'and': 1}),
#  'appear': defaultdict(int, {'like': 1}),
#  'around': defaultdict(int, {'and': 1}),
#  'since': defaultdict(int, {'man': 1}),
#  'lord': defaultdict(int, {'if': 1}),
#  'havent': defaultdict(int, {'you': 1, 'as': 1}),
#  'whats': defaultdict(int, {'wanted': 1, 'this': 1, 'the': 2}),
#  'estelles': defaultdict(int, {'to': 1, 'the': 1}),
#  'weve': defaultdict(int, {'been': 1}),
#  'left': defaultdict(int, {'here': 1}),
#  'hell': defaultdict(int, {'sort': 1}),
#  'skyhigh': defaultdict(int, {'with': 1}),
#  'arent': defaultdict(int, {'you': 1}),
#  'john': defaultdict(int,
#              {'hall': 1,
#               'likes': 1,
#               'bought': 1,
#               'said': 1,
#               'himself': 1,
#               'threw': 1}),
#  'better': defaultdict(int, {'than': 1}),
#  'reason': defaultdict(int, {'enough': 1}),
#  'such': defaultdict(int, {'as': 1}),
#  'twas': defaultdict(int, {'we': 1}),
#  'johns': defaultdict(int, {'a': 1, 'almost': 1}),
#  'estelle': defaultdict(int, {'to': 1}),
#  'farmers': defaultdict(int, {'around': 1}),
#  'full': defaultdict(int, {'of': 1}),
#  'moving': defaultdict(int, {'a': 1}),
#  'nothings': defaultdict(int, {'too': 1}),
#  'twenty': defaultdict(int, {'for': 1}),
#  'receipted': defaultdict(int, {'and': 1}),
#  'wampum': defaultdict(int, {'i': 1}),
#  'cant': defaultdict(int, {'you': 1}),
#  'being': defaultdict(int, {'cut': 1}),
#  'oho': defaultdict(int, {'oho': 1}),
#  'bad': defaultdict(int, {'to': 1}),
#  'nonsense': defaultdict(int, {'see': 1}),
#  'whod': defaultdict(int, {'marry': 1}),
#  'say': defaultdict(int, {'it': 1}),
#  'youll': defaultdict(int, {'be': 1}),
#  'coming': defaultdict(int, {'down': 1}),
#  'isnt': defaultdict(int, {'it': 1}),
#  'do': defaultdict(int, {'go': 1}),
#  'content': defaultdict(int, {'with': 1}),
#  'an': defaultdict(int, {'hour': 1})}

# %%
np.array(list(initial_state.values())).sum()
# Out:
# 234.95821727019458

# %%
for outer_keys in first_order.keys():
    sum = np.array(list(first_order[outer_keys].values())).sum()
    for inner_keys in first_order[outer_keys].keys():
        first_order[outer_keys][inner_keys]/=sum

first_order
# Out:
# {'two': defaultdict(int,
#              {'roads': 0.25,
#               'miles': 0.125,
#               'oldbelievers': 0.125,
#               'winds': 0.125,
#               'weeks': 0.125,
#               'of': 0.125,
#               'at': 0.125}),
#  'and': defaultdict(int,
#              {'sorry': 0.015503875968992248,
#               'be': 0.007751937984496124,
#               'looked': 0.007751937984496124,
#               'having': 0.007751937984496124,
#               'both': 0.015503875968992248,
#               'that': 0.015503875968992248,
#               'miles': 0.015503875968992248,
#               'would': 0.007751937984496124,
#               'dropped': 0.007751937984496124,
#               'further': 0.007751937984496124,
#               'when': 0.007751937984496124,
#               'tell': 0.023255813953488372,
#               'the': 0.031007751937984496,
#               'caught': 0.007751937984496124,
#               'put': 0.015503875968992248,
#               'threw': 0.007751937984496124,
#               'birds': 0.007751937984496124,
#               'suddenly': 0.007751937984496124,
#               'scurf': 0.007751937984496124,
#               'since': 0.015503875968992248,
#               'whats': 0.007751937984496124,
#               'many': 0.007751937984496124,
#               'blew': 0.007751937984496124,
#               'stamped': 0.007751937984496124,
#               'sometimes': 0.007751937984496124,
#               'some': 0.007751937984496124,
#               'then': 0.023255813953488372,
#               'came': 0.007751937984496124,
#               'this': 0.015503875968992248,
#               'politician': 0.007751937984496124,
#               'thatd': 0.007751937984496124,
#               'rode': 0.007751937984496124,
#               'if': 0.015503875968992248,
#               'from': 0.007751937984496124,
#               'i': 0.031007751937984496,
#               'he': 0.007751937984496124,
#               'full': 0.007751937984496124,
#               'experts': 0.007751937984496124,
#               'built': 0.007751937984496124,
#               'thats': 0.007751937984496124,
#               'spoke': 0.015503875968992248,
#               'anyway': 0.007751937984496124,
#               'had': 0.007751937984496124,
#               'how': 0.007751937984496124,
#               'taken': 0.007751937984496124,
#               'lie': 0.007751937984496124,
#               'left': 0.007751937984496124,
#               'stroked': 0.007751937984496124,
#               'a': 0.015503875968992248,
#               'me': 0.007751937984496124,
#               'between': 0.007751937984496124,
#               'wont': 0.007751937984496124,
#               'hes': 0.007751937984496124,
#               'his': 0.007751937984496124,
#               'nothing': 0.007751937984496124,
#               'better': 0.007751937984496124,
#               'kick': 0.007751937984496124,
#               'carried': 0.007751937984496124,
#               'thought': 0.007751937984496124,
#               'swollen': 0.015503875968992248,
#               'hold': 0.007751937984496124,
#               'all': 0.015503875968992248,
#               'fell': 0.007751937984496124,
#               'set': 0.007751937984496124,
#               'sit': 0.015503875968992248,
#               'bring': 0.007751937984496124,
#               'push': 0.007751937984496124,
#               'those': 0.015503875968992248,
#               'sproutlands': 0.007751937984496124,
#               'perhaps': 0.015503875968992248,
#               'see': 0.007751937984496124,
#               'dangle': 0.007751937984496124,
#               'disappeared': 0.007751937984496124,
#               'below': 0.007751937984496124,
#               'what': 0.007751937984496124,
#               'come': 0.007751937984496124,
#               'begin': 0.007751937984496124,
#               'build': 0.007751937984496124,
#               'in': 0.015503875968992248,
#               'theres': 0.007751937984496124,
#               'stifling': 0.007751937984496124,
#               'got': 0.007751937984496124,
#               'lift': 0.007751937984496124,
#               'give': 0.007751937984496124,
#               'fight': 0.007751937984496124,
#               'such': 0.007751937984496124,
#               'moon': 0.007751937984496124,
#               'jupiter': 0.007751937984496124,
#               'save': 0.007751937984496124,
#               'nation': 0.007751937984496124,
#               'though': 0.007751937984496124,
#               'now': 0.007751937984496124,
#               'wheres': 0.007751937984496124,
#               'shell': 0.007751937984496124,
#               'no': 0.007751937984496124,
#               'end': 0.007751937984496124,
#               'after': 0.007751937984496124,
#               'we': 0.007751937984496124,
#               'like': 0.007751937984496124,
#               'youre': 0.007751937984496124,
#               'turn': 0.007751937984496124,
#               'not': 0.007751937984496124,
#               'last': 0.007751937984496124}),
#  'to': defaultdict(int,
#              {'where': 0.02,
#               'watch': 0.04,
#               'stop': 0.02,
#               'ask': 0.02,
#               'say': 0.04,
#               'carry': 0.02,
#               'think': 0.02,
#               'make': 0.12,
#               'everything': 0.02,
#               'spare': 0.02,
#               'see': 0.1,
#               'turn': 0.02,
#               'undo': 0.02,
#               'let': 0.02,
#               'go': 0.02,
#               'shut': 0.02,
#               'bring': 0.02,
#               'entertain': 0.02,
#               'find': 0.02,
#               'send': 0.02,
#               'such': 0.02,
#               'wonder': 0.02,
#               'no': 0.02,
#               'tell': 0.02,
#               'stand': 0.02,
#               'reconnoitre': 0.02,
#               'set': 0.02,
#               'blow': 0.02,
#               'ridgely': 0.02,
#               'the': 0.04,
#               'curl': 0.02,
#               'call': 0.02,
#               'which': 0.02,
#               'be': 0.02,
#               'drag': 0.02,
#               'come': 0.02,
#               'live': 0.02,
#               'break': 0.02}),
#  'then': defaultdict(int,
#              {'took': 0.08333333333333333,
#               'leaf': 0.08333333333333333,
#               'shook': 0.08333333333333333,
#               'that': 0.08333333333333333,
#               'he': 0.08333333333333333,
#               'ran': 0.08333333333333333,
#               'we': 0.08333333333333333,
#               'i': 0.08333333333333333,
#               'make': 0.08333333333333333,
#               'for': 0.08333333333333333,
#               'cane': 0.08333333333333333,
#               'its': 0.08333333333333333}),
#  'because': defaultdict(int, {'it': 1.0}),
#  'though': defaultdict(int,
#              {'as': 0.14285714285714285,
#               'slight': 0.14285714285714285,
#               'what': 0.2857142857142857,
#               'not': 0.14285714285714285,
#               'strange': 0.14285714285714285,
#               'set': 0.14285714285714285}),
#  'had': defaultdict(int,
#              {'worn': 0.25, 'spilled': 0.25, 'been': 0.25, 'checked': 0.25}),
#  'in': defaultdict(int,
#              {'leaves': 0.034482758620689655,
#               'front': 0.10344827586206896,
#               'the': 0.034482758620689655,
#               'every': 0.06896551724137931,
#               'winter': 0.034482758620689655,
#               'warren': 0.034482758620689655,
#               'wentworth': 0.034482758620689655,
#               'dalton': 0.034482758620689655,
#               'eightyfive': 0.034482758620689655,
#               'dust': 0.034482758620689655,
#               'virgin': 0.034482758620689655,
#               'time': 0.034482758620689655,
#               'one': 0.06896551724137931,
#               'snow': 0.034482758620689655,
#               'its': 0.034482758620689655,
#               'summer': 0.034482758620689655,
#               'going': 0.034482758620689655,
#               'an': 0.034482758620689655,
#               'a': 0.034482758620689655,
#               'rain': 0.06896551724137931,
#               'that': 0.06896551724137931,
#               'separate': 0.034482758620689655,
#               'ways': 0.034482758620689655}),
#  'oh': defaultdict(int, {'i': 0.25, 'if': 0.5, 'thats': 0.25}),
#  'yet': defaultdict(int,
#              {'knowing': 0.3333333333333333,
#               'oh': 0.3333333333333333,
#               'does': 0.3333333333333333}),
#  'i': defaultdict(int,
#              {'doubted': 0.00847457627118644,
#               'shall': 0.01694915254237288,
#               'took': 0.00847457627118644,
#               'hold': 0.00847457627118644,
#               'think': 0.01694915254237288,
#               'have': 0.07627118644067797,
#               'end': 0.00847457627118644,
#               'cant': 0.0423728813559322,
#               'fancied': 0.00847457627118644,
#               'looked': 0.00847457627118644,
#               'was': 0.05084745762711865,
#               'paused': 0.00847457627118644,
#               'saw': 0.01694915254237288,
#               'wonder': 0.0423728813559322,
#               'could': 0.025423728813559324,
#               'guess': 0.03389830508474576,
#               'know': 0.03389830508474576,
#               'made': 0.01694915254237288,
#               'hope': 0.00847457627118644,
#               'might': 0.00847457627118644,
#               'thought': 0.025423728813559324,
#               'am': 0.00847457627118644,
#               'wont': 0.01694915254237288,
#               'want': 0.025423728813559324,
#               'vow': 0.00847457627118644,
#               'didnt': 0.01694915254237288,
#               'never': 0.025423728813559324,
#               'stay': 0.00847457627118644,
#               'can': 0.025423728813559324,
#               'staid': 0.00847457627118644,
#               'went': 0.01694915254237288,
#               'had': 0.05084745762711865,
#               'struck': 0.00847457627118644,
#               'sat': 0.00847457627118644,
#               'listened': 0.00847457627118644,
#               'pushed': 0.00847457627118644,
#               'wanted': 0.01694915254237288,
#               'heard': 0.00847457627118644,
#               'promised': 0.00847457627118644,
#               'mean': 0.025423728813559324,
#               'dont': 0.03389830508474576,
#               'verified': 0.00847457627118644,
#               'judged': 0.00847457627118644,
#               'only': 0.01694915254237288,
#               'idled': 0.00847457627118644,
#               'may': 0.00847457627118644,
#               'let': 0.025423728813559324,
#               'should': 0.00847457627118644,
#               'like': 0.00847457627118644,
#               'turned': 0.00847457627118644,
#               'often': 0.00847457627118644,
#               'name': 0.00847457627118644,
#               'stole': 0.00847457627118644,
#               'walked': 0.00847457627118644,
#               'help': 0.00847457627118644,
#               'tell': 0.00847457627118644,
#               'hate': 0.00847457627118644,
#               'blame': 0.00847457627118644,
#               'take': 0.00847457627118644,
#               'suppose': 0.00847457627118644}),
#  'somewhere': defaultdict(int, {'ages': 1.0}),
#  'whose': defaultdict(int, {'woods': 0.5, 'shoes': 0.5}),
#  'his': defaultdict(int,
#              {'house': 0.14285714285714285,
#               'lantern': 0.14285714285714285,
#               'wild': 0.14285714285714285,
#               'journey': 0.14285714285714285,
#               'neck': 0.14285714285714285,
#               'names': 0.14285714285714285,
#               'small': 0.14285714285714285}),
#  'he': defaultdict(int,
#              {'will': 0.029411764705882353,
#               'gives': 0.029411764705882353,
#               'saw': 0.029411764705882353,
#               'gained': 0.029411764705882353,
#               'never': 0.08823529411764706,
#               'reeled': 0.029411764705882353,
#               'fell': 0.029411764705882353,
#               'looked': 0.029411764705882353,
#               'couldnt': 0.029411764705882353,
#               'bowed': 0.029411764705882353,
#               'steered': 0.029411764705882353,
#               'want': 0.029411764705882353,
#               'stood': 0.029411764705882353,
#               'said': 0.08823529411764706,
#               'dont': 0.029411764705882353,
#               'guessed': 0.029411764705882353,
#               'read': 0.029411764705882353,
#               'broke': 0.029411764705882353,
#               'always': 0.029411764705882353,
#               'thinks': 0.058823529411764705,
#               'must': 0.029411764705882353,
#               'wont': 0.029411764705882353,
#               'cant': 0.029411764705882353,
#               'gets': 0.029411764705882353,
#               'and': 0.029411764705882353,
#               'hoed': 0.029411764705882353,
#               'knows': 0.029411764705882353,
#               'manages': 0.029411764705882353,
#               'can': 0.029411764705882353}),
#  'my': defaultdict(int,
#              {'little': 0.14285714285714285,
#               'french': 0.14285714285714285,
#               'first': 0.14285714285714285,
#               'mother': 0.14285714285714285,
#               'window': 0.14285714285714285,
#               'fingers': 0.14285714285714285,
#               'but': 0.14285714285714285}),
#  'between': defaultdict(int,
#              {'the': 0.6666666666666666, 'me': 0.3333333333333333}),
#  'the': defaultdict(int,
#              {'darkest': 0.012195121951219513,
#               'only': 0.012195121951219513,
#               'woods': 0.012195121951219513,
#               'headless': 0.012195121951219513,
#               'whir': 0.012195121951219513,
#               'hillside': 0.012195121951219513,
#               'swarm': 0.012195121951219513,
#               'moon': 0.012195121951219513,
#               'spell': 0.012195121951219513,
#               'thought': 0.012195121951219513,
#               'figures': 0.012195121951219513,
#               'arthur': 0.024390243902439025,
#               'tote': 0.012195121951219513,
#               'poor': 0.012195121951219513,
#               'crib': 0.012195121951219513,
#               'smarty': 0.012195121951219513,
#               'mica': 0.012195121951219513,
#               'early': 0.012195121951219513,
#               'mountain': 0.012195121951219513,
#               'old': 0.012195121951219513,
#               'two': 0.012195121951219513,
#               'outside': 0.012195121951219513,
#               'poetess': 0.024390243902439025,
#               'posies': 0.012195121951219513,
#               'attic': 0.024390243902439025,
#               'small': 0.012195121951219513,
#               'seal': 0.012195121951219513,
#               'night': 0.012195121951219513,
#               'board': 0.012195121951219513,
#               'way': 0.024390243902439025,
#               'bulkhead': 0.012195121951219513,
#               'cellar': 0.012195121951219513,
#               'door': 0.012195121951219513,
#               'faintest': 0.012195121951219513,
#               'fingerpieces': 0.012195121951219513,
#               'kitchen': 0.012195121951219513,
#               'uncommonly': 0.012195121951219513,
#               'steps': 0.012195121951219513,
#               'least': 0.012195121951219513,
#               'rural': 0.012195121951219513,
#               'west': 0.012195121951219513,
#               'breath': 0.012195121951219513,
#               'origin': 0.012195121951219513,
#               'past': 0.012195121951219513,
#               'young': 0.012195121951219513,
#               'second': 0.012195121951219513,
#               'town': 0.012195121951219513,
#               'situation': 0.012195121951219513,
#               'sound': 0.012195121951219513,
#               'indians': 0.012195121951219513,
#               'nose': 0.012195121951219513,
#               'meaning': 0.012195121951219513,
#               'voices': 0.024390243902439025,
#               'life': 0.012195121951219513,
#               'hours': 0.012195121951219513,
#               'road': 0.012195121951219513,
#               'ledges': 0.012195121951219513,
#               'chisel': 0.012195121951219513,
#               'height': 0.012195121951219513,
#               'playthings': 0.012195121951219513,
#               'sun': 0.012195121951219513,
#               'frogs': 0.012195121951219513,
#               'minute': 0.012195121951219513,
#               'same': 0.012195121951219513,
#               'snow': 0.012195121951219513,
#               'tower': 0.012195121951219513,
#               'sigmas': 0.012195121951219513,
#               'cosmic': 0.012195121951219513,
#               'utmost': 0.012195121951219513,
#               'surest': 0.012195121951219513,
#               'strains': 0.012195121951219513,
#               'rights': 0.012195121951219513,
#               'smell': 0.012195121951219513,
#               'little': 0.012195121951219513,
#               'upper': 0.012195121951219513,
#               'crystal': 0.012195121951219513,
#               'man': 0.012195121951219513}),
#  'of': defaultdict(int,
#              {'easy': 0.034482758620689655,
#               'the': 0.20689655172413793,
#               'wire': 0.034482758620689655,
#               'getting': 0.034482758620689655,
#               'arthur': 0.034482758620689655,
#               'having': 0.034482758620689655,
#               'door': 0.034482758620689655,
#               'his': 0.034482758620689655,
#               'what': 0.034482758620689655,
#               'here': 0.034482758620689655,
#               'stranger': 0.034482758620689655,
#               'an': 0.06896551724137931,
#               'castles': 0.034482758620689655,
#               'youthful': 0.034482758620689655,
#               'detail': 0.034482758620689655,
#               'being': 0.034482758620689655,
#               'country': 0.034482758620689655,
#               'dust': 0.034482758620689655,
#               'earthly': 0.034482758620689655,
#               'constellations': 0.034482758620689655,
#               'yawning': 0.034482758620689655,
#               'once': 0.034482758620689655,
#               'both': 0.034482758620689655}),
#  'but': defaultdict(int,
#              {'i': 0.1568627450980392,
#               'if': 0.058823529411764705,
#               'only': 0.0392156862745098,
#               'not': 0.058823529411764705,
#               'a': 0.0196078431372549,
#               'though': 0.0392156862745098,
#               'saved': 0.0196078431372549,
#               'now': 0.0196078431372549,
#               'most': 0.0196078431372549,
#               'everybody': 0.0196078431372549,
#               'smith': 0.0196078431372549,
#               'you': 0.0392156862745098,
#               'welcomed': 0.0196078431372549,
#               'all': 0.0196078431372549,
#               'it': 0.0196078431372549,
#               'we': 0.0196078431372549,
#               'wont': 0.0196078431372549,
#               'left': 0.0196078431372549,
#               'tonight': 0.0196078431372549,
#               'rain': 0.0196078431372549,
#               'the': 0.0196078431372549,
#               'wait': 0.0196078431372549,
#               'why': 0.0392156862745098,
#               'theres': 0.0196078431372549,
#               'dont': 0.0196078431372549,
#               'please': 0.0196078431372549,
#               'me': 0.0196078431372549,
#               'where': 0.0196078431372549,
#               'get': 0.0196078431372549,
#               'feared': 0.0196078431372549,
#               'being': 0.0196078431372549,
#               'when': 0.0392156862745098,
#               'estelle': 0.0196078431372549,
#               'its': 0.0196078431372549,
#               'whats': 0.0196078431372549}),
#  'some': defaultdict(int,
#              {'say': 0.4, 'cried': 0.2, 'zealous': 0.2, 'shattered': 0.2}),
#  'from': defaultdict(int,
#              {'what': 0.1,
#               'the': 0.4,
#               'that': 0.1,
#               'my': 0.1,
#               'north': 0.1,
#               'stumps': 0.1,
#               'sleeping': 0.1}),
#  'is': defaultdict(int,
#              {'also': 0.2,
#               'sadder': 0.2,
#               'back': 0.2,
#               'supposed': 0.2,
#               'this': 0.2}),
#  'natures': defaultdict(int, {'first': 1.0}),
#  'her': defaultdict(int, {'hardest': 0.5, 'early': 0.5}),
#  'so': defaultdict(int,
#              {'eden': 0.07692307692307693,
#               'dawn': 0.07692307692307693,
#               'halfway': 0.07692307692307693,
#               'now': 0.07692307692307693,
#               'they': 0.07692307692307693,
#               'as': 0.15384615384615385,
#               'suddenly': 0.07692307692307693,
#               'that': 0.15384615384615385,
#               'lying': 0.07692307692307693,
#               'cant': 0.07692307692307693,
#               'near': 0.07692307692307693}),
#  'nothing': defaultdict(int, {'gold': 0.5, 'would': 0.5}),
#  'when': defaultdict(int,
#              {'far': 0.1111111111111111,
#               'i': 0.4444444444444444,
#               'the': 0.1111111111111111,
#               'there': 0.1111111111111111,
#               'shoeing': 0.1111111111111111,
#               'all': 0.1111111111111111}),
#  'came': defaultdict(int, {'over': 1.0}),
#  'one': defaultdict(int,
#              {'luminary': 0.09090909090909091,
#               'lizard': 0.09090909090909091,
#               'of': 0.09090909090909091,
#               'and': 0.09090909090909091,
#               'ought': 0.09090909090909091,
#               'mustnt': 0.09090909090909091,
#               'down': 0.18181818181818182,
#               'thing': 0.09090909090909091,
#               'level': 0.18181818181818182}),
#  'proclaimed': defaultdict(int, {'the': 1.0}),
#  'smoothlaid': defaultdict(int, {'like': 1.0}),
#  'half': defaultdict(int,
#              {'closes': 0.3333333333333333,
#               'looking': 0.3333333333333333,
#               'of': 0.3333333333333333}),
#  'up': defaultdict(int,
#              {'from': 0.14285714285714285,
#               'at': 0.14285714285714285,
#               'where': 0.14285714285714285,
#               'attic': 0.2857142857142857,
#               'one': 0.14285714285714285,
#               'to': 0.14285714285714285}),
#  'a': defaultdict(int,
#              {'tree': 0.06666666666666667,
#               'voice': 0.03333333333333333,
#               'swamp': 0.03333333333333333,
#               'barkless': 0.03333333333333333,
#               'hole': 0.03333333333333333,
#               'leak': 0.03333333333333333,
#               'cliff': 0.03333333333333333,
#               'likeness': 0.03333333333333333,
#               'whole': 0.03333333333333333,
#               'small': 0.03333333333333333,
#               'moment': 0.03333333333333333,
#               'bird': 0.03333333333333333,
#               'single': 0.03333333333333333,
#               'brush': 0.03333333333333333,
#               'piercing': 0.03333333333333333,
#               'governor': 0.03333333333333333,
#               'rockstrewn': 0.03333333333333333,
#               'bead': 0.03333333333333333,
#               'little': 0.03333333333333333,
#               'shelfs': 0.03333333333333333,
#               'chimney': 0.03333333333333333,
#               'few': 0.03333333333333333,
#               'brook': 0.03333333333333333,
#               'broken': 0.03333333333333333,
#               'note': 0.03333333333333333,
#               'friend': 0.03333333333333333,
#               'bill': 0.03333333333333333,
#               'winter': 0.03333333333333333,
#               'featherhammer': 0.03333333333333333}),
#  'disturbed': defaultdict(int, {'i': 0.5, 'the': 0.5}),
#  'comes': defaultdict(int, {'softly': 1.0}),
#  'by': defaultdict(int,
#              {'picking': 0.09090909090909091,
#               'doubling': 0.09090909090909091,
#               'all': 0.09090909090909091,
#               'its': 0.09090909090909091,
#               'road': 0.09090909090909091,
#               'having': 0.09090909090909091,
#               'being': 0.09090909090909091,
#               'flying': 0.09090909090909091,
#               'a': 0.09090909090909091,
#               'now': 0.09090909090909091,
#               'tying': 0.09090909090909091}),
#  'if': defaultdict(int,
#              {'all': 0.08333333333333333,
#               'i': 0.25,
#               'some': 0.08333333333333333,
#               'anyone': 0.08333333333333333,
#               'you': 0.08333333333333333,
#               'seen': 0.08333333333333333,
#               'the': 0.16666666666666666,
#               'he': 0.08333333333333333,
#               'hes': 0.08333333333333333}),
#  'were': defaultdict(int, {'not': 1.0}),
#  'ten': defaultdict(int, {'million': 1.0}),
#  'as': defaultdict(int,
#              {'often': 0.14285714285714285,
#               'if': 0.14285714285714285,
#               'standing': 0.07142857142857142,
#               'long': 0.07142857142857142,
#               'we': 0.07142857142857142,
#               'gilt': 0.07142857142857142,
#               'one': 0.07142857142857142,
#               'pale': 0.07142857142857142,
#               'for': 0.07142857142857142,
#               'winds': 0.07142857142857142,
#               'married': 0.07142857142857142,
#               'near': 0.07142857142857142}),
#  'it': defaultdict(int,
#              {'looks': 0.09090909090909091,
#               'takes': 0.045454545454545456,
#               'must': 0.09090909090909091,
#               'want': 0.045454545454545456,
#               'doesnt': 0.045454545454545456,
#               'wasnt': 0.045454545454545456,
#               'was': 0.09090909090909091,
#               'took': 0.045454545454545456,
#               'ought': 0.09090909090909091,
#               'rests': 0.045454545454545456,
#               'has': 0.09090909090909091,
#               'in': 0.045454545454545456,
#               'will': 0.045454545454545456,
#               'seems': 0.045454545454545456,
#               'makes': 0.045454545454545456,
#               'lifts': 0.09090909090909091}),
#  'lifted': defaultdict(int, {'the': 1.0}),
#  'she': defaultdict(int,
#              {'has': 0.058823529411764705,
#               'thinks': 0.11764705882352941,
#               'might': 0.058823529411764705,
#               'never': 0.058823529411764705,
#               'was': 0.058823529411764705,
#               'could': 0.058823529411764705,
#               'hadnt': 0.058823529411764705,
#               'swept': 0.058823529411764705,
#               'made': 0.058823529411764705,
#               'should': 0.058823529411764705,
#               'does': 0.058823529411764705,
#               'seems': 0.058823529411764705,
#               'wants': 0.058823529411764705,
#               'wont': 0.11764705882352941,
#               'raised': 0.058823529411764705}),
#  'transfixed': defaultdict(int, {'on': 1.0}),
#  'across': defaultdict(int, {'each': 1.0}),
#  'was': defaultdict(int,
#              {'wrought': 0.1111111111111111,
#               'arthur': 0.1111111111111111,
#               'singing': 0.1111111111111111,
#               'only': 0.1111111111111111,
#               'a': 0.1111111111111111,
#               'something': 0.1111111111111111,
#               'hot': 0.1111111111111111,
#               'counting': 0.1111111111111111,
#               'it': 0.1111111111111111}),
#  'once': defaultdict(int, {'on': 0.5, 'more': 0.5}),
#  'that': defaultdict(int,
#              {'had': 0.06896551724137931,
#               'everyone': 0.034482758620689655,
#               'cased': 0.034482758620689655,
#               'is': 0.034482758620689655,
#               'even': 0.034482758620689655,
#               'as': 0.034482758620689655,
#               'they': 0.034482758620689655,
#               'was': 0.034482758620689655,
#               'happens': 0.034482758620689655,
#               'overflowing': 0.034482758620689655,
#               'doesnt': 0.034482758620689655,
#               'need': 0.034482758620689655,
#               'theres': 0.034482758620689655,
#               'made': 0.034482758620689655,
#               'now': 0.034482758620689655,
#               'turned': 0.034482758620689655,
#               'the': 0.034482758620689655,
#               'a': 0.034482758620689655,
#               'you': 0.034482758620689655,
#               'there': 0.06896551724137931,
#               'are': 0.034482758620689655,
#               'no': 0.034482758620689655,
#               'braced': 0.034482758620689655,
#               'sends': 0.034482758620689655,
#               'struck': 0.034482758620689655,
#               'much': 0.034482758620689655,
#               'isnt': 0.034482758620689655}),
#  'looked': defaultdict(int, {'up': 1.0}),
#  'stood': defaultdict(int, {'over': 1.0}),
#  'you': defaultdict(int,
#              {'here': 0.025,
#               'can': 0.075,
#               'said': 0.05,
#               'wont': 0.025,
#               'mean': 0.075,
#               'dont': 0.075,
#               'must': 0.1,
#               'and': 0.025,
#               'know': 0.05,
#               'riddle': 0.025,
#               'take': 0.025,
#               'look': 0.025,
#               'never': 0.05,
#               'poor': 0.025,
#               'will': 0.05,
#               'want': 0.025,
#               'see': 0.05,
#               'seem': 0.025,
#               'think': 0.025,
#               'let': 0.025,
#               'couldnt': 0.025,
#               'cant': 0.025,
#               'say': 0.025,
#               'spoke': 0.025,
#               'ought': 0.025,
#               'neednt': 0.025}),
#  'me': defaultdict(int, {'im': 1.0}),
#  'sometimes': defaultdict(int, {'i': 0.25, 'he': 0.5, 'as': 0.25}),
#  'brown': defaultdict(int, {'lived': 0.5, 'makes': 0.5}),
#  'cross': defaultdict(int, {'lots': 1.0}),
#  'describing': defaultdict(int, {'rings': 1.0}),
#  'got': defaultdict(int, {'him': 1.0}),
#  'walls': defaultdict(int, {'were': 1.0}),
#  'like': defaultdict(int,
#              {'wings': 0.125,
#               'no': 0.125,
#               'a': 0.25,
#               'wild': 0.125,
#               'profanation': 0.125,
#               'graveyard': 0.125,
#               'some': 0.125}),
#  'upon': defaultdict(int, {'his': 0.5, 'a': 0.5}),
#  'with': defaultdict(int,
#              {'no': 0.05555555555555555,
#               'all': 0.1111111111111111,
#               'stone': 0.05555555555555555,
#               'furs': 0.05555555555555555,
#               'the': 0.2222222222222222,
#               'our': 0.05555555555555555,
#               'sounds': 0.05555555555555555,
#               'clouds': 0.05555555555555555,
#               'a': 0.05555555555555555,
#               'his': 0.05555555555555555,
#               'flowers': 0.05555555555555555,
#               'half': 0.05555555555555555,
#               'whose': 0.05555555555555555,
#               'me': 0.05555555555555555}),
#  'faster': defaultdict(int, {'or': 1.0}),
#  'sitting': defaultdict(int, {'or': 1.0}),
#  'according': defaultdict(int, {'as': 1.0}),
#  'hes': defaultdict(int,
#              {'celebrating': 0.09090909090909091,
#               'so': 0.09090909090909091,
#               'after': 0.09090909090909091,
#               'groping': 0.09090909090909091,
#               'nothing': 0.09090909090909091,
#               'just': 0.09090909090909091,
#               'got': 0.09090909090909091,
#               'fiftyfive': 0.09090909090909091,
#               'given': 0.09090909090909091,
#               'fond': 0.09090909090909091,
#               'been': 0.09090909090909091}),
#  'or': defaultdict(int,
#              {'been': 0.09090909090909091,
#               'even': 0.09090909090909091,
#               'stained': 0.09090909090909091,
#               'like': 0.09090909090909091,
#               'else': 0.09090909090909091,
#               'a': 0.09090909090909091,
#               'i': 0.09090909090909091,
#               'it': 0.09090909090909091,
#               'creaking': 0.09090909090909091,
#               'some': 0.09090909090909091,
#               'old': 0.09090909090909091}),
#  'incredulous': defaultdict(int, {'of': 1.0}),
#  'well—i—be—': defaultdict(int, {'that': 1.0}),
#  'on': defaultdict(int,
#              {'motorcars': 0.09090909090909091,
#               'moosilauke': 0.09090909090909091,
#               'slippery': 0.09090909090909091,
#               'marshall': 0.09090909090909091,
#               'an': 0.09090909090909091,
#               'fathers': 0.09090909090909091,
#               'last': 0.09090909090909091,
#               'planets': 0.09090909090909091,
#               'his': 0.09090909090909091,
#               'something': 0.09090909090909091,
#               'some': 0.09090909090909091}),
#  'should': defaultdict(int, {'say': 0.5, 'take': 0.5}),
#  'yankees': defaultdict(int, {'are': 1.0}),
#  'dont': defaultdict(int,
#              {'think': 0.14285714285714285,
#               'donkeys': 0.14285714285714285,
#               'ask': 0.14285714285714285,
#               'make': 0.14285714285714285,
#               'be': 0.14285714285714285,
#               'the': 0.14285714285714285,
#               'build': 0.14285714285714285}),
#  'until': defaultdict(int, {'the': 0.5, 'id': 0.5}),
#  'after': defaultdict(int, {'the': 1.0}),
#  'not': defaultdict(int,
#              {'much': 0.15384615384615385,
#               'that': 0.07692307692307693,
#               'so': 0.07692307692307693,
#               'like': 0.07692307692307693,
#               'from': 0.07692307692307693,
#               'fireweed': 0.07692307692307693,
#               'bluebells': 0.07692307692307693,
#               'lupine': 0.07692307692307693,
#               'in': 0.15384615384615385,
#               'to': 0.07692307692307693,
#               'answering': 0.07692307692307693}),
#  'at': defaultdict(int,
#              {'that': 0.16666666666666666,
#               'having': 0.3333333333333333,
#               'least': 0.3333333333333333,
#               'ten': 0.16666666666666666}),
#  'no': defaultdict(int,
#              {'more': 0.16666666666666666,
#               'doubt': 0.08333333333333333,
#               'bird': 0.08333333333333333,
#               'fête': 0.08333333333333333,
#               'its': 0.08333333333333333,
#               'one': 0.25,
#               'i': 0.08333333333333333,
#               'matter': 0.08333333333333333,
#               'he': 0.08333333333333333}),
#  'ive': defaultdict(int,
#              {'kept': 0.25, 'never': 0.25, 'been': 0.25, 'got': 0.25}),
#  'while': defaultdict(int, {'i': 1.0}),
#  'bout': defaultdict(int, {'out': 1.0}),
#  'now': defaultdict(int,
#              {'that': 0.25, 'give': 0.25, 'lefts': 0.25, 'slowly': 0.25}),
#  'im': defaultdict(int,
#              {'going': 0.2,
#               'stark': 0.2,
#               'waiting': 0.2,
#               'getting': 0.2,
#               'sure': 0.2}),
#  'theyve': defaultdict(int, {'got': 1.0}),
#  'flattered': defaultdict(int, {'i': 1.0}),
#  'they': defaultdict(int,
#              {'dont': 0.05263157894736842,
#               'set': 0.05263157894736842,
#               'made': 0.05263157894736842,
#               'found': 0.05263157894736842,
#               'bad': 0.05263157894736842,
#               'simply': 0.05263157894736842,
#               'were': 0.15789473684210525,
#               'have': 0.05263157894736842,
#               'eddy': 0.05263157894736842,
#               'think': 0.05263157894736842,
#               'might': 0.05263157894736842,
#               'spoke': 0.15789473684210525,
#               'left': 0.10526315789473684,
#               'filled': 0.05263157894736842}),
#  'always': defaultdict(int, {'the': 1.0}),
#  'ill': defaultdict(int,
#              {'double': 0.1,
#               'tell': 0.3,
#               'find': 0.1,
#               'show': 0.2,
#               'hardly': 0.1,
#               'say': 0.1,
#               'talk': 0.1}),
#  'theyll': defaultdict(int, {'find': 1.0}),
#  'for': defaultdict(int,
#              {'hog': 0.14285714285714285,
#               'gods': 0.14285714285714285,
#               'a': 0.2857142857142857,
#               'god': 0.14285714285714285,
#               'helping': 0.14285714285714285,
#               'fifty': 0.14285714285714285}),
#  'couldnt': defaultdict(int, {'have': 0.5, 'one': 0.5}),
#  'voted': defaultdict(int, {'the': 1.0}),
#  'which': defaultdict(int,
#              {'wasnt': 0.3333333333333333,
#               'means': 0.3333333333333333,
#               'is': 0.3333333333333333}),
#  'their': defaultdict(int, {'arthur': 0.5, 'solemn': 0.5}),
#  'wentworth': defaultdict(int, {'and': 1.0}),
#  'only': defaultdict(int,
#              {'i': 0.2, 'bewitched': 0.2, 'to': 0.2, 'one': 0.2, 'too': 0.2}),
#  'rights': defaultdict(int, {'right': 1.0}),
#  'has': defaultdict(int, {'always': 0.5, 'been': 0.5}),
#  'itd': defaultdict(int, {'make': 1.0}),
#  'said': defaultdict(int, {'that': 1.0}),
#  'hed': defaultdict(int, {'bet': 0.2, 'like': 0.2, 'say': 0.4, 'need': 0.2}),
#  'all': defaultdict(int,
#              {'four': 0.125,
#               'is': 0.25,
#               'the': 0.125,
#               'claiming': 0.125,
#               'fresh': 0.125,
#               'that': 0.125,
#               'we': 0.125}),
#  'gnaws': defaultdict(int, {'in': 1.0}),
#  'last': defaultdict(int, {'night': 1.0}),
#  'over': defaultdict(int,
#              {'the': 0.4, 'so': 0.2, 'descended': 0.2, 'back': 0.2}),
#  'well': defaultdict(int, {'i': 0.2, 'take': 0.2, 'if': 0.2, 'then': 0.4}),
#  'off': defaultdict(int, {'from': 0.5, 'here': 0.5}),
#  'old': defaultdict(int, {'davis': 0.5, 'as': 0.5}),
#  'thered': defaultdict(int, {'been': 1.0}),
#  'someday': defaultdict(int, {'i': 1.0}),
#  'huh': defaultdict(int, {'that': 1.0}),
#  'lets': defaultdict(int,
#              {'talk': 0.3333333333333333,
#               'go': 0.3333333333333333,
#               'trap': 0.3333333333333333}),
#  'youve': defaultdict(int, {'lost': 1.0}),
#  'can': defaultdict(int, {'do': 1.0}),
#  'be': defaultdict(int,
#              {'dragged': 0.3333333333333333,
#               'ready': 0.3333333333333333,
#               'good': 0.3333333333333333}),
#  'we': defaultdict(int,
#              {'made': 0.06666666666666667,
#               'came': 0.13333333333333333,
#               'may': 0.06666666666666667,
#               'struck': 0.06666666666666667,
#               'trod': 0.06666666666666667,
#               'were': 0.06666666666666667,
#               'have': 0.26666666666666666,
#               'know': 0.06666666666666667,
#               'can': 0.06666666666666667,
#               'wouldnt': 0.06666666666666667,
#               'fence': 0.06666666666666667}),
#  'ascending': defaultdict(int, {'to': 1.0}),
#  'sos': defaultdict(int, {'everything': 0.5, 'to': 0.5}),
#  'hadnt': defaultdict(int, {'you': 1.0}),
#  'look': defaultdict(int, {'here': 1.0}),
#  'what': defaultdict(int,
#              {'signify': 0.07142857142857142,
#               'it': 0.14285714285714285,
#               'bones': 0.07142857142857142,
#               'do': 0.21428571428571427,
#               'i': 0.14285714285714285,
#               'is': 0.07142857142857142,
#               'he': 0.07142857142857142,
#               'childishness': 0.07142857142857142,
#               'are': 0.07142857142857142,
#               'well': 0.07142857142857142}),
#  'however': defaultdict(int, {'natural': 0.5, 'far': 0.5}),
#  'come': defaultdict(int,
#              {'straight': 0.25, 'down': 0.25, 'here': 0.25, 'out': 0.25}),
#  'its': defaultdict(int,
#              {'hell': 0.047619047619047616,
#               'not': 0.09523809523809523,
#               'sometimes': 0.047619047619047616,
#               'the': 0.047619047619047616,
#               'to': 0.047619047619047616,
#               'harmless': 0.047619047619047616,
#               'coming': 0.047619047619047616,
#               'with': 0.047619047619047616,
#               'looking': 0.047619047619047616,
#               'raining': 0.047619047619047616,
#               'as': 0.14285714285714285,
#               'going': 0.047619047619047616,
#               'hands': 0.047619047619047616,
#               'whirling': 0.047619047619047616,
#               'you': 0.047619047619047616,
#               'gone': 0.047619047619047616,
#               'too': 0.047619047619047616,
#               'different': 0.047619047619047616}),
#  'perhaps': defaultdict(int, {'to': 0.5, 'you': 0.5}),
#  'excuse': defaultdict(int, {'me': 1.0}),
#  'who': defaultdict(int,
#              {'used': 0.16666666666666666,
#               'failed': 0.16666666666666666,
#               'only': 0.16666666666666666,
#               'may': 0.16666666666666666,
#               'are': 0.16666666666666666,
#               'wants': 0.16666666666666666}),
#  'life': defaultdict(int, {'long': 1.0}),
#  'our': defaultdict(int, {'business': 0.5, 'hens': 0.5}),
#  'through': defaultdict(int, {'a': 0.5, 'everything': 0.5}),
#  'except': defaultdict(int, {'it': 0.5, 'always': 0.5}),
#  'books': defaultdict(int, {'i': 0.5, 'were': 0.5}),
#  'where': defaultdict(int,
#              {'driven': 0.125,
#               'did': 0.125,
#               'shall': 0.125,
#               'the': 0.125,
#               'were': 0.125,
#               'is': 0.125,
#               'conies': 0.125,
#               'he': 0.125}),
#  'enough': defaultdict(int, {'to': 1.0}),
#  'unfortunately': defaultdict(int, {'all': 1.0}),
#  'boys': defaultdict(int, {'and': 1.0}),
#  'shatter': defaultdict(int, {'it': 1.0}),
#  'how': defaultdict(int,
#              {'had': 0.16666666666666666,
#               'could': 0.16666666666666666,
#               'shall': 0.3333333333333333,
#               'do': 0.16666666666666666,
#               'are': 0.16666666666666666}),
#  'till': defaultdict(int, {'it': 0.5, 'well': 0.5}),
#  'tried': defaultdict(int, {'to': 1.0}),
#  'having': defaultdict(int, {'tried': 1.0}),
#  'here': defaultdict(int,
#              {'were': 0.25, 'are': 0.25, 'he': 0.25, 'loveless': 0.25}),
#  'take': defaultdict(int,
#              {'one': 0.3333333333333333,
#               'all': 0.3333333333333333,
#               'it': 0.3333333333333333}),
#  'why': defaultdict(int,
#              {'not': 0.6666666666666666, 'do': 0.3333333333333333}),
#  'goodlooking': defaultdict(int, {'books': 1.0}),
#  'both': defaultdict(int, {'either': 1.0}),
#  'legitimately': defaultdict(int, {'my': 1.0}),
#  'there': defaultdict(int,
#              {'wasnt': 0.16666666666666666,
#               'aint': 0.16666666666666666,
#               'is': 0.3333333333333333,
#               'was': 0.3333333333333333}),
#  'alias': defaultdict(int, {'john': 1.0}),
#  'about': defaultdict(int, {'where': 1.0}),
#  'theres': defaultdict(int, {'not': 1.0}),
#  'give': defaultdict(int, {'a': 1.0}),
#  'thrown': defaultdict(int, {'away': 1.0}),
#  'unless': defaultdict(int, {'it': 1.0}),
#  'than': defaultdict(int, {'lifes': 0.5, 'folks': 0.5}),
#  'behind': defaultdict(int, {'the': 1.0}),
#  'mother': defaultdict(int,
#              {'folks': 0.14285714285714285,
#               'and': 0.14285714285714285,
#               'bones': 0.14285714285714285,
#               'well': 0.14285714285714285,
#               'the': 0.14285714285714285,
#               'we': 0.14285714285714285,
#               'yes': 0.14285714285714285}),
#  'summoning': defaultdict(int, {'spirits': 1.0}),
#  'whos': defaultdict(int, {'got': 1.0}),
#  'son': defaultdict(int,
#              {'mother': 0.1111111111111111,
#               'you': 0.2222222222222222,
#               'but': 0.1111111111111111,
#               'it': 0.1111111111111111,
#               'we': 0.2222222222222222,
#               'knows': 0.1111111111111111,
#               'looks': 0.1111111111111111}),
#  'rather': defaultdict(int, {'than': 1.0}),
#  'tell': defaultdict(int, {'you': 0.5, 'me': 0.5}),
#  'yes': defaultdict(int,
#              {'theres': 0.125,
#               'stark': 0.125,
#               'what': 0.125,
#               'its': 0.125,
#               'you': 0.125,
#               'whats': 0.125,
#               'but': 0.125,
#               'i': 0.125}),
#  'against': defaultdict(int, {'the': 1.0}),
#  'halting': defaultdict(int, {'perplexed': 1.0}),
#  'another': defaultdict(int, {'from': 1.0}),
#  'right': defaultdict(int, {'past': 1.0}),
#  'father': defaultdict(int, {'had': 1.0}),
#  'especially': defaultdict(int, {'in': 1.0}),
#  'might': defaultdict(int, {'just': 1.0}),
#  'toffile': defaultdict(int,
#              {'had': 0.2, 'for': 0.2, 'agreed': 0.2, 'get': 0.2, 'if': 0.2}),
#  'struck': defaultdict(int, {'the': 1.0}),
#  'began': defaultdict(int, {'the': 1.0}),
#  'waiting': defaultdict(int, {'for': 1.0}),
#  'flashed': defaultdict(int, {'out': 1.0}),
#  'smoke': defaultdict(int, {'rolled': 1.0}),
#  'hand': defaultdict(int, {'me': 1.0}),
#  'stillgoing': defaultdict(int, {'every': 1.0}),
#  'before': defaultdict(int, {'i': 0.5, 'its': 0.5}),
#  'almost': defaultdict(int, {'the': 1.0}),
#  'quick': defaultdict(int, {'i': 1.0}),
#  'let': defaultdict(int, {'them': 0.5, 'people': 0.5}),
#  'brushing': defaultdict(int, {'their': 1.0}),
#  'thats': defaultdict(int, {'what': 0.2, 'a': 0.4, 'no': 0.2, 'his': 0.2}),
#  '2o3': defaultdict(int, {'let': 1.0}),
#  'wed': defaultdict(int, {'kept': 1.0}),
#  'could': defaultdict(int, {'tell': 1.0}),
#  'among': defaultdict(int,
#              {'the': 0.6666666666666666, 'unearthed': 0.3333333333333333}),
#  'ancestral': defaultdict(int, {'memories': 1.0}),
#  'someone': defaultdict(int, {'had': 1.0}),
#  'thence': defaultdict(int, {'they': 1.0}),
#  'made': defaultdict(int, {'shift': 1.0}),
#  'are': defaultdict(int, {'there': 1.0}),
#  'strolled': defaultdict(int, {'thither': 1.0}),
#  'anyone': defaultdict(int, {'else': 0.5, 'upon': 0.5}),
#  'this': defaultdict(int,
#              {'was': 0.3333333333333333,
#               'he': 0.16666666666666666,
#               'is': 0.3333333333333333,
#               'eden': 0.16666666666666666}),
#  'provision': defaultdict(int, {'there': 1.0}),
#  'drawn': defaultdict(int, {'on': 0.5, 'into': 0.5}),
#  'stark': defaultdict(int, {'he': 1.0}),
#  'would': defaultdict(int, {'have': 0.5, 'name': 0.5}),
#  'several': defaultdict(int, {'times': 1.0}),
#  'under': defaultdict(int, {'the': 0.5, 'a': 0.5}),
#  'just': defaultdict(int, {'so': 1.0}),
#  'does': defaultdict(int, {'the': 0.5, 'it': 0.5}),
#  'bowed': defaultdict(int, {'outward': 1.0}),
#  'beyond': defaultdict(int, {'where': 0.5, 'which': 0.5}),
#  'four': defaultdict(int, {'cards': 1.0}),
#  'dyou': defaultdict(int, {'know': 1.0}),
#  'studying': defaultdict(int, {'genealogy': 1.0}),
#  'first': defaultdict(int, {'let': 0.5, 'theres': 0.5}),
#  'bless': defaultdict(int, {'you': 1.0}),
#  'shes': defaultdict(int,
#              {'after': 0.3333333333333333,
#               'in': 0.3333333333333333,
#               'let': 0.3333333333333333}),
#  'heres': defaultdict(int, {'hoping': 1.0}),
#  'making': defaultdict(int, {'allowance': 1.0}),
#  'see': defaultdict(int, {'that': 1.0}),
#  'strung': defaultdict(int, {'on': 1.0}),
#  'something': defaultdict(int, {'i': 0.5, 'went': 0.5}),
#  'speaking': defaultdict(int, {'or': 1.0}),
#  'strangely': defaultdict(int, {'its': 1.0}),
#  'call': defaultdict(int, {'her': 1.0}),
#  'nor': defaultdict(int,
#              {'grannys': 0.25, 'never': 0.25, 'need': 0.25, 'want': 0.25}),
#  'nine': defaultdict(int, {'times': 1.0}),
#  'anything': defaultdict(int, {'she': 1.0}),
#  'folks': defaultdict(int, {'in': 1.0}),
#  'mebbe': defaultdict(int, {'im': 1.0}),
#  'more': defaultdict(int, {'of': 1.0}),
#  'will': defaultdict(int, {'you': 0.5, 'leave': 0.5}),
#  'nowhere': defaultdict(int, {'but': 1.0}),
#  'builder': defaultdict(int, {'in': 1.0}),
#  'whatever': defaultdict(int, {'they': 1.0}),
#  'inscription': defaultdict(int, {'for': 1.0}),
#  'winds': defaultdict(int, {'blow': 1.0}),
#  'moisture': defaultdict(int, {'and': 1.0}),
#  'heaven': defaultdict(int, {'gives': 1.0}),
#  'back': defaultdict(int, {'out': 0.5, 'in': 0.5}),
#  'may': defaultdict(int, {'seem': 1.0}),
#  'great': defaultdict(int, {'monolithic': 1.0}),
#  'long': defaultdict(int, {'since': 1.0}),
#  'besides': defaultdict(int, {'the': 1.0}),
#  'still': defaultdict(int, {'said': 0.5, 'more': 0.5}),
#  'charge': defaultdict(int, {'that': 1.0}),
#  'make': defaultdict(int, {'yourself': 0.5, 'so': 0.5}),
#  'someones': defaultdict(int, {'road': 1.0}),
#  'into': defaultdict(int, {'each': 1.0}),
#  'weep': defaultdict(int, {'for': 1.0}),
#  'your': defaultdict(int, {'destination': 1.0}),
#  'cold': defaultdict(int, {'as': 1.0}),
#  'too': defaultdict(int, {'lofty': 0.5, 'late': 0.5}),
#  'drink': defaultdict(int, {'and': 1.0}),
#  'wherever': defaultdict(int, {'the': 1.0}),
#  'birch': defaultdict(int, {'boughs': 1.0}),
#  'time': defaultdict(int, {'someone': 1.0}),
#  'small': defaultdict(int, {'good': 1.0}),
#  'out': defaultdict(int, {'in': 1.0}),
#  'awake': defaultdict(int, {'that': 1.0}),
#  'wishing': defaultdict(int, {'that': 1.0}),
#  'saturn': defaultdict(int, {'and': 1.0}),
#  'theirs': defaultdict(int, {'interlock': 1.0}),
#  'uttered': defaultdict(int, {'alone': 1.0}),
#  'trembled': defaultdict(int, {'and': 1.0}),
#  'appear': defaultdict(int, {'like': 1.0}),
#  'around': defaultdict(int, {'and': 1.0}),
#  'since': defaultdict(int, {'man': 1.0}),
#  'lord': defaultdict(int, {'if': 1.0}),
#  'havent': defaultdict(int, {'you': 0.5, 'as': 0.5}),
#  'whats': defaultdict(int, {'wanted': 0.25, 'this': 0.25, 'the': 0.5}),
#  'estelles': defaultdict(int, {'to': 0.5, 'the': 0.5}),
#  'weve': defaultdict(int, {'been': 1.0}),
#  'left': defaultdict(int, {'here': 1.0}),
#  'hell': defaultdict(int, {'sort': 1.0}),
#  'skyhigh': defaultdict(int, {'with': 1.0}),
#  'arent': defaultdict(int, {'you': 1.0}),
#  'john': defaultdict(int,
#              {'hall': 0.16666666666666666,
#               'likes': 0.16666666666666666,
#               'bought': 0.16666666666666666,
#               'said': 0.16666666666666666,
#               'himself': 0.16666666666666666,
#               'threw': 0.16666666666666666}),
#  'better': defaultdict(int, {'than': 1.0}),
#  'reason': defaultdict(int, {'enough': 1.0}),
#  'such': defaultdict(int, {'as': 1.0}),
#  'twas': defaultdict(int, {'we': 1.0}),
#  'johns': defaultdict(int, {'a': 0.5, 'almost': 0.5}),
#  'estelle': defaultdict(int, {'to': 1.0}),
#  'farmers': defaultdict(int, {'around': 1.0}),
#  'full': defaultdict(int, {'of': 1.0}),
#  'moving': defaultdict(int, {'a': 1.0}),
#  'nothings': defaultdict(int, {'too': 1.0}),
#  'twenty': defaultdict(int, {'for': 1.0}),
#  'receipted': defaultdict(int, {'and': 1.0}),
#  'wampum': defaultdict(int, {'i': 1.0}),
#  'cant': defaultdict(int, {'you': 1.0}),
#  'being': defaultdict(int, {'cut': 1.0}),
#  'oho': defaultdict(int, {'oho': 1.0}),
#  'bad': defaultdict(int, {'to': 1.0}),
#  'nonsense': defaultdict(int, {'see': 1.0}),
#  'whod': defaultdict(int, {'marry': 1.0}),
#  'say': defaultdict(int, {'it': 1.0}),
#  'youll': defaultdict(int, {'be': 1.0}),
#  'coming': defaultdict(int, {'down': 1.0}),
#  'isnt': defaultdict(int, {'it': 1.0}),
#  'do': defaultdict(int, {'go': 1.0}),
#  'content': defaultdict(int, {'with': 1.0}),
#  'an': defaultdict(int, {'hour': 1.0})}

# %%
np.array(list(first_order['and'].values())).sum()
# Out:
# 1.0

# %% [markdown]
# ### Cumulative Probability Distribution First Order

# %%
for outer_keys in first_order.keys():
    first_order_keys_list = list(first_order[outer_keys].keys())
    
    for idx, key in enumerate(first_order_keys_list):
        
        if idx==0:
            continue
        
        first_order[outer_keys][key]+=first_order[outer_keys][first_order_keys_list[idx-1]]

first_order
# Out:
# {'two': defaultdict(int,
#              {'roads': 0.25,
#               'miles': 0.375,
#               'oldbelievers': 0.5,
#               'winds': 0.625,
#               'weeks': 0.75,
#               'of': 0.875,
#               'at': 1.0}),
#  'and': defaultdict(int,
#              {'sorry': 0.015503875968992248,
#               'be': 0.023255813953488372,
#               'looked': 0.031007751937984496,
#               'having': 0.03875968992248062,
#               'both': 0.05426356589147287,
#               'that': 0.06976744186046512,
#               'miles': 0.08527131782945736,
#               'would': 0.09302325581395349,
#               'dropped': 0.10077519379844961,
#               'further': 0.10852713178294573,
#               'when': 0.11627906976744186,
#               'tell': 0.13953488372093023,
#               'the': 0.17054263565891473,
#               'caught': 0.17829457364341084,
#               'put': 0.19379844961240308,
#               'threw': 0.2015503875968992,
#               'birds': 0.20930232558139533,
#               'suddenly': 0.21705426356589147,
#               'scurf': 0.2248062015503876,
#               'since': 0.24031007751937986,
#               'whats': 0.24806201550387597,
#               'many': 0.2558139534883721,
#               'blew': 0.26356589147286824,
#               'stamped': 0.2713178294573644,
#               'sometimes': 0.2790697674418605,
#               'some': 0.28682170542635665,
#               'then': 0.310077519379845,
#               'came': 0.31782945736434115,
#               'this': 0.33333333333333337,
#               'politician': 0.3410852713178295,
#               'thatd': 0.34883720930232565,
#               'rode': 0.3565891472868218,
#               'if': 0.37209302325581406,
#               'from': 0.3798449612403102,
#               'i': 0.4108527131782947,
#               'he': 0.41860465116279083,
#               'full': 0.42635658914728697,
#               'experts': 0.4341085271317831,
#               'built': 0.44186046511627924,
#               'thats': 0.4496124031007754,
#               'spoke': 0.4651162790697676,
#               'anyway': 0.47286821705426374,
#               'had': 0.4806201550387599,
#               'how': 0.488372093023256,
#               'taken': 0.49612403100775215,
#               'lie': 0.5038759689922483,
#               'left': 0.5116279069767444,
#               'stroked': 0.5193798449612406,
#               'a': 0.5348837209302328,
#               'me': 0.542635658914729,
#               'between': 0.5503875968992251,
#               'wont': 0.5581395348837213,
#               'hes': 0.5658914728682174,
#               'his': 0.5736434108527135,
#               'nothing': 0.5813953488372097,
#               'better': 0.5891472868217058,
#               'kick': 0.596899224806202,
#               'carried': 0.6046511627906981,
#               'thought': 0.6124031007751942,
#               'swollen': 0.6279069767441865,
#               'hold': 0.6356589147286826,
#               'all': 0.6511627906976749,
#               'fell': 0.658914728682171,
#               'set': 0.6666666666666672,
#               'sit': 0.6821705426356595,
#               'bring': 0.6899224806201556,
#               'push': 0.6976744186046517,
#               'those': 0.713178294573644,
#               'sproutlands': 0.7209302325581401,
#               'perhaps': 0.7364341085271324,
#               'see': 0.7441860465116286,
#               'dangle': 0.7519379844961247,
#               'disappeared': 0.7596899224806208,
#               'below': 0.767441860465117,
#               'what': 0.7751937984496131,
#               'come': 0.7829457364341093,
#               'begin': 0.7906976744186054,
#               'build': 0.7984496124031015,
#               'in': 0.8139534883720938,
#               'theres': 0.8217054263565899,
#               'stifling': 0.8294573643410861,
#               'got': 0.8372093023255822,
#               'lift': 0.8449612403100784,
#               'give': 0.8527131782945745,
#               'fight': 0.8604651162790706,
#               'such': 0.8682170542635668,
#               'moon': 0.8759689922480629,
#               'jupiter': 0.883720930232559,
#               'save': 0.8914728682170552,
#               'nation': 0.8992248062015513,
#               'though': 0.9069767441860475,
#               'now': 0.9147286821705436,
#               'wheres': 0.9224806201550397,
#               'shell': 0.9302325581395359,
#               'no': 0.937984496124032,
#               'end': 0.9457364341085281,
#               'after': 0.9534883720930243,
#               'we': 0.9612403100775204,
#               'like': 0.9689922480620166,
#               'youre': 0.9767441860465127,
#               'turn': 0.9844961240310088,
#               'not': 0.992248062015505,
#               'last': 1.000000000000001}),
#  'to': defaultdict(int,
#              {'where': 0.02,
#               'watch': 0.06,
#               'stop': 0.08,
#               'ask': 0.1,
#               'say': 0.14,
#               'carry': 0.16,
#               'think': 0.18,
#               'make': 0.3,
#               'everything': 0.32,
#               'spare': 0.34,
#               'see': 0.44000000000000006,
#               'turn': 0.4600000000000001,
#               'undo': 0.4800000000000001,
#               'let': 0.5000000000000001,
#               'go': 0.5200000000000001,
#               'shut': 0.5400000000000001,
#               'bring': 0.5600000000000002,
#               'entertain': 0.5800000000000002,
#               'find': 0.6000000000000002,
#               'send': 0.6200000000000002,
#               'such': 0.6400000000000002,
#               'wonder': 0.6600000000000003,
#               'no': 0.6800000000000003,
#               'tell': 0.7000000000000003,
#               'stand': 0.7200000000000003,
#               'reconnoitre': 0.7400000000000003,
#               'set': 0.7600000000000003,
#               'blow': 0.7800000000000004,
#               'ridgely': 0.8000000000000004,
#               'the': 0.8400000000000004,
#               'curl': 0.8600000000000004,
#               'call': 0.8800000000000004,
#               'which': 0.9000000000000005,
#               'be': 0.9200000000000005,
#               'drag': 0.9400000000000005,
#               'come': 0.9600000000000005,
#               'live': 0.9800000000000005,
#               'break': 1.0000000000000004}),
#  'then': defaultdict(int,
#              {'took': 0.08333333333333333,
#               'leaf': 0.16666666666666666,
#               'shook': 0.25,
#               'that': 0.3333333333333333,
#               'he': 0.41666666666666663,
#               'ran': 0.49999999999999994,
#               'we': 0.5833333333333333,
#               'i': 0.6666666666666666,
#               'make': 0.75,
#               'for': 0.8333333333333334,
#               'cane': 0.9166666666666667,
#               'its': 1.0}),
#  'because': defaultdict(int, {'it': 1.0}),
#  'though': defaultdict(int,
#              {'as': 0.14285714285714285,
#               'slight': 0.2857142857142857,
#               'what': 0.5714285714285714,
#               'not': 0.7142857142857142,
#               'strange': 0.857142857142857,
#               'set': 0.9999999999999998}),
#  'had': defaultdict(int,
#              {'worn': 0.25, 'spilled': 0.5, 'been': 0.75, 'checked': 1.0}),
#  'in': defaultdict(int,
#              {'leaves': 0.034482758620689655,
#               'front': 0.13793103448275862,
#               'the': 0.1724137931034483,
#               'every': 0.2413793103448276,
#               'winter': 0.27586206896551724,
#               'warren': 0.3103448275862069,
#               'wentworth': 0.3448275862068966,
#               'dalton': 0.37931034482758624,
#               'eightyfive': 0.4137931034482759,
#               'dust': 0.4482758620689656,
#               'virgin': 0.48275862068965525,
#               'time': 0.5172413793103449,
#               'one': 0.5862068965517242,
#               'snow': 0.6206896551724138,
#               'its': 0.6551724137931034,
#               'summer': 0.689655172413793,
#               'going': 0.7241379310344827,
#               'an': 0.7586206896551723,
#               'a': 0.7931034482758619,
#               'rain': 0.8620689655172412,
#               'that': 0.9310344827586206,
#               'separate': 0.9655172413793102,
#               'ways': 0.9999999999999998}),
#  'oh': defaultdict(int, {'i': 0.25, 'if': 0.75, 'thats': 1.0}),
#  'yet': defaultdict(int,
#              {'knowing': 0.3333333333333333,
#               'oh': 0.6666666666666666,
#               'does': 1.0}),
#  'i': defaultdict(int,
#              {'doubted': 0.00847457627118644,
#               'shall': 0.025423728813559324,
#               'took': 0.03389830508474576,
#               'hold': 0.0423728813559322,
#               'think': 0.05932203389830508,
#               'have': 0.13559322033898305,
#               'end': 0.1440677966101695,
#               'cant': 0.1864406779661017,
#               'fancied': 0.19491525423728814,
#               'looked': 0.2033898305084746,
#               'was': 0.2542372881355932,
#               'paused': 0.2627118644067796,
#               'saw': 0.2796610169491525,
#               'wonder': 0.3220338983050847,
#               'could': 0.34745762711864403,
#               'guess': 0.3813559322033898,
#               'know': 0.4152542372881356,
#               'made': 0.4322033898305085,
#               'hope': 0.4406779661016949,
#               'might': 0.4491525423728813,
#               'thought': 0.47457627118644063,
#               'am': 0.48305084745762705,
#               'wont': 0.49999999999999994,
#               'want': 0.5254237288135593,
#               'vow': 0.5338983050847457,
#               'didnt': 0.5508474576271185,
#               'never': 0.5762711864406779,
#               'stay': 0.5847457627118643,
#               'can': 0.6101694915254237,
#               'staid': 0.6186440677966101,
#               'went': 0.6355932203389829,
#               'had': 0.6864406779661015,
#               'struck': 0.694915254237288,
#               'sat': 0.7033898305084744,
#               'listened': 0.7118644067796608,
#               'pushed': 0.7203389830508472,
#               'wanted': 0.73728813559322,
#               'heard': 0.7457627118644065,
#               'promised': 0.7542372881355929,
#               'mean': 0.7796610169491522,
#               'dont': 0.813559322033898,
#               'verified': 0.8220338983050844,
#               'judged': 0.8305084745762709,
#               'only': 0.8474576271186437,
#               'idled': 0.8559322033898301,
#               'may': 0.8644067796610165,
#               'let': 0.8898305084745759,
#               'should': 0.8983050847457623,
#               'like': 0.9067796610169487,
#               'turned': 0.9152542372881352,
#               'often': 0.9237288135593216,
#               'name': 0.932203389830508,
#               'stole': 0.9406779661016944,
#               'walked': 0.9491525423728808,
#               'help': 0.9576271186440672,
#               'tell': 0.9661016949152537,
#               'hate': 0.9745762711864401,
#               'blame': 0.9830508474576265,
#               'take': 0.9915254237288129,
#               'suppose': 0.9999999999999993}),
#  'somewhere': defaultdict(int, {'ages': 1.0}),
#  'whose': defaultdict(int, {'woods': 0.5, 'shoes': 1.0}),
#  'his': defaultdict(int,
#              {'house': 0.14285714285714285,
#               'lantern': 0.2857142857142857,
#               'wild': 0.42857142857142855,
#               'journey': 0.5714285714285714,
#               'neck': 0.7142857142857142,
#               'names': 0.857142857142857,
#               'small': 0.9999999999999998}),
#  'he': defaultdict(int,
#              {'will': 0.029411764705882353,
#               'gives': 0.058823529411764705,
#               'saw': 0.08823529411764705,
#               'gained': 0.11764705882352941,
#               'never': 0.20588235294117646,
#               'reeled': 0.23529411764705882,
#               'fell': 0.2647058823529412,
#               'looked': 0.29411764705882354,
#               'couldnt': 0.3235294117647059,
#               'bowed': 0.35294117647058826,
#               'steered': 0.3823529411764706,
#               'want': 0.411764705882353,
#               'stood': 0.44117647058823534,
#               'said': 0.5294117647058824,
#               'dont': 0.5588235294117647,
#               'guessed': 0.5882352941176471,
#               'read': 0.6176470588235294,
#               'broke': 0.6470588235294118,
#               'always': 0.6764705882352942,
#               'thinks': 0.7352941176470589,
#               'must': 0.7647058823529412,
#               'wont': 0.7941176470588236,
#               'cant': 0.823529411764706,
#               'gets': 0.8529411764705883,
#               'and': 0.8823529411764707,
#               'hoed': 0.911764705882353,
#               'knows': 0.9411764705882354,
#               'manages': 0.9705882352941178,
#               'can': 1.0}),
#  'my': defaultdict(int,
#              {'little': 0.14285714285714285,
#               'french': 0.2857142857142857,
#               'first': 0.42857142857142855,
#               'mother': 0.5714285714285714,
#               'window': 0.7142857142857142,
#               'fingers': 0.857142857142857,
#               'but': 0.9999999999999998}),
#  'between': defaultdict(int, {'the': 0.6666666666666666, 'me': 1.0}),
#  'the': defaultdict(int,
#              {'darkest': 0.012195121951219513,
#               'only': 0.024390243902439025,
#               'woods': 0.03658536585365854,
#               'headless': 0.04878048780487805,
#               'whir': 0.06097560975609756,
#               'hillside': 0.07317073170731707,
#               'swarm': 0.08536585365853658,
#               'moon': 0.09756097560975609,
#               'spell': 0.1097560975609756,
#               'thought': 0.1219512195121951,
#               'figures': 0.13414634146341461,
#               'arthur': 0.15853658536585363,
#               'tote': 0.17073170731707316,
#               'poor': 0.18292682926829268,
#               'crib': 0.1951219512195122,
#               'smarty': 0.20731707317073172,
#               'mica': 0.21951219512195125,
#               'early': 0.23170731707317077,
#               'mountain': 0.2439024390243903,
#               'old': 0.2560975609756098,
#               'two': 0.26829268292682934,
#               'outside': 0.28048780487804886,
#               'poetess': 0.3048780487804879,
#               'posies': 0.31707317073170743,
#               'attic': 0.3414634146341465,
#               'small': 0.353658536585366,
#               'seal': 0.3658536585365855,
#               'night': 0.37804878048780505,
#               'board': 0.39024390243902457,
#               'way': 0.4146341463414636,
#               'bulkhead': 0.42682926829268314,
#               'cellar': 0.43902439024390266,
#               'door': 0.4512195121951222,
#               'faintest': 0.4634146341463417,
#               'fingerpieces': 0.47560975609756123,
#               'kitchen': 0.48780487804878075,
#               'uncommonly': 0.5000000000000002,
#               'steps': 0.5121951219512197,
#               'least': 0.5243902439024393,
#               'rural': 0.5365853658536588,
#               'west': 0.5487804878048783,
#               'breath': 0.5609756097560978,
#               'origin': 0.5731707317073174,
#               'past': 0.5853658536585369,
#               'young': 0.5975609756097564,
#               'second': 0.6097560975609759,
#               'town': 0.6219512195121955,
#               'situation': 0.634146341463415,
#               'sound': 0.6463414634146345,
#               'indians': 0.658536585365854,
#               'nose': 0.6707317073170735,
#               'meaning': 0.6829268292682931,
#               'voices': 0.7073170731707321,
#               'life': 0.7195121951219516,
#               'hours': 0.7317073170731712,
#               'road': 0.7439024390243907,
#               'ledges': 0.7560975609756102,
#               'chisel': 0.7682926829268297,
#               'height': 0.7804878048780493,
#               'playthings': 0.7926829268292688,
#               'sun': 0.8048780487804883,
#               'frogs': 0.8170731707317078,
#               'minute': 0.8292682926829273,
#               'same': 0.8414634146341469,
#               'snow': 0.8536585365853664,
#               'tower': 0.8658536585365859,
#               'sigmas': 0.8780487804878054,
#               'cosmic': 0.890243902439025,
#               'utmost': 0.9024390243902445,
#               'surest': 0.914634146341464,
#               'strains': 0.9268292682926835,
#               'rights': 0.939024390243903,
#               'smell': 0.9512195121951226,
#               'little': 0.9634146341463421,
#               'upper': 0.9756097560975616,
#               'crystal': 0.9878048780487811,
#               'man': 1.0000000000000007}),
#  'of': defaultdict(int,
#              {'easy': 0.034482758620689655,
#               'the': 0.24137931034482757,
#               'wire': 0.27586206896551724,
#               'getting': 0.3103448275862069,
#               'arthur': 0.3448275862068966,
#               'having': 0.37931034482758624,
#               'door': 0.4137931034482759,
#               'his': 0.4482758620689656,
#               'what': 0.48275862068965525,
#               'here': 0.5172413793103449,
#               'stranger': 0.5517241379310345,
#               'an': 0.6206896551724138,
#               'castles': 0.6551724137931034,
#               'youthful': 0.689655172413793,
#               'detail': 0.7241379310344827,
#               'being': 0.7586206896551723,
#               'country': 0.7931034482758619,
#               'dust': 0.8275862068965515,
#               'earthly': 0.8620689655172411,
#               'constellations': 0.8965517241379307,
#               'yawning': 0.9310344827586203,
#               'once': 0.9655172413793099,
#               'both': 0.9999999999999996}),
#  'but': defaultdict(int,
#              {'i': 0.1568627450980392,
#               'if': 0.21568627450980393,
#               'only': 0.2549019607843137,
#               'not': 0.3137254901960784,
#               'a': 0.3333333333333333,
#               'though': 0.37254901960784315,
#               'saved': 0.39215686274509803,
#               'now': 0.4117647058823529,
#               'most': 0.4313725490196078,
#               'everybody': 0.4509803921568627,
#               'smith': 0.4705882352941176,
#               'you': 0.5098039215686274,
#               'welcomed': 0.5294117647058824,
#               'all': 0.5490196078431373,
#               'it': 0.5686274509803922,
#               'we': 0.5882352941176472,
#               'wont': 0.6078431372549021,
#               'left': 0.6274509803921571,
#               'tonight': 0.647058823529412,
#               'rain': 0.666666666666667,
#               'the': 0.6862745098039219,
#               'wait': 0.7058823529411768,
#               'why': 0.7450980392156866,
#               'theres': 0.7647058823529416,
#               'dont': 0.7843137254901965,
#               'please': 0.8039215686274515,
#               'me': 0.8235294117647064,
#               'where': 0.8431372549019613,
#               'get': 0.8627450980392163,
#               'feared': 0.8823529411764712,
#               'being': 0.9019607843137262,
#               'when': 0.941176470588236,
#               'estelle': 0.9607843137254909,
#               'its': 0.9803921568627458,
#               'whats': 1.0000000000000007}),
#  'some': defaultdict(int,
#              {'say': 0.4,
#               'cried': 0.6000000000000001,
#               'zealous': 0.8,
#               'shattered': 1.0}),
#  'from': defaultdict(int,
#              {'what': 0.1,
#               'the': 0.5,
#               'that': 0.6,
#               'my': 0.7,
#               'north': 0.7999999999999999,
#               'stumps': 0.8999999999999999,
#               'sleeping': 0.9999999999999999}),
#  'is': defaultdict(int,
#              {'also': 0.2,
#               'sadder': 0.4,
#               'back': 0.6000000000000001,
#               'supposed': 0.8,
#               'this': 1.0}),
#  'natures': defaultdict(int, {'first': 1.0}),
#  'her': defaultdict(int, {'hardest': 0.5, 'early': 1.0}),
#  'so': defaultdict(int,
#              {'eden': 0.07692307692307693,
#               'dawn': 0.15384615384615385,
#               'halfway': 0.23076923076923078,
#               'now': 0.3076923076923077,
#               'they': 0.38461538461538464,
#               'as': 0.5384615384615385,
#               'suddenly': 0.6153846153846154,
#               'that': 0.7692307692307693,
#               'lying': 0.8461538461538463,
#               'cant': 0.9230769230769231,
#               'near': 1.0}),
#  'nothing': defaultdict(int, {'gold': 0.5, 'would': 1.0}),
#  'when': defaultdict(int,
#              {'far': 0.1111111111111111,
#               'i': 0.5555555555555556,
#               'the': 0.6666666666666667,
#               'there': 0.7777777777777779,
#               'shoeing': 0.8888888888888891,
#               'all': 1.0000000000000002}),
#  'came': defaultdict(int, {'over': 1.0}),
#  'one': defaultdict(int,
#              {'luminary': 0.09090909090909091,
#               'lizard': 0.18181818181818182,
#               'of': 0.2727272727272727,
#               'and': 0.36363636363636365,
#               'ought': 0.4545454545454546,
#               'mustnt': 0.5454545454545455,
#               'down': 0.7272727272727273,
#               'thing': 0.8181818181818182,
#               'level': 1.0}),
#  'proclaimed': defaultdict(int, {'the': 1.0}),
#  'smoothlaid': defaultdict(int, {'like': 1.0}),
#  'half': defaultdict(int,
#              {'closes': 0.3333333333333333,
#               'looking': 0.6666666666666666,
#               'of': 1.0}),
#  'up': defaultdict(int,
#              {'from': 0.14285714285714285,
#               'at': 0.2857142857142857,
#               'where': 0.42857142857142855,
#               'attic': 0.7142857142857142,
#               'one': 0.857142857142857,
#               'to': 0.9999999999999998}),
#  'a': defaultdict(int,
#              {'tree': 0.06666666666666667,
#               'voice': 0.1,
#               'swamp': 0.13333333333333333,
#               'barkless': 0.16666666666666666,
#               'hole': 0.19999999999999998,
#               'leak': 0.2333333333333333,
#               'cliff': 0.26666666666666666,
#               'likeness': 0.3,
#               'whole': 0.3333333333333333,
#               'small': 0.36666666666666664,
#               'moment': 0.39999999999999997,
#               'bird': 0.4333333333333333,
#               'single': 0.4666666666666666,
#               'brush': 0.49999999999999994,
#               'piercing': 0.5333333333333333,
#               'governor': 0.5666666666666667,
#               'rockstrewn': 0.6,
#               'bead': 0.6333333333333333,
#               'little': 0.6666666666666666,
#               'shelfs': 0.7,
#               'chimney': 0.7333333333333333,
#               'few': 0.7666666666666666,
#               'brook': 0.7999999999999999,
#               'broken': 0.8333333333333333,
#               'note': 0.8666666666666666,
#               'friend': 0.8999999999999999,
#               'bill': 0.9333333333333332,
#               'winter': 0.9666666666666666,
#               'featherhammer': 0.9999999999999999}),
#  'disturbed': defaultdict(int, {'i': 0.5, 'the': 1.0}),
#  'comes': defaultdict(int, {'softly': 1.0}),
#  'by': defaultdict(int,
#              {'picking': 0.09090909090909091,
#               'doubling': 0.18181818181818182,
#               'all': 0.2727272727272727,
#               'its': 0.36363636363636365,
#               'road': 0.4545454545454546,
#               'having': 0.5454545454545455,
#               'being': 0.6363636363636365,
#               'flying': 0.7272727272727274,
#               'a': 0.8181818181818183,
#               'now': 0.9090909090909093,
#               'tying': 1.0000000000000002}),
#  'if': defaultdict(int,
#              {'all': 0.08333333333333333,
#               'i': 0.3333333333333333,
#               'some': 0.41666666666666663,
#               'anyone': 0.49999999999999994,
#               'you': 0.5833333333333333,
#               'seen': 0.6666666666666666,
#               'the': 0.8333333333333333,
#               'he': 0.9166666666666666,
#               'hes': 1.0}),
#  'were': defaultdict(int, {'not': 1.0}),
#  'ten': defaultdict(int, {'million': 1.0}),
#  'as': defaultdict(int,
#              {'often': 0.14285714285714285,
#               'if': 0.2857142857142857,
#               'standing': 0.3571428571428571,
#               'long': 0.4285714285714285,
#               'we': 0.4999999999999999,
#               'gilt': 0.5714285714285713,
#               'one': 0.6428571428571427,
#               'pale': 0.7142857142857141,
#               'for': 0.7857142857142855,
#               'winds': 0.8571428571428569,
#               'married': 0.9285714285714283,
#               'near': 0.9999999999999997}),
#  'it': defaultdict(int,
#              {'looks': 0.09090909090909091,
#               'takes': 0.13636363636363635,
#               'must': 0.22727272727272727,
#               'want': 0.2727272727272727,
#               'doesnt': 0.3181818181818182,
#               'wasnt': 0.36363636363636365,
#               'was': 0.4545454545454546,
#               'took': 0.5,
#               'ought': 0.5909090909090909,
#               'rests': 0.6363636363636364,
#               'has': 0.7272727272727273,
#               'in': 0.7727272727272727,
#               'will': 0.8181818181818181,
#               'seems': 0.8636363636363635,
#               'makes': 0.909090909090909,
#               'lifts': 0.9999999999999999}),
#  'lifted': defaultdict(int, {'the': 1.0}),
#  'she': defaultdict(int,
#              {'has': 0.058823529411764705,
#               'thinks': 0.1764705882352941,
#               'might': 0.23529411764705882,
#               'never': 0.29411764705882354,
#               'was': 0.35294117647058826,
#               'could': 0.411764705882353,
#               'hadnt': 0.4705882352941177,
#               'swept': 0.5294117647058824,
#               'made': 0.5882352941176471,
#               'should': 0.6470588235294118,
#               'does': 0.7058823529411765,
#               'seems': 0.7647058823529412,
#               'wants': 0.823529411764706,
#               'wont': 0.9411764705882354,
#               'raised': 1.0}),
#  'transfixed': defaultdict(int, {'on': 1.0}),
#  'across': defaultdict(int, {'each': 1.0}),
#  'was': defaultdict(int,
#              {'wrought': 0.1111111111111111,
#               'arthur': 0.2222222222222222,
#               'singing': 0.3333333333333333,
#               'only': 0.4444444444444444,
#               'a': 0.5555555555555556,
#               'something': 0.6666666666666667,
#               'hot': 0.7777777777777779,
#               'counting': 0.8888888888888891,
#               'it': 1.0000000000000002}),
#  'once': defaultdict(int, {'on': 0.5, 'more': 1.0}),
#  'that': defaultdict(int,
#              {'had': 0.06896551724137931,
#               'everyone': 0.10344827586206896,
#               'cased': 0.13793103448275862,
#               'is': 0.1724137931034483,
#               'even': 0.20689655172413796,
#               'as': 0.24137931034482762,
#               'they': 0.2758620689655173,
#               'was': 0.31034482758620696,
#               'happens': 0.34482758620689663,
#               'overflowing': 0.3793103448275863,
#               'doesnt': 0.41379310344827597,
#               'need': 0.44827586206896564,
#               'theres': 0.4827586206896553,
#               'made': 0.517241379310345,
#               'now': 0.5517241379310346,
#               'turned': 0.5862068965517242,
#               'the': 0.6206896551724138,
#               'a': 0.6551724137931034,
#               'you': 0.689655172413793,
#               'there': 0.7586206896551724,
#               'are': 0.793103448275862,
#               'no': 0.8275862068965516,
#               'braced': 0.8620689655172412,
#               'sends': 0.8965517241379308,
#               'struck': 0.9310344827586204,
#               'much': 0.96551724137931,
#               'isnt': 0.9999999999999997}),
#  'looked': defaultdict(int, {'up': 1.0}),
#  'stood': defaultdict(int, {'over': 1.0}),
#  'you': defaultdict(int,
#              {'here': 0.025,
#               'can': 0.1,
#               'said': 0.15000000000000002,
#               'wont': 0.17500000000000002,
#               'mean': 0.25,
#               'dont': 0.325,
#               'must': 0.42500000000000004,
#               'and': 0.45000000000000007,
#               'know': 0.5000000000000001,
#               'riddle': 0.5250000000000001,
#               'take': 0.5500000000000002,
#               'look': 0.5750000000000002,
#               'never': 0.6250000000000002,
#               'poor': 0.6500000000000002,
#               'will': 0.7000000000000003,
#               'want': 0.7250000000000003,
#               'see': 0.7750000000000004,
#               'seem': 0.8000000000000004,
#               'think': 0.8250000000000004,
#               'let': 0.8500000000000004,
#               'couldnt': 0.8750000000000004,
#               'cant': 0.9000000000000005,
#               'say': 0.9250000000000005,
#               'spoke': 0.9500000000000005,
#               'ought': 0.9750000000000005,
#               'neednt': 1.0000000000000004}),
#  'me': defaultdict(int, {'im': 1.0}),
#  'sometimes': defaultdict(int, {'i': 0.25, 'he': 0.75, 'as': 1.0}),
#  'brown': defaultdict(int, {'lived': 0.5, 'makes': 1.0}),
#  'cross': defaultdict(int, {'lots': 1.0}),
#  'describing': defaultdict(int, {'rings': 1.0}),
#  'got': defaultdict(int, {'him': 1.0}),
#  'walls': defaultdict(int, {'were': 1.0}),
#  'like': defaultdict(int,
#              {'wings': 0.125,
#               'no': 0.25,
#               'a': 0.5,
#               'wild': 0.625,
#               'profanation': 0.75,
#               'graveyard': 0.875,
#               'some': 1.0}),
#  'upon': defaultdict(int, {'his': 0.5, 'a': 1.0}),
#  'with': defaultdict(int,
#              {'no': 0.05555555555555555,
#               'all': 0.16666666666666666,
#               'stone': 0.2222222222222222,
#               'furs': 0.2777777777777778,
#               'the': 0.5,
#               'our': 0.5555555555555556,
#               'sounds': 0.6111111111111112,
#               'clouds': 0.6666666666666667,
#               'a': 0.7222222222222223,
#               'his': 0.7777777777777779,
#               'flowers': 0.8333333333333335,
#               'half': 0.8888888888888891,
#               'whose': 0.9444444444444446,
#               'me': 1.0000000000000002}),
#  'faster': defaultdict(int, {'or': 1.0}),
#  'sitting': defaultdict(int, {'or': 1.0}),
#  'according': defaultdict(int, {'as': 1.0}),
#  'hes': defaultdict(int,
#              {'celebrating': 0.09090909090909091,
#               'so': 0.18181818181818182,
#               'after': 0.2727272727272727,
#               'groping': 0.36363636363636365,
#               'nothing': 0.4545454545454546,
#               'just': 0.5454545454545455,
#               'got': 0.6363636363636365,
#               'fiftyfive': 0.7272727272727274,
#               'given': 0.8181818181818183,
#               'fond': 0.9090909090909093,
#               'been': 1.0000000000000002}),
#  'or': defaultdict(int,
#              {'been': 0.09090909090909091,
#               'even': 0.18181818181818182,
#               'stained': 0.2727272727272727,
#               'like': 0.36363636363636365,
#               'else': 0.4545454545454546,
#               'a': 0.5454545454545455,
#               'i': 0.6363636363636365,
#               'it': 0.7272727272727274,
#               'creaking': 0.8181818181818183,
#               'some': 0.9090909090909093,
#               'old': 1.0000000000000002}),
#  'incredulous': defaultdict(int, {'of': 1.0}),
#  'well—i—be—': defaultdict(int, {'that': 1.0}),
#  'on': defaultdict(int,
#              {'motorcars': 0.09090909090909091,
#               'moosilauke': 0.18181818181818182,
#               'slippery': 0.2727272727272727,
#               'marshall': 0.36363636363636365,
#               'an': 0.4545454545454546,
#               'fathers': 0.5454545454545455,
#               'last': 0.6363636363636365,
#               'planets': 0.7272727272727274,
#               'his': 0.8181818181818183,
#               'something': 0.9090909090909093,
#               'some': 1.0000000000000002}),
#  'should': defaultdict(int, {'say': 0.5, 'take': 1.0}),
#  'yankees': defaultdict(int, {'are': 1.0}),
#  'dont': defaultdict(int,
#              {'think': 0.14285714285714285,
#               'donkeys': 0.2857142857142857,
#               'ask': 0.42857142857142855,
#               'make': 0.5714285714285714,
#               'be': 0.7142857142857142,
#               'the': 0.857142857142857,
#               'build': 0.9999999999999998}),
#  'until': defaultdict(int, {'the': 0.5, 'id': 1.0}),
#  'after': defaultdict(int, {'the': 1.0}),
#  'not': defaultdict(int,
#              {'much': 0.15384615384615385,
#               'that': 0.23076923076923078,
#               'so': 0.3076923076923077,
#               'like': 0.38461538461538464,
#               'from': 0.46153846153846156,
#               'fireweed': 0.5384615384615385,
#               'bluebells': 0.6153846153846154,
#               'lupine': 0.6923076923076923,
#               'in': 0.8461538461538461,
#               'to': 0.9230769230769231,
#               'answering': 1.0}),
#  'at': defaultdict(int,
#              {'that': 0.16666666666666666,
#               'having': 0.5,
#               'least': 0.8333333333333333,
#               'ten': 0.9999999999999999}),
#  'no': defaultdict(int,
#              {'more': 0.16666666666666666,
#               'doubt': 0.25,
#               'bird': 0.3333333333333333,
#               'fête': 0.41666666666666663,
#               'its': 0.49999999999999994,
#               'one': 0.75,
#               'i': 0.8333333333333334,
#               'matter': 0.9166666666666667,
#               'he': 1.0}),
#  'ive': defaultdict(int,
#              {'kept': 0.25, 'never': 0.5, 'been': 0.75, 'got': 1.0}),
#  'while': defaultdict(int, {'i': 1.0}),
#  'bout': defaultdict(int, {'out': 1.0}),
#  'now': defaultdict(int,
#              {'that': 0.25, 'give': 0.5, 'lefts': 0.75, 'slowly': 1.0}),
#  'im': defaultdict(int,
#              {'going': 0.2,
#               'stark': 0.4,
#               'waiting': 0.6000000000000001,
#               'getting': 0.8,
#               'sure': 1.0}),
#  'theyve': defaultdict(int, {'got': 1.0}),
#  'flattered': defaultdict(int, {'i': 1.0}),
#  'they': defaultdict(int,
#              {'dont': 0.05263157894736842,
#               'set': 0.10526315789473684,
#               'made': 0.15789473684210525,
#               'found': 0.21052631578947367,
#               'bad': 0.2631578947368421,
#               'simply': 0.3157894736842105,
#               'were': 0.47368421052631576,
#               'have': 0.5263157894736842,
#               'eddy': 0.5789473684210527,
#               'think': 0.631578947368421,
#               'might': 0.6842105263157894,
#               'spoke': 0.8421052631578947,
#               'left': 0.9473684210526315,
#               'filled': 1.0}),
#  'always': defaultdict(int, {'the': 1.0}),
#  'ill': defaultdict(int,
#              {'double': 0.1,
#               'tell': 0.4,
#               'find': 0.5,
#               'show': 0.7,
#               'hardly': 0.7999999999999999,
#               'say': 0.8999999999999999,
#               'talk': 0.9999999999999999}),
#  'theyll': defaultdict(int, {'find': 1.0}),
#  'for': defaultdict(int,
#              {'hog': 0.14285714285714285,
#               'gods': 0.2857142857142857,
#               'a': 0.5714285714285714,
#               'god': 0.7142857142857142,
#               'helping': 0.857142857142857,
#               'fifty': 0.9999999999999998}),
#  'couldnt': defaultdict(int, {'have': 0.5, 'one': 1.0}),
#  'voted': defaultdict(int, {'the': 1.0}),
#  'which': defaultdict(int,
#              {'wasnt': 0.3333333333333333,
#               'means': 0.6666666666666666,
#               'is': 1.0}),
#  'their': defaultdict(int, {'arthur': 0.5, 'solemn': 1.0}),
#  'wentworth': defaultdict(int, {'and': 1.0}),
#  'only': defaultdict(int,
#              {'i': 0.2,
#               'bewitched': 0.4,
#               'to': 0.6000000000000001,
#               'one': 0.8,
#               'too': 1.0}),
#  'rights': defaultdict(int, {'right': 1.0}),
#  'has': defaultdict(int, {'always': 0.5, 'been': 1.0}),
#  'itd': defaultdict(int, {'make': 1.0}),
#  'said': defaultdict(int, {'that': 1.0}),
#  'hed': defaultdict(int, {'bet': 0.2, 'like': 0.4, 'say': 0.8, 'need': 1.0}),
#  'all': defaultdict(int,
#              {'four': 0.125,
#               'is': 0.375,
#               'the': 0.5,
#               'claiming': 0.625,
#               'fresh': 0.75,
#               'that': 0.875,
#               'we': 1.0}),
#  'gnaws': defaultdict(int, {'in': 1.0}),
#  'last': defaultdict(int, {'night': 1.0}),
#  'over': defaultdict(int,
#              {'the': 0.4,
#               'so': 0.6000000000000001,
#               'descended': 0.8,
#               'back': 1.0}),
#  'well': defaultdict(int,
#              {'i': 0.2, 'take': 0.4, 'if': 0.6000000000000001, 'then': 1.0}),
#  'off': defaultdict(int, {'from': 0.5, 'here': 1.0}),
#  'old': defaultdict(int, {'davis': 0.5, 'as': 1.0}),
#  'thered': defaultdict(int, {'been': 1.0}),
#  'someday': defaultdict(int, {'i': 1.0}),
#  'huh': defaultdict(int, {'that': 1.0}),
#  'lets': defaultdict(int,
#              {'talk': 0.3333333333333333,
#               'go': 0.6666666666666666,
#               'trap': 1.0}),
#  'youve': defaultdict(int, {'lost': 1.0}),
#  'can': defaultdict(int, {'do': 1.0}),
#  'be': defaultdict(int,
#              {'dragged': 0.3333333333333333,
#               'ready': 0.6666666666666666,
#               'good': 1.0}),
#  'we': defaultdict(int,
#              {'made': 0.06666666666666667,
#               'came': 0.2,
#               'may': 0.26666666666666666,
#               'struck': 0.3333333333333333,
#               'trod': 0.39999999999999997,
#               'were': 0.4666666666666666,
#               'have': 0.7333333333333333,
#               'know': 0.7999999999999999,
#               'can': 0.8666666666666666,
#               'wouldnt': 0.9333333333333332,
#               'fence': 0.9999999999999999}),
#  'ascending': defaultdict(int, {'to': 1.0}),
#  'sos': defaultdict(int, {'everything': 0.5, 'to': 1.0}),
#  'hadnt': defaultdict(int, {'you': 1.0}),
#  'look': defaultdict(int, {'here': 1.0}),
#  'what': defaultdict(int,
#              {'signify': 0.07142857142857142,
#               'it': 0.21428571428571427,
#               'bones': 0.2857142857142857,
#               'do': 0.5,
#               'i': 0.6428571428571428,
#               'is': 0.7142857142857142,
#               'he': 0.7857142857142856,
#               'childishness': 0.857142857142857,
#               'are': 0.9285714285714284,
#               'well': 0.9999999999999998}),
#  'however': defaultdict(int, {'natural': 0.5, 'far': 1.0}),
#  'come': defaultdict(int,
#              {'straight': 0.25, 'down': 0.5, 'here': 0.75, 'out': 1.0}),
#  'its': defaultdict(int,
#              {'hell': 0.047619047619047616,
#               'not': 0.14285714285714285,
#               'sometimes': 0.19047619047619047,
#               'the': 0.23809523809523808,
#               'to': 0.2857142857142857,
#               'harmless': 0.3333333333333333,
#               'coming': 0.38095238095238093,
#               'with': 0.42857142857142855,
#               'looking': 0.47619047619047616,
#               'raining': 0.5238095238095237,
#               'as': 0.6666666666666665,
#               'going': 0.7142857142857142,
#               'hands': 0.7619047619047619,
#               'whirling': 0.8095238095238095,
#               'you': 0.8571428571428572,
#               'gone': 0.9047619047619049,
#               'too': 0.9523809523809526,
#               'different': 1.0000000000000002}),
#  'perhaps': defaultdict(int, {'to': 0.5, 'you': 1.0}),
#  'excuse': defaultdict(int, {'me': 1.0}),
#  'who': defaultdict(int,
#              {'used': 0.16666666666666666,
#               'failed': 0.3333333333333333,
#               'only': 0.5,
#               'may': 0.6666666666666666,
#               'are': 0.8333333333333333,
#               'wants': 0.9999999999999999}),
#  'life': defaultdict(int, {'long': 1.0}),
#  'our': defaultdict(int, {'business': 0.5, 'hens': 1.0}),
#  'through': defaultdict(int, {'a': 0.5, 'everything': 1.0}),
#  'except': defaultdict(int, {'it': 0.5, 'always': 1.0}),
#  'books': defaultdict(int, {'i': 0.5, 'were': 1.0}),
#  'where': defaultdict(int,
#              {'driven': 0.125,
#               'did': 0.25,
#               'shall': 0.375,
#               'the': 0.5,
#               'were': 0.625,
#               'is': 0.75,
#               'conies': 0.875,
#               'he': 1.0}),
#  'enough': defaultdict(int, {'to': 1.0}),
#  'unfortunately': defaultdict(int, {'all': 1.0}),
#  'boys': defaultdict(int, {'and': 1.0}),
#  'shatter': defaultdict(int, {'it': 1.0}),
#  'how': defaultdict(int,
#              {'had': 0.16666666666666666,
#               'could': 0.3333333333333333,
#               'shall': 0.6666666666666666,
#               'do': 0.8333333333333333,
#               'are': 0.9999999999999999}),
#  'till': defaultdict(int, {'it': 0.5, 'well': 1.0}),
#  'tried': defaultdict(int, {'to': 1.0}),
#  'having': defaultdict(int, {'tried': 1.0}),
#  'here': defaultdict(int,
#              {'were': 0.25, 'are': 0.5, 'he': 0.75, 'loveless': 1.0}),
#  'take': defaultdict(int,
#              {'one': 0.3333333333333333,
#               'all': 0.6666666666666666,
#               'it': 1.0}),
#  'why': defaultdict(int, {'not': 0.6666666666666666, 'do': 1.0}),
#  'goodlooking': defaultdict(int, {'books': 1.0}),
#  'both': defaultdict(int, {'either': 1.0}),
#  'legitimately': defaultdict(int, {'my': 1.0}),
#  'there': defaultdict(int,
#              {'wasnt': 0.16666666666666666,
#               'aint': 0.3333333333333333,
#               'is': 0.6666666666666666,
#               'was': 1.0}),
#  'alias': defaultdict(int, {'john': 1.0}),
#  'about': defaultdict(int, {'where': 1.0}),
#  'theres': defaultdict(int, {'not': 1.0}),
#  'give': defaultdict(int, {'a': 1.0}),
#  'thrown': defaultdict(int, {'away': 1.0}),
#  'unless': defaultdict(int, {'it': 1.0}),
#  'than': defaultdict(int, {'lifes': 0.5, 'folks': 1.0}),
#  'behind': defaultdict(int, {'the': 1.0}),
#  'mother': defaultdict(int,
#              {'folks': 0.14285714285714285,
#               'and': 0.2857142857142857,
#               'bones': 0.42857142857142855,
#               'well': 0.5714285714285714,
#               'the': 0.7142857142857142,
#               'we': 0.857142857142857,
#               'yes': 0.9999999999999998}),
#  'summoning': defaultdict(int, {'spirits': 1.0}),
#  'whos': defaultdict(int, {'got': 1.0}),
#  'son': defaultdict(int,
#              {'mother': 0.1111111111111111,
#               'you': 0.3333333333333333,
#               'but': 0.4444444444444444,
#               'it': 0.5555555555555556,
#               'we': 0.7777777777777778,
#               'knows': 0.8888888888888888,
#               'looks': 1.0}),
#  'rather': defaultdict(int, {'than': 1.0}),
#  'tell': defaultdict(int, {'you': 0.5, 'me': 1.0}),
#  'yes': defaultdict(int,
#              {'theres': 0.125,
#               'stark': 0.25,
#               'what': 0.375,
#               'its': 0.5,
#               'you': 0.625,
#               'whats': 0.75,
#               'but': 0.875,
#               'i': 1.0}),
#  'against': defaultdict(int, {'the': 1.0}),
#  'halting': defaultdict(int, {'perplexed': 1.0}),
#  'another': defaultdict(int, {'from': 1.0}),
#  'right': defaultdict(int, {'past': 1.0}),
#  'father': defaultdict(int, {'had': 1.0}),
#  'especially': defaultdict(int, {'in': 1.0}),
#  'might': defaultdict(int, {'just': 1.0}),
#  'toffile': defaultdict(int,
#              {'had': 0.2,
#               'for': 0.4,
#               'agreed': 0.6000000000000001,
#               'get': 0.8,
#               'if': 1.0}),
#  'struck': defaultdict(int, {'the': 1.0}),
#  'began': defaultdict(int, {'the': 1.0}),
#  'waiting': defaultdict(int, {'for': 1.0}),
#  'flashed': defaultdict(int, {'out': 1.0}),
#  'smoke': defaultdict(int, {'rolled': 1.0}),
#  'hand': defaultdict(int, {'me': 1.0}),
#  'stillgoing': defaultdict(int, {'every': 1.0}),
#  'before': defaultdict(int, {'i': 0.5, 'its': 1.0}),
#  'almost': defaultdict(int, {'the': 1.0}),
#  'quick': defaultdict(int, {'i': 1.0}),
#  'let': defaultdict(int, {'them': 0.5, 'people': 1.0}),
#  'brushing': defaultdict(int, {'their': 1.0}),
#  'thats': defaultdict(int,
#              {'what': 0.2, 'a': 0.6000000000000001, 'no': 0.8, 'his': 1.0}),
#  '2o3': defaultdict(int, {'let': 1.0}),
#  'wed': defaultdict(int, {'kept': 1.0}),
#  'could': defaultdict(int, {'tell': 1.0}),
#  'among': defaultdict(int, {'the': 0.6666666666666666, 'unearthed': 1.0}),
#  'ancestral': defaultdict(int, {'memories': 1.0}),
#  'someone': defaultdict(int, {'had': 1.0}),
#  'thence': defaultdict(int, {'they': 1.0}),
#  'made': defaultdict(int, {'shift': 1.0}),
#  'are': defaultdict(int, {'there': 1.0}),
#  'strolled': defaultdict(int, {'thither': 1.0}),
#  'anyone': defaultdict(int, {'else': 0.5, 'upon': 1.0}),
#  'this': defaultdict(int,
#              {'was': 0.3333333333333333,
#               'he': 0.5,
#               'is': 0.8333333333333333,
#               'eden': 0.9999999999999999}),
#  'provision': defaultdict(int, {'there': 1.0}),
#  'drawn': defaultdict(int, {'on': 0.5, 'into': 1.0}),
#  'stark': defaultdict(int, {'he': 1.0}),
#  'would': defaultdict(int, {'have': 0.5, 'name': 1.0}),
#  'several': defaultdict(int, {'times': 1.0}),
#  'under': defaultdict(int, {'the': 0.5, 'a': 1.0}),
#  'just': defaultdict(int, {'so': 1.0}),
#  'does': defaultdict(int, {'the': 0.5, 'it': 1.0}),
#  'bowed': defaultdict(int, {'outward': 1.0}),
#  'beyond': defaultdict(int, {'where': 0.5, 'which': 1.0}),
#  'four': defaultdict(int, {'cards': 1.0}),
#  'dyou': defaultdict(int, {'know': 1.0}),
#  'studying': defaultdict(int, {'genealogy': 1.0}),
#  'first': defaultdict(int, {'let': 0.5, 'theres': 1.0}),
#  'bless': defaultdict(int, {'you': 1.0}),
#  'shes': defaultdict(int,
#              {'after': 0.3333333333333333,
#               'in': 0.6666666666666666,
#               'let': 1.0}),
#  'heres': defaultdict(int, {'hoping': 1.0}),
#  'making': defaultdict(int, {'allowance': 1.0}),
#  'see': defaultdict(int, {'that': 1.0}),
#  'strung': defaultdict(int, {'on': 1.0}),
#  'something': defaultdict(int, {'i': 0.5, 'went': 1.0}),
#  'speaking': defaultdict(int, {'or': 1.0}),
#  'strangely': defaultdict(int, {'its': 1.0}),
#  'call': defaultdict(int, {'her': 1.0}),
#  'nor': defaultdict(int,
#              {'grannys': 0.25, 'never': 0.5, 'need': 0.75, 'want': 1.0}),
#  'nine': defaultdict(int, {'times': 1.0}),
#  'anything': defaultdict(int, {'she': 1.0}),
#  'folks': defaultdict(int, {'in': 1.0}),
#  'mebbe': defaultdict(int, {'im': 1.0}),
#  'more': defaultdict(int, {'of': 1.0}),
#  'will': defaultdict(int, {'you': 0.5, 'leave': 1.0}),
#  'nowhere': defaultdict(int, {'but': 1.0}),
#  'builder': defaultdict(int, {'in': 1.0}),
#  'whatever': defaultdict(int, {'they': 1.0}),
#  'inscription': defaultdict(int, {'for': 1.0}),
#  'winds': defaultdict(int, {'blow': 1.0}),
#  'moisture': defaultdict(int, {'and': 1.0}),
#  'heaven': defaultdict(int, {'gives': 1.0}),
#  'back': defaultdict(int, {'out': 0.5, 'in': 1.0}),
#  'may': defaultdict(int, {'seem': 1.0}),
#  'great': defaultdict(int, {'monolithic': 1.0}),
#  'long': defaultdict(int, {'since': 1.0}),
#  'besides': defaultdict(int, {'the': 1.0}),
#  'still': defaultdict(int, {'said': 0.5, 'more': 1.0}),
#  'charge': defaultdict(int, {'that': 1.0}),
#  'make': defaultdict(int, {'yourself': 0.5, 'so': 1.0}),
#  'someones': defaultdict(int, {'road': 1.0}),
#  'into': defaultdict(int, {'each': 1.0}),
#  'weep': defaultdict(int, {'for': 1.0}),
#  'your': defaultdict(int, {'destination': 1.0}),
#  'cold': defaultdict(int, {'as': 1.0}),
#  'too': defaultdict(int, {'lofty': 0.5, 'late': 1.0}),
#  'drink': defaultdict(int, {'and': 1.0}),
#  'wherever': defaultdict(int, {'the': 1.0}),
#  'birch': defaultdict(int, {'boughs': 1.0}),
#  'time': defaultdict(int, {'someone': 1.0}),
#  'small': defaultdict(int, {'good': 1.0}),
#  'out': defaultdict(int, {'in': 1.0}),
#  'awake': defaultdict(int, {'that': 1.0}),
#  'wishing': defaultdict(int, {'that': 1.0}),
#  'saturn': defaultdict(int, {'and': 1.0}),
#  'theirs': defaultdict(int, {'interlock': 1.0}),
#  'uttered': defaultdict(int, {'alone': 1.0}),
#  'trembled': defaultdict(int, {'and': 1.0}),
#  'appear': defaultdict(int, {'like': 1.0}),
#  'around': defaultdict(int, {'and': 1.0}),
#  'since': defaultdict(int, {'man': 1.0}),
#  'lord': defaultdict(int, {'if': 1.0}),
#  'havent': defaultdict(int, {'you': 0.5, 'as': 1.0}),
#  'whats': defaultdict(int, {'wanted': 0.25, 'this': 0.5, 'the': 1.0}),
#  'estelles': defaultdict(int, {'to': 0.5, 'the': 1.0}),
#  'weve': defaultdict(int, {'been': 1.0}),
#  'left': defaultdict(int, {'here': 1.0}),
#  'hell': defaultdict(int, {'sort': 1.0}),
#  'skyhigh': defaultdict(int, {'with': 1.0}),
#  'arent': defaultdict(int, {'you': 1.0}),
#  'john': defaultdict(int,
#              {'hall': 0.16666666666666666,
#               'likes': 0.3333333333333333,
#               'bought': 0.5,
#               'said': 0.6666666666666666,
#               'himself': 0.8333333333333333,
#               'threw': 0.9999999999999999}),
#  'better': defaultdict(int, {'than': 1.0}),
#  'reason': defaultdict(int, {'enough': 1.0}),
#  'such': defaultdict(int, {'as': 1.0}),
#  'twas': defaultdict(int, {'we': 1.0}),
#  'johns': defaultdict(int, {'a': 0.5, 'almost': 1.0}),
#  'estelle': defaultdict(int, {'to': 1.0}),
#  'farmers': defaultdict(int, {'around': 1.0}),
#  'full': defaultdict(int, {'of': 1.0}),
#  'moving': defaultdict(int, {'a': 1.0}),
#  'nothings': defaultdict(int, {'too': 1.0}),
#  'twenty': defaultdict(int, {'for': 1.0}),
#  'receipted': defaultdict(int, {'and': 1.0}),
#  'wampum': defaultdict(int, {'i': 1.0}),
#  'cant': defaultdict(int, {'you': 1.0}),
#  'being': defaultdict(int, {'cut': 1.0}),
#  'oho': defaultdict(int, {'oho': 1.0}),
#  'bad': defaultdict(int, {'to': 1.0}),
#  'nonsense': defaultdict(int, {'see': 1.0}),
#  'whod': defaultdict(int, {'marry': 1.0}),
#  'say': defaultdict(int, {'it': 1.0}),
#  'youll': defaultdict(int, {'be': 1.0}),
#  'coming': defaultdict(int, {'down': 1.0}),
#  'isnt': defaultdict(int, {'it': 1.0}),
#  'do': defaultdict(int, {'go': 1.0}),
#  'content': defaultdict(int, {'with': 1.0}),
#  'an': defaultdict(int, {'hour': 1.0})}

# %% [markdown]
# ### Filling second order markov distribution

# %%
for text in poems['text']:
    words = text.split()
    if(len(words)<3):
        continue
    for i in range(2,len(words)):
        if words[i-2] not in second_order.keys():
            second_order[words[i-2]] = {}
        if words[i-1] not in second_order[words[i-2]].keys():
            second_order[words[i-2]][words[i-1]] = defaultdict(int)
        second_order[words[i-2]][words[i-1]][words[i]]+=1

second_order
# Out:
# {'two': {'roads': defaultdict(int, {'diverged': 2}),
#   'miles': defaultdict(int, {'it': 1}),
#   'towns': defaultdict(int, {'fighting': 1}),
#   'converging': defaultdict(int, {'slides': 1}),
#   'or': defaultdict(int, {'three': 1}),
#   'oldbelievers': defaultdict(int, {'they': 1}),
#   'legs': defaultdict(int, {'like': 1}),
#   'footsteps': defaultdict(int, {'for': 1}),
#   'village': defaultdict(int, {'cultures': 1}),
#   'winds': defaultdict(int, {'would': 1}),
#   'weeks': defaultdict(int, {'since': 1}),
#   'of': defaultdict(int, {'you': 1}),
#   'as': defaultdict(int, {'good': 1}),
#   'at': defaultdict(int, {'a': 1})},
#  'roads': {'diverged': defaultdict(int, {'in': 2})},
#  'diverged': {'in': defaultdict(int, {'a': 2})},
#  'in': {'a': defaultdict(int,
#               {'yellow': 1,
#                'wood': 1,
#                'window': 1,
#                'packing': 1,
#                'byroad': 1,
#                'family': 1,
#                'new': 1,
#                'row': 1,
#                'time': 1,
#                'town': 1,
#                'book': 1,
#                'smother': 1,
#                'glass': 2}),
#   'the': defaultdict(int,
#               {'undergrowth': 1,
#                'village': 1,
#                'stars': 1,
#                'confusion': 1,
#                'excited': 1,
#                'scene': 1,
#                'river': 1,
#                'cold': 2,
#                'town': 1,
#                'warrant': 1,
#                'stable': 1,
#                'huse': 1,
#                'tail': 1,
#                'dark': 2,
#                'mountain': 1,
#                'box': 1,
#                'night': 1,
#                'bedroom': 1,
#                'cellar': 7,
#                'joints': 1,
#                'light': 1,
#                'room': 1,
#                'attic': 2,
#                'grass': 1,
#                'rain': 1,
#                'sun': 1,
#                'empty': 1,
#                'open': 1,
#                'kitchen': 1,
#                'weather': 1,
#                'playhouse': 1,
#                'instep': 1,
#                'newcut': 1,
#                'plowed': 1,
#                'bushy': 1,
#                'heat': 1,
#                'yard': 1}),
#   'leaves': defaultdict(int, {'no': 1}),
#   'rain': defaultdict(int, {'and': 1, 'sometime': 1, 'tomorrow': 1}),
#   'front': defaultdict(int, {'of': 3}),
#   'every': defaultdict(int, {'lifelike': 1, 'open': 1, 'way': 1}),
#   'it': defaultdict(int, {'from': 1, 'sweet': 1, 'now': 1, 'a': 1}),
#   'winter': defaultdict(int, {'after': 1, 'when': 1}),
#   'somewhere': defaultdict(int, {'with': 1}),
#   'march': defaultdict(int, {'meeting': 1}),
#   'warren': defaultdict(int, {'at': 1}),
#   'wentworth': defaultdict(int, {'from': 1}),
#   'their': defaultdict(int, {'town': 1, 'favour': 1}),
#   'his': defaultdict(int, {'old': 1, 'mouth': 1, 'mans': 1}),
#   'grafton': defaultdict(int, {'county': 1}),
#   'and': defaultdict(int, {'as': 1, 'the': 1}),
#   'folks': defaultdict(int, {'faces': 1}),
#   'dalton': defaultdict(int, {'that': 1}),
#   'dust': defaultdict(int, {'once': 1}),
#   'for': defaultdict(int, {'life': 1}),
#   'bed': defaultdict(int, {'and': 1}),
#   'stones': defaultdict(int, {'and': 1}),
#   'virgin': defaultdict(int, {'wrapper': 1}),
#   'one': defaultdict(int, {'and': 1, 'himself': 1, 'self': 1}),
#   'my': defaultdict(int, {'pocket': 1}),
#   'time': defaultdict(int, {'she': 1}),
#   'at': defaultdict(int, {'the': 2}),
#   'snow': defaultdict(int, {'and': 1}),
#   'its': defaultdict(int, {'twothousandmile': 1}),
#   'life': defaultdict(int, {'once': 1}),
#   'all': defaultdict(int, {'directions': 1}),
#   'her': defaultdict(int, {'lap': 2, 'day': 1}),
#   'summer': defaultdict(int, {'when': 1}),
#   'going': defaultdict(int, {'twice': 1}),
#   'new': defaultdict(int, {'hampshire': 1}),
#   'an': defaultdict(int, {'old': 1, 'alder': 1}),
#   'grove': defaultdict(int, {'and': 1}),
#   'such': defaultdict(int, {'a': 3}),
#   'among': defaultdict(int, {'the': 1}),
#   'across': defaultdict(int, {'the': 1}),
#   'dialect': defaultdict(int, {'whose': 1}),
#   'not': defaultdict(int, {'old': 1}),
#   'this': defaultdict(int, {'place': 1}),
#   'sunshine': defaultdict(int, {'so': 1}),
#   'building': defaultdict(int, {'the': 1}),
#   'position': defaultdict(int, {'to': 1}),
#   'your': defaultdict(int, {'ladder': 1}),
#   'that': defaultdict(int, {'grave': 2, 'case': 1, 'apple': 1}),
#   'than': defaultdict(int, {'i': 1}),
#   'earnest': defaultdict(int, {'it': 1}),
#   'here': defaultdict(int, {'like': 1}),
#   'year': defaultdict(int, {'out': 1}),
#   'separate': defaultdict(int, {'coops': 1}),
#   'ways': defaultdict(int, {'that': 1})},
#  'a': {'yellow': defaultdict(int, {'wood': 1}),
#   'wood': defaultdict(int, {'and': 1}),
#   'farmhouse': defaultdict(int, {'near': 1}),
#   'tree': defaultdict(int, {'beside': 1, 'that': 1}),
#   'leaf': defaultdict(int, {'that': 1, 'if': 1}),
#   'voice': defaultdict(int, {'said': 1}),
#   'gentle': defaultdict(int, {'cast': 1, 'lot': 1}),
#   'jerk': defaultdict(int, {'or': 1}),
#   'breath': defaultdict(int, {'of': 1}),
#   'swamp': defaultdict(int, {'of': 1}),
#   'sort': defaultdict(int, {'of': 2}),
#   'resurrected': defaultdict(int, {'tree': 1}),
#   'barkless': defaultdict(int, {'spectre': 1}),
#   'lofty': defaultdict(int, {'farm': 1}),
#   'hole': defaultdict(int, {'in': 1, 'i': 1}),
#   'coasting': defaultdict(int, {'child': 1}),
#   'matter': defaultdict(int, {'of': 1}),
#   'present': defaultdict(int, {'of': 1}),
#   'lot': defaultdict(int, {'now': 1}),
#   'noted': defaultdict(int, {'witch': 1}),
#   'witch': defaultdict(int, {'id': 1, 'or': 1, 'who': 1}),
#   'cribber': defaultdict(int, {'and': 1}),
#   'strapping': defaultdict(int, {'girl': 1}),
#   'night': defaultdict(int, {'of': 1}),
#   'solid': defaultdict(int, {'mica': 1}),
#   'stone': defaultdict(int, {'baptismal': 1}),
#   'worse': defaultdict(int, {'fight': 1}),
#   'leak': defaultdict(int, {'and': 1}),
#   'good': defaultdict(int, {'deal': 1, 'home': 1}),
#   'day': defaultdict(int, {'of': 1}),
#   'lookoff': defaultdict(int, {'where': 1}),
#   'cliff': defaultdict(int, {'and': 1}),
#   'bottle': defaultdict(int, {'painted': 1}),
#   'likeness': defaultdict(int, {'to': 1}),
#   'donkeys': defaultdict(int, {'cars': 1}),
#   'road': defaultdict(int, {'i': 1}),
#   'house': defaultdict(int,
#               {'deserted': 1, 'stripped': 1, 'that': 2, 'in': 1}),
#   'whole': defaultdict(int, {'edition': 1}),
#   'packing': defaultdict(int, {'case': 1}),
#   'horn': defaultdict(int, {'of': 1}),
#   'village': defaultdict(int, {'library': 1}),
#   'bird': defaultdict(int, {'silent': 1, 'alight': 1, 'with': 1}),
#   'stricken': defaultdict(int, {'bird': 1}),
#   'hornyhanded': defaultdict(int, {'kindness': 1}),
#   'demand': defaultdict(int, {'she': 1}),
#   'small': defaultdict(int, {'skiff': 1}),
#   'paddle': defaultdict(int, {'blade': 1}),
#   'trapper': defaultdict(int, {'looking': 1}),
#   'mother': defaultdict(int, {'and': 1}),
#   'winter': defaultdict(int, {'evening': 1, 'eve': 1, 'garden': 1}),
#   'common': defaultdict(int, {'table': 1}),
#   'table': defaultdict(int, {'for': 1}),
#   'pile': defaultdict(int, {'of': 1}),
#   'baby': defaultdict(int, {'i': 1}),
#   'man': defaultdict(int,
#               {'with': 1, 'but': 1, 'he': 1, 'let': 1, 'to': 1, 'at': 1}),
#   'little': defaultdict(int,
#               {'child': 1,
#                'little': 1,
#                'longer': 1,
#                'finger': 1,
#                'yesterday': 1}),
#   'vision': defaultdict(int, {'of': 1}),
#   'moment': defaultdict(int, {'he': 1}),
#   'tongue': defaultdict(int, {'of': 1}),
#   'grave': defaultdict(int, {'down': 2}),
#   'mans': defaultdict(int, {'his': 1}),
#   'single': defaultdict(int, {'leaf': 1}),
#   'crystal': defaultdict(int, {'chill': 1}),
#   'brush': defaultdict(int, {'had': 1}),
#   'crooked': defaultdict(int, {'stroke': 1}),
#   'piercing': defaultdict(int, {'little': 1}),
#   'governor': defaultdict(int, {'it': 1}),
#   'rockstrewn': defaultdict(int, {'town': 1}),
#   'tent': defaultdict(int, {'in': 1}),
#   'swish': defaultdict(int, {'in': 1}),
#   'farm': defaultdict(int, {'not': 1, 'that': 1}),
#   'girl': defaultdict(int, {'and': 1}),
#   'family': defaultdict(int, {'tree': 1}),
#   'sudden': defaultdict(int, {'movement': 1}),
#   'lane': defaultdict(int, {'yet': 1}),
#   'viola': defaultdict(int, {'i': 1}),
#   'plain': defaultdict(int, {'statement': 1}),
#   'shattered': defaultdict(int, {'seedpod': 1}),
#   'brook': defaultdict(int, {'hidden': 1, 'makes': 1, 'that': 1}),
#   'member': defaultdict(int, {'of': 1}),
#   'person': defaultdict(int, {'so': 1}),
#   'lake': defaultdict(int, {'before': 1}),
#   'myth': defaultdict(int, {'of': 1}),
#   'match': defaultdict(int, {'flame': 1}),
#   'hand': defaultdict(int, {'up': 1}),
#   'bead': defaultdict(int, {'of': 1}),
#   'wild': defaultdict(int, {'descent': 1}),
#   'purer': defaultdict(int, {'oracle': 1}),
#   'picture': defaultdict(int, {'on': 1}),
#   'name': defaultdict(int, {'should': 1}),
#   'doorsill': defaultdict(int, {'or': 1}),
#   'new': defaultdict(int, {'cottage': 1}),
#   'dite': defaultdict(int, {'too': 1}),
#   'chimney': defaultdict(int, {'upon': 1, 'that': 1}),
#   'fulllength': defaultdict(int, {'chimney': 1}),
#   'shelfs': defaultdict(int, {'for': 1}),
#   'clock': defaultdict(int, {'or': 1}),
#   'glimpse': defaultdict(int, {'through': 1}),
#   'garden': defaultdict(int, {'wall': 1}),
#   'sunny': defaultdict(int, {'cheek': 1}),
#   'passing': defaultdict(int, {'car': 1}),
#   'tunnel': defaultdict(int, {'mouth': 1}),
#   'time': defaultdict(int, {'made': 1}),
#   'town': defaultdict(int, {'that': 1}),
#   'guide': defaultdict(int, {'direct': 1}),
#   'story': defaultdict(int, {'in': 1}),
#   'book': defaultdict(int, {'about': 1}),
#   'certain': defaultdict(int, {'coolness': 1}),
#   'few': defaultdict(int, {'old': 1}),
#   'cheering': defaultdict(int, {'song': 1}),
#   'buggy': defaultdict(int, {'load': 1}),
#   'sign': defaultdict(int, {'up': 1}),
#   'harness': defaultdict(int, {'gall': 1}),
#   'belilaced': defaultdict(int, {'cellar': 1}),
#   'dent': defaultdict(int, {'in': 1}),
#   'spring': defaultdict(int, {'as': 1}),
#   'broken': defaultdict(int, {'drinking': 1}),
#   'spell': defaultdict(int, {'so': 1}),
#   'thousand': defaultdict(int, {'shrill': 1}),
#   'piano': defaultdict(int, {'loudly': 1}),
#   'note': defaultdict(int, {'unruffled': 1}),
#   'beaded': defaultdict(int, {'fur': 1}),
#   'headless': defaultdict(int, {'horse': 1}),
#   'smart': defaultdict(int, {'pair': 1}),
#   'big': defaultdict(int, {'church': 1}),
#   'long': defaultdict(int, {'time': 1}),
#   'friend': defaultdict(int, {'or': 1}),
#   'bad': defaultdict(int, {'farmer': 1}),
#   'home': defaultdict(int, {'for': 1}),
#   'hen': defaultdict(int, {'you': 1}),
#   'flock': defaultdict(int, {'of': 1}),
#   'times': defaultdict(int, {'the': 1}),
#   'glass': defaultdict(int, {'case': 2}),
#   'tall': defaultdict(int, {'one': 1}),
#   'barrel': defaultdict(int, {'from': 1}),
#   'paradise': defaultdict(int, {'as': 1}),
#   'dormant': defaultdict(int, {'tree': 1}),
#   'plane': defaultdict(int, {'of': 1}),
#   'gaunt': defaultdict(int, {'luxuriating': 1}),
#   'featherhammer': defaultdict(int, {'gives': 1}),
#   'double': defaultdict(int, {'knock': 1})},
#  'and': {'sorry': defaultdict(int, {'i': 2}),
#   'be': defaultdict(int, {'one': 1, 'whole': 1}),
#   'looked': defaultdict(int, {'down': 1}),
#   'having': defaultdict(int, {'perhaps': 1}),
#   'wanted': defaultdict(int, {'wear': 1}),
#   'both': defaultdict(int, {'that': 1, 'of': 1}),
#   'ages': defaultdict(int, {'hence': 1}),
#   'that': defaultdict(int, {'has': 1, 'was': 1}),
#   'frozen': defaultdict(int, {'lake': 1}),
#   'downy': defaultdict(int, {'flake': 1}),
#   'miles': defaultdict(int, {'to': 2}),
#   'would': defaultdict(int, {'suffice': 1}),
#   'back': defaultdict(int, {'in': 1}),
#   'dropped': defaultdict(int, {'my': 1}),
#   'stopped': defaultdict(int, {'the': 1}),
#   'further': defaultdict(int, {'still': 1}),
#   'when': defaultdict(int, {'i': 1, 'alls': 1, 'ive': 1}),
#   'tell': defaultdict(int, {'me': 3, 'him': 1}),
#   'now': defaultdict(int, {'know': 1, 'the': 1}),
#   'the': defaultdict(int,
#               {'light': 1,
#                'sun': 1,
#                'temptation': 1,
#                'birds': 1,
#                'fur': 1,
#                'north': 1,
#                'clothes': 1,
#                'jug': 1,
#                'bandmusic': 1,
#                'smell': 1,
#                'hens': 1,
#                'cock': 1}),
#   'caught': defaultdict(int, {'one': 1}),
#   'put': defaultdict(int, {'my': 1, 'a': 1}),
#   'threw': defaultdict(int, {'myself': 1}),
#   'birds': defaultdict(int, {'that': 1}),
#   'redoubling': defaultdict(int, {'song': 1}),
#   'suddenly': defaultdict(int, {'without': 1}),
#   'scuttled': defaultdict(int, {'just': 1}),
#   'side': defaultdict(int, {'by': 1}),
#   'scurf': defaultdict(int, {'of': 1}),
#   'weary': defaultdict(int, {'and': 1}),
#   'rested': defaultdict(int, {'on': 1}),
#   'since': defaultdict(int, {'there': 1, 'it': 1}),
#   'there': defaultdict(int, {'against': 1, 'a': 1}),
#   'raised': defaultdict(int, {'again—': 1}),
#   'whats': defaultdict(int, {'the': 1}),
#   'many': defaultdict(int, {'must': 1}),
#   'barn': defaultdict(int, {'the': 1}),
#   'blew': defaultdict(int, {'him': 1}),
#   'he': defaultdict(int, {'was': 1, 'liked': 1}),
#   'stamped': defaultdict(int, {'and': 1}),
#   'said': defaultdict(int, {'things': 1}),
#   'sometimes': defaultdict(int, {'something': 1}),
#   'some': defaultdict(int, {'exclaimed': 1}),
#   'made': defaultdict(int, {'the': 1}),
#   'then': defaultdict(int,
#               {'becoming': 1,
#                'went': 1,
#                'someone': 1,
#                'made': 1,
#                'a': 1,
#                'pull': 1}),
#   'came': defaultdict(int, {'down': 1}),
#   'this': defaultdict(int, {'is': 1, 'bill': 1}),
#   'politician': defaultdict(int, {'at': 1}),
#   'took': defaultdict(int, {'the': 1}),
#   'i': defaultdict(int,
#               {'can': 1,
#                'dont': 1,
#                'read': 1,
#                'know': 1,
#                'dread': 1,
#                'thought': 1,
#                'only': 1,
#                'have': 1,
#                'get': 1}),
#   'warrens': defaultdict(int, {'both': 1}),
#   'thatd': defaultdict(int, {'be': 1}),
#   'rode': defaultdict(int, {'all': 1}),
#   'if': defaultdict(int, {'id': 1, 'youre': 1}),
#   'leave': defaultdict(int, {'his': 1}),
#   'had': defaultdict(int, {'gnawed': 1, 'it': 1}),
#   'as': defaultdict(int, {'sures': 1}),
#   'posts': defaultdict(int, {'and': 1}),
#   'fences': defaultdict(int, {'too': 1}),
#   'make': defaultdict(int, {'it': 1, 'your': 1}),
#   'from': defaultdict(int, {'barn': 1}),
#   'snow': defaultdict(int, {'of': 1}),
#   'full': defaultdict(int, {'of': 1}),
#   'kick': defaultdict(int, {'up': 1, 'with': 1}),
#   'experts': defaultdict(int, {'said': 1}),
#   'show': defaultdict(int, {'it': 1}),
#   'built': defaultdict(int, {'a': 1}),
#   'emptied': defaultdict(int, {'then': 1}),
#   'forty': defaultdict(int, {'years': 1}),
#   'were': defaultdict(int, {'off': 1}),
#   'thats': defaultdict(int, {'why': 1, 'not': 1}),
#   'spoke': defaultdict(int, {'his': 1, 'of': 1}),
#   'on': defaultdict(int, {'the': 1}),
#   'anyway': defaultdict(int, {'this': 1}),
#   'save': defaultdict(int, {'the': 1, 'for': 1}),
#   'keep': defaultdict(int, {'abouncing': 1}),
#   'how': defaultdict(int, {'she': 1, 'much': 1, 'many': 1}),
#   'wrote': defaultdict(int, {'her': 1}),
#   'hold': defaultdict(int, {'the': 2, 'his': 1}),
#   'swollen': defaultdict(int, {'them': 1, 'tight': 2}),
#   'taken': defaultdict(int, {'thus': 1}),
#   'bad': defaultdict(int, {'hunters': 1}),
#   'lead': defaultdict(int, {'to': 1}),
#   'opening': defaultdict(int, {'out': 1}),
#   'lie': defaultdict(int, {'in': 1}),
#   'bushes': defaultdict(int, {'unretrieved': 1}),
#   'left': defaultdict(int, {'it': 1, 'me': 1}),
#   'stroked': defaultdict(int, {'it': 1}),
#   'a': defaultdict(int, {'paddle': 1, 'trapper': 1, 'crutch': 1}),
#   'me': defaultdict(int, {'on': 1}),
#   'between': defaultdict(int, {'what': 1}),
#   'wont': defaultdict(int, {'tell': 1}),
#   'hes': defaultdict(int, {'off': 1}),
#   'his': defaultdict(int, {'crew': 1, 'brown': 1}),
#   'nothing': defaultdict(int, {'came': 1}),
#   'better': defaultdict(int, {'defeat': 1}),
#   'headboard': defaultdict(int, {'where': 1, 'of': 1}),
#   'carried': defaultdict(int, {'itself': 1}),
#   'mother': defaultdict(int, {'and': 1}),
#   'neither': defaultdict(int, {'stopped': 1}),
#   'thought': defaultdict(int, {'i': 1}),
#   'buried': defaultdict(int, {'under': 2}),
#   'good': defaultdict(int, {'reason': 1}),
#   'all': defaultdict(int, {'but': 1, 'our': 1}),
#   'licked': defaultdict(int, {'along': 1}),
#   'fell': defaultdict(int, {'back': 1}),
#   'shouted': defaultdict(int, {'toffile': 1, 'shut': 1}),
#   'set': defaultdict(int, {'off': 1}),
#   'in': defaultdict(int, {'the': 1, 'a': 1, 'it': 1}),
#   'sit': defaultdict(int, {'up': 1, 'before': 1}),
#   'take': defaultdict(int, {'hold': 1, 'a': 1}),
#   'bring': defaultdict(int, {'the': 1}),
#   'sure': defaultdict(int, {'enough': 1}),
#   'held': defaultdict(int, {'the': 1}),
#   'push': defaultdict(int, {'the': 1}),
#   'stand': defaultdict(int, {'perplexed': 1}),
#   'lift': defaultdict(int, {'my': 1, 'themselves': 1}),
#   'those': defaultdict(int, {'of': 1, 'will': 1}),
#   'sproutlands': defaultdict(int, {'flourish': 1}),
#   'try': defaultdict(int, {'to': 1}),
#   'get': defaultdict(int, {'some': 1}),
#   'moments': defaultdict(int, {'of': 1}),
#   'one': defaultdict(int, {'other': 1}),
#   'she': defaultdict(int, {'halted': 1}),
#   'see': defaultdict(int, {'who': 1, 'if': 1, 'what': 1}),
#   'perhaps': defaultdict(int, {'hear': 1, 'she': 1}),
#   'still': defaultdict(int, {'be': 1, 'her': 1}),
#   'doubtless': defaultdict(int, {'here': 1}),
#   'by': defaultdict(int, {'marrying': 1}),
#   'dangle': defaultdict(int, {'feet': 1}),
#   'disappeared': defaultdict(int, {'and': 1}),
#   'ended': defaultdict(int, {'not': 1}),
#   'below': defaultdict(int, {'roared': 1}),
#   'what': defaultdict(int, {'do': 1}),
#   'dim': defaultdict(int, {'as': 1}),
#   'its': defaultdict(int, {'flooded': 1}),
#   'smoking': defaultdict(int, {'and': 1}),
#   'gets': defaultdict(int, {'out': 1}),
#   'sos': defaultdict(int, {'the': 1}),
#   'hew': defaultdict(int, {'and': 1}),
#   'shape': defaultdict(int, {'it': 1}),
#   'come': defaultdict(int, {'and': 1}),
#   'begin': defaultdict(int, {'over': 1}),
#   'it': defaultdict(int, {'was': 1}),
#   'build': defaultdict(int, {'the': 1}),
#   'youthful': defaultdict(int, {'faces': 1}),
#   'repented': defaultdict(int, {'but': 1}),
#   'color': defaultdict(int, {'and': 1}),
#   'odor': defaultdict(int, {'thicken': 1}),
#   'go': defaultdict(int, {'back': 1}),
#   'broken': defaultdict(int, {'off': 1}),
#   'theres': defaultdict(int, {'a': 1}),
#   'your': defaultdict(int, {'destinys': 1, 'watering': 1}),
#   'original': defaultdict(int, {'to': 1}),
#   'stifling': defaultdict(int, {'hot': 1}),
#   'sound': defaultdict(int, {'from': 1}),
#   'got': defaultdict(int, {'them': 1}),
#   'new': defaultdict(int, {'paint': 1}),
#   'music': defaultdict(int, {'out': 1}),
#   'give': defaultdict(int, {'up': 1}),
#   'fight': defaultdict(int, {'in': 1}),
#   'such': defaultdict(int, {'few': 1}),
#   'moon': defaultdict(int, {'and': 1}),
#   'nation': defaultdict(int, {'nation': 1}),
#   'though': defaultdict(int, {'none': 1}),
#   'wheres': defaultdict(int, {'john': 1}),
#   'gone': defaultdict(int, {'to': 1}),
#   'shell': defaultdict(int, {'come': 1}),
#   'lord': defaultdict(int, {'if': 1}),
#   'where': defaultdict(int, {'it': 1}),
#   'no': defaultdict(int, {'one': 1}),
#   'end': defaultdict(int, {'it': 1}),
#   'after': defaultdict(int, {'all': 1}),
#   'cows': defaultdict(int, {'and': 1}),
#   'pigs': defaultdict(int, {'are': 1}),
#   'we': defaultdict(int, {'live': 1, 'paid': 1}),
#   'like': defaultdict(int, {'it': 1}),
#   'youre': defaultdict(int, {'her': 1}),
#   'turn': defaultdict(int, {'doll': 1}),
#   'stop': defaultdict(int, {'his': 1}),
#   'not': defaultdict(int, {'melt': 1}),
#   'last': defaultdict(int, {'years': 1}),
#   'which': defaultdict(int, {'are': 1})},
#  'sorry': {'i': defaultdict(int, {'could': 1, 'ever': 1})},
#  'i': {'could': defaultdict(int, {'not': 2, 'have': 2, 'see': 3, 'do': 1}),
#   'kept': defaultdict(int, {'the': 1, 'remembering': 1}),
#   'doubted': defaultdict(int, {'if': 1}),
#   'should': defaultdict(int, {'ever': 1, 'say': 1, 'feel': 1}),
#   'shall': defaultdict(int, {'be': 1, 'suspect': 1}),
#   'took': defaultdict(int, {'the': 1, 'him': 1}),
#   'think': defaultdict(int, {'i': 2, 'its': 1, 'were': 1, 'he': 1, 'ill': 1}),
#   'have': defaultdict(int,
#               {'promises': 1,
#                'been': 2,
#                'walked': 1,
#                'outwalked': 1,
#                'looked': 1,
#                'passed': 1,
#                'stood': 1,
#                'no': 1,
#                'kept': 1,
#                'filled': 1}),
#   'hold': defaultdict(int, {'with': 1}),
#   'know': defaultdict(int,
#               {'enough': 1, 'of': 2, 'and': 1, 'what': 1, 'the': 1}),
#   'go': defaultdict(int, {'up': 1}),
#   'come': defaultdict(int, {'to': 1}),
#   'doubt': defaultdict(int, {'not': 1}),
#   'end': defaultdict(int, {'not': 1}),
#   'cant': defaultdict(int,
#               {'pretend': 1,
#                'decently': 1,
#                'say': 1,
#                'give': 1,
#                'get': 1,
#                'keep': 1,
#                'talk': 1,
#                'stay': 1,
#                'explain': 1}),
#   'though': defaultdict(int, {'to': 1}),
#   'tell': defaultdict(int, {'but': 1, 'them': 2}),
#   'fancied': defaultdict(int, {'when': 1}),
#   'looked': defaultdict(int, {'at': 2}),
#   'was': defaultdict(int,
#               {'half': 1,
#                'married': 2,
#                'to': 1,
#                'a': 3,
#                'young': 2,
#                'soon': 1,
#                'going': 1,
#                'just': 1,
#                'too': 1}),
#   'ever': defaultdict(int, {'left': 1, 'cared': 1}),
#   'paused': defaultdict(int, {'and': 1}),
#   'saw': defaultdict(int, {'the': 1, 'it': 1, 'a': 1, 'no': 1, 'him': 1}),
#   'said': defaultdict(int, {'where': 1}),
#   'wander': defaultdict(int, {'out': 1}),
#   'wonder': defaultdict(int, {'what': 1, 'if': 2, 'where': 1, 'why': 1}),
#   'invested': defaultdict(int, {'him': 1}),
#   'can': defaultdict(int,
#               {'prove': 1,
#                'hurt': 1,
#                'find': 1,
#                'just': 1,
#                'make': 1,
#                'see': 2,
#                'tell': 1,
#                'no': 1,
#                'keep': 1,
#                'sew': 1,
#                'hardly': 1}),
#   'must': defaultdict(int, {'be': 1, 'have': 1, 'go': 1}),
#   'guess': defaultdict(int, {'theyd': 1, 'he': 1, 'youd': 1, 'estelle': 1}),
#   'happen': defaultdict(int, {'to': 1}),
#   'would': defaultdict(int, {'be': 1, 'last': 1, 'have': 1}),
#   'spose': defaultdict(int, {'when': 1}),
#   'mistrusted': defaultdict(int, {'he': 1}),
#   'showed': defaultdict(int, {'arthur': 1}),
#   'dont': defaultdict(int,
#               {'mean': 1,
#                'know': 4,
#                'see': 3,
#                'care': 1,
#                'remember': 1,
#                'believe': 1,
#                'follow': 1,
#                'trust': 1,
#                'just': 1,
#                'ask': 1}),
#   'made': defaultdict(int, {'him': 4}),
#   'hope': defaultdict(int, {'if': 1}),
#   'might': defaultdict(int, {'have': 1}),
#   'remember': defaultdict(int, {'rightly': 1}),
#   'am': defaultdict(int, {'im': 1, 'a': 1, 'sure': 1}),
#   'thought': defaultdict(int,
#               {'you': 1, 'for': 1, 'the': 2, 'i': 2, 'twas': 1}),
#   'havent': defaultdict(int, {'brought': 1, 'had': 1}),
#   'wont': defaultdict(int, {'accept': 1, 'be': 1}),
#   'want': defaultdict(int, {'my': 1, 'to': 3}),
#   'vow': defaultdict(int, {'we': 1}),
#   'show': defaultdict(int, {'you': 1}),
#   'didnt': defaultdict(int,
#               {'recognize': 1, 'know': 1, 'always': 1, 'relish': 1}),
#   'never': defaultdict(int, {'saw': 2, 'could': 1, 'heard': 1}),
#   'ask': defaultdict(int, {'you': 1}),
#   'read': defaultdict(int, {'in': 1}),
#   'knew': defaultdict(int, {'in': 1, 'them': 1, 'there': 1}),
#   'staid': defaultdict(int, {'the': 1}),
#   'asked': defaultdict(int, {'him': 1}),
#   'went': defaultdict(int, {'to': 2, 'till': 1}),
#   'heard': defaultdict(int, {'toffile': 1, 'him': 1, 'them': 1}),
#   'had': defaultdict(int,
#               {'a': 2, 'just': 1, 'to': 2, 'for': 1, 'the': 3, 'such': 1}),
#   'flung': defaultdict(int, {'the': 1}),
#   'struck': defaultdict(int, {'the': 1}),
#   'see': defaultdict(int, {'one': 1, 'raspberry': 1, 'its': 1}),
#   'sat': defaultdict(int, {'up': 1}),
#   'listened': defaultdict(int, {'till': 1}),
#   'got': defaultdict(int, {'up': 1, 'wonted': 1}),
#   'pushed': defaultdict(int, {'myself': 1}),
#   'wanted': defaultdict(int, {'to': 2}),
#   'slammed': defaultdict(int, {'to': 1}),
#   'sit': defaultdict(int, {'up': 1}),
#   'promised': defaultdict(int, {'toffile': 1}),
#   'mean': defaultdict(int, {'a': 1, 'estelle': 1, 'shes': 1}),
#   'verified': defaultdict(int, {'the': 1}),
#   'passed': defaultdict(int, {'the': 1}),
#   'judged': defaultdict(int, {'that': 1}),
#   'only': defaultdict(int, {'idled': 1, 'mean': 1, 'have': 1, 'hinder': 1}),
#   'idled': defaultdict(int, {'down': 1}),
#   'own': defaultdict(int, {'what': 1}),
#   'may': defaultdict(int, {'be': 1}),
#   'lean': defaultdict(int, {'like': 1}),
#   'give': defaultdict(int, {'you': 1}),
#   'used': defaultdict(int, {'the': 1, 'to': 1}),
#   'mustnt': defaultdict(int, {'feel': 1}),
#   'let': defaultdict(int, {'you': 2, 'myself': 1}),
#   'speak': defaultdict(int, {'but': 1}),
#   'like': defaultdict(int, {'your': 1}),
#   'dread': defaultdict(int, {'the': 1}),
#   'turned': defaultdict(int, {'and': 1}),
#   'often': defaultdict(int, {'see': 1}),
#   'name': defaultdict(int, {'all': 1}),
#   'stole': defaultdict(int, {'the': 1}),
#   'walked': defaultdict(int, {'down': 1}),
#   'came': defaultdict(int, {'to': 1}),
#   'help': defaultdict(int, {'out': 1}),
#   'were': defaultdict(int, {'to': 1}),
#   'primped': defaultdict(int, {'to': 1}),
#   'hate': defaultdict(int, {'to': 1}),
#   'blame': defaultdict(int, {'his': 1}),
#   'take': defaultdict(int, {'it': 1}),
#   'call': defaultdict(int, {'it': 1}),
#   'get': defaultdict(int, {'to': 1}),
#   'say': defaultdict(int, {'shes': 1}),
#   'pity': defaultdict(int, {'estelle': 1}),
#   'suppose': defaultdict(int, {'she': 1})},
#  'could': {'not': defaultdict(int, {'travel': 1, 'say': 1}),
#   'hold': defaultdict(int, {'them': 1}),
#   'have': defaultdict(int, {'told': 1, 'done': 1, 'to': 1}),
#   'recognize': defaultdict(int, {'them': 1}),
#   'hear': defaultdict(int, {'tell': 1}),
#   'call': defaultdict(int, {'up': 1}),
#   'that': defaultdict(int, {'be': 1}),
#   'be': defaultdict(int, {'there': 1}),
#   'see': defaultdict(int, {'nothing': 1, 'it': 1}),
#   'find': defaultdict(int, {'out': 1}),
#   'too': defaultdict(int, {'son': 1}),
#   'do': defaultdict(int, {'was': 1}),
#   'tell': defaultdict(int, {'you': 1}),
#   'make': defaultdict(int, {'them': 1}),
#   'sell': defaultdict(int, {'the': 1})},
#  'not': {'travel': defaultdict(int, {'both': 1}),
#   'see': defaultdict(int, {'me': 1}),
#   'to': defaultdict(int,
#               {'call': 1,
#                'blanket': 1,
#                'be': 1,
#                'care': 1,
#                'sink': 1,
#                'stand': 1}),
#   'by': defaultdict(int, {'my': 1}),
#   'far': defaultdict(int, {'from': 1, 'away': 1, 'off': 1}),
#   'too': defaultdict(int, {'much': 1}),
#   'off': defaultdict(int, {'for': 1}),
#   'much': defaultdict(int, {'concerned': 2}),
#   'a': defaultdict(int, {'post': 1, 'soul': 1}),
#   'that': defaultdict(int, {'he': 1, 'im': 1}),
#   'so': defaultdict(int, {'but': 1}),
#   'thrown': defaultdict(int, {'irreverently': 1}),
#   'take': defaultdict(int, {'two': 1, 'seats': 1}),
#   'men': defaultdict(int, {'by': 1}),
#   'like': defaultdict(int, {'a': 1}),
#   'for': defaultdict(int, {'him': 1}),
#   'all': defaultdict(int, {'the': 1, 'hes': 1}),
#   'expecting': defaultdict(int, {'he': 1}),
#   'be': defaultdict(int, {'and': 1}),
#   'from': defaultdict(int, {'the': 1}),
#   'your': defaultdict(int, {'makebelieve': 1}),
#   'yet': defaultdict(int, {'all': 1, 'light': 1}),
#   'come': defaultdict(int, {'in': 1}),
#   'old': defaultdict(int, {'grandsirs': 1}),
#   'fireweed': defaultdict(int, {'loving': 1}),
#   'bluebells': defaultdict(int, {'gracing': 1}),
#   'lupine': defaultdict(int, {'living': 1}),
#   'in': defaultdict(int, {'position': 1, 'a': 1}),
#   'mind': defaultdict(int, {'a': 1}),
#   'twenty': defaultdict(int, {'years': 1}),
#   'their': defaultdict(int, {'own': 1}),
#   'answering': defaultdict(int, {'your': 1}),
#   'if': defaultdict(int, {'he': 1}),
#   'he': defaultdict(int, {'us': 1}),
#   'blaming': defaultdict(int, {'him': 1}),
#   'being': defaultdict(int, {'safe': 1}),
#   'allowed': defaultdict(int, {'to': 1}),
#   'melt': defaultdict(int, {'snow': 1})},
#  'be': {'one': defaultdict(int, {'traveler': 1}),
#   'telling': defaultdict(int, {'this': 1}),
#   'to': defaultdict(int, {'have': 1, 'my': 1}),
#   'set': defaultdict(int, {'up': 1}),
#   'they': defaultdict(int, {'ought': 1}),
#   'enough': defaultdict(int, {'to': 1, 'protection': 1}),
#   'the': defaultdict(int, {'end': 1, 'best': 1}),
#   'dragged': defaultdict(int, {'by': 1}),
#   'near': defaultdict(int, {'the': 1}),
#   'ready': defaultdict(int, {'i': 1}),
#   'broken': defaultdict(int, {'davis': 1}),
#   'rid': defaultdict(int, {'of': 1}),
#   'burned': defaultdict(int, {'at': 1}),
#   'i': defaultdict(int, {'thought': 1}),
#   'ice': defaultdict(int, {'and': 1}),
#   'cruel': defaultdict(int, {'to': 1, 'once': 1}),
#   'and': defaultdict(int, {'still': 1}),
#   'thrown': defaultdict(int, {'into': 1}),
#   'too': defaultdict(int, {'technical': 1}),
#   'learned': defaultdict(int, {'thats': 1}),
#   'teased': defaultdict(int, {'but': 1}),
#   'strange': defaultdict(int, {'enough': 1}),
#   'very': defaultdict(int, {'still': 1}),
#   'good': defaultdict(int, {'the': 1, 'friends': 1, 'for': 1}),
#   'heard': defaultdict(int, {'in': 1}),
#   'likely': defaultdict(int, {'to': 1}),
#   'you': defaultdict(int, {'said': 1}),
#   'in': defaultdict(int, {'rain': 1}),
#   'just': defaultdict(int, {'ahead': 1}),
#   'whole': defaultdict(int, {'again': 1}),
#   'a': defaultdict(int, {'nova': 1}),
#   'long': defaultdict(int, {'in': 1}),
#   'or': defaultdict(int, {'anyone': 1}),
#   'right': defaultdict(int, {'to': 1}),
#   'as': defaultdict(int, {'good': 1}),
#   'expecting': defaultdict(int, {'john': 1})},
#  'one': {'traveler': defaultdict(int, {'long': 1}),
#   'as': defaultdict(int, {'far': 1}),
#   'less': defaultdict(int, {'traveled': 1}),
#   'acquainted': defaultdict(int, {'with': 2}),
#   'luminary': defaultdict(int, {'clock': 1}),
#   'silver': defaultdict(int, {'lizard': 1}),
#   'without': defaultdict(int, {'avail': 1}),
#   'lizard': defaultdict(int, {'at': 1}),
#   'of': defaultdict(int, {'them': 2, 'the': 1, 'her': 1, 'those': 1}),
#   'they': defaultdict(int, {'say': 1}),
#   'town': defaultdict(int, {'hall': 1}),
#   'in': defaultdict(int, {'grafton': 1}),
#   'hadnt': defaultdict(int, {'said': 1}),
#   'kind': defaultdict(int, {'though': 1}),
#   'had': defaultdict(int, {'dropped': 1}),
#   'old': defaultdict(int, {'davis': 1}),
#   'and': defaultdict(int, {'i': 1, 'one': 1}),
#   'more': defaultdict(int, {'copy': 1}),
#   'himself': defaultdict(int, {'perhaps': 1}),
#   'flight': defaultdict(int, {'from': 1}),
#   'leg': defaultdict(int, {'and': 1}),
#   'hand': defaultdict(int, {'outstretched': 1}),
#   'any': defaultdict(int, {'more': 1}),
#   'night': defaultdict(int, {'in': 1}),
#   'from': defaultdict(int, {'a': 1}),
#   'other': defaultdict(int, {'yes': 1}),
#   'bearing': defaultdict(int, {'it': 1}),
#   'who': defaultdict(int, {'clasps': 1}),
#   'ought': defaultdict(int, {'not': 1}),
#   'went': defaultdict(int, {'home': 1}),
#   'yours': defaultdict(int, {'three': 1}),
#   'for': defaultdict(int, {'each': 1}),
#   'mustnt': defaultdict(int, {'bear': 1}),
#   'that': defaultdict(int, {'didnt': 1}),
#   'at': defaultdict(int, {'all': 1}),
#   'on': defaultdict(int, {'earth': 1, 'each': 1}),
#   'a': defaultdict(int, {'hill': 1}),
#   'down': defaultdict(int, {'one': 1, 'another': 1}),
#   'self': defaultdict(int, {'station': 1}),
#   'here': defaultdict(int, {'but': 1}),
#   'will': defaultdict(int, {'ever': 1}),
#   'talk': defaultdict(int, {'to': 1}),
#   'thing': defaultdict(int, {'you': 1}),
#   'langshang': defaultdict(int, {'cock': 1}),
#   'you': defaultdict(int, {'neednt': 1}),
#   'level': defaultdict(int, {'higher': 1, 'nearer': 1})},
#  'traveler': {'long': defaultdict(int, {'i': 1})},
#  'long': {'i': defaultdict(int, {'stood': 1, 'lay': 1}),
#   'way': defaultdict(int, {'home': 1}),
#   'ago': defaultdict(int, {'as': 1}),
#   'suspected': defaultdict(int, {'where': 1}),
#   'in': defaultdict(int, {'bed': 1, 'that': 1}),
#   'since': defaultdict(int, {'gave': 1})},
#  'looked': {'down': defaultdict(int, {'one': 1, 'the': 1}),
#   'at': defaultdict(int, {'six': 1, 'nine': 1}),
#   'up': defaultdict(int, {'toward': 1}),
#   'back': defaultdict(int, {'up': 1}),
#   'as': defaultdict(int, {'if': 1}),
#   'like': defaultdict(int, {'lightning': 1})},
#  'down': {'one': defaultdict(int, {'as': 1, 'street': 1}),
#   'to': defaultdict(int, {'day': 1, 'walk': 1}),
#   'the': defaultdict(int, {'saddest': 1, 'stairs': 1}),
#   'and': defaultdict(int, {'raised': 1}),
#   'from': defaultdict(int, {'field': 1, 'everything': 1}),
#   'he': defaultdict(int, {'fought': 1}),
#   'like': defaultdict(int, {'a': 1}),
#   'in': defaultdict(int, {'the': 3}),
#   'off': defaultdict(int, {'this': 1}),
#   'ill': defaultdict(int, {'tell': 1}),
#   'alone': defaultdict(int, {'sunday': 1}),
#   'this': defaultdict(int, {'is': 1}),
#   'thats': defaultdict(int, {'been': 1}),
#   'ryans': defaultdict(int, {'hill': 1})},
#  'as': {'far': defaultdict(int, {'as': 2}),
#   'i': defaultdict(int, {'could': 1, 'am': 1, 'do': 1, 'say': 1}),
#   'just': defaultdict(int, {'as': 1}),
#   'for': defaultdict(int, {'that': 2, 'the': 1}),
#   'often': defaultdict(int, {'as': 2}),
#   'ive': defaultdict(int, {'seen': 1}),
#   'if': defaultdict(int,
#               {'some': 1,
#                'for': 1,
#                'the': 1,
#                'id': 1,
#                'it': 1,
#                'by': 1,
#                'and': 1,
#                'he': 1}),
#   'they': defaultdict(int, {'were': 1}),
#   'good': defaultdict(int, {'as': 2, 'they': 1}),
#   'he': defaultdict(int, {'chanced': 1, 'chose': 1, 'feared': 1, 'had': 1}),
#   'standing': defaultdict(int, {'in': 1}),
#   'an': defaultdict(int, {'authority': 1}),
#   'a': defaultdict(int, {'witch': 1, 'match': 1, 'spring': 1}),
#   'sures': defaultdict(int, {'youre': 1}),
#   'well': defaultdict(int, {'herself': 1, 'see': 1, 'be': 1, 'off': 1}),
#   'we': defaultdict(int, {'could': 1, 'can': 1}),
#   'plateglass': defaultdict(int, {'windows': 1}),
#   'long': defaultdict(int, {'ago': 1}),
#   'yet': defaultdict(int, {'have': 1, 'so': 1}),
#   'to': defaultdict(int, {'sort': 1, 'have': 1, 'hens': 1}),
#   'gilt': defaultdict(int, {'to': 1}),
#   'one': defaultdict(int, {'who': 1}),
#   'pale': defaultdict(int, {'and': 1}),
#   'you': defaultdict(int, {'throw': 1, 'seize': 1, 'may': 1}),
#   'youre': defaultdict(int, {'told': 1}),
#   'sound': defaultdict(int, {'as': 1}),
#   'the': defaultdict(int, {'day': 1}),
#   'saint': defaultdict(int, {'mark': 1}),
#   'winds': defaultdict(int, {'might': 1}),
#   'married': defaultdict(int, {'thats': 1}),
#   'own': defaultdict(int, {'the': 1}),
#   'it': defaultdict(int, {'is': 1, 'can': 1}),
#   'much': defaultdict(int, {'to': 1}),
#   'near': defaultdict(int, {'a': 1}),
#   'winter': defaultdict(int, {'friends': 1})},
#  'far': {'as': defaultdict(int, {'i': 1, 'we': 1}),
#   'away': defaultdict(int, {'an': 1}),
#   'from': defaultdict(int, {'my': 1}),
#   'off': defaultdict(int, {'he': 1}),
#   'you': defaultdict(int, {'must': 1}),
#   'youve': defaultdict(int, {'heard': 1}),
#   'and': defaultdict(int, {'how': 1}),
#   'before': defaultdict(int, {'the': 1})},
#  'to': {'where': defaultdict(int, {'it': 2}),
#   'watch': defaultdict(int, {'his': 1, 'me': 1}),
#   'stop': defaultdict(int, {'without': 1, 'the': 1, 'and': 1}),
#   'ask': defaultdict(int, {'if': 1}),
#   'go': defaultdict(int, {'before': 2, 'by': 1, 'west': 1}),
#   'perish': defaultdict(int, {'twice': 1}),
#   'say': defaultdict(int, {'that': 1, 'you': 1, 'the': 1, 'which': 1}),
#   'call': defaultdict(int, {'me': 1, 'it': 1}),
#   'the': defaultdict(int,
#               {'garden': 1,
#                'fountain': 1,
#                'famous': 1,
#                'people': 1,
#                'kitchen': 1,
#                'bedroom': 1,
#                'attic': 1,
#                'knob': 1,
#                'cellar': 1,
#                'only': 1,
#                'door': 1,
#                'place': 1,
#                'pianos': 1,
#                'eye': 1,
#                'root': 1}),
#   'carry': defaultdict(int, {'again': 1}),
#   'pay': defaultdict(int, {'for': 1}),
#   'think': defaultdict(int, {'to': 1, 'of': 3}),
#   'know': defaultdict(int, {'the': 1}),
#   'tell': defaultdict(int, {'the': 3, 'them': 1, 'him': 1}),
#   'make': defaultdict(int, {'a': 2, 'it': 2, 'so': 1, 'them': 1}),
#   'be': defaultdict(int,
#               {'undone': 1,
#                'broken': 1,
#                'cruel': 1,
#                'thrown': 1,
#                'enough': 1,
#                'mad': 1,
#                'heard': 1,
#                'salted': 1,
#                'good': 1,
#                'you': 1,
#                'in': 1,
#                'a': 1,
#                'as': 1,
#                'the': 1}),
#   'spare': defaultdict(int, {'his': 1, 'them': 1}),
#   'everything': defaultdict(int, {'he': 1}),
#   'his': defaultdict(int, {'abode': 1, 'house': 1}),
#   'natural': defaultdict(int, {'law': 1}),
#   'have': defaultdict(int, {'two': 1, 'it': 1, 'the': 2, 'grandchildren': 1}),
#   'each': defaultdict(int, {'other': 2}),
#   'do': defaultdict(int,
#               {'over': 1,
#                'right': 1,
#                'it': 1,
#                'to': 2,
#                'anything': 1,
#                'at': 1,
#                'the': 1}),
#   'see': defaultdict(int,
#               {'if': 1,
#                'it': 1,
#                'how': 1,
#                'me': 1,
#                'what': 1,
#                'for': 1,
#                'us': 1,
#                'where': 1}),
#   'take': defaultdict(int,
#               {'over': 1, 'me': 2, 'it': 1, 'any': 1, 'her': 1, 'them': 1}),
#   'our': defaultdict(int, {'clearing': 1, 'greatgrandmother': 1}),
#   'live': defaultdict(int, {'in': 1, 'here': 1, 'together': 1, 'with': 1}),
#   'prefer': defaultdict(int, {'to': 1}),
#   'last': defaultdict(int, {'for': 1}),
#   'consent': defaultdict(int, {'to': 1}),
#   'give': defaultdict(int, {'some': 1, 'a': 1}),
#   'skin': defaultdict(int, {'and': 1}),
#   'blanket': defaultdict(int, {'him': 1}),
#   'gnaw': defaultdict(int, {'the': 1}),
#   'splinters': defaultdict(int, {'what': 1}),
#   'turn': defaultdict(int, {'him': 1}),
#   'saying': defaultdict(int, {'things': 1}),
#   'undo': defaultdict(int, {'what': 1}),
#   'let': defaultdict(int, {'on': 1, 'myself': 1}),
#   'death': defaultdict(int, {'with': 1}),
#   'put': defaultdict(int, {'up': 1, 'out': 1}),
#   'a': defaultdict(int, {'worse': 1}),
#   'shut': defaultdict(int, {'you': 1}),
#   'woods': defaultdict(int, {'around': 1}),
#   'bad': defaultdict(int, {'masonry': 1}),
#   'find': defaultdict(int, {'it': 1, 'out': 1, 'or': 1, 'yourself': 1}),
#   'descend': defaultdict(int, {'to': 1}),
#   'surprise': defaultdict(int, {'the': 1}),
#   'spend': defaultdict(int, {'the': 1}),
#   'lave': defaultdict(int, {'my': 1}),
#   'bring': defaultdict(int, {'me': 1}),
#   'for': defaultdict(int, {'broadboard': 1}),
#   'introduce': defaultdict(int, {'you': 1}),
#   'entertain': defaultdict(int, {'the': 1}),
#   'stock': defaultdict(int, {'a': 1}),
#   'unprotected': defaultdict(int, {'glass': 1}),
#   'hurt': defaultdict(int, {'a': 1}),
#   'send': defaultdict(int, {'it': 1}),
#   'improve': defaultdict(int, {'on': 1}),
#   'tumble': defaultdict(int, {'like': 1}),
#   'sell': defaultdict(int, {'or': 1, 'theyre': 1}),
#   'such': defaultdict(int, {'a': 1}),
#   'pass': defaultdict(int, {'a': 1, 'by': 1}),
#   'sleep': defaultdict(int, {'before': 1}),
#   'bed': defaultdict(int, {'alone': 1}),
#   'cool': defaultdict(int, {'the': 2}),
#   'sort': defaultdict(int, {'of': 1}),
#   'myself': defaultdict(int, {'enough': 1}),
#   'wonder': defaultdict(int, {'where': 1}),
#   'walk': defaultdict(int, {'dryshod': 1}),
#   'get': defaultdict(int,
#               {'to': 1,
#                'outdoors': 1,
#                'out': 1,
#                'at': 1,
#                'married': 1,
#                'away': 1}),
#   'happen': defaultdict(int, {'in': 1}),
#   'you': defaultdict(int, {'it': 1, 'to': 1, 'old': 1}),
#   'sing': defaultdict(int, {'along': 1}),
#   'that': defaultdict(int, {'and': 1}),
#   'climb': defaultdict(int, {'the': 1}),
#   'hear': defaultdict(int,
#               {'them': 1, 'today': 1, 'the': 1, 'me': 1, 'your': 1}),
#   'us': defaultdict(int, {'than': 1}),
#   'no': defaultdict(int, {'one': 1}),
#   'help': defaultdict(int, {'dig': 1}),
#   'gold': defaultdict(int, {'that': 1}),
#   'south': defaultdict(int, {'across': 1}),
#   'shelter': defaultdict(int, {'them': 1}),
#   'stand': defaultdict(int, {'together': 1}),
#   'reconnoitre': defaultdict(int, {'and': 1}),
#   'till': defaultdict(int, {'she': 1}),
#   'use': defaultdict(int, {'your': 1}),
#   'try': defaultdict(int, {'something': 1}),
#   'set': defaultdict(int, {'the': 1}),
#   'speak': defaultdict(int, {'in': 1}),
#   'regard': defaultdict(int, {'as': 1}),
#   'plain': defaultdict(int, {'speaking': 1}),
#   'cut': defaultdict(int, {'her': 1}),
#   'my': defaultdict(int, {'way': 1}),
#   'remind': defaultdict(int, {'me': 1}),
#   'build': defaultdict(int, {'in': 1}),
#   'their': defaultdict(int, {'shining': 1, 'leaves': 1}),
#   'blow': defaultdict(int, {'the': 1}),
#   'ridgely': defaultdict(int, {'torrence': 1}),
#   'look': defaultdict(int, {'too': 1}),
#   'haunt': defaultdict(int, {'this': 1}),
#   'upstart': defaultdict(int, {'inexperience': 1}),
#   'all': defaultdict(int, {'but': 1}),
#   'bush': defaultdict(int, {'my': 1}),
#   'curl': defaultdict(int, {'a': 1}),
#   'anything': defaultdict(int, {'growing': 1}),
#   'sink': defaultdict(int, {'under': 1}),
#   'which': defaultdict(int, {'man': 1}),
#   'drag': defaultdict(int, {'down': 1}),
#   'dream': defaultdict(int, {'of': 1}),
#   'dance': defaultdict(int, {'in': 1}),
#   'come': defaultdict(int, {'to': 1}),
#   'her': defaultdict(int, {'and': 1, 'what': 1}),
#   'sit': defaultdict(int, {'and': 1}),
#   'leave': defaultdict(int, {'him': 1}),
#   'keep': defaultdict(int, {'the': 2, 'accounts': 1}),
#   'stay': defaultdict(int, {'with': 1}),
#   'it': defaultdict(int, {'or': 1, 'and': 1}),
#   'break': defaultdict(int, {'it': 1}),
#   'him': defaultdict(int, {'you': 1}),
#   'pasture': defaultdict(int, {'rig': 1}),
#   'me': defaultdict(int, {'these': 1}),
#   'sun': defaultdict(int, {'and': 1}),
#   'paradise': defaultdict(int, {'all': 1}),
#   'wake': defaultdict(int, {'and': 1})},
#  'where': {'it': defaultdict(int,
#               {'bent': 1,
#                'ended': 1,
#                'fell': 1,
#                'wants': 1,
#                'came': 1,
#                'is': 1}),
#   'arent': defaultdict(int, {'you': 1}),
#   'youre': defaultdict(int, {'off': 1}),
#   'we': defaultdict(int, {'lived': 1, 'faced': 1}),
#   'the': defaultdict(int, {'trees': 1, 'cold': 1, 'axe': 1, 'chimney': 1}),
#   'he': defaultdict(int, {'sees': 1, 'can': 1}),
#   'once': defaultdict(int, {'on': 1}),
#   'i': defaultdict(int, {'am': 1, 'show': 1, 'was': 1}),
#   'you': defaultdict(int, {'were': 1, 'are': 1}),
#   'driven': defaultdict(int, {'rain': 1}),
#   'someone': defaultdict(int, {'now': 1}),
#   'henry': defaultdict(int, {'hudsons': 1}),
#   'be': defaultdict(int, {'failed': 1}),
#   'did': defaultdict(int, {'i': 1}),
#   'farming': defaultdict(int, {'has': 1}),
#   'they': defaultdict(int, {'were': 1, 'speak': 1}),
#   'your': defaultdict(int, {'oracle': 1}),
#   'shall': defaultdict(int, {'we': 1}),
#   'this': defaultdict(int, {'old': 1}),
#   'woods': defaultdict(int, {'have': 1}),
#   'were': defaultdict(int, {'they': 1}),
#   'two': defaultdict(int, {'village': 1}),
#   'john': defaultdict(int, {'has': 1}),
#   'myself': defaultdict(int, {'john': 1}),
#   'is': defaultdict(int, {'estelle': 1}),
#   'she': defaultdict(int, {'is': 1}),
#   'all': defaultdict(int, {'the': 1}),
#   'conies': defaultdict(int, {'now': 1})},
#  'it': {'bent': defaultdict(int, {'in': 1}),
#   'was': defaultdict(int,
#               {'grassy': 1,
#                'to': 1,
#                'the': 2,
#                'all': 1,
#                'there': 1,
#                'proclaimed': 1,
#                'cut': 1,
#                'raining': 1,
#                'coming': 1,
#                'long': 1,
#                'bad': 1}),
#   'had': defaultdict(int, {'to': 1, 'sprung': 1, 'its': 1}),
#   'done': defaultdict(int, {'before': 1, 'in': 1}),
#   'looks': defaultdict(int, {'as': 1, 'that': 1}),
#   'takes': defaultdict(int, {'the': 1, 'all': 1}),
#   'from': defaultdict(int, {'men': 1}),
#   'on': defaultdict(int, {'his': 1, 'consideration': 1}),
#   'must': defaultdict(int, {'have': 1, 'be': 3}),
#   'settled': defaultdict(int, {'whose': 1, 'wrong': 1}),
#   'through': defaultdict(int, {'the': 1, 'again': 1}),
#   'surer': defaultdict(int, {'that': 1}),
#   'want': defaultdict(int, {'no': 1}),
#   'would': defaultdict(int, {'have': 1, 'speak': 1}),
#   'for': defaultdict(int, {'proof': 1, 'me': 1}),
#   'that': defaultdict(int, {'this': 1}),
#   'doesnt': defaultdict(int, {'seem': 2}),
#   'to': defaultdict(int, {'me': 1, 'him': 1}),
#   'and': defaultdict(int, {'were': 1, 'besides': 1}),
#   'out': defaultdict(int, {'of': 1}),
#   'ended': defaultdict(int, {'at': 1}),
#   'published': defaultdict(int, {'it': 1}),
#   'seemed': defaultdict(int, {'the': 1}),
#   'inward': defaultdict(int, {'on': 1}),
#   'sailing': defaultdict(int, {'out': 1}),
#   'caught': defaultdict(int, {'wind': 1}),
#   'at': defaultdict(int, {'his': 1}),
#   'lying': defaultdict(int, {'where': 1}),
#   'fell': defaultdict(int, {'rejected': 1}),
#   'with': defaultdict(int, {'a': 1}),
#   'isnt': defaultdict(int, {'as': 1, 'going': 1, 'grandsir': 1, 'worth': 1}),
#   'is': defaultdict(int, {'to': 2, 'it': 1}),
#   'what': defaultdict(int, {'good': 1, 'was': 1}),
#   'in': defaultdict(int, {'the': 1, 'creation': 1}),
#   'wants': defaultdict(int, {'to': 1}),
#   'came': defaultdict(int, {'from': 1}),
#   'left': defaultdict(int, {'the': 1}),
#   'wasnt': defaultdict(int, {'toffile': 1, 'anyone': 1}),
#   'took': defaultdict(int, {'the': 1}),
#   'looked': defaultdict(int, {'like': 1}),
#   'almost': defaultdict(int, {'climbed': 1}),
#   'or': defaultdict(int, {'else': 1, 'i': 1}),
#   'one': defaultdict(int, {'night': 1}),
#   'ready': defaultdict(int, {'for': 1}),
#   'sweet': defaultdict(int, {'and': 1}),
#   'seems': defaultdict(int, {'were': 1, 'as': 1}),
#   'ought': defaultdict(int, {'to': 2}),
#   'all': defaultdict(int, {'is': 1, 'about': 1, 'the': 2}),
#   'purport': defaultdict(int, {'to': 1}),
#   'rests': defaultdict(int, {'with': 1}),
#   'as': defaultdict(int, {'i': 1}),
#   'should': defaultdict(int, {'have': 2}),
#   'too': defaultdict(int, {'toppling': 1, 'it': 1}),
#   'glimpses': defaultdict(int, {'only': 1}),
#   'living': defaultdict(int, {'for': 1}),
#   'a': defaultdict(int, {'piano': 1}),
#   'some': defaultdict(int, {'money': 1}),
#   'has': defaultdict(int, {'not': 2}),
#   'runs': defaultdict(int, {'unbridled': 1}),
#   'will': defaultdict(int, {'go': 1}),
#   'any': defaultdict(int, {'other': 1}),
#   'year': defaultdict(int, {'in': 1}),
#   'turns': defaultdict(int, {'out': 1}),
#   'more': defaultdict(int, {'because': 1}),
#   'mind': defaultdict(int, {'we': 1}),
#   'makes': defaultdict(int, {'it': 2}),
#   'the': defaultdict(int, {'neighbours': 1}),
#   'folks': defaultdict(int, {'arent': 1}),
#   'worry': defaultdict(int, {'her': 1}),
#   'along': defaultdict(int, {'at': 1}),
#   'right': defaultdict(int, {'out': 1}),
#   'hell': defaultdict(int, {'he': 1}),
#   'can': defaultdict(int, {'be': 1}),
#   'lifts': defaultdict(int, {'existence': 1, 'a': 1}),
#   'worth': defaultdict(int, {'lifes': 1})},
#  'bent': {'in': defaultdict(int, {'the': 1})},
#  'then': {'took': defaultdict(int, {'the': 1}),
#   'leaf': defaultdict(int, {'subsides': 1}),
#   'becoming': defaultdict(int, {'reconciled': 1}),
#   'went': defaultdict(int, {'round': 1}),
#   'shook': defaultdict(int, {'his': 1}),
#   'that': defaultdict(int, {'same': 1}),
#   'and': defaultdict(int, {'forty': 1}),
#   'right': defaultdict(int, {'here': 1}),
#   'he': defaultdict(int, {'came': 1, 'cant': 1}),
#   'ran': defaultdict(int, {'and': 1}),
#   'we': defaultdict(int, {'asked': 1}),
#   'made': defaultdict(int, {'up': 1}),
#   'i': defaultdict(int, {'dont': 1}),
# ...
#   'we': defaultdict(int, {'know': 1}),
#   'yes': defaultdict(int, {'we': 1})},
#  'oldbelievers': {'they': defaultdict(int, {'did': 1})},
#  'pass': {'a': defaultdict(int, {'winter': 1}),
#   'by': defaultdict(int, {'and': 1})},
#  'burned': {'at': defaultdict(int, {'the': 1}),
#   'dissolved': defaultdict(int, {'and': 1})},
#  'stake': {'or': defaultdict(int, {'something': 1})},
#  'summoning': {'spirits': defaultdict(int, {'isnt': 1})},
#  'spirits': {'isnt': defaultdict(int, {'button': 1})},
#  'whos': {'got': defaultdict(int, {'the': 1})},
#  'button': {'i': defaultdict(int, {'would': 1})},
#  'son': {'mother': defaultdict(int, {'can': 1}),
#   'you': defaultdict(int, {'wouldnt': 1, 'do': 1}),
#   'but': defaultdict(int, {'the': 1}),
#   'it': defaultdict(int, {'left': 1}),
#   'we': defaultdict(int, {'think': 1, 'never': 1}),
#   'tell': defaultdict(int, {'the': 1}),
#   'knows': defaultdict(int, {'the': 1}),
#   'looks': defaultdict(int, {'surprised': 1})},
#  'common': {'table': defaultdict(int, {'rear': 1})},
#  'legs': {'like': defaultdict(int, {'an': 1}),
#   'out': defaultdict(int, {'of': 1})},
#  'rather': {'than': defaultdict(int, {'tip': 1})},
#  'tip': {'a': defaultdict(int, {'table': 1})},
#  'table': {'for': defaultdict(int, {'you': 1})},
#  'ralle': {'the': defaultdict(int, {'sioux': 1})},
#  'sioux': {'control': defaultdict(int, {'once': 1})},
#  'control': {'once': defaultdict(int, {'told': 1})},
#  'souls': {'but': defaultdict(int, {'when': 1})},
#  'broke': {'my': defaultdict(int, {'trance': 1})},
#  'trance': {'dont': defaultdict(int, {'that': 1}),
#   'you': defaultdict(int, {'are': 1})},
#  'yes': {'theres': defaultdict(int, {'something': 1}),
#   'we': defaultdict(int, {'could': 1}),
#   'for': defaultdict(int, {'there': 1}),
#   'stark': defaultdict(int, {'and': 1}),
#   'what': defaultdict(int, {'do': 1}),
#   'its': defaultdict(int, {'important': 1}),
#   'you': defaultdict(int, {'must': 1}),
#   'whats': defaultdict(int, {'it': 1}),
#   'but': defaultdict(int, {'he': 1}),
#   'i': defaultdict(int, {'do': 1})},
#  'wouldnt': {'want': defaultdict(int, {'to': 1}),
#   'have': defaultdict(int, {'him': 1}),
#   'hurt': defaultdict(int, {'a': 1}),
#   'give': defaultdict(int, {'way': 1})},
#  'bones': {'a': defaultdict(int, {'skeleton': 1}),
#   'came': defaultdict(int, {'up': 1}),
#   'i': defaultdict(int, {'knew': 1}),
#   'didnt': defaultdict(int, {'try': 1}),
#   'the': defaultdict(int, {'cellar': 1}),
#   'out': defaultdict(int, {'of': 1}),
#   'liked': defaultdict(int, {'the': 1}),
#   'they': defaultdict(int, {'were': 1})},
#  'headboard': {'of': defaultdict(int, {'mothers': 1, 'the': 2}),
#   'where': defaultdict(int, {'it': 1})},
#  'mothers': {'bed': defaultdict(int, {'is': 1})},
#  'door': {'the': defaultdict(int, {'door': 1}),
#   'is': defaultdict(int, {'nailed': 1}),
#   'and': defaultdict(int, {'headboard': 2, 'held': 1}),
#   'to': defaultdict(int, {'cool': 1, 'the': 1, 'try': 1, 'get': 1}),
#   'but': defaultdict(int, {'the': 1}),
#   'they': defaultdict(int, {'halted': 1}),
#   'wide': defaultdict(int, {'on': 1, 'but': 1}),
#   'for': defaultdict(int, {'the': 1}),
#   'up': defaultdict(int, {'attic': 1})},
#  'harmless': {'mother': defaultdict(int, {'hears': 1})},
#  'hears': {'it': defaultdict(int, {'in': 1})},
#  'halting': {'perplexed': defaultdict(int, {'behind': 1})},
#  'perplexed': {'behind': defaultdict(int, {'the': 1})},
#  'wants': {'to': defaultdict(int, {'get': 1, 'hear': 1}),
#   'our': defaultdict(int, {'hens': 1})},
#  'cellar': {'where': defaultdict(int, {'it': 1}),
#   'forty': defaultdict(int, {'years': 1}),
#   'to': defaultdict(int, {'the': 1}),
#   'in': defaultdict(int, {'spring': 1}),
#   'bottom': defaultdict(int, {'and': 1}),
#   'windows': defaultdict(int, {'were': 1}),
#   'or': defaultdict(int, {'the': 1}),
#   'bones': defaultdict(int, {'out': 1}),
#   'hole': defaultdict(int, {'in': 1}),
#   'after': defaultdict(int, {'jam': 1})},
#  'forty': {'years': defaultdict(int, {'ago': 1}),
#   'cellar': defaultdict(int, {'holes': 1})},
#  'carried': {'itself': defaultdict(int, {'like': 1})},
#  'itself': {'like': defaultdict(int, {'a': 1})},
#  'pile': {'of': defaultdict(int, {'dishes': 1})},
#  'flight': {'from': defaultdict(int, {'the': 1})},
#  'another': {'from': defaultdict(int, {'the': 2}),
#   'door': defaultdict(int, {'to': 1})},
#  'kitchen': {'to': defaultdict(int, {'the': 1, 'yourself': 1}),
#   'had': defaultdict(int, {'been': 1})},
#  'bedroom': {'to': defaultdict(int, {'the': 1})},
#  'past': {'both': defaultdict(int, {'father': 1}),
#   'and': defaultdict(int, {'get': 1})},
#  'gone': {'upstairs': defaultdict(int, {'mother': 1}),
#   'to': defaultdict(int, {'bed': 1, 'yours': 1, 'garlands': 1}),
#   'out': defaultdict(int, {'of': 1}),
#   'before': defaultdict(int, {'i': 1}),
#   'so': defaultdict(int, {'far': 1}),
#   'of': defaultdict(int, {'course': 1})},
#  'upstairs': {'mother': defaultdict(int, {'was': 1}),
#   'in': defaultdict(int, {'the': 1}),
#   'and': defaultdict(int, {'in': 1})},
#  'baby': {'i': defaultdict(int, {'dont': 1})},
#  'fault': {'my': defaultdict(int, {'husband': 1})},
#  'husband': {'found': defaultdict(int, {'with': 1})},
#  'sleep': {'before': defaultdict(int, {'i': 1})},
#  'especially': {'in': defaultdict(int, {'winter': 1})},
#  'ice': {'and': defaultdict(int, {'the': 1})},
#  'toffile': {'had': defaultdict(int, {'gone': 1}),
#   'upstairs': defaultdict(int, {'in': 1}),
#   'for': defaultdict(int, {'my': 1}),
#   'i': defaultdict(int, {'dont': 1}),
#   'agreed': defaultdict(int, {'to': 1}),
#   'didnt': defaultdict(int, {'seem': 1}),
#   'get': defaultdict(int, {'nails': 1}),
#   'to': defaultdict(int, {'be': 1}),
#   'if': defaultdict(int, {'he': 1})},
#  'alone': {'and': defaultdict(int, {'left': 1}),
#   'sunday': defaultdict(int, {'after': 1})},
#  'open': {'door': defaultdict(int, {'to': 2, 'up': 1}),
#   'grassy': defaultdict(int, {'places': 1})},
#  'cool': {'the': defaultdict(int, {'room': 1, 'eyes': 1})},
#  'coming': {'to': defaultdict(int, {'myself': 1}),
#   'up': defaultdict(int, {'to': 1, 'had': 1}),
#   'down': defaultdict(int, {'ryans': 1})},
#  'cold': {'was': defaultdict(int, {'coming': 1}),
#   'as': defaultdict(int, {'a': 1}),
#   'a': defaultdict(int, {'digger': 1})},
#  'downstairs': {'in': defaultdict(int, {'the': 1})},
#  'board': {'we': defaultdict(int, {'had': 1})},
#  'laid': {'down': defaultdict(int, {'to': 1})},
#  'walk': {'dryshod': defaultdict(int, {'on': 1})},
#  'water': {'in': defaultdict(int, {'the': 1}),
#   'more': defaultdict(int, {'or': 1}),
#   'of': defaultdict(int, {'the': 1})},
#  'hard': {'cellar': defaultdict(int, {'bottom': 1}),
#   'on': defaultdict(int, {'the': 1}),
#   'with': defaultdict(int, {'john': 1})},
#  'bottom': {'and': defaultdict(int, {'then': 1})},
#  'began': {'the': defaultdict(int, {'stairs': 1}),
#   'to': defaultdict(int, {'climb': 1})},
#  'stairs': {'two': defaultdict(int, {'footsteps': 1}),
#   'at': defaultdict(int, {'night': 1})},
#  'footsteps': {'for': defaultdict(int, {'each': 1})},
#  'leg': {'and': defaultdict(int, {'a': 1})},
#  'child': {'comes': defaultdict(int, {'up': 1})},
#  'bulkhead': {'doubledoors': defaultdict(int, {'were': 1})},
#  'doubledoors': {'were': defaultdict(int, {'doublelocked': 1})},
#  'swollen': {'tight': defaultdict(int, {'and': 2})},
#  'tight': {'and': defaultdict(int, {'buried': 2})},
#  'windows': {'were': defaultdict(int, {'banked': 1})},
#  'banked': {'up': defaultdict(int, {'with': 1})},
#  'impulse': {'was': defaultdict(int, {'to': 1}),
#   'not': defaultdict(int, {'to': 1})},
#  'get': {'to': defaultdict(int, {'the': 2}),
#   'up': defaultdict(int, {'im': 1, 'forgive': 1}),
#   'nails': defaultdict(int, {'i': 1}),
#   'some': defaultdict(int, {'strangeness': 1, 'color': 1}),
#   'her': defaultdict(int, {'greatness': 1}),
#   'out': defaultdict(int, {'of': 1}),
#   'saved': defaultdict(int, {'as': 1}),
#   'me': defaultdict(int, {'through': 1}),
#   'married': defaultdict(int, {'when': 1}),
#   'far': defaultdict(int, {'before': 1})},
#  'halted': {'helpless': defaultdict(int, {'on': 1}),
#   'some': defaultdict(int, {'way': 1})},
#  'helpless': {'on': defaultdict(int, {'the': 1})},
#  'faintest': {'restless': defaultdict(int, {'rustling': 1})},
#  'restless': {'rustling': defaultdict(int, {'ran': 1})},
#  'rustling': {'ran': defaultdict(int, {'all': 1})},
#  'wish': {'hadnt': defaultdict(int, {'been': 1}),
#   'to': defaultdict(int, {'hear': 1, 'give': 1})},
#  'strong': {'in': defaultdict(int, {'me': 1})},
#  'mounted': {'for': defaultdict(int, {'this': 1}),
#   'bareback': defaultdict(int, {'on': 1})},
#  'vision': {'of': defaultdict(int, {'them': 1})},
#  'flung': {'the': defaultdict(int, {'door': 1})},
#  'wide': {'on': defaultdict(int, {'him': 1}),
#   'but': defaultdict(int, {'he': 1})},
#  'moment': {'he': defaultdict(int, {'stood': 1, 'was': 1})},
#  'balancing': {'with': defaultdict(int, {'emotion': 1})},
#  'himself': {'a': defaultdict(int, {'tongue': 1}),
#   'wont': defaultdict(int, {'imagine': 1})},
#  'tongue': {'of': defaultdict(int, {'fire': 1})},
#  'flashed': {'out': defaultdict(int, {'and': 1})},
#  'licked': {'along': defaultdict(int, {'his': 1})},
#  'along': {'his': defaultdict(int, {'upper': 1}),
#   'the': defaultdict(int, {'toteroad': 1}),
#   'at': defaultdict(int, {'first': 1}),
#   'with': defaultdict(int, {'him': 1})},
#  'smoke': {'rolled': defaultdict(int, {'inside': 1})},
#  'rolled': {'inside': defaultdict(int, {'the': 1})},
#  'inside': {'the': defaultdict(int, {'sockets': 1})},
#  'sockets': {'of': defaultdict(int, {'his': 1})},
#  'hand': {'off': defaultdict(int, {'brittle': 1}),
#   'me': defaultdict(int, {'my': 1}),
#   'up': defaultdict(int, {'pick': 1})},
#  'brittle': {'on': defaultdict(int, {'the': 1})},
#  'fingerpieces': {'slid': defaultdict(int, {'in': 1})},
#  'slid': {'in': defaultdict(int, {'all': 1})},
#  'buttonbox': {'it': defaultdict(int, {'must': 1})},
#  'sat': {'up': defaultdict(int, {'on': 1}),
#   'listening': defaultdict(int, {'to': 1})},
#  'floor': {'and': defaultdict(int, {'shouted': 1})},
#  'briskly': {'for': defaultdict(int, {'so': 1})},
#  'slow': {'a': defaultdict(int, {'thing': 1})},
#  'stillgoing': {'every': defaultdict(int, {'which': 1})},
#  'lightning': {'or': defaultdict(int, {'a': 1})},
#  'slap': {'i': defaultdict(int, {'had': 1})},
#  'given': {'its': defaultdict(int, {'hand': 1}),
#   'an': defaultdict(int, {'opening': 1}),
#   'to': defaultdict(int, {'plain': 1}),
#   'her': defaultdict(int, {'time': 1})},
#  'listened': {'till': defaultdict(int, {'it': 1}),
#   'in': defaultdict(int, {'among': 1})},
#  'almost': {'climbed': defaultdict(int, {'the': 1}),
#   'the': defaultdict(int, {'moment': 1}),
#   'here': defaultdict(int, {'ive': 1})},
#  'climbed': {'the': defaultdict(int, {'stairs': 1})},
#  'shouted': {'shut': defaultdict(int, {'the': 1})},
#  'company': {'he': defaultdict(int, {'said': 1}),
#   'outward': defaultdict(int, {'bound': 1})},
#  'warm': {'in': defaultdict(int, {'bed': 1})},
#  'forward': {'weakly': defaultdict(int, {'on': 1})},
#  'weakly': {'on': defaultdict(int, {'the': 1})},
#  'pushed': {'myself': defaultdict(int, {'upstairs': 1})},
#  'us': {'in': defaultdict(int, {'the': 1}),
#   'than': defaultdict(int, {'the': 1}),
#   'back': defaultdict(int, {'into': 1}),
#   'always': defaultdict(int, {'to': 1}),
#   'but': defaultdict(int, {'look': 1}),
#   'have': defaultdict(int, {'any': 1})},
#  'room': {'though': defaultdict(int, {'its': 1}),
#   'before': defaultdict(int, {'a': 1})},
#  'throw': {'his': defaultdict(int, {'bare': 1}),
#   'a': defaultdict(int, {'picture': 1}),
#   'the': defaultdict(int, {'hoe': 1})},
#  'bare': {'legs': defaultdict(int, {'out': 1})},
#  'sit': {'up': defaultdict(int, {'by': 1, 'in': 1}),
#   'before': defaultdict(int, {'you': 1}),
#   'and': defaultdict(int, {'tell': 1})},
#  'mow': {'the': defaultdict(int, {'room': 1})},
#  'arms': {'at': defaultdict(int, {'the': 1})},
#  'level': {'of': defaultdict(int, {'our': 1}),
#   'higher': defaultdict(int, {'than': 1}),
#   'nearer': defaultdict(int, {'heaven': 1})},
#  'chalkpile': {'down': defaultdict(int, {'ill': 1})},
#  'uncommonly': {'deep': defaultdict(int, {'snow': 1})},
#  'sing': {'along': defaultdict(int, {'the': 1})},
#  'trap': {'him': defaultdict(int, {'with': 1})},
#  'agreed': {'to': defaultdict(int, {'that': 1})},
#  'steps': {'began': defaultdict(int, {'to': 1})},
#  'quick': {'i': defaultdict(int, {'slammed': 1})},
#  'slammed': {'to': defaultdict(int, {'the': 1})},
#  'nails': {'i': defaultdict(int, {'made': 1})},
#  'nail': {'the': defaultdict(int, {'door': 1})},
#  'push': {'the': defaultdict(int, {'headboard': 1})},
#  'wed': {'ever': defaultdict(int, {'want': 1}),
#   'kept': defaultdict(int, {'all': 1})},
#  'brushing': {'their': defaultdict(int, {'chalky': 1})},
#  'chalky': {'skull': defaultdict(int, {'with': 1})},
#  'skull': {'with': defaultdict(int, {'chalky': 1})},
#  'dry': {'rattling': defaultdict(int, {'of': 1})},
#  'rattling': {'of': defaultdict(int, {'a': 1})},
#  '2o3': {'let': defaultdict(int, {'them': 1})},
#  'promised': {'toffile': defaultdict(int, {'to': 1})},
#  'cruel': {'to': defaultdict(int, {'them': 1}),
#   'once': defaultdict(int, {'to': 1})},
#  'helping': {'them': defaultdict(int, {'be': 1})},
#  'grave': {'down': defaultdict(int, {'in': 2})},
#  'truth': {'for': defaultdict(int, {'once': 1}),
#   'suppose': defaultdict(int, {'the': 1}),
#   'i': defaultdict(int, {'speak': 1})},
#  'mans': {'his': defaultdict(int, {'father': 1})},
#  'killed': {'for': defaultdict(int, {'me': 1}),
#   'instead': defaultdict(int, {'of': 1})},
#  'instead': {'of': defaultdict(int, {'me': 1})},
#  'help': {'dig': defaultdict(int, {'their': 1}),
#   'out': defaultdict(int, {'with': 1}),
#   'liking': defaultdict(int, {'about': 1})},
#  'dig': {'their': defaultdict(int, {'grave': 1})},
#  'knows': {'the': defaultdict(int, {'story': 1}),
#   'his': defaultdict(int, {'friends': 1}),
#   'hes': defaultdict(int, {'kinder': 1}),
#   'my': defaultdict(int, {'interest': 1})},
#  'story': {'but': defaultdict(int, {'twas': 1}),
#   'in': defaultdict(int, {'a': 1})},
#  'suppose': {'the': defaultdict(int, {'time': 1}),
#   'she': defaultdict(int, {'deserves': 1})},
#  'surprised': {'to': defaultdict(int, {'see': 1})},
#  'years': {'between': defaultdict(int, {'ourselves': 1}),
#   'berries': defaultdict(int, {'shining': 1}),
#   'high': defaultdict(int, {'girdle': 1})},
#  'tonight': {'i': defaultdict(int, {'dont': 1})},
#  'care': {'enough': defaultdict(int, {'to': 1}),
#   'of': defaultdict(int, {'him': 1})},
#  'fingerbone': {'she': defaultdict(int, {'wanted': 1})},
#  'among': {'the': defaultdict(int,
#               {'buttons': 1, 'raspberry': 1, 'sounds': 1, 'raspberries': 1}),
#   'unearthed': defaultdict(int, {'potatoes': 1})},
#  'buttons': {'poured': defaultdict(int, {'out': 1})},
#  'poured': {'out': defaultdict(int, {'in': 1})},
#  'verified': {'the': defaultdict(int, {'name': 1})},
#  'name': {'next': defaultdict(int, {'morning': 1}),
#   'stark': defaultdict(int, {'gathered': 1}),
#   'should': defaultdict(int, {'matter': 1}),
#   'all': defaultdict(int, {'the': 1}),
#   'the': defaultdict(int, {'hour': 1}),
#   'no': defaultdict(int, {'names': 1})},
#  'next': {'morning': defaultdict(int, {'toffile': 1})},
#  'rural': {'letterbox': defaultdict(int, {'said': 1})},
#  'letterbox': {'said': defaultdict(int, {'toffile': 1})},
#  'air': {'had': defaultdict(int, {'died': 1}),
#   'of': defaultdict(int, {'what': 1})},
#  'died': {'of': defaultdict(int, {'cold': 1})},
#  'shoeing': {'home': defaultdict(int, {'across': 1})},
#  'summer': {'when': defaultdict(int, {'i': 1}),
#   'dwelling': defaultdict(int, {'here': 1})},
#  'lift': {'my': defaultdict(int, {'face': 1}),
#   'themselves': defaultdict(int, {'up': 1})},
#  'singing': {'in': defaultdict(int, {'it': 2}),
#   'and': defaultdict(int, {'the': 1})},
#  'sweet': {'and': defaultdict(int, {'swift': 1})},
#  'single': {'leaf': defaultdict(int, {'was': 1})},
#  'twice': {'around': defaultdict(int, {'the': 1}),
#   'as': defaultdict(int, {'well': 1})},
#  'around': {'the': defaultdict(int, {'tree': 1}),
#   'and': defaultdict(int, {'under': 1}),
#   'twice': defaultdict(int, {'as': 1})},
#  'advantage': {'on': defaultdict(int, {'a': 1})},
#  'judged': {'that': defaultdict(int, {'such': 1})},
#  'adding': {'frost': defaultdict(int, {'to': 1})},
#  'frost': {'to': defaultdict(int, {'snow': 1})},
#  'gilt': {'to': defaultdict(int, {'gold': 1})},
#  ...}

# %%
for second_outer_keys in second_order.keys():
    for first_outer_keys in second_order[second_outer_keys].keys():
        sum = np.array(list(second_order[second_outer_keys][first_outer_keys].values())).sum()
        for inner_keys in second_order[second_outer_keys][first_outer_keys].keys():
            second_order[second_outer_keys][first_outer_keys][inner_keys]/=sum

second_order
# Out:
# {'two': {'roads': defaultdict(int, {'diverged': 1.0}),
#   'miles': defaultdict(int, {'it': 1.0}),
#   'towns': defaultdict(int, {'fighting': 1.0}),
#   'converging': defaultdict(int, {'slides': 1.0}),
#   'or': defaultdict(int, {'three': 1.0}),
#   'oldbelievers': defaultdict(int, {'they': 1.0}),
#   'legs': defaultdict(int, {'like': 1.0}),
#   'footsteps': defaultdict(int, {'for': 1.0}),
#   'village': defaultdict(int, {'cultures': 1.0}),
#   'winds': defaultdict(int, {'would': 1.0}),
#   'weeks': defaultdict(int, {'since': 1.0}),
#   'of': defaultdict(int, {'you': 1.0}),
#   'as': defaultdict(int, {'good': 1.0}),
#   'at': defaultdict(int, {'a': 1.0})},
#  'roads': {'diverged': defaultdict(int, {'in': 1.0})},
#  'diverged': {'in': defaultdict(int, {'a': 1.0})},
#  'in': {'a': defaultdict(int,
#               {'yellow': 0.07142857142857142,
#                'wood': 0.07142857142857142,
#                'window': 0.07142857142857142,
#                'packing': 0.07142857142857142,
#                'byroad': 0.07142857142857142,
#                'family': 0.07142857142857142,
#                'new': 0.07142857142857142,
#                'row': 0.07142857142857142,
#                'time': 0.07142857142857142,
#                'town': 0.07142857142857142,
#                'book': 0.07142857142857142,
#                'smother': 0.07142857142857142,
#                'glass': 0.14285714285714285}),
#   'the': defaultdict(int,
#               {'undergrowth': 0.021739130434782608,
#                'village': 0.021739130434782608,
#                'stars': 0.021739130434782608,
#                'confusion': 0.021739130434782608,
#                'excited': 0.021739130434782608,
#                'scene': 0.021739130434782608,
#                'river': 0.021739130434782608,
#                'cold': 0.043478260869565216,
#                'town': 0.021739130434782608,
#                'warrant': 0.021739130434782608,
#                'stable': 0.021739130434782608,
#                'huse': 0.021739130434782608,
#                'tail': 0.021739130434782608,
#                'dark': 0.043478260869565216,
#                'mountain': 0.021739130434782608,
#                'box': 0.021739130434782608,
#                'night': 0.021739130434782608,
#                'bedroom': 0.021739130434782608,
#                'cellar': 0.15217391304347827,
#                'joints': 0.021739130434782608,
#                'light': 0.021739130434782608,
#                'room': 0.021739130434782608,
#                'attic': 0.043478260869565216,
#                'grass': 0.021739130434782608,
#                'rain': 0.021739130434782608,
#                'sun': 0.021739130434782608,
#                'empty': 0.021739130434782608,
#                'open': 0.021739130434782608,
#                'kitchen': 0.021739130434782608,
#                'weather': 0.021739130434782608,
#                'playhouse': 0.021739130434782608,
#                'instep': 0.021739130434782608,
#                'newcut': 0.021739130434782608,
#                'plowed': 0.021739130434782608,
#                'bushy': 0.021739130434782608,
#                'heat': 0.021739130434782608,
#                'yard': 0.021739130434782608}),
#   'leaves': defaultdict(int, {'no': 1.0}),
#   'rain': defaultdict(int,
#               {'and': 0.3333333333333333,
#                'sometime': 0.3333333333333333,
#                'tomorrow': 0.3333333333333333}),
#   'front': defaultdict(int, {'of': 1.0}),
#   'every': defaultdict(int,
#               {'lifelike': 0.3333333333333333,
#                'open': 0.3333333333333333,
#                'way': 0.3333333333333333}),
#   'it': defaultdict(int,
#               {'from': 0.25, 'sweet': 0.25, 'now': 0.25, 'a': 0.25}),
#   'winter': defaultdict(int, {'after': 0.5, 'when': 0.5}),
#   'somewhere': defaultdict(int, {'with': 1.0}),
#   'march': defaultdict(int, {'meeting': 1.0}),
#   'warren': defaultdict(int, {'at': 1.0}),
#   'wentworth': defaultdict(int, {'from': 1.0}),
#   'their': defaultdict(int, {'town': 0.5, 'favour': 0.5}),
#   'his': defaultdict(int,
#               {'old': 0.3333333333333333,
#                'mouth': 0.3333333333333333,
#                'mans': 0.3333333333333333}),
#   'grafton': defaultdict(int, {'county': 1.0}),
#   'and': defaultdict(int, {'as': 0.5, 'the': 0.5}),
#   'folks': defaultdict(int, {'faces': 1.0}),
#   'dalton': defaultdict(int, {'that': 1.0}),
#   'dust': defaultdict(int, {'once': 1.0}),
#   'for': defaultdict(int, {'life': 1.0}),
#   'bed': defaultdict(int, {'and': 1.0}),
#   'stones': defaultdict(int, {'and': 1.0}),
#   'virgin': defaultdict(int, {'wrapper': 1.0}),
#   'one': defaultdict(int,
#               {'and': 0.3333333333333333,
#                'himself': 0.3333333333333333,
#                'self': 0.3333333333333333}),
#   'my': defaultdict(int, {'pocket': 1.0}),
#   'time': defaultdict(int, {'she': 1.0}),
#   'at': defaultdict(int, {'the': 1.0}),
#   'snow': defaultdict(int, {'and': 1.0}),
#   'its': defaultdict(int, {'twothousandmile': 1.0}),
#   'life': defaultdict(int, {'once': 1.0}),
#   'all': defaultdict(int, {'directions': 1.0}),
#   'her': defaultdict(int,
#               {'lap': 0.6666666666666666, 'day': 0.3333333333333333}),
#   'summer': defaultdict(int, {'when': 1.0}),
#   'going': defaultdict(int, {'twice': 1.0}),
#   'new': defaultdict(int, {'hampshire': 1.0}),
#   'an': defaultdict(int, {'old': 0.5, 'alder': 0.5}),
#   'grove': defaultdict(int, {'and': 1.0}),
#   'such': defaultdict(int, {'a': 1.0}),
#   'among': defaultdict(int, {'the': 1.0}),
#   'across': defaultdict(int, {'the': 1.0}),
#   'dialect': defaultdict(int, {'whose': 1.0}),
#   'not': defaultdict(int, {'old': 1.0}),
#   'this': defaultdict(int, {'place': 1.0}),
#   'sunshine': defaultdict(int, {'so': 1.0}),
#   'building': defaultdict(int, {'the': 1.0}),
#   'position': defaultdict(int, {'to': 1.0}),
#   'your': defaultdict(int, {'ladder': 1.0}),
#   'that': defaultdict(int, {'grave': 0.5, 'case': 0.25, 'apple': 0.25}),
#   'than': defaultdict(int, {'i': 1.0}),
#   'earnest': defaultdict(int, {'it': 1.0}),
#   'here': defaultdict(int, {'like': 1.0}),
#   'year': defaultdict(int, {'out': 1.0}),
#   'separate': defaultdict(int, {'coops': 1.0}),
#   'ways': defaultdict(int, {'that': 1.0})},
#  'a': {'yellow': defaultdict(int, {'wood': 1.0}),
#   'wood': defaultdict(int, {'and': 1.0}),
#   'farmhouse': defaultdict(int, {'near': 1.0}),
#   'tree': defaultdict(int, {'beside': 0.5, 'that': 0.5}),
#   'leaf': defaultdict(int, {'that': 0.5, 'if': 0.5}),
#   'voice': defaultdict(int, {'said': 1.0}),
#   'gentle': defaultdict(int, {'cast': 0.5, 'lot': 0.5}),
#   'jerk': defaultdict(int, {'or': 1.0}),
#   'breath': defaultdict(int, {'of': 1.0}),
#   'swamp': defaultdict(int, {'of': 1.0}),
#   'sort': defaultdict(int, {'of': 1.0}),
#   'resurrected': defaultdict(int, {'tree': 1.0}),
#   'barkless': defaultdict(int, {'spectre': 1.0}),
#   'lofty': defaultdict(int, {'farm': 1.0}),
#   'hole': defaultdict(int, {'in': 0.5, 'i': 0.5}),
#   'coasting': defaultdict(int, {'child': 1.0}),
#   'matter': defaultdict(int, {'of': 1.0}),
#   'present': defaultdict(int, {'of': 1.0}),
#   'lot': defaultdict(int, {'now': 1.0}),
#   'noted': defaultdict(int, {'witch': 1.0}),
#   'witch': defaultdict(int,
#               {'id': 0.3333333333333333,
#                'or': 0.3333333333333333,
#                'who': 0.3333333333333333}),
#   'cribber': defaultdict(int, {'and': 1.0}),
#   'strapping': defaultdict(int, {'girl': 1.0}),
#   'night': defaultdict(int, {'of': 1.0}),
#   'solid': defaultdict(int, {'mica': 1.0}),
#   'stone': defaultdict(int, {'baptismal': 1.0}),
#   'worse': defaultdict(int, {'fight': 1.0}),
#   'leak': defaultdict(int, {'and': 1.0}),
#   'good': defaultdict(int, {'deal': 0.5, 'home': 0.5}),
#   'day': defaultdict(int, {'of': 1.0}),
#   'lookoff': defaultdict(int, {'where': 1.0}),
#   'cliff': defaultdict(int, {'and': 1.0}),
#   'bottle': defaultdict(int, {'painted': 1.0}),
#   'likeness': defaultdict(int, {'to': 1.0}),
#   'donkeys': defaultdict(int, {'cars': 1.0}),
#   'road': defaultdict(int, {'i': 1.0}),
#   'house': defaultdict(int,
#               {'deserted': 0.2, 'stripped': 0.2, 'that': 0.4, 'in': 0.2}),
#   'whole': defaultdict(int, {'edition': 1.0}),
#   'packing': defaultdict(int, {'case': 1.0}),
#   'horn': defaultdict(int, {'of': 1.0}),
#   'village': defaultdict(int, {'library': 1.0}),
#   'bird': defaultdict(int,
#               {'silent': 0.3333333333333333,
#                'alight': 0.3333333333333333,
#                'with': 0.3333333333333333}),
#   'stricken': defaultdict(int, {'bird': 1.0}),
#   'hornyhanded': defaultdict(int, {'kindness': 1.0}),
#   'demand': defaultdict(int, {'she': 1.0}),
#   'small': defaultdict(int, {'skiff': 1.0}),
#   'paddle': defaultdict(int, {'blade': 1.0}),
#   'trapper': defaultdict(int, {'looking': 1.0}),
#   'mother': defaultdict(int, {'and': 1.0}),
#   'winter': defaultdict(int,
#               {'evening': 0.3333333333333333,
#                'eve': 0.3333333333333333,
#                'garden': 0.3333333333333333}),
#   'common': defaultdict(int, {'table': 1.0}),
#   'table': defaultdict(int, {'for': 1.0}),
#   'pile': defaultdict(int, {'of': 1.0}),
#   'baby': defaultdict(int, {'i': 1.0}),
#   'man': defaultdict(int,
#               {'with': 0.16666666666666666,
#                'but': 0.16666666666666666,
#                'he': 0.16666666666666666,
#                'let': 0.16666666666666666,
#                'to': 0.16666666666666666,
#                'at': 0.16666666666666666}),
#   'little': defaultdict(int,
#               {'child': 0.2,
#                'little': 0.2,
#                'longer': 0.2,
#                'finger': 0.2,
#                'yesterday': 0.2}),
#   'vision': defaultdict(int, {'of': 1.0}),
#   'moment': defaultdict(int, {'he': 1.0}),
#   'tongue': defaultdict(int, {'of': 1.0}),
#   'grave': defaultdict(int, {'down': 1.0}),
#   'mans': defaultdict(int, {'his': 1.0}),
#   'single': defaultdict(int, {'leaf': 1.0}),
#   'crystal': defaultdict(int, {'chill': 1.0}),
#   'brush': defaultdict(int, {'had': 1.0}),
#   'crooked': defaultdict(int, {'stroke': 1.0}),
#   'piercing': defaultdict(int, {'little': 1.0}),
#   'governor': defaultdict(int, {'it': 1.0}),
#   'rockstrewn': defaultdict(int, {'town': 1.0}),
#   'tent': defaultdict(int, {'in': 1.0}),
#   'swish': defaultdict(int, {'in': 1.0}),
#   'farm': defaultdict(int, {'not': 0.5, 'that': 0.5}),
#   'girl': defaultdict(int, {'and': 1.0}),
#   'family': defaultdict(int, {'tree': 1.0}),
#   'sudden': defaultdict(int, {'movement': 1.0}),
#   'lane': defaultdict(int, {'yet': 1.0}),
#   'viola': defaultdict(int, {'i': 1.0}),
#   'plain': defaultdict(int, {'statement': 1.0}),
#   'shattered': defaultdict(int, {'seedpod': 1.0}),
#   'brook': defaultdict(int,
#               {'hidden': 0.3333333333333333,
#                'makes': 0.3333333333333333,
#                'that': 0.3333333333333333}),
#   'member': defaultdict(int, {'of': 1.0}),
#   'person': defaultdict(int, {'so': 1.0}),
#   'lake': defaultdict(int, {'before': 1.0}),
#   'myth': defaultdict(int, {'of': 1.0}),
#   'match': defaultdict(int, {'flame': 1.0}),
#   'hand': defaultdict(int, {'up': 1.0}),
#   'bead': defaultdict(int, {'of': 1.0}),
#   'wild': defaultdict(int, {'descent': 1.0}),
#   'purer': defaultdict(int, {'oracle': 1.0}),
#   'picture': defaultdict(int, {'on': 1.0}),
#   'name': defaultdict(int, {'should': 1.0}),
#   'doorsill': defaultdict(int, {'or': 1.0}),
#   'new': defaultdict(int, {'cottage': 1.0}),
#   'dite': defaultdict(int, {'too': 1.0}),
#   'chimney': defaultdict(int, {'upon': 0.5, 'that': 0.5}),
#   'fulllength': defaultdict(int, {'chimney': 1.0}),
#   'shelfs': defaultdict(int, {'for': 1.0}),
#   'clock': defaultdict(int, {'or': 1.0}),
#   'glimpse': defaultdict(int, {'through': 1.0}),
#   'garden': defaultdict(int, {'wall': 1.0}),
#   'sunny': defaultdict(int, {'cheek': 1.0}),
#   'passing': defaultdict(int, {'car': 1.0}),
#   'tunnel': defaultdict(int, {'mouth': 1.0}),
#   'time': defaultdict(int, {'made': 1.0}),
#   'town': defaultdict(int, {'that': 1.0}),
#   'guide': defaultdict(int, {'direct': 1.0}),
#   'story': defaultdict(int, {'in': 1.0}),
#   'book': defaultdict(int, {'about': 1.0}),
#   'certain': defaultdict(int, {'coolness': 1.0}),
#   'few': defaultdict(int, {'old': 1.0}),
#   'cheering': defaultdict(int, {'song': 1.0}),
#   'buggy': defaultdict(int, {'load': 1.0}),
#   'sign': defaultdict(int, {'up': 1.0}),
#   'harness': defaultdict(int, {'gall': 1.0}),
#   'belilaced': defaultdict(int, {'cellar': 1.0}),
#   'dent': defaultdict(int, {'in': 1.0}),
#   'spring': defaultdict(int, {'as': 1.0}),
#   'broken': defaultdict(int, {'drinking': 1.0}),
#   'spell': defaultdict(int, {'so': 1.0}),
#   'thousand': defaultdict(int, {'shrill': 1.0}),
#   'piano': defaultdict(int, {'loudly': 1.0}),
#   'note': defaultdict(int, {'unruffled': 1.0}),
#   'beaded': defaultdict(int, {'fur': 1.0}),
#   'headless': defaultdict(int, {'horse': 1.0}),
#   'smart': defaultdict(int, {'pair': 1.0}),
#   'big': defaultdict(int, {'church': 1.0}),
#   'long': defaultdict(int, {'time': 1.0}),
#   'friend': defaultdict(int, {'or': 1.0}),
#   'bad': defaultdict(int, {'farmer': 1.0}),
#   'home': defaultdict(int, {'for': 1.0}),
#   'hen': defaultdict(int, {'you': 1.0}),
#   'flock': defaultdict(int, {'of': 1.0}),
#   'times': defaultdict(int, {'the': 1.0}),
#   'glass': defaultdict(int, {'case': 1.0}),
#   'tall': defaultdict(int, {'one': 1.0}),
#   'barrel': defaultdict(int, {'from': 1.0}),
#   'paradise': defaultdict(int, {'as': 1.0}),
#   'dormant': defaultdict(int, {'tree': 1.0}),
#   'plane': defaultdict(int, {'of': 1.0}),
#   'gaunt': defaultdict(int, {'luxuriating': 1.0}),
#   'featherhammer': defaultdict(int, {'gives': 1.0}),
#   'double': defaultdict(int, {'knock': 1.0})},
#  'and': {'sorry': defaultdict(int, {'i': 1.0}),
#   'be': defaultdict(int, {'one': 0.5, 'whole': 0.5}),
#   'looked': defaultdict(int, {'down': 1.0}),
#   'having': defaultdict(int, {'perhaps': 1.0}),
#   'wanted': defaultdict(int, {'wear': 1.0}),
#   'both': defaultdict(int, {'that': 0.5, 'of': 0.5}),
#   'ages': defaultdict(int, {'hence': 1.0}),
#   'that': defaultdict(int, {'has': 0.5, 'was': 0.5}),
#   'frozen': defaultdict(int, {'lake': 1.0}),
#   'downy': defaultdict(int, {'flake': 1.0}),
#   'miles': defaultdict(int, {'to': 1.0}),
#   'would': defaultdict(int, {'suffice': 1.0}),
#   'back': defaultdict(int, {'in': 1.0}),
#   'dropped': defaultdict(int, {'my': 1.0}),
#   'stopped': defaultdict(int, {'the': 1.0}),
#   'further': defaultdict(int, {'still': 1.0}),
#   'when': defaultdict(int,
#               {'i': 0.3333333333333333,
#                'alls': 0.3333333333333333,
#                'ive': 0.3333333333333333}),
#   'tell': defaultdict(int, {'me': 0.75, 'him': 0.25}),
#   'now': defaultdict(int, {'know': 0.5, 'the': 0.5}),
#   'the': defaultdict(int,
#               {'light': 0.08333333333333333,
#                'sun': 0.08333333333333333,
#                'temptation': 0.08333333333333333,
#                'birds': 0.08333333333333333,
#                'fur': 0.08333333333333333,
#                'north': 0.08333333333333333,
#                'clothes': 0.08333333333333333,
#                'jug': 0.08333333333333333,
#                'bandmusic': 0.08333333333333333,
#                'smell': 0.08333333333333333,
#                'hens': 0.08333333333333333,
#                'cock': 0.08333333333333333}),
#   'caught': defaultdict(int, {'one': 1.0}),
#   'put': defaultdict(int, {'my': 0.5, 'a': 0.5}),
#   'threw': defaultdict(int, {'myself': 1.0}),
#   'birds': defaultdict(int, {'that': 1.0}),
#   'redoubling': defaultdict(int, {'song': 1.0}),
#   'suddenly': defaultdict(int, {'without': 1.0}),
#   'scuttled': defaultdict(int, {'just': 1.0}),
#   'side': defaultdict(int, {'by': 1.0}),
#   'scurf': defaultdict(int, {'of': 1.0}),
#   'weary': defaultdict(int, {'and': 1.0}),
#   'rested': defaultdict(int, {'on': 1.0}),
#   'since': defaultdict(int, {'there': 0.5, 'it': 0.5}),
#   'there': defaultdict(int, {'against': 0.5, 'a': 0.5}),
#   'raised': defaultdict(int, {'again—': 1.0}),
#   'whats': defaultdict(int, {'the': 1.0}),
#   'many': defaultdict(int, {'must': 1.0}),
#   'barn': defaultdict(int, {'the': 1.0}),
#   'blew': defaultdict(int, {'him': 1.0}),
#   'he': defaultdict(int, {'was': 0.5, 'liked': 0.5}),
#   'stamped': defaultdict(int, {'and': 1.0}),
#   'said': defaultdict(int, {'things': 1.0}),
#   'sometimes': defaultdict(int, {'something': 1.0}),
#   'some': defaultdict(int, {'exclaimed': 1.0}),
#   'made': defaultdict(int, {'the': 1.0}),
#   'then': defaultdict(int,
#               {'becoming': 0.16666666666666666,
#                'went': 0.16666666666666666,
#                'someone': 0.16666666666666666,
#                'made': 0.16666666666666666,
#                'a': 0.16666666666666666,
#                'pull': 0.16666666666666666}),
#   'came': defaultdict(int, {'down': 1.0}),
#   'this': defaultdict(int, {'is': 0.5, 'bill': 0.5}),
#   'politician': defaultdict(int, {'at': 1.0}),
#   'took': defaultdict(int, {'the': 1.0}),
#   'i': defaultdict(int,
#               {'can': 0.1111111111111111,
#                'dont': 0.1111111111111111,
#                'read': 0.1111111111111111,
#                'know': 0.1111111111111111,
#                'dread': 0.1111111111111111,
#                'thought': 0.1111111111111111,
#                'only': 0.1111111111111111,
#                'have': 0.1111111111111111,
#                'get': 0.1111111111111111}),
#   'warrens': defaultdict(int, {'both': 1.0}),
#   'thatd': defaultdict(int, {'be': 1.0}),
#   'rode': defaultdict(int, {'all': 1.0}),
#   'if': defaultdict(int, {'id': 0.5, 'youre': 0.5}),
#   'leave': defaultdict(int, {'his': 1.0}),
#   'had': defaultdict(int, {'gnawed': 0.5, 'it': 0.5}),
#   'as': defaultdict(int, {'sures': 1.0}),
#   'posts': defaultdict(int, {'and': 1.0}),
#   'fences': defaultdict(int, {'too': 1.0}),
#   'make': defaultdict(int, {'it': 0.5, 'your': 0.5}),
#   'from': defaultdict(int, {'barn': 1.0}),
#   'snow': defaultdict(int, {'of': 1.0}),
#   'full': defaultdict(int, {'of': 1.0}),
#   'kick': defaultdict(int, {'up': 0.5, 'with': 0.5}),
#   'experts': defaultdict(int, {'said': 1.0}),
#   'show': defaultdict(int, {'it': 1.0}),
#   'built': defaultdict(int, {'a': 1.0}),
#   'emptied': defaultdict(int, {'then': 1.0}),
#   'forty': defaultdict(int, {'years': 1.0}),
#   'were': defaultdict(int, {'off': 1.0}),
#   'thats': defaultdict(int, {'why': 0.5, 'not': 0.5}),
#   'spoke': defaultdict(int, {'his': 0.5, 'of': 0.5}),
#   'on': defaultdict(int, {'the': 1.0}),
#   'anyway': defaultdict(int, {'this': 1.0}),
#   'save': defaultdict(int, {'the': 0.5, 'for': 0.5}),
#   'keep': defaultdict(int, {'abouncing': 1.0}),
#   'how': defaultdict(int,
#               {'she': 0.3333333333333333,
#                'much': 0.3333333333333333,
#                'many': 0.3333333333333333}),
#   'wrote': defaultdict(int, {'her': 1.0}),
#   'hold': defaultdict(int,
#               {'the': 0.6666666666666666, 'his': 0.3333333333333333}),
#   'swollen': defaultdict(int,
#               {'them': 0.3333333333333333, 'tight': 0.6666666666666666}),
#   'taken': defaultdict(int, {'thus': 1.0}),
#   'bad': defaultdict(int, {'hunters': 1.0}),
#   'lead': defaultdict(int, {'to': 1.0}),
#   'opening': defaultdict(int, {'out': 1.0}),
#   'lie': defaultdict(int, {'in': 1.0}),
#   'bushes': defaultdict(int, {'unretrieved': 1.0}),
#   'left': defaultdict(int, {'it': 0.5, 'me': 0.5}),
#   'stroked': defaultdict(int, {'it': 1.0}),
#   'a': defaultdict(int,
#               {'paddle': 0.3333333333333333,
#                'trapper': 0.3333333333333333,
#                'crutch': 0.3333333333333333}),
#   'me': defaultdict(int, {'on': 1.0}),
#   'between': defaultdict(int, {'what': 1.0}),
#   'wont': defaultdict(int, {'tell': 1.0}),
#   'hes': defaultdict(int, {'off': 1.0}),
#   'his': defaultdict(int, {'crew': 0.5, 'brown': 0.5}),
#   'nothing': defaultdict(int, {'came': 1.0}),
#   'better': defaultdict(int, {'defeat': 1.0}),
#   'headboard': defaultdict(int, {'where': 0.5, 'of': 0.5}),
#   'carried': defaultdict(int, {'itself': 1.0}),
#   'mother': defaultdict(int, {'and': 1.0}),
#   'neither': defaultdict(int, {'stopped': 1.0}),
#   'thought': defaultdict(int, {'i': 1.0}),
#   'buried': defaultdict(int, {'under': 1.0}),
#   'good': defaultdict(int, {'reason': 1.0}),
#   'all': defaultdict(int, {'but': 0.5, 'our': 0.5}),
#   'licked': defaultdict(int, {'along': 1.0}),
#   'fell': defaultdict(int, {'back': 1.0}),
#   'shouted': defaultdict(int, {'toffile': 0.5, 'shut': 0.5}),
#   'set': defaultdict(int, {'off': 1.0}),
#   'in': defaultdict(int,
#               {'the': 0.3333333333333333,
#                'a': 0.3333333333333333,
#                'it': 0.3333333333333333}),
#   'sit': defaultdict(int, {'up': 0.5, 'before': 0.5}),
#   'take': defaultdict(int, {'hold': 0.5, 'a': 0.5}),
#   'bring': defaultdict(int, {'the': 1.0}),
#   'sure': defaultdict(int, {'enough': 1.0}),
#   'held': defaultdict(int, {'the': 1.0}),
#   'push': defaultdict(int, {'the': 1.0}),
#   'stand': defaultdict(int, {'perplexed': 1.0}),
#   'lift': defaultdict(int, {'my': 0.5, 'themselves': 0.5}),
#   'those': defaultdict(int, {'of': 0.5, 'will': 0.5}),
#   'sproutlands': defaultdict(int, {'flourish': 1.0}),
#   'try': defaultdict(int, {'to': 1.0}),
#   'get': defaultdict(int, {'some': 1.0}),
#   'moments': defaultdict(int, {'of': 1.0}),
#   'one': defaultdict(int, {'other': 1.0}),
#   'she': defaultdict(int, {'halted': 1.0}),
#   'see': defaultdict(int,
#               {'who': 0.3333333333333333,
#                'if': 0.3333333333333333,
#                'what': 0.3333333333333333}),
#   'perhaps': defaultdict(int, {'hear': 0.5, 'she': 0.5}),
#   'still': defaultdict(int, {'be': 0.5, 'her': 0.5}),
#   'doubtless': defaultdict(int, {'here': 1.0}),
#   'by': defaultdict(int, {'marrying': 1.0}),
#   'dangle': defaultdict(int, {'feet': 1.0}),
#   'disappeared': defaultdict(int, {'and': 1.0}),
#   'ended': defaultdict(int, {'not': 1.0}),
#   'below': defaultdict(int, {'roared': 1.0}),
#   'what': defaultdict(int, {'do': 1.0}),
#   'dim': defaultdict(int, {'as': 1.0}),
#   'its': defaultdict(int, {'flooded': 1.0}),
#   'smoking': defaultdict(int, {'and': 1.0}),
#   'gets': defaultdict(int, {'out': 1.0}),
#   'sos': defaultdict(int, {'the': 1.0}),
#   'hew': defaultdict(int, {'and': 1.0}),
#   'shape': defaultdict(int, {'it': 1.0}),
#   'come': defaultdict(int, {'and': 1.0}),
#   'begin': defaultdict(int, {'over': 1.0}),
#   'it': defaultdict(int, {'was': 1.0}),
#   'build': defaultdict(int, {'the': 1.0}),
#   'youthful': defaultdict(int, {'faces': 1.0}),
#   'repented': defaultdict(int, {'but': 1.0}),
#   'color': defaultdict(int, {'and': 1.0}),
#   'odor': defaultdict(int, {'thicken': 1.0}),
#   'go': defaultdict(int, {'back': 1.0}),
#   'broken': defaultdict(int, {'off': 1.0}),
#   'theres': defaultdict(int, {'a': 1.0}),
#   'your': defaultdict(int, {'destinys': 0.5, 'watering': 0.5}),
#   'original': defaultdict(int, {'to': 1.0}),
#   'stifling': defaultdict(int, {'hot': 1.0}),
#   'sound': defaultdict(int, {'from': 1.0}),
#   'got': defaultdict(int, {'them': 1.0}),
#   'new': defaultdict(int, {'paint': 1.0}),
#   'music': defaultdict(int, {'out': 1.0}),
#   'give': defaultdict(int, {'up': 1.0}),
#   'fight': defaultdict(int, {'in': 1.0}),
#   'such': defaultdict(int, {'few': 1.0}),
#   'moon': defaultdict(int, {'and': 1.0}),
#   'nation': defaultdict(int, {'nation': 1.0}),
#   'though': defaultdict(int, {'none': 1.0}),
#   'wheres': defaultdict(int, {'john': 1.0}),
#   'gone': defaultdict(int, {'to': 1.0}),
#   'shell': defaultdict(int, {'come': 1.0}),
#   'lord': defaultdict(int, {'if': 1.0}),
#   'where': defaultdict(int, {'it': 1.0}),
#   'no': defaultdict(int, {'one': 1.0}),
#   'end': defaultdict(int, {'it': 1.0}),
#   'after': defaultdict(int, {'all': 1.0}),
#   'cows': defaultdict(int, {'and': 1.0}),
#   'pigs': defaultdict(int, {'are': 1.0}),
#   'we': defaultdict(int, {'live': 0.5, 'paid': 0.5}),
#   'like': defaultdict(int, {'it': 1.0}),
#   'youre': defaultdict(int, {'her': 1.0}),
#   'turn': defaultdict(int, {'doll': 1.0}),
#   'stop': defaultdict(int, {'his': 1.0}),
#   'not': defaultdict(int, {'melt': 1.0}),
#   'last': defaultdict(int, {'years': 1.0}),
#   'which': defaultdict(int, {'are': 1.0})},
#  'sorry': {'i': defaultdict(int, {'could': 0.5, 'ever': 0.5})},
#  'i': {'could': defaultdict(int,
#               {'not': 0.25, 'have': 0.25, 'see': 0.375, 'do': 0.125}),
#   'kept': defaultdict(int, {'the': 0.5, 'remembering': 0.5}),
#   'doubted': defaultdict(int, {'if': 1.0}),
#   'should': defaultdict(int,
#               {'ever': 0.3333333333333333,
#                'say': 0.3333333333333333,
#                'feel': 0.3333333333333333}),
#   'shall': defaultdict(int, {'be': 0.5, 'suspect': 0.5}),
#   'took': defaultdict(int, {'the': 0.5, 'him': 0.5}),
#   'think': defaultdict(int,
#               {'i': 0.3333333333333333,
#                'its': 0.16666666666666666,
#                'were': 0.16666666666666666,
#                'he': 0.16666666666666666,
#                'ill': 0.16666666666666666}),
#   'have': defaultdict(int,
#               {'promises': 0.09090909090909091,
#                'been': 0.18181818181818182,
#                'walked': 0.09090909090909091,
#                'outwalked': 0.09090909090909091,
#                'looked': 0.09090909090909091,
#                'passed': 0.09090909090909091,
#                'stood': 0.09090909090909091,
#                'no': 0.09090909090909091,
#                'kept': 0.09090909090909091,
#                'filled': 0.09090909090909091}),
#   'hold': defaultdict(int, {'with': 1.0}),
#   'know': defaultdict(int,
#               {'enough': 0.16666666666666666,
#                'of': 0.3333333333333333,
#                'and': 0.16666666666666666,
#                'what': 0.16666666666666666,
#                'the': 0.16666666666666666}),
#   'go': defaultdict(int, {'up': 1.0}),
#   'come': defaultdict(int, {'to': 1.0}),
#   'doubt': defaultdict(int, {'not': 1.0}),
#   'end': defaultdict(int, {'not': 1.0}),
#   'cant': defaultdict(int,
#               {'pretend': 0.1111111111111111,
#                'decently': 0.1111111111111111,
#                'say': 0.1111111111111111,
#                'give': 0.1111111111111111,
#                'get': 0.1111111111111111,
#                'keep': 0.1111111111111111,
#                'talk': 0.1111111111111111,
#                'stay': 0.1111111111111111,
#                'explain': 0.1111111111111111}),
#   'though': defaultdict(int, {'to': 1.0}),
#   'tell': defaultdict(int,
#               {'but': 0.3333333333333333, 'them': 0.6666666666666666}),
#   'fancied': defaultdict(int, {'when': 1.0}),
#   'looked': defaultdict(int, {'at': 1.0}),
#   'was': defaultdict(int,
#               {'half': 0.07692307692307693,
#                'married': 0.15384615384615385,
#                'to': 0.07692307692307693,
#                'a': 0.23076923076923078,
#                'young': 0.15384615384615385,
#                'soon': 0.07692307692307693,
#                'going': 0.07692307692307693,
#                'just': 0.07692307692307693,
#                'too': 0.07692307692307693}),
#   'ever': defaultdict(int, {'left': 0.5, 'cared': 0.5}),
#   'paused': defaultdict(int, {'and': 1.0}),
#   'saw': defaultdict(int,
#               {'the': 0.2, 'it': 0.2, 'a': 0.2, 'no': 0.2, 'him': 0.2}),
#   'said': defaultdict(int, {'where': 1.0}),
#   'wander': defaultdict(int, {'out': 1.0}),
#   'wonder': defaultdict(int,
#               {'what': 0.2, 'if': 0.4, 'where': 0.2, 'why': 0.2}),
#   'invested': defaultdict(int, {'him': 1.0}),
#   'can': defaultdict(int,
#               {'prove': 0.08333333333333333,
#                'hurt': 0.08333333333333333,
#                'find': 0.08333333333333333,
#                'just': 0.08333333333333333,
#                'make': 0.08333333333333333,
#                'see': 0.16666666666666666,
#                'tell': 0.08333333333333333,
#                'no': 0.08333333333333333,
#                'keep': 0.08333333333333333,
#                'sew': 0.08333333333333333,
#                'hardly': 0.08333333333333333}),
#   'must': defaultdict(int,
#               {'be': 0.3333333333333333,
#                'have': 0.3333333333333333,
#                'go': 0.3333333333333333}),
#   'guess': defaultdict(int,
#               {'theyd': 0.25, 'he': 0.25, 'youd': 0.25, 'estelle': 0.25}),
#   'happen': defaultdict(int, {'to': 1.0}),
#   'would': defaultdict(int,
#               {'be': 0.3333333333333333,
#                'last': 0.3333333333333333,
#                'have': 0.3333333333333333}),
#   'spose': defaultdict(int, {'when': 1.0}),
#   'mistrusted': defaultdict(int, {'he': 1.0}),
#   'showed': defaultdict(int, {'arthur': 1.0}),
#   'dont': defaultdict(int,
#               {'mean': 0.06666666666666667,
#                'know': 0.26666666666666666,
#                'see': 0.2,
#                'care': 0.06666666666666667,
#                'remember': 0.06666666666666667,
#                'believe': 0.06666666666666667,
#                'follow': 0.06666666666666667,
#                'trust': 0.06666666666666667,
#                'just': 0.06666666666666667,
#                'ask': 0.06666666666666667}),
#   'made': defaultdict(int, {'him': 1.0}),
#   'hope': defaultdict(int, {'if': 1.0}),
#   'might': defaultdict(int, {'have': 1.0}),
#   'remember': defaultdict(int, {'rightly': 1.0}),
#   'am': defaultdict(int,
#               {'im': 0.3333333333333333,
#                'a': 0.3333333333333333,
#                'sure': 0.3333333333333333}),
#   'thought': defaultdict(int,
#               {'you': 0.14285714285714285,
#                'for': 0.14285714285714285,
#                'the': 0.2857142857142857,
#                'i': 0.2857142857142857,
#                'twas': 0.14285714285714285}),
#   'havent': defaultdict(int, {'brought': 0.5, 'had': 0.5}),
#   'wont': defaultdict(int, {'accept': 0.5, 'be': 0.5}),
#   'want': defaultdict(int, {'my': 0.25, 'to': 0.75}),
#   'vow': defaultdict(int, {'we': 1.0}),
#   'show': defaultdict(int, {'you': 1.0}),
#   'didnt': defaultdict(int,
#               {'recognize': 0.25,
#                'know': 0.25,
#                'always': 0.25,
#                'relish': 0.25}),
#   'never': defaultdict(int, {'saw': 0.5, 'could': 0.25, 'heard': 0.25}),
#   'ask': defaultdict(int, {'you': 1.0}),
#   'read': defaultdict(int, {'in': 1.0}),
#   'knew': defaultdict(int,
#               {'in': 0.3333333333333333,
#                'them': 0.3333333333333333,
#                'there': 0.3333333333333333}),
#   'staid': defaultdict(int, {'the': 1.0}),
#   'asked': defaultdict(int, {'him': 1.0}),
#   'went': defaultdict(int,
#               {'to': 0.6666666666666666, 'till': 0.3333333333333333}),
#   'heard': defaultdict(int,
#               {'toffile': 0.3333333333333333,
#                'him': 0.3333333333333333,
#                'them': 0.3333333333333333}),
#   'had': defaultdict(int,
#               {'a': 0.2,
#                'just': 0.1,
#                'to': 0.2,
#                'for': 0.1,
#                'the': 0.3,
#                'such': 0.1}),
#   'flung': defaultdict(int, {'the': 1.0}),
#   'struck': defaultdict(int, {'the': 1.0}),
#   'see': defaultdict(int,
#               {'one': 0.3333333333333333,
#                'raspberry': 0.3333333333333333,
#                'its': 0.3333333333333333}),
#   'sat': defaultdict(int, {'up': 1.0}),
#   'listened': defaultdict(int, {'till': 1.0}),
#   'got': defaultdict(int, {'up': 0.5, 'wonted': 0.5}),
#   'pushed': defaultdict(int, {'myself': 1.0}),
#   'wanted': defaultdict(int, {'to': 1.0}),
#   'slammed': defaultdict(int, {'to': 1.0}),
#   'sit': defaultdict(int, {'up': 1.0}),
#   'promised': defaultdict(int, {'toffile': 1.0}),
#   'mean': defaultdict(int,
#               {'a': 0.3333333333333333,
#                'estelle': 0.3333333333333333,
#                'shes': 0.3333333333333333}),
#   'verified': defaultdict(int, {'the': 1.0}),
#   'passed': defaultdict(int, {'the': 1.0}),
#   'judged': defaultdict(int, {'that': 1.0}),
#   'only': defaultdict(int,
#               {'idled': 0.25, 'mean': 0.25, 'have': 0.25, 'hinder': 0.25}),
#   'idled': defaultdict(int, {'down': 1.0}),
#   'own': defaultdict(int, {'what': 1.0}),
#   'may': defaultdict(int, {'be': 1.0}),
#   'lean': defaultdict(int, {'like': 1.0}),
#   'give': defaultdict(int, {'you': 1.0}),
#   'used': defaultdict(int, {'the': 0.5, 'to': 0.5}),
#   'mustnt': defaultdict(int, {'feel': 1.0}),
#   'let': defaultdict(int,
#               {'you': 0.6666666666666666, 'myself': 0.3333333333333333}),
#   'speak': defaultdict(int, {'but': 1.0}),
#   'like': defaultdict(int, {'your': 1.0}),
#   'dread': defaultdict(int, {'the': 1.0}),
#   'turned': defaultdict(int, {'and': 1.0}),
#   'often': defaultdict(int, {'see': 1.0}),
#   'name': defaultdict(int, {'all': 1.0}),
#   'stole': defaultdict(int, {'the': 1.0}),
#   'walked': defaultdict(int, {'down': 1.0}),
#   'came': defaultdict(int, {'to': 1.0}),
#   'help': defaultdict(int, {'out': 1.0}),
#   'were': defaultdict(int, {'to': 1.0}),
#   'primped': defaultdict(int, {'to': 1.0}),
#   'hate': defaultdict(int, {'to': 1.0}),
#   'blame': defaultdict(int, {'his': 1.0}),
#   'take': defaultdict(int, {'it': 1.0}),
#   'call': defaultdict(int, {'it': 1.0}),
#   'get': defaultdict(int, {'to': 1.0}),
#   'say': defaultdict(int, {'shes': 1.0}),
#   'pity': defaultdict(int, {'estelle': 1.0}),
#   'suppose': defaultdict(int, {'she': 1.0})},
#  'could': {'not': defaultdict(int, {'travel': 0.5, 'say': 0.5}),
#   'hold': defaultdict(int, {'them': 1.0}),
#   'have': defaultdict(int,
#               {'told': 0.3333333333333333,
#                'done': 0.3333333333333333,
#                'to': 0.3333333333333333}),
#   'recognize': defaultdict(int, {'them': 1.0}),
#   'hear': defaultdict(int, {'tell': 1.0}),
#   'call': defaultdict(int, {'up': 1.0}),
#   'that': defaultdict(int, {'be': 1.0}),
#   'be': defaultdict(int, {'there': 1.0}),
#   'see': defaultdict(int, {'nothing': 0.5, 'it': 0.5}),
#   'find': defaultdict(int, {'out': 1.0}),
#   'too': defaultdict(int, {'son': 1.0}),
#   'do': defaultdict(int, {'was': 1.0}),
#   'tell': defaultdict(int, {'you': 1.0}),
#   'make': defaultdict(int, {'them': 1.0}),
#   'sell': defaultdict(int, {'the': 1.0})},
#  'not': {'travel': defaultdict(int, {'both': 1.0}),
#   'see': defaultdict(int, {'me': 1.0}),
#   'to': defaultdict(int,
#               {'call': 0.16666666666666666,
#                'blanket': 0.16666666666666666,
#                'be': 0.16666666666666666,
#                'care': 0.16666666666666666,
#                'sink': 0.16666666666666666,
#                'stand': 0.16666666666666666}),
#   'by': defaultdict(int, {'my': 1.0}),
#   'far': defaultdict(int,
#               {'from': 0.3333333333333333,
#                'away': 0.3333333333333333,
#                'off': 0.3333333333333333}),
#   'too': defaultdict(int, {'much': 1.0}),
#   'off': defaultdict(int, {'for': 1.0}),
#   'much': defaultdict(int, {'concerned': 1.0}),
#   'a': defaultdict(int, {'post': 0.5, 'soul': 0.5}),
#   'that': defaultdict(int, {'he': 0.5, 'im': 0.5}),
#   'so': defaultdict(int, {'but': 1.0}),
#   'thrown': defaultdict(int, {'irreverently': 1.0}),
#   'take': defaultdict(int, {'two': 0.5, 'seats': 0.5}),
#   'men': defaultdict(int, {'by': 1.0}),
#   'like': defaultdict(int, {'a': 1.0}),
#   'for': defaultdict(int, {'him': 1.0}),
#   'all': defaultdict(int, {'the': 0.5, 'hes': 0.5}),
#   'expecting': defaultdict(int, {'he': 1.0}),
#   'be': defaultdict(int, {'and': 1.0}),
#   'from': defaultdict(int, {'the': 1.0}),
#   'your': defaultdict(int, {'makebelieve': 1.0}),
#   'yet': defaultdict(int, {'all': 0.5, 'light': 0.5}),
#   'come': defaultdict(int, {'in': 1.0}),
#   'old': defaultdict(int, {'grandsirs': 1.0}),
#   'fireweed': defaultdict(int, {'loving': 1.0}),
#   'bluebells': defaultdict(int, {'gracing': 1.0}),
#   'lupine': defaultdict(int, {'living': 1.0}),
#   'in': defaultdict(int, {'position': 0.5, 'a': 0.5}),
#   'mind': defaultdict(int, {'a': 1.0}),
#   'twenty': defaultdict(int, {'years': 1.0}),
#   'their': defaultdict(int, {'own': 1.0}),
#   'answering': defaultdict(int, {'your': 1.0}),
#   'if': defaultdict(int, {'he': 1.0}),
#   'he': defaultdict(int, {'us': 1.0}),
#   'blaming': defaultdict(int, {'him': 1.0}),
#   'being': defaultdict(int, {'safe': 1.0}),
#   'allowed': defaultdict(int, {'to': 1.0}),
#   'melt': defaultdict(int, {'snow': 1.0})},
#  'be': {'one': defaultdict(int, {'traveler': 1.0}),
#   'telling': defaultdict(int, {'this': 1.0}),
#   'to': defaultdict(int, {'have': 0.5, 'my': 0.5}),
#   'set': defaultdict(int, {'up': 1.0}),
#   'they': defaultdict(int, {'ought': 1.0}),
#   'enough': defaultdict(int, {'to': 0.5, 'protection': 0.5}),
#   'the': defaultdict(int, {'end': 0.5, 'best': 0.5}),
#   'dragged': defaultdict(int, {'by': 1.0}),
#   'near': defaultdict(int, {'the': 1.0}),
#   'ready': defaultdict(int, {'i': 1.0}),
#   'broken': defaultdict(int, {'davis': 1.0}),
#   'rid': defaultdict(int, {'of': 1.0}),
#   'burned': defaultdict(int, {'at': 1.0}),
#   'i': defaultdict(int, {'thought': 1.0}),
#   'ice': defaultdict(int, {'and': 1.0}),
#   'cruel': defaultdict(int, {'to': 0.5, 'once': 0.5}),
#   'and': defaultdict(int, {'still': 1.0}),
#   'thrown': defaultdict(int, {'into': 1.0}),
#   'too': defaultdict(int, {'technical': 1.0}),
#   'learned': defaultdict(int, {'thats': 1.0}),
#   'teased': defaultdict(int, {'but': 1.0}),
#   'strange': defaultdict(int, {'enough': 1.0}),
#   'very': defaultdict(int, {'still': 1.0}),
#   'good': defaultdict(int,
#               {'the': 0.3333333333333333,
#                'friends': 0.3333333333333333,
#                'for': 0.3333333333333333}),
#   'heard': defaultdict(int, {'in': 1.0}),
#   'likely': defaultdict(int, {'to': 1.0}),
#   'you': defaultdict(int, {'said': 1.0}),
#   'in': defaultdict(int, {'rain': 1.0}),
#   'just': defaultdict(int, {'ahead': 1.0}),
#   'whole': defaultdict(int, {'again': 1.0}),
#   'a': defaultdict(int, {'nova': 1.0}),
#   'long': defaultdict(int, {'in': 1.0}),
#   'or': defaultdict(int, {'anyone': 1.0}),
#   'right': defaultdict(int, {'to': 1.0}),
#   'as': defaultdict(int, {'good': 1.0}),
#   'expecting': defaultdict(int, {'john': 1.0})},
#  'one': {'traveler': defaultdict(int, {'long': 1.0}),
#   'as': defaultdict(int, {'far': 1.0}),
#   'less': defaultdict(int, {'traveled': 1.0}),
#   'acquainted': defaultdict(int, {'with': 1.0}),
#   'luminary': defaultdict(int, {'clock': 1.0}),
#   'silver': defaultdict(int, {'lizard': 1.0}),
#   'without': defaultdict(int, {'avail': 1.0}),
#   'lizard': defaultdict(int, {'at': 1.0}),
#   'of': defaultdict(int, {'them': 0.4, 'the': 0.2, 'her': 0.2, 'those': 0.2}),
#   'they': defaultdict(int, {'say': 1.0}),
#   'town': defaultdict(int, {'hall': 1.0}),
#   'in': defaultdict(int, {'grafton': 1.0}),
#   'hadnt': defaultdict(int, {'said': 1.0}),
#   'kind': defaultdict(int, {'though': 1.0}),
#   'had': defaultdict(int, {'dropped': 1.0}),
#   'old': defaultdict(int, {'davis': 1.0}),
#   'and': defaultdict(int, {'i': 0.5, 'one': 0.5}),
#   'more': defaultdict(int, {'copy': 1.0}),
#   'himself': defaultdict(int, {'perhaps': 1.0}),
#   'flight': defaultdict(int, {'from': 1.0}),
#   'leg': defaultdict(int, {'and': 1.0}),
#   'hand': defaultdict(int, {'outstretched': 1.0}),
#   'any': defaultdict(int, {'more': 1.0}),
#   'night': defaultdict(int, {'in': 1.0}),
#   'from': defaultdict(int, {'a': 1.0}),
#   'other': defaultdict(int, {'yes': 1.0}),
#   'bearing': defaultdict(int, {'it': 1.0}),
#   'who': defaultdict(int, {'clasps': 1.0}),
#   'ought': defaultdict(int, {'not': 1.0}),
#   'went': defaultdict(int, {'home': 1.0}),
#   'yours': defaultdict(int, {'three': 1.0}),
#   'for': defaultdict(int, {'each': 1.0}),
#   'mustnt': defaultdict(int, {'bear': 1.0}),
#   'that': defaultdict(int, {'didnt': 1.0}),
#   'at': defaultdict(int, {'all': 1.0}),
#   'on': defaultdict(int, {'earth': 0.5, 'each': 0.5}),
#   'a': defaultdict(int, {'hill': 1.0}),
#   'down': defaultdict(int, {'one': 0.5, 'another': 0.5}),
#   'self': defaultdict(int, {'station': 1.0}),
#   'here': defaultdict(int, {'but': 1.0}),
#   'will': defaultdict(int, {'ever': 1.0}),
#   'talk': defaultdict(int, {'to': 1.0}),
#   'thing': defaultdict(int, {'you': 1.0}),
#   'langshang': defaultdict(int, {'cock': 1.0}),
#   'you': defaultdict(int, {'neednt': 1.0}),
#   'level': defaultdict(int, {'higher': 0.5, 'nearer': 0.5})},
#  'traveler': {'long': defaultdict(int, {'i': 1.0})},
#  'long': {'i': defaultdict(int, {'stood': 0.5, 'lay': 0.5}),
#   'way': defaultdict(int, {'home': 1.0}),
#   'ago': defaultdict(int, {'as': 1.0}),
#   'suspected': defaultdict(int, {'where': 1.0}),
#   'in': defaultdict(int, {'bed': 0.5, 'that': 0.5}),
#   'since': defaultdict(int, {'gave': 1.0})},
#  'looked': {'down': defaultdict(int, {'one': 0.5, 'the': 0.5}),
#   'at': defaultdict(int, {'six': 0.5, 'nine': 0.5}),
#   'up': defaultdict(int, {'toward': 1.0}),
#   'back': defaultdict(int, {'up': 1.0}),
#   'as': defaultdict(int, {'if': 1.0}),
#   'like': defaultdict(int, {'lightning': 1.0})},
#  'down': {'one': defaultdict(int, {'as': 0.5, 'street': 0.5}),
#   'to': defaultdict(int, {'day': 0.5, 'walk': 0.5}),
#   'the': defaultdict(int, {'saddest': 0.5, 'stairs': 0.5}),
#   'and': defaultdict(int, {'raised': 1.0}),
#   'from': defaultdict(int, {'field': 0.5, 'everything': 0.5}),
#   'he': defaultdict(int, {'fought': 1.0}),
#   'like': defaultdict(int, {'a': 1.0}),
#   'in': defaultdict(int, {'the': 1.0}),
#   'off': defaultdict(int, {'this': 1.0}),
#   'ill': defaultdict(int, {'tell': 1.0}),
#   'alone': defaultdict(int, {'sunday': 1.0}),
#   'this': defaultdict(int, {'is': 1.0}),
#   'thats': defaultdict(int, {'been': 1.0}),
#   'ryans': defaultdict(int, {'hill': 1.0})},
#  'as': {'far': defaultdict(int, {'as': 1.0}),
#   'i': defaultdict(int, {'could': 0.25, 'am': 0.25, 'do': 0.25, 'say': 0.25}),
#   'just': defaultdict(int, {'as': 1.0}),
#   'for': defaultdict(int,
#               {'that': 0.6666666666666666, 'the': 0.3333333333333333}),
#   'often': defaultdict(int, {'as': 1.0}),
#   'ive': defaultdict(int, {'seen': 1.0}),
#   'if': defaultdict(int,
#               {'some': 0.125,
#                'for': 0.125,
#                'the': 0.125,
#                'id': 0.125,
#                'it': 0.125,
#                'by': 0.125,
#                'and': 0.125,
#                'he': 0.125}),
#   'they': defaultdict(int, {'were': 1.0}),
#   'good': defaultdict(int,
#               {'as': 0.6666666666666666, 'they': 0.3333333333333333}),
#   'he': defaultdict(int,
#               {'chanced': 0.25, 'chose': 0.25, 'feared': 0.25, 'had': 0.25}),
#   'standing': defaultdict(int, {'in': 1.0}),
#   'an': defaultdict(int, {'authority': 1.0}),
#   'a': defaultdict(int,
#               {'witch': 0.3333333333333333,
#                'match': 0.3333333333333333,
#                'spring': 0.3333333333333333}),
#   'sures': defaultdict(int, {'youre': 1.0}),
#   'well': defaultdict(int,
#               {'herself': 0.25, 'see': 0.25, 'be': 0.25, 'off': 0.25}),
#   'we': defaultdict(int, {'could': 0.5, 'can': 0.5}),
#   'plateglass': defaultdict(int, {'windows': 1.0}),
#   'long': defaultdict(int, {'ago': 1.0}),
#   'yet': defaultdict(int, {'have': 0.5, 'so': 0.5}),
#   'to': defaultdict(int,
#               {'sort': 0.3333333333333333,
#                'have': 0.3333333333333333,
#                'hens': 0.3333333333333333}),
#   'gilt': defaultdict(int, {'to': 1.0}),
#   'one': defaultdict(int, {'who': 1.0}),
#   'pale': defaultdict(int, {'and': 1.0}),
#   'you': defaultdict(int,
#               {'throw': 0.3333333333333333,
#                'seize': 0.3333333333333333,
#                'may': 0.3333333333333333}),
#   'youre': defaultdict(int, {'told': 1.0}),
#   'sound': defaultdict(int, {'as': 1.0}),
#   'the': defaultdict(int, {'day': 1.0}),
#   'saint': defaultdict(int, {'mark': 1.0}),
#   'winds': defaultdict(int, {'might': 1.0}),
#   'married': defaultdict(int, {'thats': 1.0}),
#   'own': defaultdict(int, {'the': 1.0}),
#   'it': defaultdict(int, {'is': 0.5, 'can': 0.5}),
#   'much': defaultdict(int, {'to': 1.0}),
#   'near': defaultdict(int, {'a': 1.0}),
#   'winter': defaultdict(int, {'friends': 1.0})},
#  'far': {'as': defaultdict(int, {'i': 0.5, 'we': 0.5}),
#   'away': defaultdict(int, {'an': 1.0}),
#   'from': defaultdict(int, {'my': 1.0}),
#   'off': defaultdict(int, {'he': 1.0}),
#   'you': defaultdict(int, {'must': 1.0}),
#   'youve': defaultdict(int, {'heard': 1.0}),
#   'and': defaultdict(int, {'how': 1.0}),
#   'before': defaultdict(int, {'the': 1.0})},
#  'to': {'where': defaultdict(int, {'it': 1.0}),
#   'watch': defaultdict(int, {'his': 0.5, 'me': 0.5}),
#   'stop': defaultdict(int,
#               {'without': 0.3333333333333333,
#                'the': 0.3333333333333333,
#                'and': 0.3333333333333333}),
#   'ask': defaultdict(int, {'if': 1.0}),
#   'go': defaultdict(int, {'before': 0.5, 'by': 0.25, 'west': 0.25}),
#   'perish': defaultdict(int, {'twice': 1.0}),
#   'say': defaultdict(int,
#               {'that': 0.25, 'you': 0.25, 'the': 0.25, 'which': 0.25}),
#   'call': defaultdict(int, {'me': 0.5, 'it': 0.5}),
#   'the': defaultdict(int,
#               {'garden': 0.06666666666666667,
#                'fountain': 0.06666666666666667,
#                'famous': 0.06666666666666667,
#                'people': 0.06666666666666667,
#                'kitchen': 0.06666666666666667,
#                'bedroom': 0.06666666666666667,
#                'attic': 0.06666666666666667,
#                'knob': 0.06666666666666667,
#                'cellar': 0.06666666666666667,
#                'only': 0.06666666666666667,
#                'door': 0.06666666666666667,
#                'place': 0.06666666666666667,
#                'pianos': 0.06666666666666667,
#                'eye': 0.06666666666666667,
#                'root': 0.06666666666666667}),
#   'carry': defaultdict(int, {'again': 1.0}),
#   'pay': defaultdict(int, {'for': 1.0}),
#   'think': defaultdict(int, {'to': 0.25, 'of': 0.75}),
#   'know': defaultdict(int, {'the': 1.0}),
#   'tell': defaultdict(int, {'the': 0.6, 'them': 0.2, 'him': 0.2}),
#   'make': defaultdict(int,
#               {'a': 0.3333333333333333,
#                'it': 0.3333333333333333,
#                'so': 0.16666666666666666,
#                'them': 0.16666666666666666}),
#   'be': defaultdict(int,
#               {'undone': 0.07142857142857142,
#                'broken': 0.07142857142857142,
#                'cruel': 0.07142857142857142,
#                'thrown': 0.07142857142857142,
#                'enough': 0.07142857142857142,
#                'mad': 0.07142857142857142,
#                'heard': 0.07142857142857142,
#                'salted': 0.07142857142857142,
#                'good': 0.07142857142857142,
#                'you': 0.07142857142857142,
#                'in': 0.07142857142857142,
#                'a': 0.07142857142857142,
#                'as': 0.07142857142857142,
#                'the': 0.07142857142857142}),
#   'spare': defaultdict(int, {'his': 0.5, 'them': 0.5}),
#   'everything': defaultdict(int, {'he': 1.0}),
#   'his': defaultdict(int, {'abode': 0.5, 'house': 0.5}),
#   'natural': defaultdict(int, {'law': 1.0}),
#   'have': defaultdict(int,
#               {'two': 0.2, 'it': 0.2, 'the': 0.4, 'grandchildren': 0.2}),
#   'each': defaultdict(int, {'other': 1.0}),
#   'do': defaultdict(int,
#               {'over': 0.125,
#                'right': 0.125,
#                'it': 0.125,
#                'to': 0.25,
#                'anything': 0.125,
#                'at': 0.125,
#                'the': 0.125}),
#   'see': defaultdict(int,
#               {'if': 0.125,
#                'it': 0.125,
#                'how': 0.125,
#                'me': 0.125,
#                'what': 0.125,
#                'for': 0.125,
#                'us': 0.125,
#                'where': 0.125}),
#   'take': defaultdict(int,
#               {'over': 0.14285714285714285,
#                'me': 0.2857142857142857,
#                'it': 0.14285714285714285,
#                'any': 0.14285714285714285,
#                'her': 0.14285714285714285,
#                'them': 0.14285714285714285}),
#   'our': defaultdict(int, {'clearing': 0.5, 'greatgrandmother': 0.5}),
#   'live': defaultdict(int,
#               {'in': 0.25, 'here': 0.25, 'together': 0.25, 'with': 0.25}),
#   'prefer': defaultdict(int, {'to': 1.0}),
#   'last': defaultdict(int, {'for': 1.0}),
#   'consent': defaultdict(int, {'to': 1.0}),
#   'give': defaultdict(int, {'some': 0.5, 'a': 0.5}),
#   'skin': defaultdict(int, {'and': 1.0}),
#   'blanket': defaultdict(int, {'him': 1.0}),
#   'gnaw': defaultdict(int, {'the': 1.0}),
#   'splinters': defaultdict(int, {'what': 1.0}),
#   'turn': defaultdict(int, {'him': 1.0}),
#   'saying': defaultdict(int, {'things': 1.0}),
#   'undo': defaultdict(int, {'what': 1.0}),
#   'let': defaultdict(int, {'on': 0.5, 'myself': 0.5}),
#   'death': defaultdict(int, {'with': 1.0}),
#   'put': defaultdict(int, {'up': 0.5, 'out': 0.5}),
#   'a': defaultdict(int, {'worse': 1.0}),
#   'shut': defaultdict(int, {'you': 1.0}),
#   'woods': defaultdict(int, {'around': 1.0}),
#   'bad': defaultdict(int, {'masonry': 1.0}),
#   'find': defaultdict(int,
#               {'it': 0.25, 'out': 0.25, 'or': 0.25, 'yourself': 0.25}),
#   'descend': defaultdict(int, {'to': 1.0}),
#   'surprise': defaultdict(int, {'the': 1.0}),
#   'spend': defaultdict(int, {'the': 1.0}),
#   'lave': defaultdict(int, {'my': 1.0}),
# ...
#  'common': {'table': defaultdict(int, {'rear': 1.0})},
#  'legs': {'like': defaultdict(int, {'an': 1.0}),
#   'out': defaultdict(int, {'of': 1.0})},
#  'rather': {'than': defaultdict(int, {'tip': 1.0})},
#  'tip': {'a': defaultdict(int, {'table': 1.0})},
#  'table': {'for': defaultdict(int, {'you': 1.0})},
#  'ralle': {'the': defaultdict(int, {'sioux': 1.0})},
#  'sioux': {'control': defaultdict(int, {'once': 1.0})},
#  'control': {'once': defaultdict(int, {'told': 1.0})},
#  'souls': {'but': defaultdict(int, {'when': 1.0})},
#  'broke': {'my': defaultdict(int, {'trance': 1.0})},
#  'trance': {'dont': defaultdict(int, {'that': 1.0}),
#   'you': defaultdict(int, {'are': 1.0})},
#  'yes': {'theres': defaultdict(int, {'something': 1.0}),
#   'we': defaultdict(int, {'could': 1.0}),
#   'for': defaultdict(int, {'there': 1.0}),
#   'stark': defaultdict(int, {'and': 1.0}),
#   'what': defaultdict(int, {'do': 1.0}),
#   'its': defaultdict(int, {'important': 1.0}),
#   'you': defaultdict(int, {'must': 1.0}),
#   'whats': defaultdict(int, {'it': 1.0}),
#   'but': defaultdict(int, {'he': 1.0}),
#   'i': defaultdict(int, {'do': 1.0})},
#  'wouldnt': {'want': defaultdict(int, {'to': 1.0}),
#   'have': defaultdict(int, {'him': 1.0}),
#   'hurt': defaultdict(int, {'a': 1.0}),
#   'give': defaultdict(int, {'way': 1.0})},
#  'bones': {'a': defaultdict(int, {'skeleton': 1.0}),
#   'came': defaultdict(int, {'up': 1.0}),
#   'i': defaultdict(int, {'knew': 1.0}),
#   'didnt': defaultdict(int, {'try': 1.0}),
#   'the': defaultdict(int, {'cellar': 1.0}),
#   'out': defaultdict(int, {'of': 1.0}),
#   'liked': defaultdict(int, {'the': 1.0}),
#   'they': defaultdict(int, {'were': 1.0})},
#  'headboard': {'of': defaultdict(int,
#               {'mothers': 0.3333333333333333, 'the': 0.6666666666666666}),
#   'where': defaultdict(int, {'it': 1.0})},
#  'mothers': {'bed': defaultdict(int, {'is': 1.0})},
#  'door': {'the': defaultdict(int, {'door': 1.0}),
#   'is': defaultdict(int, {'nailed': 1.0}),
#   'and': defaultdict(int,
#               {'headboard': 0.6666666666666666, 'held': 0.3333333333333333}),
#   'to': defaultdict(int,
#               {'cool': 0.25, 'the': 0.25, 'try': 0.25, 'get': 0.25}),
#   'but': defaultdict(int, {'the': 1.0}),
#   'they': defaultdict(int, {'halted': 1.0}),
#   'wide': defaultdict(int, {'on': 0.5, 'but': 0.5}),
#   'for': defaultdict(int, {'the': 1.0}),
#   'up': defaultdict(int, {'attic': 1.0})},
#  'harmless': {'mother': defaultdict(int, {'hears': 1.0})},
#  'hears': {'it': defaultdict(int, {'in': 1.0})},
#  'halting': {'perplexed': defaultdict(int, {'behind': 1.0})},
#  'perplexed': {'behind': defaultdict(int, {'the': 1.0})},
#  'wants': {'to': defaultdict(int, {'get': 0.5, 'hear': 0.5}),
#   'our': defaultdict(int, {'hens': 1.0})},
#  'cellar': {'where': defaultdict(int, {'it': 1.0}),
#   'forty': defaultdict(int, {'years': 1.0}),
#   'to': defaultdict(int, {'the': 1.0}),
#   'in': defaultdict(int, {'spring': 1.0}),
#   'bottom': defaultdict(int, {'and': 1.0}),
#   'windows': defaultdict(int, {'were': 1.0}),
#   'or': defaultdict(int, {'the': 1.0}),
#   'bones': defaultdict(int, {'out': 1.0}),
#   'hole': defaultdict(int, {'in': 1.0}),
#   'after': defaultdict(int, {'jam': 1.0})},
#  'forty': {'years': defaultdict(int, {'ago': 1.0}),
#   'cellar': defaultdict(int, {'holes': 1.0})},
#  'carried': {'itself': defaultdict(int, {'like': 1.0})},
#  'itself': {'like': defaultdict(int, {'a': 1.0})},
#  'pile': {'of': defaultdict(int, {'dishes': 1.0})},
#  'flight': {'from': defaultdict(int, {'the': 1.0})},
#  'another': {'from': defaultdict(int, {'the': 1.0}),
#   'door': defaultdict(int, {'to': 1.0})},
#  'kitchen': {'to': defaultdict(int, {'the': 0.5, 'yourself': 0.5}),
#   'had': defaultdict(int, {'been': 1.0})},
#  'bedroom': {'to': defaultdict(int, {'the': 1.0})},
#  'past': {'both': defaultdict(int, {'father': 1.0}),
#   'and': defaultdict(int, {'get': 1.0})},
#  'gone': {'upstairs': defaultdict(int, {'mother': 1.0}),
#   'to': defaultdict(int,
#               {'bed': 0.3333333333333333,
#                'yours': 0.3333333333333333,
#                'garlands': 0.3333333333333333}),
#   'out': defaultdict(int, {'of': 1.0}),
#   'before': defaultdict(int, {'i': 1.0}),
#   'so': defaultdict(int, {'far': 1.0}),
#   'of': defaultdict(int, {'course': 1.0})},
#  'upstairs': {'mother': defaultdict(int, {'was': 1.0}),
#   'in': defaultdict(int, {'the': 1.0}),
#   'and': defaultdict(int, {'in': 1.0})},
#  'baby': {'i': defaultdict(int, {'dont': 1.0})},
#  'fault': {'my': defaultdict(int, {'husband': 1.0})},
#  'husband': {'found': defaultdict(int, {'with': 1.0})},
#  'sleep': {'before': defaultdict(int, {'i': 1.0})},
#  'especially': {'in': defaultdict(int, {'winter': 1.0})},
#  'ice': {'and': defaultdict(int, {'the': 1.0})},
#  'toffile': {'had': defaultdict(int, {'gone': 1.0}),
#   'upstairs': defaultdict(int, {'in': 1.0}),
#   'for': defaultdict(int, {'my': 1.0}),
#   'i': defaultdict(int, {'dont': 1.0}),
#   'agreed': defaultdict(int, {'to': 1.0}),
#   'didnt': defaultdict(int, {'seem': 1.0}),
#   'get': defaultdict(int, {'nails': 1.0}),
#   'to': defaultdict(int, {'be': 1.0}),
#   'if': defaultdict(int, {'he': 1.0})},
#  'alone': {'and': defaultdict(int, {'left': 1.0}),
#   'sunday': defaultdict(int, {'after': 1.0})},
#  'open': {'door': defaultdict(int,
#               {'to': 0.6666666666666666, 'up': 0.3333333333333333}),
#   'grassy': defaultdict(int, {'places': 1.0})},
#  'cool': {'the': defaultdict(int, {'room': 0.5, 'eyes': 0.5})},
#  'coming': {'to': defaultdict(int, {'myself': 1.0}),
#   'up': defaultdict(int, {'to': 0.5, 'had': 0.5}),
#   'down': defaultdict(int, {'ryans': 1.0})},
#  'cold': {'was': defaultdict(int, {'coming': 1.0}),
#   'as': defaultdict(int, {'a': 1.0}),
#   'a': defaultdict(int, {'digger': 1.0})},
#  'downstairs': {'in': defaultdict(int, {'the': 1.0})},
#  'board': {'we': defaultdict(int, {'had': 1.0})},
#  'laid': {'down': defaultdict(int, {'to': 1.0})},
#  'walk': {'dryshod': defaultdict(int, {'on': 1.0})},
#  'water': {'in': defaultdict(int, {'the': 1.0}),
#   'more': defaultdict(int, {'or': 1.0}),
#   'of': defaultdict(int, {'the': 1.0})},
#  'hard': {'cellar': defaultdict(int, {'bottom': 1.0}),
#   'on': defaultdict(int, {'the': 1.0}),
#   'with': defaultdict(int, {'john': 1.0})},
#  'bottom': {'and': defaultdict(int, {'then': 1.0})},
#  'began': {'the': defaultdict(int, {'stairs': 1.0}),
#   'to': defaultdict(int, {'climb': 1.0})},
#  'stairs': {'two': defaultdict(int, {'footsteps': 1.0}),
#   'at': defaultdict(int, {'night': 1.0})},
#  'footsteps': {'for': defaultdict(int, {'each': 1.0})},
#  'leg': {'and': defaultdict(int, {'a': 1.0})},
#  'child': {'comes': defaultdict(int, {'up': 1.0})},
#  'bulkhead': {'doubledoors': defaultdict(int, {'were': 1.0})},
#  'doubledoors': {'were': defaultdict(int, {'doublelocked': 1.0})},
#  'swollen': {'tight': defaultdict(int, {'and': 1.0})},
#  'tight': {'and': defaultdict(int, {'buried': 1.0})},
#  'windows': {'were': defaultdict(int, {'banked': 1.0})},
#  'banked': {'up': defaultdict(int, {'with': 1.0})},
#  'impulse': {'was': defaultdict(int, {'to': 1.0}),
#   'not': defaultdict(int, {'to': 1.0})},
#  'get': {'to': defaultdict(int, {'the': 1.0}),
#   'up': defaultdict(int, {'im': 0.5, 'forgive': 0.5}),
#   'nails': defaultdict(int, {'i': 1.0}),
#   'some': defaultdict(int, {'strangeness': 0.5, 'color': 0.5}),
#   'her': defaultdict(int, {'greatness': 1.0}),
#   'out': defaultdict(int, {'of': 1.0}),
#   'saved': defaultdict(int, {'as': 1.0}),
#   'me': defaultdict(int, {'through': 1.0}),
#   'married': defaultdict(int, {'when': 1.0}),
#   'far': defaultdict(int, {'before': 1.0})},
#  'halted': {'helpless': defaultdict(int, {'on': 1.0}),
#   'some': defaultdict(int, {'way': 1.0})},
#  'helpless': {'on': defaultdict(int, {'the': 1.0})},
#  'faintest': {'restless': defaultdict(int, {'rustling': 1.0})},
#  'restless': {'rustling': defaultdict(int, {'ran': 1.0})},
#  'rustling': {'ran': defaultdict(int, {'all': 1.0})},
#  'wish': {'hadnt': defaultdict(int, {'been': 1.0}),
#   'to': defaultdict(int, {'hear': 0.5, 'give': 0.5})},
#  'strong': {'in': defaultdict(int, {'me': 1.0})},
#  'mounted': {'for': defaultdict(int, {'this': 1.0}),
#   'bareback': defaultdict(int, {'on': 1.0})},
#  'vision': {'of': defaultdict(int, {'them': 1.0})},
#  'flung': {'the': defaultdict(int, {'door': 1.0})},
#  'wide': {'on': defaultdict(int, {'him': 1.0}),
#   'but': defaultdict(int, {'he': 1.0})},
#  'moment': {'he': defaultdict(int, {'stood': 0.5, 'was': 0.5})},
#  'balancing': {'with': defaultdict(int, {'emotion': 1.0})},
#  'himself': {'a': defaultdict(int, {'tongue': 1.0}),
#   'wont': defaultdict(int, {'imagine': 1.0})},
#  'tongue': {'of': defaultdict(int, {'fire': 1.0})},
#  'flashed': {'out': defaultdict(int, {'and': 1.0})},
#  'licked': {'along': defaultdict(int, {'his': 1.0})},
#  'along': {'his': defaultdict(int, {'upper': 1.0}),
#   'the': defaultdict(int, {'toteroad': 1.0}),
#   'at': defaultdict(int, {'first': 1.0}),
#   'with': defaultdict(int, {'him': 1.0})},
#  'smoke': {'rolled': defaultdict(int, {'inside': 1.0})},
#  'rolled': {'inside': defaultdict(int, {'the': 1.0})},
#  'inside': {'the': defaultdict(int, {'sockets': 1.0})},
#  'sockets': {'of': defaultdict(int, {'his': 1.0})},
#  'hand': {'off': defaultdict(int, {'brittle': 1.0}),
#   'me': defaultdict(int, {'my': 1.0}),
#   'up': defaultdict(int, {'pick': 1.0})},
#  'brittle': {'on': defaultdict(int, {'the': 1.0})},
#  'fingerpieces': {'slid': defaultdict(int, {'in': 1.0})},
#  'slid': {'in': defaultdict(int, {'all': 1.0})},
#  'buttonbox': {'it': defaultdict(int, {'must': 1.0})},
#  'sat': {'up': defaultdict(int, {'on': 1.0}),
#   'listening': defaultdict(int, {'to': 1.0})},
#  'floor': {'and': defaultdict(int, {'shouted': 1.0})},
#  'briskly': {'for': defaultdict(int, {'so': 1.0})},
#  'slow': {'a': defaultdict(int, {'thing': 1.0})},
#  'stillgoing': {'every': defaultdict(int, {'which': 1.0})},
#  'lightning': {'or': defaultdict(int, {'a': 1.0})},
#  'slap': {'i': defaultdict(int, {'had': 1.0})},
#  'given': {'its': defaultdict(int, {'hand': 1.0}),
#   'an': defaultdict(int, {'opening': 1.0}),
#   'to': defaultdict(int, {'plain': 1.0}),
#   'her': defaultdict(int, {'time': 1.0})},
#  'listened': {'till': defaultdict(int, {'it': 1.0}),
#   'in': defaultdict(int, {'among': 1.0})},
#  'almost': {'climbed': defaultdict(int, {'the': 1.0}),
#   'the': defaultdict(int, {'moment': 1.0}),
#   'here': defaultdict(int, {'ive': 1.0})},
#  'climbed': {'the': defaultdict(int, {'stairs': 1.0})},
#  'shouted': {'shut': defaultdict(int, {'the': 1.0})},
#  'company': {'he': defaultdict(int, {'said': 1.0}),
#   'outward': defaultdict(int, {'bound': 1.0})},
#  'warm': {'in': defaultdict(int, {'bed': 1.0})},
#  'forward': {'weakly': defaultdict(int, {'on': 1.0})},
#  'weakly': {'on': defaultdict(int, {'the': 1.0})},
#  'pushed': {'myself': defaultdict(int, {'upstairs': 1.0})},
#  'us': {'in': defaultdict(int, {'the': 1.0}),
#   'than': defaultdict(int, {'the': 1.0}),
#   'back': defaultdict(int, {'into': 1.0}),
#   'always': defaultdict(int, {'to': 1.0}),
#   'but': defaultdict(int, {'look': 1.0}),
#   'have': defaultdict(int, {'any': 1.0})},
#  'room': {'though': defaultdict(int, {'its': 1.0}),
#   'before': defaultdict(int, {'a': 1.0})},
#  'throw': {'his': defaultdict(int, {'bare': 1.0}),
#   'a': defaultdict(int, {'picture': 1.0}),
#   'the': defaultdict(int, {'hoe': 1.0})},
#  'bare': {'legs': defaultdict(int, {'out': 1.0})},
#  'sit': {'up': defaultdict(int, {'by': 0.5, 'in': 0.5}),
#   'before': defaultdict(int, {'you': 1.0}),
#   'and': defaultdict(int, {'tell': 1.0})},
#  'mow': {'the': defaultdict(int, {'room': 1.0})},
#  'arms': {'at': defaultdict(int, {'the': 1.0})},
#  'level': {'of': defaultdict(int, {'our': 1.0}),
#   'higher': defaultdict(int, {'than': 1.0}),
#   'nearer': defaultdict(int, {'heaven': 1.0})},
#  'chalkpile': {'down': defaultdict(int, {'ill': 1.0})},
#  'uncommonly': {'deep': defaultdict(int, {'snow': 1.0})},
#  'sing': {'along': defaultdict(int, {'the': 1.0})},
#  'trap': {'him': defaultdict(int, {'with': 1.0})},
#  'agreed': {'to': defaultdict(int, {'that': 1.0})},
#  'steps': {'began': defaultdict(int, {'to': 1.0})},
#  'quick': {'i': defaultdict(int, {'slammed': 1.0})},
#  'slammed': {'to': defaultdict(int, {'the': 1.0})},
#  'nails': {'i': defaultdict(int, {'made': 1.0})},
#  'nail': {'the': defaultdict(int, {'door': 1.0})},
#  'push': {'the': defaultdict(int, {'headboard': 1.0})},
#  'wed': {'ever': defaultdict(int, {'want': 1.0}),
#   'kept': defaultdict(int, {'all': 1.0})},
#  'brushing': {'their': defaultdict(int, {'chalky': 1.0})},
#  'chalky': {'skull': defaultdict(int, {'with': 1.0})},
#  'skull': {'with': defaultdict(int, {'chalky': 1.0})},
#  'dry': {'rattling': defaultdict(int, {'of': 1.0})},
#  'rattling': {'of': defaultdict(int, {'a': 1.0})},
#  '2o3': {'let': defaultdict(int, {'them': 1.0})},
#  'promised': {'toffile': defaultdict(int, {'to': 1.0})},
#  'cruel': {'to': defaultdict(int, {'them': 1.0}),
#   'once': defaultdict(int, {'to': 1.0})},
#  'helping': {'them': defaultdict(int, {'be': 1.0})},
#  'grave': {'down': defaultdict(int, {'in': 1.0})},
#  'truth': {'for': defaultdict(int, {'once': 1.0}),
#   'suppose': defaultdict(int, {'the': 1.0}),
#   'i': defaultdict(int, {'speak': 1.0})},
#  'mans': {'his': defaultdict(int, {'father': 1.0})},
#  'killed': {'for': defaultdict(int, {'me': 1.0}),
#   'instead': defaultdict(int, {'of': 1.0})},
#  'instead': {'of': defaultdict(int, {'me': 1.0})},
#  'help': {'dig': defaultdict(int, {'their': 1.0}),
#   'out': defaultdict(int, {'with': 1.0}),
#   'liking': defaultdict(int, {'about': 1.0})},
#  'dig': {'their': defaultdict(int, {'grave': 1.0})},
#  'knows': {'the': defaultdict(int, {'story': 1.0}),
#   'his': defaultdict(int, {'friends': 1.0}),
#   'hes': defaultdict(int, {'kinder': 1.0}),
#   'my': defaultdict(int, {'interest': 1.0})},
#  'story': {'but': defaultdict(int, {'twas': 1.0}),
#   'in': defaultdict(int, {'a': 1.0})},
#  'suppose': {'the': defaultdict(int, {'time': 1.0}),
#   'she': defaultdict(int, {'deserves': 1.0})},
#  'surprised': {'to': defaultdict(int, {'see': 1.0})},
#  'years': {'between': defaultdict(int, {'ourselves': 1.0}),
#   'berries': defaultdict(int, {'shining': 1.0}),
#   'high': defaultdict(int, {'girdle': 1.0})},
#  'tonight': {'i': defaultdict(int, {'dont': 1.0})},
#  'care': {'enough': defaultdict(int, {'to': 1.0}),
#   'of': defaultdict(int, {'him': 1.0})},
#  'fingerbone': {'she': defaultdict(int, {'wanted': 1.0})},
#  'among': {'the': defaultdict(int,
#               {'buttons': 0.25,
#                'raspberry': 0.25,
#                'sounds': 0.25,
#                'raspberries': 0.25}),
#   'unearthed': defaultdict(int, {'potatoes': 1.0})},
#  'buttons': {'poured': defaultdict(int, {'out': 1.0})},
#  'poured': {'out': defaultdict(int, {'in': 1.0})},
#  'verified': {'the': defaultdict(int, {'name': 1.0})},
#  'name': {'next': defaultdict(int, {'morning': 1.0}),
#   'stark': defaultdict(int, {'gathered': 1.0}),
#   'should': defaultdict(int, {'matter': 1.0}),
#   'all': defaultdict(int, {'the': 1.0}),
#   'the': defaultdict(int, {'hour': 1.0}),
#   'no': defaultdict(int, {'names': 1.0})},
#  'next': {'morning': defaultdict(int, {'toffile': 1.0})},
#  'rural': {'letterbox': defaultdict(int, {'said': 1.0})},
#  'letterbox': {'said': defaultdict(int, {'toffile': 1.0})},
#  'air': {'had': defaultdict(int, {'died': 1.0}),
#   'of': defaultdict(int, {'what': 1.0})},
#  'died': {'of': defaultdict(int, {'cold': 1.0})},
#  'shoeing': {'home': defaultdict(int, {'across': 1.0})},
#  'summer': {'when': defaultdict(int, {'i': 1.0}),
#   'dwelling': defaultdict(int, {'here': 1.0})},
#  'lift': {'my': defaultdict(int, {'face': 1.0}),
#   'themselves': defaultdict(int, {'up': 1.0})},
#  'singing': {'in': defaultdict(int, {'it': 1.0}),
#   'and': defaultdict(int, {'the': 1.0})},
#  'sweet': {'and': defaultdict(int, {'swift': 1.0})},
#  'single': {'leaf': defaultdict(int, {'was': 1.0})},
#  'twice': {'around': defaultdict(int, {'the': 1.0}),
#   'as': defaultdict(int, {'well': 1.0})},
#  'around': {'the': defaultdict(int, {'tree': 1.0}),
#   'and': defaultdict(int, {'under': 1.0}),
#   'twice': defaultdict(int, {'as': 1.0})},
#  'advantage': {'on': defaultdict(int, {'a': 1.0})},
#  'judged': {'that': defaultdict(int, {'such': 1.0})},
#  'adding': {'frost': defaultdict(int, {'to': 1.0})},
#  'frost': {'to': defaultdict(int, {'snow': 1.0})},
#  'gilt': {'to': defaultdict(int, {'gold': 1.0})},
#  ...}

# %% [markdown]
# ### Cumulative Probability Distribution of Second Order

# %%
for second_outer_keys in second_order.keys():
    for first_outer_keys in second_order[second_outer_keys].keys():
        
        second_order_key_list = list(second_order[second_outer_keys][first_outer_keys])
        for idx, key in enumerate(second_order_key_list):
            
            if idx==0:
                continue
            
            second_order[second_outer_keys][first_outer_keys][key]+=second_order[second_outer_keys][first_outer_keys][second_order_key_list[idx-1]]
            
second_order
# Out:
# {'two': {'roads': defaultdict(int, {'diverged': 1.0}),
#   'miles': defaultdict(int, {'it': 1.0}),
#   'towns': defaultdict(int, {'fighting': 1.0}),
#   'converging': defaultdict(int, {'slides': 1.0}),
#   'or': defaultdict(int, {'three': 1.0}),
#   'oldbelievers': defaultdict(int, {'they': 1.0}),
#   'legs': defaultdict(int, {'like': 1.0}),
#   'footsteps': defaultdict(int, {'for': 1.0}),
#   'village': defaultdict(int, {'cultures': 1.0}),
#   'winds': defaultdict(int, {'would': 1.0}),
#   'weeks': defaultdict(int, {'since': 1.0}),
#   'of': defaultdict(int, {'you': 1.0}),
#   'as': defaultdict(int, {'good': 1.0}),
#   'at': defaultdict(int, {'a': 1.0})},
#  'roads': {'diverged': defaultdict(int, {'in': 1.0})},
#  'diverged': {'in': defaultdict(int, {'a': 1.0})},
#  'in': {'a': defaultdict(int,
#               {'yellow': 0.07142857142857142,
#                'wood': 0.14285714285714285,
#                'window': 0.21428571428571427,
#                'packing': 0.2857142857142857,
#                'byroad': 0.3571428571428571,
#                'family': 0.4285714285714285,
#                'new': 0.4999999999999999,
#                'row': 0.5714285714285713,
#                'time': 0.6428571428571427,
#                'town': 0.7142857142857141,
#                'book': 0.7857142857142855,
#                'smother': 0.8571428571428569,
#                'glass': 0.9999999999999998}),
#   'the': defaultdict(int,
#               {'undergrowth': 0.021739130434782608,
#                'village': 0.043478260869565216,
#                'stars': 0.06521739130434782,
#                'confusion': 0.08695652173913043,
#                'excited': 0.10869565217391304,
#                'scene': 0.13043478260869565,
#                'river': 0.15217391304347827,
#                'cold': 0.1956521739130435,
#                'town': 0.2173913043478261,
#                'warrant': 0.2391304347826087,
#                'stable': 0.2608695652173913,
#                'huse': 0.2826086956521739,
#                'tail': 0.3043478260869565,
#                'dark': 0.34782608695652173,
#                'mountain': 0.3695652173913043,
#                'box': 0.3913043478260869,
#                'night': 0.4130434782608695,
#                'bedroom': 0.4347826086956521,
#                'cellar': 0.5869565217391304,
#                'joints': 0.608695652173913,
#                'light': 0.6304347826086956,
#                'room': 0.6521739130434782,
#                'attic': 0.6956521739130433,
#                'grass': 0.7173913043478259,
#                'rain': 0.7391304347826085,
#                'sun': 0.7608695652173911,
#                'empty': 0.7826086956521737,
#                'open': 0.8043478260869563,
#                'kitchen': 0.8260869565217389,
#                'weather': 0.8478260869565215,
#                'playhouse': 0.8695652173913041,
#                'instep': 0.8913043478260867,
#                'newcut': 0.9130434782608693,
#                'plowed': 0.9347826086956519,
#                'bushy': 0.9565217391304345,
#                'heat': 0.9782608695652171,
#                'yard': 0.9999999999999997}),
#   'leaves': defaultdict(int, {'no': 1.0}),
#   'rain': defaultdict(int,
#               {'and': 0.3333333333333333,
#                'sometime': 0.6666666666666666,
#                'tomorrow': 1.0}),
#   'front': defaultdict(int, {'of': 1.0}),
#   'every': defaultdict(int,
#               {'lifelike': 0.3333333333333333,
#                'open': 0.6666666666666666,
#                'way': 1.0}),
#   'it': defaultdict(int, {'from': 0.25, 'sweet': 0.5, 'now': 0.75, 'a': 1.0}),
#   'winter': defaultdict(int, {'after': 0.5, 'when': 1.0}),
#   'somewhere': defaultdict(int, {'with': 1.0}),
#   'march': defaultdict(int, {'meeting': 1.0}),
#   'warren': defaultdict(int, {'at': 1.0}),
#   'wentworth': defaultdict(int, {'from': 1.0}),
#   'their': defaultdict(int, {'town': 0.5, 'favour': 1.0}),
#   'his': defaultdict(int,
#               {'old': 0.3333333333333333,
#                'mouth': 0.6666666666666666,
#                'mans': 1.0}),
#   'grafton': defaultdict(int, {'county': 1.0}),
#   'and': defaultdict(int, {'as': 0.5, 'the': 1.0}),
#   'folks': defaultdict(int, {'faces': 1.0}),
#   'dalton': defaultdict(int, {'that': 1.0}),
#   'dust': defaultdict(int, {'once': 1.0}),
#   'for': defaultdict(int, {'life': 1.0}),
#   'bed': defaultdict(int, {'and': 1.0}),
#   'stones': defaultdict(int, {'and': 1.0}),
#   'virgin': defaultdict(int, {'wrapper': 1.0}),
#   'one': defaultdict(int,
#               {'and': 0.3333333333333333,
#                'himself': 0.6666666666666666,
#                'self': 1.0}),
#   'my': defaultdict(int, {'pocket': 1.0}),
#   'time': defaultdict(int, {'she': 1.0}),
#   'at': defaultdict(int, {'the': 1.0}),
#   'snow': defaultdict(int, {'and': 1.0}),
#   'its': defaultdict(int, {'twothousandmile': 1.0}),
#   'life': defaultdict(int, {'once': 1.0}),
#   'all': defaultdict(int, {'directions': 1.0}),
#   'her': defaultdict(int, {'lap': 0.6666666666666666, 'day': 1.0}),
#   'summer': defaultdict(int, {'when': 1.0}),
#   'going': defaultdict(int, {'twice': 1.0}),
#   'new': defaultdict(int, {'hampshire': 1.0}),
#   'an': defaultdict(int, {'old': 0.5, 'alder': 1.0}),
#   'grove': defaultdict(int, {'and': 1.0}),
#   'such': defaultdict(int, {'a': 1.0}),
#   'among': defaultdict(int, {'the': 1.0}),
#   'across': defaultdict(int, {'the': 1.0}),
#   'dialect': defaultdict(int, {'whose': 1.0}),
#   'not': defaultdict(int, {'old': 1.0}),
#   'this': defaultdict(int, {'place': 1.0}),
#   'sunshine': defaultdict(int, {'so': 1.0}),
#   'building': defaultdict(int, {'the': 1.0}),
#   'position': defaultdict(int, {'to': 1.0}),
#   'your': defaultdict(int, {'ladder': 1.0}),
#   'that': defaultdict(int, {'grave': 0.5, 'case': 0.75, 'apple': 1.0}),
#   'than': defaultdict(int, {'i': 1.0}),
#   'earnest': defaultdict(int, {'it': 1.0}),
#   'here': defaultdict(int, {'like': 1.0}),
#   'year': defaultdict(int, {'out': 1.0}),
#   'separate': defaultdict(int, {'coops': 1.0}),
#   'ways': defaultdict(int, {'that': 1.0})},
#  'a': {'yellow': defaultdict(int, {'wood': 1.0}),
#   'wood': defaultdict(int, {'and': 1.0}),
#   'farmhouse': defaultdict(int, {'near': 1.0}),
#   'tree': defaultdict(int, {'beside': 0.5, 'that': 1.0}),
#   'leaf': defaultdict(int, {'that': 0.5, 'if': 1.0}),
#   'voice': defaultdict(int, {'said': 1.0}),
#   'gentle': defaultdict(int, {'cast': 0.5, 'lot': 1.0}),
#   'jerk': defaultdict(int, {'or': 1.0}),
#   'breath': defaultdict(int, {'of': 1.0}),
#   'swamp': defaultdict(int, {'of': 1.0}),
#   'sort': defaultdict(int, {'of': 1.0}),
#   'resurrected': defaultdict(int, {'tree': 1.0}),
#   'barkless': defaultdict(int, {'spectre': 1.0}),
#   'lofty': defaultdict(int, {'farm': 1.0}),
#   'hole': defaultdict(int, {'in': 0.5, 'i': 1.0}),
#   'coasting': defaultdict(int, {'child': 1.0}),
#   'matter': defaultdict(int, {'of': 1.0}),
#   'present': defaultdict(int, {'of': 1.0}),
#   'lot': defaultdict(int, {'now': 1.0}),
#   'noted': defaultdict(int, {'witch': 1.0}),
#   'witch': defaultdict(int,
#               {'id': 0.3333333333333333,
#                'or': 0.6666666666666666,
#                'who': 1.0}),
#   'cribber': defaultdict(int, {'and': 1.0}),
#   'strapping': defaultdict(int, {'girl': 1.0}),
#   'night': defaultdict(int, {'of': 1.0}),
#   'solid': defaultdict(int, {'mica': 1.0}),
#   'stone': defaultdict(int, {'baptismal': 1.0}),
#   'worse': defaultdict(int, {'fight': 1.0}),
#   'leak': defaultdict(int, {'and': 1.0}),
#   'good': defaultdict(int, {'deal': 0.5, 'home': 1.0}),
#   'day': defaultdict(int, {'of': 1.0}),
#   'lookoff': defaultdict(int, {'where': 1.0}),
#   'cliff': defaultdict(int, {'and': 1.0}),
#   'bottle': defaultdict(int, {'painted': 1.0}),
#   'likeness': defaultdict(int, {'to': 1.0}),
#   'donkeys': defaultdict(int, {'cars': 1.0}),
#   'road': defaultdict(int, {'i': 1.0}),
#   'house': defaultdict(int,
#               {'deserted': 0.2, 'stripped': 0.4, 'that': 0.8, 'in': 1.0}),
#   'whole': defaultdict(int, {'edition': 1.0}),
#   'packing': defaultdict(int, {'case': 1.0}),
#   'horn': defaultdict(int, {'of': 1.0}),
#   'village': defaultdict(int, {'library': 1.0}),
#   'bird': defaultdict(int,
#               {'silent': 0.3333333333333333,
#                'alight': 0.6666666666666666,
#                'with': 1.0}),
#   'stricken': defaultdict(int, {'bird': 1.0}),
#   'hornyhanded': defaultdict(int, {'kindness': 1.0}),
#   'demand': defaultdict(int, {'she': 1.0}),
#   'small': defaultdict(int, {'skiff': 1.0}),
#   'paddle': defaultdict(int, {'blade': 1.0}),
#   'trapper': defaultdict(int, {'looking': 1.0}),
#   'mother': defaultdict(int, {'and': 1.0}),
#   'winter': defaultdict(int,
#               {'evening': 0.3333333333333333,
#                'eve': 0.6666666666666666,
#                'garden': 1.0}),
#   'common': defaultdict(int, {'table': 1.0}),
#   'table': defaultdict(int, {'for': 1.0}),
#   'pile': defaultdict(int, {'of': 1.0}),
#   'baby': defaultdict(int, {'i': 1.0}),
#   'man': defaultdict(int,
#               {'with': 0.16666666666666666,
#                'but': 0.3333333333333333,
#                'he': 0.5,
#                'let': 0.6666666666666666,
#                'to': 0.8333333333333333,
#                'at': 0.9999999999999999}),
#   'little': defaultdict(int,
#               {'child': 0.2,
#                'little': 0.4,
#                'longer': 0.6000000000000001,
#                'finger': 0.8,
#                'yesterday': 1.0}),
#   'vision': defaultdict(int, {'of': 1.0}),
#   'moment': defaultdict(int, {'he': 1.0}),
#   'tongue': defaultdict(int, {'of': 1.0}),
#   'grave': defaultdict(int, {'down': 1.0}),
#   'mans': defaultdict(int, {'his': 1.0}),
#   'single': defaultdict(int, {'leaf': 1.0}),
#   'crystal': defaultdict(int, {'chill': 1.0}),
#   'brush': defaultdict(int, {'had': 1.0}),
#   'crooked': defaultdict(int, {'stroke': 1.0}),
#   'piercing': defaultdict(int, {'little': 1.0}),
#   'governor': defaultdict(int, {'it': 1.0}),
#   'rockstrewn': defaultdict(int, {'town': 1.0}),
#   'tent': defaultdict(int, {'in': 1.0}),
#   'swish': defaultdict(int, {'in': 1.0}),
#   'farm': defaultdict(int, {'not': 0.5, 'that': 1.0}),
#   'girl': defaultdict(int, {'and': 1.0}),
#   'family': defaultdict(int, {'tree': 1.0}),
#   'sudden': defaultdict(int, {'movement': 1.0}),
#   'lane': defaultdict(int, {'yet': 1.0}),
#   'viola': defaultdict(int, {'i': 1.0}),
#   'plain': defaultdict(int, {'statement': 1.0}),
#   'shattered': defaultdict(int, {'seedpod': 1.0}),
#   'brook': defaultdict(int,
#               {'hidden': 0.3333333333333333,
#                'makes': 0.6666666666666666,
#                'that': 1.0}),
#   'member': defaultdict(int, {'of': 1.0}),
#   'person': defaultdict(int, {'so': 1.0}),
#   'lake': defaultdict(int, {'before': 1.0}),
#   'myth': defaultdict(int, {'of': 1.0}),
#   'match': defaultdict(int, {'flame': 1.0}),
#   'hand': defaultdict(int, {'up': 1.0}),
#   'bead': defaultdict(int, {'of': 1.0}),
#   'wild': defaultdict(int, {'descent': 1.0}),
#   'purer': defaultdict(int, {'oracle': 1.0}),
#   'picture': defaultdict(int, {'on': 1.0}),
#   'name': defaultdict(int, {'should': 1.0}),
#   'doorsill': defaultdict(int, {'or': 1.0}),
#   'new': defaultdict(int, {'cottage': 1.0}),
#   'dite': defaultdict(int, {'too': 1.0}),
#   'chimney': defaultdict(int, {'upon': 0.5, 'that': 1.0}),
#   'fulllength': defaultdict(int, {'chimney': 1.0}),
#   'shelfs': defaultdict(int, {'for': 1.0}),
#   'clock': defaultdict(int, {'or': 1.0}),
#   'glimpse': defaultdict(int, {'through': 1.0}),
#   'garden': defaultdict(int, {'wall': 1.0}),
#   'sunny': defaultdict(int, {'cheek': 1.0}),
#   'passing': defaultdict(int, {'car': 1.0}),
#   'tunnel': defaultdict(int, {'mouth': 1.0}),
#   'time': defaultdict(int, {'made': 1.0}),
#   'town': defaultdict(int, {'that': 1.0}),
#   'guide': defaultdict(int, {'direct': 1.0}),
#   'story': defaultdict(int, {'in': 1.0}),
#   'book': defaultdict(int, {'about': 1.0}),
#   'certain': defaultdict(int, {'coolness': 1.0}),
#   'few': defaultdict(int, {'old': 1.0}),
#   'cheering': defaultdict(int, {'song': 1.0}),
#   'buggy': defaultdict(int, {'load': 1.0}),
#   'sign': defaultdict(int, {'up': 1.0}),
#   'harness': defaultdict(int, {'gall': 1.0}),
#   'belilaced': defaultdict(int, {'cellar': 1.0}),
#   'dent': defaultdict(int, {'in': 1.0}),
#   'spring': defaultdict(int, {'as': 1.0}),
#   'broken': defaultdict(int, {'drinking': 1.0}),
#   'spell': defaultdict(int, {'so': 1.0}),
#   'thousand': defaultdict(int, {'shrill': 1.0}),
#   'piano': defaultdict(int, {'loudly': 1.0}),
#   'note': defaultdict(int, {'unruffled': 1.0}),
#   'beaded': defaultdict(int, {'fur': 1.0}),
#   'headless': defaultdict(int, {'horse': 1.0}),
#   'smart': defaultdict(int, {'pair': 1.0}),
#   'big': defaultdict(int, {'church': 1.0}),
#   'long': defaultdict(int, {'time': 1.0}),
#   'friend': defaultdict(int, {'or': 1.0}),
#   'bad': defaultdict(int, {'farmer': 1.0}),
#   'home': defaultdict(int, {'for': 1.0}),
#   'hen': defaultdict(int, {'you': 1.0}),
#   'flock': defaultdict(int, {'of': 1.0}),
#   'times': defaultdict(int, {'the': 1.0}),
#   'glass': defaultdict(int, {'case': 1.0}),
#   'tall': defaultdict(int, {'one': 1.0}),
#   'barrel': defaultdict(int, {'from': 1.0}),
#   'paradise': defaultdict(int, {'as': 1.0}),
#   'dormant': defaultdict(int, {'tree': 1.0}),
#   'plane': defaultdict(int, {'of': 1.0}),
#   'gaunt': defaultdict(int, {'luxuriating': 1.0}),
#   'featherhammer': defaultdict(int, {'gives': 1.0}),
#   'double': defaultdict(int, {'knock': 1.0})},
#  'and': {'sorry': defaultdict(int, {'i': 1.0}),
#   'be': defaultdict(int, {'one': 0.5, 'whole': 1.0}),
#   'looked': defaultdict(int, {'down': 1.0}),
#   'having': defaultdict(int, {'perhaps': 1.0}),
#   'wanted': defaultdict(int, {'wear': 1.0}),
#   'both': defaultdict(int, {'that': 0.5, 'of': 1.0}),
#   'ages': defaultdict(int, {'hence': 1.0}),
#   'that': defaultdict(int, {'has': 0.5, 'was': 1.0}),
#   'frozen': defaultdict(int, {'lake': 1.0}),
#   'downy': defaultdict(int, {'flake': 1.0}),
#   'miles': defaultdict(int, {'to': 1.0}),
#   'would': defaultdict(int, {'suffice': 1.0}),
#   'back': defaultdict(int, {'in': 1.0}),
#   'dropped': defaultdict(int, {'my': 1.0}),
#   'stopped': defaultdict(int, {'the': 1.0}),
#   'further': defaultdict(int, {'still': 1.0}),
#   'when': defaultdict(int,
#               {'i': 0.3333333333333333,
#                'alls': 0.6666666666666666,
#                'ive': 1.0}),
#   'tell': defaultdict(int, {'me': 0.75, 'him': 1.0}),
#   'now': defaultdict(int, {'know': 0.5, 'the': 1.0}),
#   'the': defaultdict(int,
#               {'light': 0.08333333333333333,
#                'sun': 0.16666666666666666,
#                'temptation': 0.25,
#                'birds': 0.3333333333333333,
#                'fur': 0.41666666666666663,
#                'north': 0.49999999999999994,
#                'clothes': 0.5833333333333333,
#                'jug': 0.6666666666666666,
#                'bandmusic': 0.75,
#                'smell': 0.8333333333333334,
#                'hens': 0.9166666666666667,
#                'cock': 1.0}),
#   'caught': defaultdict(int, {'one': 1.0}),
#   'put': defaultdict(int, {'my': 0.5, 'a': 1.0}),
#   'threw': defaultdict(int, {'myself': 1.0}),
#   'birds': defaultdict(int, {'that': 1.0}),
#   'redoubling': defaultdict(int, {'song': 1.0}),
#   'suddenly': defaultdict(int, {'without': 1.0}),
#   'scuttled': defaultdict(int, {'just': 1.0}),
#   'side': defaultdict(int, {'by': 1.0}),
#   'scurf': defaultdict(int, {'of': 1.0}),
#   'weary': defaultdict(int, {'and': 1.0}),
#   'rested': defaultdict(int, {'on': 1.0}),
#   'since': defaultdict(int, {'there': 0.5, 'it': 1.0}),
#   'there': defaultdict(int, {'against': 0.5, 'a': 1.0}),
#   'raised': defaultdict(int, {'again—': 1.0}),
#   'whats': defaultdict(int, {'the': 1.0}),
#   'many': defaultdict(int, {'must': 1.0}),
#   'barn': defaultdict(int, {'the': 1.0}),
#   'blew': defaultdict(int, {'him': 1.0}),
#   'he': defaultdict(int, {'was': 0.5, 'liked': 1.0}),
#   'stamped': defaultdict(int, {'and': 1.0}),
#   'said': defaultdict(int, {'things': 1.0}),
#   'sometimes': defaultdict(int, {'something': 1.0}),
#   'some': defaultdict(int, {'exclaimed': 1.0}),
#   'made': defaultdict(int, {'the': 1.0}),
#   'then': defaultdict(int,
#               {'becoming': 0.16666666666666666,
#                'went': 0.3333333333333333,
#                'someone': 0.5,
#                'made': 0.6666666666666666,
#                'a': 0.8333333333333333,
#                'pull': 0.9999999999999999}),
#   'came': defaultdict(int, {'down': 1.0}),
#   'this': defaultdict(int, {'is': 0.5, 'bill': 1.0}),
#   'politician': defaultdict(int, {'at': 1.0}),
#   'took': defaultdict(int, {'the': 1.0}),
#   'i': defaultdict(int,
#               {'can': 0.1111111111111111,
#                'dont': 0.2222222222222222,
#                'read': 0.3333333333333333,
#                'know': 0.4444444444444444,
#                'dread': 0.5555555555555556,
#                'thought': 0.6666666666666667,
#                'only': 0.7777777777777779,
#                'have': 0.8888888888888891,
#                'get': 1.0000000000000002}),
#   'warrens': defaultdict(int, {'both': 1.0}),
#   'thatd': defaultdict(int, {'be': 1.0}),
#   'rode': defaultdict(int, {'all': 1.0}),
#   'if': defaultdict(int, {'id': 0.5, 'youre': 1.0}),
#   'leave': defaultdict(int, {'his': 1.0}),
#   'had': defaultdict(int, {'gnawed': 0.5, 'it': 1.0}),
#   'as': defaultdict(int, {'sures': 1.0}),
#   'posts': defaultdict(int, {'and': 1.0}),
#   'fences': defaultdict(int, {'too': 1.0}),
#   'make': defaultdict(int, {'it': 0.5, 'your': 1.0}),
#   'from': defaultdict(int, {'barn': 1.0}),
#   'snow': defaultdict(int, {'of': 1.0}),
#   'full': defaultdict(int, {'of': 1.0}),
#   'kick': defaultdict(int, {'up': 0.5, 'with': 1.0}),
#   'experts': defaultdict(int, {'said': 1.0}),
#   'show': defaultdict(int, {'it': 1.0}),
#   'built': defaultdict(int, {'a': 1.0}),
#   'emptied': defaultdict(int, {'then': 1.0}),
#   'forty': defaultdict(int, {'years': 1.0}),
#   'were': defaultdict(int, {'off': 1.0}),
#   'thats': defaultdict(int, {'why': 0.5, 'not': 1.0}),
#   'spoke': defaultdict(int, {'his': 0.5, 'of': 1.0}),
#   'on': defaultdict(int, {'the': 1.0}),
#   'anyway': defaultdict(int, {'this': 1.0}),
#   'save': defaultdict(int, {'the': 0.5, 'for': 1.0}),
#   'keep': defaultdict(int, {'abouncing': 1.0}),
#   'how': defaultdict(int,
#               {'she': 0.3333333333333333,
#                'much': 0.6666666666666666,
#                'many': 1.0}),
#   'wrote': defaultdict(int, {'her': 1.0}),
#   'hold': defaultdict(int, {'the': 0.6666666666666666, 'his': 1.0}),
#   'swollen': defaultdict(int, {'them': 0.3333333333333333, 'tight': 1.0}),
#   'taken': defaultdict(int, {'thus': 1.0}),
#   'bad': defaultdict(int, {'hunters': 1.0}),
#   'lead': defaultdict(int, {'to': 1.0}),
#   'opening': defaultdict(int, {'out': 1.0}),
#   'lie': defaultdict(int, {'in': 1.0}),
#   'bushes': defaultdict(int, {'unretrieved': 1.0}),
#   'left': defaultdict(int, {'it': 0.5, 'me': 1.0}),
#   'stroked': defaultdict(int, {'it': 1.0}),
#   'a': defaultdict(int,
#               {'paddle': 0.3333333333333333,
#                'trapper': 0.6666666666666666,
#                'crutch': 1.0}),
#   'me': defaultdict(int, {'on': 1.0}),
#   'between': defaultdict(int, {'what': 1.0}),
#   'wont': defaultdict(int, {'tell': 1.0}),
#   'hes': defaultdict(int, {'off': 1.0}),
#   'his': defaultdict(int, {'crew': 0.5, 'brown': 1.0}),
#   'nothing': defaultdict(int, {'came': 1.0}),
#   'better': defaultdict(int, {'defeat': 1.0}),
#   'headboard': defaultdict(int, {'where': 0.5, 'of': 1.0}),
#   'carried': defaultdict(int, {'itself': 1.0}),
#   'mother': defaultdict(int, {'and': 1.0}),
#   'neither': defaultdict(int, {'stopped': 1.0}),
#   'thought': defaultdict(int, {'i': 1.0}),
#   'buried': defaultdict(int, {'under': 1.0}),
#   'good': defaultdict(int, {'reason': 1.0}),
#   'all': defaultdict(int, {'but': 0.5, 'our': 1.0}),
#   'licked': defaultdict(int, {'along': 1.0}),
#   'fell': defaultdict(int, {'back': 1.0}),
#   'shouted': defaultdict(int, {'toffile': 0.5, 'shut': 1.0}),
#   'set': defaultdict(int, {'off': 1.0}),
#   'in': defaultdict(int,
#               {'the': 0.3333333333333333, 'a': 0.6666666666666666, 'it': 1.0}),
#   'sit': defaultdict(int, {'up': 0.5, 'before': 1.0}),
#   'take': defaultdict(int, {'hold': 0.5, 'a': 1.0}),
#   'bring': defaultdict(int, {'the': 1.0}),
#   'sure': defaultdict(int, {'enough': 1.0}),
#   'held': defaultdict(int, {'the': 1.0}),
#   'push': defaultdict(int, {'the': 1.0}),
#   'stand': defaultdict(int, {'perplexed': 1.0}),
#   'lift': defaultdict(int, {'my': 0.5, 'themselves': 1.0}),
#   'those': defaultdict(int, {'of': 0.5, 'will': 1.0}),
#   'sproutlands': defaultdict(int, {'flourish': 1.0}),
#   'try': defaultdict(int, {'to': 1.0}),
#   'get': defaultdict(int, {'some': 1.0}),
#   'moments': defaultdict(int, {'of': 1.0}),
#   'one': defaultdict(int, {'other': 1.0}),
#   'she': defaultdict(int, {'halted': 1.0}),
#   'see': defaultdict(int,
#               {'who': 0.3333333333333333,
#                'if': 0.6666666666666666,
#                'what': 1.0}),
#   'perhaps': defaultdict(int, {'hear': 0.5, 'she': 1.0}),
#   'still': defaultdict(int, {'be': 0.5, 'her': 1.0}),
#   'doubtless': defaultdict(int, {'here': 1.0}),
#   'by': defaultdict(int, {'marrying': 1.0}),
#   'dangle': defaultdict(int, {'feet': 1.0}),
#   'disappeared': defaultdict(int, {'and': 1.0}),
#   'ended': defaultdict(int, {'not': 1.0}),
#   'below': defaultdict(int, {'roared': 1.0}),
#   'what': defaultdict(int, {'do': 1.0}),
#   'dim': defaultdict(int, {'as': 1.0}),
#   'its': defaultdict(int, {'flooded': 1.0}),
#   'smoking': defaultdict(int, {'and': 1.0}),
#   'gets': defaultdict(int, {'out': 1.0}),
#   'sos': defaultdict(int, {'the': 1.0}),
#   'hew': defaultdict(int, {'and': 1.0}),
#   'shape': defaultdict(int, {'it': 1.0}),
#   'come': defaultdict(int, {'and': 1.0}),
#   'begin': defaultdict(int, {'over': 1.0}),
#   'it': defaultdict(int, {'was': 1.0}),
#   'build': defaultdict(int, {'the': 1.0}),
#   'youthful': defaultdict(int, {'faces': 1.0}),
#   'repented': defaultdict(int, {'but': 1.0}),
#   'color': defaultdict(int, {'and': 1.0}),
#   'odor': defaultdict(int, {'thicken': 1.0}),
#   'go': defaultdict(int, {'back': 1.0}),
#   'broken': defaultdict(int, {'off': 1.0}),
#   'theres': defaultdict(int, {'a': 1.0}),
#   'your': defaultdict(int, {'destinys': 0.5, 'watering': 1.0}),
#   'original': defaultdict(int, {'to': 1.0}),
#   'stifling': defaultdict(int, {'hot': 1.0}),
#   'sound': defaultdict(int, {'from': 1.0}),
#   'got': defaultdict(int, {'them': 1.0}),
#   'new': defaultdict(int, {'paint': 1.0}),
#   'music': defaultdict(int, {'out': 1.0}),
#   'give': defaultdict(int, {'up': 1.0}),
#   'fight': defaultdict(int, {'in': 1.0}),
#   'such': defaultdict(int, {'few': 1.0}),
#   'moon': defaultdict(int, {'and': 1.0}),
#   'nation': defaultdict(int, {'nation': 1.0}),
#   'though': defaultdict(int, {'none': 1.0}),
#   'wheres': defaultdict(int, {'john': 1.0}),
#   'gone': defaultdict(int, {'to': 1.0}),
#   'shell': defaultdict(int, {'come': 1.0}),
#   'lord': defaultdict(int, {'if': 1.0}),
#   'where': defaultdict(int, {'it': 1.0}),
#   'no': defaultdict(int, {'one': 1.0}),
#   'end': defaultdict(int, {'it': 1.0}),
#   'after': defaultdict(int, {'all': 1.0}),
#   'cows': defaultdict(int, {'and': 1.0}),
#   'pigs': defaultdict(int, {'are': 1.0}),
#   'we': defaultdict(int, {'live': 0.5, 'paid': 1.0}),
#   'like': defaultdict(int, {'it': 1.0}),
#   'youre': defaultdict(int, {'her': 1.0}),
#   'turn': defaultdict(int, {'doll': 1.0}),
#   'stop': defaultdict(int, {'his': 1.0}),
#   'not': defaultdict(int, {'melt': 1.0}),
#   'last': defaultdict(int, {'years': 1.0}),
#   'which': defaultdict(int, {'are': 1.0})},
#  'sorry': {'i': defaultdict(int, {'could': 0.5, 'ever': 1.0})},
#  'i': {'could': defaultdict(int,
#               {'not': 0.25, 'have': 0.5, 'see': 0.875, 'do': 1.0}),
#   'kept': defaultdict(int, {'the': 0.5, 'remembering': 1.0}),
#   'doubted': defaultdict(int, {'if': 1.0}),
#   'should': defaultdict(int,
#               {'ever': 0.3333333333333333,
#                'say': 0.6666666666666666,
#                'feel': 1.0}),
#   'shall': defaultdict(int, {'be': 0.5, 'suspect': 1.0}),
#   'took': defaultdict(int, {'the': 0.5, 'him': 1.0}),
#   'think': defaultdict(int,
#               {'i': 0.3333333333333333,
#                'its': 0.5,
#                'were': 0.6666666666666666,
#                'he': 0.8333333333333333,
#                'ill': 0.9999999999999999}),
#   'have': defaultdict(int,
#               {'promises': 0.09090909090909091,
#                'been': 0.2727272727272727,
#                'walked': 0.36363636363636365,
#                'outwalked': 0.4545454545454546,
#                'looked': 0.5454545454545455,
#                'passed': 0.6363636363636365,
#                'stood': 0.7272727272727274,
#                'no': 0.8181818181818183,
#                'kept': 0.9090909090909093,
#                'filled': 1.0000000000000002}),
#   'hold': defaultdict(int, {'with': 1.0}),
#   'know': defaultdict(int,
#               {'enough': 0.16666666666666666,
#                'of': 0.5,
#                'and': 0.6666666666666666,
#                'what': 0.8333333333333333,
#                'the': 0.9999999999999999}),
#   'go': defaultdict(int, {'up': 1.0}),
#   'come': defaultdict(int, {'to': 1.0}),
#   'doubt': defaultdict(int, {'not': 1.0}),
#   'end': defaultdict(int, {'not': 1.0}),
#   'cant': defaultdict(int,
#               {'pretend': 0.1111111111111111,
#                'decently': 0.2222222222222222,
#                'say': 0.3333333333333333,
#                'give': 0.4444444444444444,
#                'get': 0.5555555555555556,
#                'keep': 0.6666666666666667,
#                'talk': 0.7777777777777779,
#                'stay': 0.8888888888888891,
#                'explain': 1.0000000000000002}),
#   'though': defaultdict(int, {'to': 1.0}),
#   'tell': defaultdict(int, {'but': 0.3333333333333333, 'them': 1.0}),
#   'fancied': defaultdict(int, {'when': 1.0}),
#   'looked': defaultdict(int, {'at': 1.0}),
#   'was': defaultdict(int,
#               {'half': 0.07692307692307693,
#                'married': 0.23076923076923078,
#                'to': 0.3076923076923077,
#                'a': 0.5384615384615385,
#                'young': 0.6923076923076924,
#                'soon': 0.7692307692307694,
#                'going': 0.8461538461538463,
#                'just': 0.9230769230769231,
#                'too': 1.0}),
#   'ever': defaultdict(int, {'left': 0.5, 'cared': 1.0}),
#   'paused': defaultdict(int, {'and': 1.0}),
#   'saw': defaultdict(int,
#               {'the': 0.2,
#                'it': 0.4,
#                'a': 0.6000000000000001,
#                'no': 0.8,
#                'him': 1.0}),
#   'said': defaultdict(int, {'where': 1.0}),
#   'wander': defaultdict(int, {'out': 1.0}),
#   'wonder': defaultdict(int,
#               {'what': 0.2,
#                'if': 0.6000000000000001,
#                'where': 0.8,
#                'why': 1.0}),
#   'invested': defaultdict(int, {'him': 1.0}),
#   'can': defaultdict(int,
#               {'prove': 0.08333333333333333,
#                'hurt': 0.16666666666666666,
#                'find': 0.25,
#                'just': 0.3333333333333333,
#                'make': 0.41666666666666663,
#                'see': 0.5833333333333333,
#                'tell': 0.6666666666666666,
#                'no': 0.75,
#                'keep': 0.8333333333333334,
#                'sew': 0.9166666666666667,
#                'hardly': 1.0}),
#   'must': defaultdict(int,
#               {'be': 0.3333333333333333,
#                'have': 0.6666666666666666,
#                'go': 1.0}),
#   'guess': defaultdict(int,
#               {'theyd': 0.25, 'he': 0.5, 'youd': 0.75, 'estelle': 1.0}),
#   'happen': defaultdict(int, {'to': 1.0}),
#   'would': defaultdict(int,
#               {'be': 0.3333333333333333,
#                'last': 0.6666666666666666,
#                'have': 1.0}),
#   'spose': defaultdict(int, {'when': 1.0}),
#   'mistrusted': defaultdict(int, {'he': 1.0}),
#   'showed': defaultdict(int, {'arthur': 1.0}),
#   'dont': defaultdict(int,
#               {'mean': 0.06666666666666667,
#                'know': 0.3333333333333333,
#                'see': 0.5333333333333333,
#                'care': 0.6,
#                'remember': 0.6666666666666666,
#                'believe': 0.7333333333333333,
#                'follow': 0.7999999999999999,
#                'trust': 0.8666666666666666,
#                'just': 0.9333333333333332,
#                'ask': 0.9999999999999999}),
#   'made': defaultdict(int, {'him': 1.0}),
#   'hope': defaultdict(int, {'if': 1.0}),
#   'might': defaultdict(int, {'have': 1.0}),
#   'remember': defaultdict(int, {'rightly': 1.0}),
#   'am': defaultdict(int,
#               {'im': 0.3333333333333333,
#                'a': 0.6666666666666666,
#                'sure': 1.0}),
#   'thought': defaultdict(int,
#               {'you': 0.14285714285714285,
#                'for': 0.2857142857142857,
#                'the': 0.5714285714285714,
#                'i': 0.8571428571428571,
#                'twas': 1.0}),
#   'havent': defaultdict(int, {'brought': 0.5, 'had': 1.0}),
#   'wont': defaultdict(int, {'accept': 0.5, 'be': 1.0}),
#   'want': defaultdict(int, {'my': 0.25, 'to': 1.0}),
#   'vow': defaultdict(int, {'we': 1.0}),
#   'show': defaultdict(int, {'you': 1.0}),
#   'didnt': defaultdict(int,
#               {'recognize': 0.25, 'know': 0.5, 'always': 0.75, 'relish': 1.0}),
#   'never': defaultdict(int, {'saw': 0.5, 'could': 0.75, 'heard': 1.0}),
#   'ask': defaultdict(int, {'you': 1.0}),
#   'read': defaultdict(int, {'in': 1.0}),
#   'knew': defaultdict(int,
#               {'in': 0.3333333333333333,
#                'them': 0.6666666666666666,
#                'there': 1.0}),
#   'staid': defaultdict(int, {'the': 1.0}),
#   'asked': defaultdict(int, {'him': 1.0}),
#   'went': defaultdict(int, {'to': 0.6666666666666666, 'till': 1.0}),
#   'heard': defaultdict(int,
#               {'toffile': 0.3333333333333333,
#                'him': 0.6666666666666666,
#                'them': 1.0}),
#   'had': defaultdict(int,
#               {'a': 0.2,
#                'just': 0.30000000000000004,
#                'to': 0.5,
#                'for': 0.6,
#                'the': 0.8999999999999999,
#                'such': 0.9999999999999999}),
#   'flung': defaultdict(int, {'the': 1.0}),
#   'struck': defaultdict(int, {'the': 1.0}),
#   'see': defaultdict(int,
#               {'one': 0.3333333333333333,
#                'raspberry': 0.6666666666666666,
#                'its': 1.0}),
#   'sat': defaultdict(int, {'up': 1.0}),
#   'listened': defaultdict(int, {'till': 1.0}),
#   'got': defaultdict(int, {'up': 0.5, 'wonted': 1.0}),
#   'pushed': defaultdict(int, {'myself': 1.0}),
#   'wanted': defaultdict(int, {'to': 1.0}),
#   'slammed': defaultdict(int, {'to': 1.0}),
#   'sit': defaultdict(int, {'up': 1.0}),
#   'promised': defaultdict(int, {'toffile': 1.0}),
#   'mean': defaultdict(int,
#               {'a': 0.3333333333333333,
#                'estelle': 0.6666666666666666,
#                'shes': 1.0}),
#   'verified': defaultdict(int, {'the': 1.0}),
#   'passed': defaultdict(int, {'the': 1.0}),
#   'judged': defaultdict(int, {'that': 1.0}),
#   'only': defaultdict(int,
#               {'idled': 0.25, 'mean': 0.5, 'have': 0.75, 'hinder': 1.0}),
#   'idled': defaultdict(int, {'down': 1.0}),
#   'own': defaultdict(int, {'what': 1.0}),
#   'may': defaultdict(int, {'be': 1.0}),
#   'lean': defaultdict(int, {'like': 1.0}),
#   'give': defaultdict(int, {'you': 1.0}),
#   'used': defaultdict(int, {'the': 0.5, 'to': 1.0}),
#   'mustnt': defaultdict(int, {'feel': 1.0}),
#   'let': defaultdict(int, {'you': 0.6666666666666666, 'myself': 1.0}),
#   'speak': defaultdict(int, {'but': 1.0}),
#   'like': defaultdict(int, {'your': 1.0}),
#   'dread': defaultdict(int, {'the': 1.0}),
#   'turned': defaultdict(int, {'and': 1.0}),
#   'often': defaultdict(int, {'see': 1.0}),
#   'name': defaultdict(int, {'all': 1.0}),
#   'stole': defaultdict(int, {'the': 1.0}),
#   'walked': defaultdict(int, {'down': 1.0}),
#   'came': defaultdict(int, {'to': 1.0}),
#   'help': defaultdict(int, {'out': 1.0}),
#   'were': defaultdict(int, {'to': 1.0}),
#   'primped': defaultdict(int, {'to': 1.0}),
#   'hate': defaultdict(int, {'to': 1.0}),
#   'blame': defaultdict(int, {'his': 1.0}),
#   'take': defaultdict(int, {'it': 1.0}),
#   'call': defaultdict(int, {'it': 1.0}),
#   'get': defaultdict(int, {'to': 1.0}),
#   'say': defaultdict(int, {'shes': 1.0}),
#   'pity': defaultdict(int, {'estelle': 1.0}),
#   'suppose': defaultdict(int, {'she': 1.0})},
#  'could': {'not': defaultdict(int, {'travel': 0.5, 'say': 1.0}),
#   'hold': defaultdict(int, {'them': 1.0}),
#   'have': defaultdict(int,
#               {'told': 0.3333333333333333,
#                'done': 0.6666666666666666,
#                'to': 1.0}),
#   'recognize': defaultdict(int, {'them': 1.0}),
#   'hear': defaultdict(int, {'tell': 1.0}),
#   'call': defaultdict(int, {'up': 1.0}),
#   'that': defaultdict(int, {'be': 1.0}),
#   'be': defaultdict(int, {'there': 1.0}),
#   'see': defaultdict(int, {'nothing': 0.5, 'it': 1.0}),
#   'find': defaultdict(int, {'out': 1.0}),
#   'too': defaultdict(int, {'son': 1.0}),
#   'do': defaultdict(int, {'was': 1.0}),
#   'tell': defaultdict(int, {'you': 1.0}),
#   'make': defaultdict(int, {'them': 1.0}),
#   'sell': defaultdict(int, {'the': 1.0})},
#  'not': {'travel': defaultdict(int, {'both': 1.0}),
#   'see': defaultdict(int, {'me': 1.0}),
#   'to': defaultdict(int,
#               {'call': 0.16666666666666666,
#                'blanket': 0.3333333333333333,
#                'be': 0.5,
#                'care': 0.6666666666666666,
#                'sink': 0.8333333333333333,
#                'stand': 0.9999999999999999}),
#   'by': defaultdict(int, {'my': 1.0}),
#   'far': defaultdict(int,
#               {'from': 0.3333333333333333,
#                'away': 0.6666666666666666,
#                'off': 1.0}),
#   'too': defaultdict(int, {'much': 1.0}),
#   'off': defaultdict(int, {'for': 1.0}),
#   'much': defaultdict(int, {'concerned': 1.0}),
#   'a': defaultdict(int, {'post': 0.5, 'soul': 1.0}),
#   'that': defaultdict(int, {'he': 0.5, 'im': 1.0}),
#   'so': defaultdict(int, {'but': 1.0}),
#   'thrown': defaultdict(int, {'irreverently': 1.0}),
#   'take': defaultdict(int, {'two': 0.5, 'seats': 1.0}),
#   'men': defaultdict(int, {'by': 1.0}),
#   'like': defaultdict(int, {'a': 1.0}),
#   'for': defaultdict(int, {'him': 1.0}),
#   'all': defaultdict(int, {'the': 0.5, 'hes': 1.0}),
#   'expecting': defaultdict(int, {'he': 1.0}),
#   'be': defaultdict(int, {'and': 1.0}),
#   'from': defaultdict(int, {'the': 1.0}),
#   'your': defaultdict(int, {'makebelieve': 1.0}),
#   'yet': defaultdict(int, {'all': 0.5, 'light': 1.0}),
#   'come': defaultdict(int, {'in': 1.0}),
#   'old': defaultdict(int, {'grandsirs': 1.0}),
#   'fireweed': defaultdict(int, {'loving': 1.0}),
#   'bluebells': defaultdict(int, {'gracing': 1.0}),
#   'lupine': defaultdict(int, {'living': 1.0}),
#   'in': defaultdict(int, {'position': 0.5, 'a': 1.0}),
#   'mind': defaultdict(int, {'a': 1.0}),
#   'twenty': defaultdict(int, {'years': 1.0}),
#   'their': defaultdict(int, {'own': 1.0}),
#   'answering': defaultdict(int, {'your': 1.0}),
#   'if': defaultdict(int, {'he': 1.0}),
#   'he': defaultdict(int, {'us': 1.0}),
#   'blaming': defaultdict(int, {'him': 1.0}),
#   'being': defaultdict(int, {'safe': 1.0}),
#   'allowed': defaultdict(int, {'to': 1.0}),
#   'melt': defaultdict(int, {'snow': 1.0})},
#  'be': {'one': defaultdict(int, {'traveler': 1.0}),
#   'telling': defaultdict(int, {'this': 1.0}),
#   'to': defaultdict(int, {'have': 0.5, 'my': 1.0}),
#   'set': defaultdict(int, {'up': 1.0}),
#   'they': defaultdict(int, {'ought': 1.0}),
#   'enough': defaultdict(int, {'to': 0.5, 'protection': 1.0}),
#   'the': defaultdict(int, {'end': 0.5, 'best': 1.0}),
#   'dragged': defaultdict(int, {'by': 1.0}),
#   'near': defaultdict(int, {'the': 1.0}),
#   'ready': defaultdict(int, {'i': 1.0}),
#   'broken': defaultdict(int, {'davis': 1.0}),
#   'rid': defaultdict(int, {'of': 1.0}),
#   'burned': defaultdict(int, {'at': 1.0}),
#   'i': defaultdict(int, {'thought': 1.0}),
#   'ice': defaultdict(int, {'and': 1.0}),
#   'cruel': defaultdict(int, {'to': 0.5, 'once': 1.0}),
#   'and': defaultdict(int, {'still': 1.0}),
#   'thrown': defaultdict(int, {'into': 1.0}),
#   'too': defaultdict(int, {'technical': 1.0}),
#   'learned': defaultdict(int, {'thats': 1.0}),
#   'teased': defaultdict(int, {'but': 1.0}),
#   'strange': defaultdict(int, {'enough': 1.0}),
#   'very': defaultdict(int, {'still': 1.0}),
#   'good': defaultdict(int,
#               {'the': 0.3333333333333333,
#                'friends': 0.6666666666666666,
#                'for': 1.0}),
#   'heard': defaultdict(int, {'in': 1.0}),
#   'likely': defaultdict(int, {'to': 1.0}),
#   'you': defaultdict(int, {'said': 1.0}),
#   'in': defaultdict(int, {'rain': 1.0}),
#   'just': defaultdict(int, {'ahead': 1.0}),
#   'whole': defaultdict(int, {'again': 1.0}),
#   'a': defaultdict(int, {'nova': 1.0}),
#   'long': defaultdict(int, {'in': 1.0}),
#   'or': defaultdict(int, {'anyone': 1.0}),
#   'right': defaultdict(int, {'to': 1.0}),
#   'as': defaultdict(int, {'good': 1.0}),
#   'expecting': defaultdict(int, {'john': 1.0})},
#  'one': {'traveler': defaultdict(int, {'long': 1.0}),
#   'as': defaultdict(int, {'far': 1.0}),
#   'less': defaultdict(int, {'traveled': 1.0}),
#   'acquainted': defaultdict(int, {'with': 1.0}),
#   'luminary': defaultdict(int, {'clock': 1.0}),
#   'silver': defaultdict(int, {'lizard': 1.0}),
#   'without': defaultdict(int, {'avail': 1.0}),
#   'lizard': defaultdict(int, {'at': 1.0}),
#   'of': defaultdict(int,
#               {'them': 0.4,
#                'the': 0.6000000000000001,
#                'her': 0.8,
#                'those': 1.0}),
#   'they': defaultdict(int, {'say': 1.0}),
#   'town': defaultdict(int, {'hall': 1.0}),
#   'in': defaultdict(int, {'grafton': 1.0}),
#   'hadnt': defaultdict(int, {'said': 1.0}),
#   'kind': defaultdict(int, {'though': 1.0}),
#   'had': defaultdict(int, {'dropped': 1.0}),
#   'old': defaultdict(int, {'davis': 1.0}),
#   'and': defaultdict(int, {'i': 0.5, 'one': 1.0}),
#   'more': defaultdict(int, {'copy': 1.0}),
#   'himself': defaultdict(int, {'perhaps': 1.0}),
#   'flight': defaultdict(int, {'from': 1.0}),
#   'leg': defaultdict(int, {'and': 1.0}),
#   'hand': defaultdict(int, {'outstretched': 1.0}),
#   'any': defaultdict(int, {'more': 1.0}),
#   'night': defaultdict(int, {'in': 1.0}),
#   'from': defaultdict(int, {'a': 1.0}),
#   'other': defaultdict(int, {'yes': 1.0}),
#   'bearing': defaultdict(int, {'it': 1.0}),
#   'who': defaultdict(int, {'clasps': 1.0}),
#   'ought': defaultdict(int, {'not': 1.0}),
#   'went': defaultdict(int, {'home': 1.0}),
#   'yours': defaultdict(int, {'three': 1.0}),
#   'for': defaultdict(int, {'each': 1.0}),
#   'mustnt': defaultdict(int, {'bear': 1.0}),
#   'that': defaultdict(int, {'didnt': 1.0}),
#   'at': defaultdict(int, {'all': 1.0}),
#   'on': defaultdict(int, {'earth': 0.5, 'each': 1.0}),
#   'a': defaultdict(int, {'hill': 1.0}),
#   'down': defaultdict(int, {'one': 0.5, 'another': 1.0}),
#   'self': defaultdict(int, {'station': 1.0}),
#   'here': defaultdict(int, {'but': 1.0}),
#   'will': defaultdict(int, {'ever': 1.0}),
#   'talk': defaultdict(int, {'to': 1.0}),
#   'thing': defaultdict(int, {'you': 1.0}),
#   'langshang': defaultdict(int, {'cock': 1.0}),
#   'you': defaultdict(int, {'neednt': 1.0}),
#   'level': defaultdict(int, {'higher': 0.5, 'nearer': 1.0})},
#  'traveler': {'long': defaultdict(int, {'i': 1.0})},
#  'long': {'i': defaultdict(int, {'stood': 0.5, 'lay': 1.0}),
#   'way': defaultdict(int, {'home': 1.0}),
#   'ago': defaultdict(int, {'as': 1.0}),
#   'suspected': defaultdict(int, {'where': 1.0}),
#   'in': defaultdict(int, {'bed': 0.5, 'that': 1.0}),
#   'since': defaultdict(int, {'gave': 1.0})},
#  'looked': {'down': defaultdict(int, {'one': 0.5, 'the': 1.0}),
#   'at': defaultdict(int, {'six': 0.5, 'nine': 1.0}),
#   'up': defaultdict(int, {'toward': 1.0}),
#   'back': defaultdict(int, {'up': 1.0}),
#   'as': defaultdict(int, {'if': 1.0}),
#   'like': defaultdict(int, {'lightning': 1.0})},
#  'down': {'one': defaultdict(int, {'as': 0.5, 'street': 1.0}),
#   'to': defaultdict(int, {'day': 0.5, 'walk': 1.0}),
#   'the': defaultdict(int, {'saddest': 0.5, 'stairs': 1.0}),
#   'and': defaultdict(int, {'raised': 1.0}),
#   'from': defaultdict(int, {'field': 0.5, 'everything': 1.0}),
#   'he': defaultdict(int, {'fought': 1.0}),
#   'like': defaultdict(int, {'a': 1.0}),
#   'in': defaultdict(int, {'the': 1.0}),
#   'off': defaultdict(int, {'this': 1.0}),
#   'ill': defaultdict(int, {'tell': 1.0}),
#   'alone': defaultdict(int, {'sunday': 1.0}),
#   'this': defaultdict(int, {'is': 1.0}),
#   'thats': defaultdict(int, {'been': 1.0}),
#   'ryans': defaultdict(int, {'hill': 1.0})},
#  'as': {'far': defaultdict(int, {'as': 1.0}),
#   'i': defaultdict(int, {'could': 0.25, 'am': 0.5, 'do': 0.75, 'say': 1.0}),
#   'just': defaultdict(int, {'as': 1.0}),
#   'for': defaultdict(int, {'that': 0.6666666666666666, 'the': 1.0}),
#   'often': defaultdict(int, {'as': 1.0}),
#   'ive': defaultdict(int, {'seen': 1.0}),
#   'if': defaultdict(int,
#               {'some': 0.125,
#                'for': 0.25,
#                'the': 0.375,
#                'id': 0.5,
#                'it': 0.625,
#                'by': 0.75,
#                'and': 0.875,
#                'he': 1.0}),
#   'they': defaultdict(int, {'were': 1.0}),
#   'good': defaultdict(int, {'as': 0.6666666666666666, 'they': 1.0}),
#   'he': defaultdict(int,
#               {'chanced': 0.25, 'chose': 0.5, 'feared': 0.75, 'had': 1.0}),
#   'standing': defaultdict(int, {'in': 1.0}),
#   'an': defaultdict(int, {'authority': 1.0}),
#   'a': defaultdict(int,
#               {'witch': 0.3333333333333333,
#                'match': 0.6666666666666666,
#                'spring': 1.0}),
#   'sures': defaultdict(int, {'youre': 1.0}),
#   'well': defaultdict(int,
#               {'herself': 0.25, 'see': 0.5, 'be': 0.75, 'off': 1.0}),
#   'we': defaultdict(int, {'could': 0.5, 'can': 1.0}),
#   'plateglass': defaultdict(int, {'windows': 1.0}),
#   'long': defaultdict(int, {'ago': 1.0}),
#   'yet': defaultdict(int, {'have': 0.5, 'so': 1.0}),
#   'to': defaultdict(int,
#               {'sort': 0.3333333333333333,
#                'have': 0.6666666666666666,
#                'hens': 1.0}),
#   'gilt': defaultdict(int, {'to': 1.0}),
#   'one': defaultdict(int, {'who': 1.0}),
#   'pale': defaultdict(int, {'and': 1.0}),
#   'you': defaultdict(int,
#               {'throw': 0.3333333333333333,
#                'seize': 0.6666666666666666,
#                'may': 1.0}),
#   'youre': defaultdict(int, {'told': 1.0}),
#   'sound': defaultdict(int, {'as': 1.0}),
#   'the': defaultdict(int, {'day': 1.0}),
#   'saint': defaultdict(int, {'mark': 1.0}),
#   'winds': defaultdict(int, {'might': 1.0}),
#   'married': defaultdict(int, {'thats': 1.0}),
#   'own': defaultdict(int, {'the': 1.0}),
#   'it': defaultdict(int, {'is': 0.5, 'can': 1.0}),
#   'much': defaultdict(int, {'to': 1.0}),
#   'near': defaultdict(int, {'a': 1.0}),
#   'winter': defaultdict(int, {'friends': 1.0})},
#  'far': {'as': defaultdict(int, {'i': 0.5, 'we': 1.0}),
#   'away': defaultdict(int, {'an': 1.0}),
#   'from': defaultdict(int, {'my': 1.0}),
#   'off': defaultdict(int, {'he': 1.0}),
#   'you': defaultdict(int, {'must': 1.0}),
#   'youve': defaultdict(int, {'heard': 1.0}),
#   'and': defaultdict(int, {'how': 1.0}),
#   'before': defaultdict(int, {'the': 1.0})},
#  'to': {'where': defaultdict(int, {'it': 1.0}),
#   'watch': defaultdict(int, {'his': 0.5, 'me': 1.0}),
#   'stop': defaultdict(int,
#               {'without': 0.3333333333333333,
#                'the': 0.6666666666666666,
#                'and': 1.0}),
#   'ask': defaultdict(int, {'if': 1.0}),
#   'go': defaultdict(int, {'before': 0.5, 'by': 0.75, 'west': 1.0}),
#   'perish': defaultdict(int, {'twice': 1.0}),
#   'say': defaultdict(int,
#               {'that': 0.25, 'you': 0.5, 'the': 0.75, 'which': 1.0}),
#   'call': defaultdict(int, {'me': 0.5, 'it': 1.0}),
#   'the': defaultdict(int,
#               {'garden': 0.06666666666666667,
#                'fountain': 0.13333333333333333,
#                'famous': 0.2,
#                'people': 0.26666666666666666,
#                'kitchen': 0.3333333333333333,
#                'bedroom': 0.39999999999999997,
#                'attic': 0.4666666666666666,
#                'knob': 0.5333333333333333,
#                'cellar': 0.6,
#                'only': 0.6666666666666666,
#                'door': 0.7333333333333333,
#                'place': 0.7999999999999999,
#                'pianos': 0.8666666666666666,
#                'eye': 0.9333333333333332,
#                'root': 0.9999999999999999}),
#   'carry': defaultdict(int, {'again': 1.0}),
#   'pay': defaultdict(int, {'for': 1.0}),
#   'think': defaultdict(int, {'to': 0.25, 'of': 1.0}),
#   'know': defaultdict(int, {'the': 1.0}),
#   'tell': defaultdict(int, {'the': 0.6, 'them': 0.8, 'him': 1.0}),
#   'make': defaultdict(int,
#               {'a': 0.3333333333333333,
#                'it': 0.6666666666666666,
#                'so': 0.8333333333333333,
#                'them': 0.9999999999999999}),
#   'be': defaultdict(int,
#               {'undone': 0.07142857142857142,
#                'broken': 0.14285714285714285,
#                'cruel': 0.21428571428571427,
#                'thrown': 0.2857142857142857,
#                'enough': 0.3571428571428571,
#                'mad': 0.4285714285714285,
#                'heard': 0.4999999999999999,
#                'salted': 0.5714285714285713,
#                'good': 0.6428571428571427,
#                'you': 0.7142857142857141,
#                'in': 0.7857142857142855,
#                'a': 0.8571428571428569,
#                'as': 0.9285714285714283,
#                'the': 0.9999999999999997}),
#   'spare': defaultdict(int, {'his': 0.5, 'them': 1.0}),
#   'everything': defaultdict(int, {'he': 1.0}),
#   'his': defaultdict(int, {'abode': 0.5, 'house': 1.0}),
#   'natural': defaultdict(int, {'law': 1.0}),
#   'have': defaultdict(int,
#               {'two': 0.2, 'it': 0.4, 'the': 0.8, 'grandchildren': 1.0}),
#   'each': defaultdict(int, {'other': 1.0}),
#   'do': defaultdict(int,
#               {'over': 0.125,
#                'right': 0.25,
#                'it': 0.375,
#                'to': 0.625,
#                'anything': 0.75,
#                'at': 0.875,
#                'the': 1.0}),
#   'see': defaultdict(int,
#               {'if': 0.125,
#                'it': 0.25,
#                'how': 0.375,
#                'me': 0.5,
#                'what': 0.625,
#                'for': 0.75,
#                'us': 0.875,
#                'where': 1.0}),
#   'take': defaultdict(int,
#               {'over': 0.14285714285714285,
#                'me': 0.42857142857142855,
#                'it': 0.5714285714285714,
#                'any': 0.7142857142857142,
#                'her': 0.857142857142857,
#                'them': 0.9999999999999998}),
#   'our': defaultdict(int, {'clearing': 0.5, 'greatgrandmother': 1.0}),
#   'live': defaultdict(int,
#               {'in': 0.25, 'here': 0.5, 'together': 0.75, 'with': 1.0}),
#   'prefer': defaultdict(int, {'to': 1.0}),
#   'last': defaultdict(int, {'for': 1.0}),
#   'consent': defaultdict(int, {'to': 1.0}),
#   'give': defaultdict(int, {'some': 0.5, 'a': 1.0}),
#   'skin': defaultdict(int, {'and': 1.0}),
#   'blanket': defaultdict(int, {'him': 1.0}),
#   'gnaw': defaultdict(int, {'the': 1.0}),
#   'splinters': defaultdict(int, {'what': 1.0}),
#   'turn': defaultdict(int, {'him': 1.0}),
#   'saying': defaultdict(int, {'things': 1.0}),
#   'undo': defaultdict(int, {'what': 1.0}),
#   'let': defaultdict(int, {'on': 0.5, 'myself': 1.0}),
#   'death': defaultdict(int, {'with': 1.0}),
#   'put': defaultdict(int, {'up': 0.5, 'out': 1.0}),
#   'a': defaultdict(int, {'worse': 1.0}),
#   'shut': defaultdict(int, {'you': 1.0}),
#   'woods': defaultdict(int, {'around': 1.0}),
#   'bad': defaultdict(int, {'masonry': 1.0}),
#   'find': defaultdict(int,
#               {'it': 0.25, 'out': 0.5, 'or': 0.75, 'yourself': 1.0}),
#   'descend': defaultdict(int, {'to': 1.0}),
#   'surprise': defaultdict(int, {'the': 1.0}),
#   'spend': defaultdict(int, {'the': 1.0}),
#   'lave': defaultdict(int, {'my': 1.0}),
#   'bring': defaultdict(int, {'me': 1.0}),
#   'for': defaultdict(int, {'broadboard': 1.0}),
#   'introduce': defaultdict(int, {'you': 1.0}),
#   'entertain': defaultdict(int, {'the': 1.0}),
#   'stock': defaultdict(int, {'a': 1.0}),
#   'unprotected': defaultdict(int, {'glass': 1.0}),
#   'hurt': defaultdict(int, {'a': 1.0}),
#   'send': defaultdict(int, {'it': 1.0}),
#   'improve': defaultdict(int, {'on': 1.0}),
#   'tumble': defaultdict(int, {'like': 1.0}),
#   'sell': defaultdict(int, {'or': 0.5, 'theyre': 1.0}),
#   'such': defaultdict(int, {'a': 1.0}),
#   'pass': defaultdict(int, {'a': 0.5, 'by': 1.0}),
#   'sleep': defaultdict(int, {'before': 1.0}),
#   'bed': defaultdict(int, {'alone': 1.0}),
#   'cool': defaultdict(int, {'the': 1.0}),
#   'sort': defaultdict(int, {'of': 1.0}),
#   'myself': defaultdict(int, {'enough': 1.0}),
#   'wonder': defaultdict(int, {'where': 1.0}),
#   'walk': defaultdict(int, {'dryshod': 1.0}),
#   'get': defaultdict(int,
# ...
#   'knows': defaultdict(int, {'the': 1.0}),
#   'looks': defaultdict(int, {'surprised': 1.0})},
#  'common': {'table': defaultdict(int, {'rear': 1.0})},
#  'legs': {'like': defaultdict(int, {'an': 1.0}),
#   'out': defaultdict(int, {'of': 1.0})},
#  'rather': {'than': defaultdict(int, {'tip': 1.0})},
#  'tip': {'a': defaultdict(int, {'table': 1.0})},
#  'table': {'for': defaultdict(int, {'you': 1.0})},
#  'ralle': {'the': defaultdict(int, {'sioux': 1.0})},
#  'sioux': {'control': defaultdict(int, {'once': 1.0})},
#  'control': {'once': defaultdict(int, {'told': 1.0})},
#  'souls': {'but': defaultdict(int, {'when': 1.0})},
#  'broke': {'my': defaultdict(int, {'trance': 1.0})},
#  'trance': {'dont': defaultdict(int, {'that': 1.0}),
#   'you': defaultdict(int, {'are': 1.0})},
#  'yes': {'theres': defaultdict(int, {'something': 1.0}),
#   'we': defaultdict(int, {'could': 1.0}),
#   'for': defaultdict(int, {'there': 1.0}),
#   'stark': defaultdict(int, {'and': 1.0}),
#   'what': defaultdict(int, {'do': 1.0}),
#   'its': defaultdict(int, {'important': 1.0}),
#   'you': defaultdict(int, {'must': 1.0}),
#   'whats': defaultdict(int, {'it': 1.0}),
#   'but': defaultdict(int, {'he': 1.0}),
#   'i': defaultdict(int, {'do': 1.0})},
#  'wouldnt': {'want': defaultdict(int, {'to': 1.0}),
#   'have': defaultdict(int, {'him': 1.0}),
#   'hurt': defaultdict(int, {'a': 1.0}),
#   'give': defaultdict(int, {'way': 1.0})},
#  'bones': {'a': defaultdict(int, {'skeleton': 1.0}),
#   'came': defaultdict(int, {'up': 1.0}),
#   'i': defaultdict(int, {'knew': 1.0}),
#   'didnt': defaultdict(int, {'try': 1.0}),
#   'the': defaultdict(int, {'cellar': 1.0}),
#   'out': defaultdict(int, {'of': 1.0}),
#   'liked': defaultdict(int, {'the': 1.0}),
#   'they': defaultdict(int, {'were': 1.0})},
#  'headboard': {'of': defaultdict(int,
#               {'mothers': 0.3333333333333333, 'the': 1.0}),
#   'where': defaultdict(int, {'it': 1.0})},
#  'mothers': {'bed': defaultdict(int, {'is': 1.0})},
#  'door': {'the': defaultdict(int, {'door': 1.0}),
#   'is': defaultdict(int, {'nailed': 1.0}),
#   'and': defaultdict(int, {'headboard': 0.6666666666666666, 'held': 1.0}),
#   'to': defaultdict(int, {'cool': 0.25, 'the': 0.5, 'try': 0.75, 'get': 1.0}),
#   'but': defaultdict(int, {'the': 1.0}),
#   'they': defaultdict(int, {'halted': 1.0}),
#   'wide': defaultdict(int, {'on': 0.5, 'but': 1.0}),
#   'for': defaultdict(int, {'the': 1.0}),
#   'up': defaultdict(int, {'attic': 1.0})},
#  'harmless': {'mother': defaultdict(int, {'hears': 1.0})},
#  'hears': {'it': defaultdict(int, {'in': 1.0})},
#  'halting': {'perplexed': defaultdict(int, {'behind': 1.0})},
#  'perplexed': {'behind': defaultdict(int, {'the': 1.0})},
#  'wants': {'to': defaultdict(int, {'get': 0.5, 'hear': 1.0}),
#   'our': defaultdict(int, {'hens': 1.0})},
#  'cellar': {'where': defaultdict(int, {'it': 1.0}),
#   'forty': defaultdict(int, {'years': 1.0}),
#   'to': defaultdict(int, {'the': 1.0}),
#   'in': defaultdict(int, {'spring': 1.0}),
#   'bottom': defaultdict(int, {'and': 1.0}),
#   'windows': defaultdict(int, {'were': 1.0}),
#   'or': defaultdict(int, {'the': 1.0}),
#   'bones': defaultdict(int, {'out': 1.0}),
#   'hole': defaultdict(int, {'in': 1.0}),
#   'after': defaultdict(int, {'jam': 1.0})},
#  'forty': {'years': defaultdict(int, {'ago': 1.0}),
#   'cellar': defaultdict(int, {'holes': 1.0})},
#  'carried': {'itself': defaultdict(int, {'like': 1.0})},
#  'itself': {'like': defaultdict(int, {'a': 1.0})},
#  'pile': {'of': defaultdict(int, {'dishes': 1.0})},
#  'flight': {'from': defaultdict(int, {'the': 1.0})},
#  'another': {'from': defaultdict(int, {'the': 1.0}),
#   'door': defaultdict(int, {'to': 1.0})},
#  'kitchen': {'to': defaultdict(int, {'the': 0.5, 'yourself': 1.0}),
#   'had': defaultdict(int, {'been': 1.0})},
#  'bedroom': {'to': defaultdict(int, {'the': 1.0})},
#  'past': {'both': defaultdict(int, {'father': 1.0}),
#   'and': defaultdict(int, {'get': 1.0})},
#  'gone': {'upstairs': defaultdict(int, {'mother': 1.0}),
#   'to': defaultdict(int,
#               {'bed': 0.3333333333333333,
#                'yours': 0.6666666666666666,
#                'garlands': 1.0}),
#   'out': defaultdict(int, {'of': 1.0}),
#   'before': defaultdict(int, {'i': 1.0}),
#   'so': defaultdict(int, {'far': 1.0}),
#   'of': defaultdict(int, {'course': 1.0})},
#  'upstairs': {'mother': defaultdict(int, {'was': 1.0}),
#   'in': defaultdict(int, {'the': 1.0}),
#   'and': defaultdict(int, {'in': 1.0})},
#  'baby': {'i': defaultdict(int, {'dont': 1.0})},
#  'fault': {'my': defaultdict(int, {'husband': 1.0})},
#  'husband': {'found': defaultdict(int, {'with': 1.0})},
#  'sleep': {'before': defaultdict(int, {'i': 1.0})},
#  'especially': {'in': defaultdict(int, {'winter': 1.0})},
#  'ice': {'and': defaultdict(int, {'the': 1.0})},
#  'toffile': {'had': defaultdict(int, {'gone': 1.0}),
#   'upstairs': defaultdict(int, {'in': 1.0}),
#   'for': defaultdict(int, {'my': 1.0}),
#   'i': defaultdict(int, {'dont': 1.0}),
#   'agreed': defaultdict(int, {'to': 1.0}),
#   'didnt': defaultdict(int, {'seem': 1.0}),
#   'get': defaultdict(int, {'nails': 1.0}),
#   'to': defaultdict(int, {'be': 1.0}),
#   'if': defaultdict(int, {'he': 1.0})},
#  'alone': {'and': defaultdict(int, {'left': 1.0}),
#   'sunday': defaultdict(int, {'after': 1.0})},
#  'open': {'door': defaultdict(int, {'to': 0.6666666666666666, 'up': 1.0}),
#   'grassy': defaultdict(int, {'places': 1.0})},
#  'cool': {'the': defaultdict(int, {'room': 0.5, 'eyes': 1.0})},
#  'coming': {'to': defaultdict(int, {'myself': 1.0}),
#   'up': defaultdict(int, {'to': 0.5, 'had': 1.0}),
#   'down': defaultdict(int, {'ryans': 1.0})},
#  'cold': {'was': defaultdict(int, {'coming': 1.0}),
#   'as': defaultdict(int, {'a': 1.0}),
#   'a': defaultdict(int, {'digger': 1.0})},
#  'downstairs': {'in': defaultdict(int, {'the': 1.0})},
#  'board': {'we': defaultdict(int, {'had': 1.0})},
#  'laid': {'down': defaultdict(int, {'to': 1.0})},
#  'walk': {'dryshod': defaultdict(int, {'on': 1.0})},
#  'water': {'in': defaultdict(int, {'the': 1.0}),
#   'more': defaultdict(int, {'or': 1.0}),
#   'of': defaultdict(int, {'the': 1.0})},
#  'hard': {'cellar': defaultdict(int, {'bottom': 1.0}),
#   'on': defaultdict(int, {'the': 1.0}),
#   'with': defaultdict(int, {'john': 1.0})},
#  'bottom': {'and': defaultdict(int, {'then': 1.0})},
#  'began': {'the': defaultdict(int, {'stairs': 1.0}),
#   'to': defaultdict(int, {'climb': 1.0})},
#  'stairs': {'two': defaultdict(int, {'footsteps': 1.0}),
#   'at': defaultdict(int, {'night': 1.0})},
#  'footsteps': {'for': defaultdict(int, {'each': 1.0})},
#  'leg': {'and': defaultdict(int, {'a': 1.0})},
#  'child': {'comes': defaultdict(int, {'up': 1.0})},
#  'bulkhead': {'doubledoors': defaultdict(int, {'were': 1.0})},
#  'doubledoors': {'were': defaultdict(int, {'doublelocked': 1.0})},
#  'swollen': {'tight': defaultdict(int, {'and': 1.0})},
#  'tight': {'and': defaultdict(int, {'buried': 1.0})},
#  'windows': {'were': defaultdict(int, {'banked': 1.0})},
#  'banked': {'up': defaultdict(int, {'with': 1.0})},
#  'impulse': {'was': defaultdict(int, {'to': 1.0}),
#   'not': defaultdict(int, {'to': 1.0})},
#  'get': {'to': defaultdict(int, {'the': 1.0}),
#   'up': defaultdict(int, {'im': 0.5, 'forgive': 1.0}),
#   'nails': defaultdict(int, {'i': 1.0}),
#   'some': defaultdict(int, {'strangeness': 0.5, 'color': 1.0}),
#   'her': defaultdict(int, {'greatness': 1.0}),
#   'out': defaultdict(int, {'of': 1.0}),
#   'saved': defaultdict(int, {'as': 1.0}),
#   'me': defaultdict(int, {'through': 1.0}),
#   'married': defaultdict(int, {'when': 1.0}),
#   'far': defaultdict(int, {'before': 1.0})},
#  'halted': {'helpless': defaultdict(int, {'on': 1.0}),
#   'some': defaultdict(int, {'way': 1.0})},
#  'helpless': {'on': defaultdict(int, {'the': 1.0})},
#  'faintest': {'restless': defaultdict(int, {'rustling': 1.0})},
#  'restless': {'rustling': defaultdict(int, {'ran': 1.0})},
#  'rustling': {'ran': defaultdict(int, {'all': 1.0})},
#  'wish': {'hadnt': defaultdict(int, {'been': 1.0}),
#   'to': defaultdict(int, {'hear': 0.5, 'give': 1.0})},
#  'strong': {'in': defaultdict(int, {'me': 1.0})},
#  'mounted': {'for': defaultdict(int, {'this': 1.0}),
#   'bareback': defaultdict(int, {'on': 1.0})},
#  'vision': {'of': defaultdict(int, {'them': 1.0})},
#  'flung': {'the': defaultdict(int, {'door': 1.0})},
#  'wide': {'on': defaultdict(int, {'him': 1.0}),
#   'but': defaultdict(int, {'he': 1.0})},
#  'moment': {'he': defaultdict(int, {'stood': 0.5, 'was': 1.0})},
#  'balancing': {'with': defaultdict(int, {'emotion': 1.0})},
#  'himself': {'a': defaultdict(int, {'tongue': 1.0}),
#   'wont': defaultdict(int, {'imagine': 1.0})},
#  'tongue': {'of': defaultdict(int, {'fire': 1.0})},
#  'flashed': {'out': defaultdict(int, {'and': 1.0})},
#  'licked': {'along': defaultdict(int, {'his': 1.0})},
#  'along': {'his': defaultdict(int, {'upper': 1.0}),
#   'the': defaultdict(int, {'toteroad': 1.0}),
#   'at': defaultdict(int, {'first': 1.0}),
#   'with': defaultdict(int, {'him': 1.0})},
#  'smoke': {'rolled': defaultdict(int, {'inside': 1.0})},
#  'rolled': {'inside': defaultdict(int, {'the': 1.0})},
#  'inside': {'the': defaultdict(int, {'sockets': 1.0})},
#  'sockets': {'of': defaultdict(int, {'his': 1.0})},
#  'hand': {'off': defaultdict(int, {'brittle': 1.0}),
#   'me': defaultdict(int, {'my': 1.0}),
#   'up': defaultdict(int, {'pick': 1.0})},
#  'brittle': {'on': defaultdict(int, {'the': 1.0})},
#  'fingerpieces': {'slid': defaultdict(int, {'in': 1.0})},
#  'slid': {'in': defaultdict(int, {'all': 1.0})},
#  'buttonbox': {'it': defaultdict(int, {'must': 1.0})},
#  'sat': {'up': defaultdict(int, {'on': 1.0}),
#   'listening': defaultdict(int, {'to': 1.0})},
#  'floor': {'and': defaultdict(int, {'shouted': 1.0})},
#  'briskly': {'for': defaultdict(int, {'so': 1.0})},
#  'slow': {'a': defaultdict(int, {'thing': 1.0})},
#  'stillgoing': {'every': defaultdict(int, {'which': 1.0})},
#  'lightning': {'or': defaultdict(int, {'a': 1.0})},
#  'slap': {'i': defaultdict(int, {'had': 1.0})},
#  'given': {'its': defaultdict(int, {'hand': 1.0}),
#   'an': defaultdict(int, {'opening': 1.0}),
#   'to': defaultdict(int, {'plain': 1.0}),
#   'her': defaultdict(int, {'time': 1.0})},
#  'listened': {'till': defaultdict(int, {'it': 1.0}),
#   'in': defaultdict(int, {'among': 1.0})},
#  'almost': {'climbed': defaultdict(int, {'the': 1.0}),
#   'the': defaultdict(int, {'moment': 1.0}),
#   'here': defaultdict(int, {'ive': 1.0})},
#  'climbed': {'the': defaultdict(int, {'stairs': 1.0})},
#  'shouted': {'shut': defaultdict(int, {'the': 1.0})},
#  'company': {'he': defaultdict(int, {'said': 1.0}),
#   'outward': defaultdict(int, {'bound': 1.0})},
#  'warm': {'in': defaultdict(int, {'bed': 1.0})},
#  'forward': {'weakly': defaultdict(int, {'on': 1.0})},
#  'weakly': {'on': defaultdict(int, {'the': 1.0})},
#  'pushed': {'myself': defaultdict(int, {'upstairs': 1.0})},
#  'us': {'in': defaultdict(int, {'the': 1.0}),
#   'than': defaultdict(int, {'the': 1.0}),
#   'back': defaultdict(int, {'into': 1.0}),
#   'always': defaultdict(int, {'to': 1.0}),
#   'but': defaultdict(int, {'look': 1.0}),
#   'have': defaultdict(int, {'any': 1.0})},
#  'room': {'though': defaultdict(int, {'its': 1.0}),
#   'before': defaultdict(int, {'a': 1.0})},
#  'throw': {'his': defaultdict(int, {'bare': 1.0}),
#   'a': defaultdict(int, {'picture': 1.0}),
#   'the': defaultdict(int, {'hoe': 1.0})},
#  'bare': {'legs': defaultdict(int, {'out': 1.0})},
#  'sit': {'up': defaultdict(int, {'by': 0.5, 'in': 1.0}),
#   'before': defaultdict(int, {'you': 1.0}),
#   'and': defaultdict(int, {'tell': 1.0})},
#  'mow': {'the': defaultdict(int, {'room': 1.0})},
#  'arms': {'at': defaultdict(int, {'the': 1.0})},
#  'level': {'of': defaultdict(int, {'our': 1.0}),
#   'higher': defaultdict(int, {'than': 1.0}),
#   'nearer': defaultdict(int, {'heaven': 1.0})},
#  'chalkpile': {'down': defaultdict(int, {'ill': 1.0})},
#  'uncommonly': {'deep': defaultdict(int, {'snow': 1.0})},
#  'sing': {'along': defaultdict(int, {'the': 1.0})},
#  'trap': {'him': defaultdict(int, {'with': 1.0})},
#  'agreed': {'to': defaultdict(int, {'that': 1.0})},
#  'steps': {'began': defaultdict(int, {'to': 1.0})},
#  'quick': {'i': defaultdict(int, {'slammed': 1.0})},
#  'slammed': {'to': defaultdict(int, {'the': 1.0})},
#  'nails': {'i': defaultdict(int, {'made': 1.0})},
#  'nail': {'the': defaultdict(int, {'door': 1.0})},
#  'push': {'the': defaultdict(int, {'headboard': 1.0})},
#  'wed': {'ever': defaultdict(int, {'want': 1.0}),
#   'kept': defaultdict(int, {'all': 1.0})},
#  'brushing': {'their': defaultdict(int, {'chalky': 1.0})},
#  'chalky': {'skull': defaultdict(int, {'with': 1.0})},
#  'skull': {'with': defaultdict(int, {'chalky': 1.0})},
#  'dry': {'rattling': defaultdict(int, {'of': 1.0})},
#  'rattling': {'of': defaultdict(int, {'a': 1.0})},
#  '2o3': {'let': defaultdict(int, {'them': 1.0})},
#  'promised': {'toffile': defaultdict(int, {'to': 1.0})},
#  'cruel': {'to': defaultdict(int, {'them': 1.0}),
#   'once': defaultdict(int, {'to': 1.0})},
#  'helping': {'them': defaultdict(int, {'be': 1.0})},
#  'grave': {'down': defaultdict(int, {'in': 1.0})},
#  'truth': {'for': defaultdict(int, {'once': 1.0}),
#   'suppose': defaultdict(int, {'the': 1.0}),
#   'i': defaultdict(int, {'speak': 1.0})},
#  'mans': {'his': defaultdict(int, {'father': 1.0})},
#  'killed': {'for': defaultdict(int, {'me': 1.0}),
#   'instead': defaultdict(int, {'of': 1.0})},
#  'instead': {'of': defaultdict(int, {'me': 1.0})},
#  'help': {'dig': defaultdict(int, {'their': 1.0}),
#   'out': defaultdict(int, {'with': 1.0}),
#   'liking': defaultdict(int, {'about': 1.0})},
#  'dig': {'their': defaultdict(int, {'grave': 1.0})},
#  'knows': {'the': defaultdict(int, {'story': 1.0}),
#   'his': defaultdict(int, {'friends': 1.0}),
#   'hes': defaultdict(int, {'kinder': 1.0}),
#   'my': defaultdict(int, {'interest': 1.0})},
#  'story': {'but': defaultdict(int, {'twas': 1.0}),
#   'in': defaultdict(int, {'a': 1.0})},
#  'suppose': {'the': defaultdict(int, {'time': 1.0}),
#   'she': defaultdict(int, {'deserves': 1.0})},
#  'surprised': {'to': defaultdict(int, {'see': 1.0})},
#  'years': {'between': defaultdict(int, {'ourselves': 1.0}),
#   'berries': defaultdict(int, {'shining': 1.0}),
#   'high': defaultdict(int, {'girdle': 1.0})},
#  'tonight': {'i': defaultdict(int, {'dont': 1.0})},
#  'care': {'enough': defaultdict(int, {'to': 1.0}),
#   'of': defaultdict(int, {'him': 1.0})},
#  'fingerbone': {'she': defaultdict(int, {'wanted': 1.0})},
#  'among': {'the': defaultdict(int,
#               {'buttons': 0.25,
#                'raspberry': 0.5,
#                'sounds': 0.75,
#                'raspberries': 1.0}),
#   'unearthed': defaultdict(int, {'potatoes': 1.0})},
#  'buttons': {'poured': defaultdict(int, {'out': 1.0})},
#  'poured': {'out': defaultdict(int, {'in': 1.0})},
#  'verified': {'the': defaultdict(int, {'name': 1.0})},
#  'name': {'next': defaultdict(int, {'morning': 1.0}),
#   'stark': defaultdict(int, {'gathered': 1.0}),
#   'should': defaultdict(int, {'matter': 1.0}),
#   'all': defaultdict(int, {'the': 1.0}),
#   'the': defaultdict(int, {'hour': 1.0}),
#   'no': defaultdict(int, {'names': 1.0})},
#  'next': {'morning': defaultdict(int, {'toffile': 1.0})},
#  'rural': {'letterbox': defaultdict(int, {'said': 1.0})},
#  'letterbox': {'said': defaultdict(int, {'toffile': 1.0})},
#  'air': {'had': defaultdict(int, {'died': 1.0}),
#   'of': defaultdict(int, {'what': 1.0})},
#  'died': {'of': defaultdict(int, {'cold': 1.0})},
#  'shoeing': {'home': defaultdict(int, {'across': 1.0})},
#  'summer': {'when': defaultdict(int, {'i': 1.0}),
#   'dwelling': defaultdict(int, {'here': 1.0})},
#  'lift': {'my': defaultdict(int, {'face': 1.0}),
#   'themselves': defaultdict(int, {'up': 1.0})},
#  'singing': {'in': defaultdict(int, {'it': 1.0}),
#   'and': defaultdict(int, {'the': 1.0})},
#  'sweet': {'and': defaultdict(int, {'swift': 1.0})},
#  'single': {'leaf': defaultdict(int, {'was': 1.0})},
#  'twice': {'around': defaultdict(int, {'the': 1.0}),
#   'as': defaultdict(int, {'well': 1.0})},
#  'around': {'the': defaultdict(int, {'tree': 1.0}),
#   'and': defaultdict(int, {'under': 1.0}),
#   'twice': defaultdict(int, {'as': 1.0})},
#  'advantage': {'on': defaultdict(int, {'a': 1.0})},
#  'judged': {'that': defaultdict(int, {'such': 1.0})},
#  'adding': {'frost': defaultdict(int, {'to': 1.0})},
#  'frost': {'to': defaultdict(int, {'snow': 1.0})},
#  'gilt': {'to': defaultdict(int, {'gold': 1.0})},
#  ...}

# %% [markdown]
# ## Text Generation

# %% [markdown]
# ### Generation function based on position

# %%
def sample_word():
    
    probability = np.random.random()
        
    for key, val in initial_state.items():
        if(probability<=val):
            return key

# %%
def sample_word_first_order(prev : str):
    
    probability = np.random.random()
    
    if prev not in first_order.keys():
        return sample_word()
    
    for key, val in first_order[prev].items():
        if(probability<=val):
            return key

# %%
def sample_word_second_order(prev : str, before_prev : str):
    
    probability = np.random.random()
    
    if before_prev not in second_order.keys():
        return sample_word()
    elif prev not in second_order[before_prev].keys():
        return sample_word()

        
    for key, val in second_order[before_prev][prev].items():
        if(probability<=val):
            return key

# %% [markdown]
# ### Generating Random Function

# %%
final_text = []

for pos in range(10):
    if pos==0:
        final_text.append(sample_word())
    elif pos==1:
        final_text.append(sample_word_first_order(final_text[0]))
    else:
        final_text.append(sample_word_second_order(final_text[pos-1],final_text[pos-2]))

final_text
# Out:
# ['you',
#  'can',
#  'come',
#  'down',
#  'the',
#  'stairs',
#  'two',
#  'footsteps',
#  'for',
#  'each']

# %%
str1 = ""
for word in final_text:
    str1+=word + " "

str1
# Out:
# 'you can come down the stairs two footsteps for each '
